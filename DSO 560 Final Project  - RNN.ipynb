# %%
import numpy as np
import pandas as pd
import re
import nltk
import difflib
from nltk.corpus import stopwords, wordnet
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import Counter
from gensim.models import Word2Vec
from gensim.test.utils import common_texts, get_tmpfile
from nltk.stem.porter import *

# %%
data = pd.read_csv('nlp project.csv', encoding = 'utf-8').fillna(' ')

# %%
new_attribute_value = []
for index in data.attribute_value:
    index = re.sub(r'\s','', index)
    new_attribute_value.append(index)
data['new_attribute_value'] = new_attribute_value

# %%
data1 = data[['brand','brand_category','description','product_full_name','details','attribute_name', 'new_attribute_value', 'file']]

# %%
data1=data1.drop_duplicates()
len(data1)
# Out:
# 68326

# %%
data=data1

# %% [markdown]
# # Description Feature Pre-Processing (Regex)

# %%
nosymbol_description = []
for sent in data.description:
    nosymbol_description.append(re.sub(r'[^\w+0-9%.]', ' ', sent, flags = re.IGNORECASE))

# %%
all_m = pd.Series(nosymbol_description).str.findall(r'(\d+)(?:%)\s(\w+)')
material = []
temp_content = ''
temp = []
number = 0
for i in range(len(all_m)):
    if all_m[i] != []:
        for j in all_m[i]:
            for k in j:
                if k == j[0]:
                    number = int(k)
                    if number >= 80:
                        temp_content = temp_content + "HIGH_"
                    elif number >= 40:
                        temp_content = temp_content + "MEDIAN_"
                    else:
                        temp_content = temp_content + "LOW_"
                if k == j[-1]:
                    temp_content = temp_content + k.upper()
            
            temp.append(temp_content)
            temp_content = ''
        material.append(temp)
        temp = []
    else:
         material.append('')

# %%
material[3]
# Out:
# ['HIGH_PIMA', 'LOW_ELASTANE']

# %%
material_description = []
for i in data.description:
    material_description.append(re.sub(r'(\d+)(?:%)\s(\w+)', 'MATERIAL', i, flags = re.IGNORECASE))

# %%
count = 0
cleaned_material = []
for i in range(len(material_description)):
    new_word = []
    for j in material_description[i].split(' '):
        if j == 'MATERIAL':
            new_word.append(material[i][count])
            count += 1
        else:
            new_word.append(j.lower())
    count = 0
    clean = " ".join(new_word)
    cleaned_material.append(clean)

# %%
cleaned_material
# Out:
# ['black leather (lamb) open top  weighs approximately 0.4lbs/ 0.2kg imported',
#  "retro-inspired yet current, this stretchy, ribbed bodysuit is based on the slim-fitting clothing that gained popularity in the '60s.",
#  "retro-inspired yet current, this stretchy, ribbed bodysuit is based on the slim-fitting clothing that gained popularity in the '60s.",
#  'black stretch-pima cotton jersey slips on HIGH_PIMA cotton, LOW_ELASTANE hand wash imported',
#  "crafted from supple leather, sally lapointe's pants are cut in a wide-leg silhouette. cinched at the waist with a matching belt, this style looks amazing when paired with your favorite sweater tucked in.",
#  'cream crepe slips on material, material; lining: material, MEDIAN_ACETATE dry clean',
#  'cream crepe slips on material, material; lining: material, MEDIAN_ACETATE dry clean',
#  "crafted from supple leather, sally lapointe's pants are cut in a wide-leg silhouette. cinched at the waist with a matching belt, this style looks amazing when paired with your favorite sweater tucked in.",
#  "crafted from supple leather, sally lapointe's pants are cut in a wide-leg silhouette. cinched at the waist with a matching belt, this style looks amazing when paired with your favorite sweater tucked in.",
#  'heel measures approximately 105mm/ 4 inches gold mirrored-leather (calf) buckle-fastening ankle strap come with dust bag made in italy',
#  'heel measures approximately 105mm/ 4 inches gold mirrored-leather (calf) buckle-fastening ankle strap come with dust bag made in italy',
#  'clean seams and a towering stacked heel define a polished day-to-night boot.',
#  'chase your summery dreams in this ombré rainbow metallic sandal in a beach-chic design with knotted straps reaching up to wrap the ankle.',
#  'chase your summery dreams in this ombré rainbow metallic sandal in a beach-chic design with knotted straps reaching up to wrap the ankle.',
#  'heel measures approximately 105mm/ 4 inches gold mirrored-leather (calf) buckle-fastening ankle strap come with dust bag made in italy',
#  'heel measures approximately 105mm/ 4 inches gold mirrored-leather (calf) buckle-fastening ankle strap come with dust bag made in italy',
#  'cream crepe slips on material, material; lining: material, MEDIAN_ACETATE dry clean',
#  'cream crepe slips on material, material; lining: material, MEDIAN_ACETATE dry clean',
#  'camel grain de poudre wool button fastening at front material; buttons: HIGH_WOOL (buffalo) dry clean made in italy',
#  'cream crepe slips on material, material; lining: material, MEDIAN_ACETATE dry clean',
#  'black stretch-pima cotton jersey slips on HIGH_PIMA cotton, LOW_ELASTANE hand wash imported',
#  'clean seams and a towering stacked heel define a polished day-to-night boot.',
#  "a mens-y military-inspired button up that our designers tailored just for the ladies, thanks to a slimmer fit that's super-flattering.",
#  "a mens-y military-inspired button up that our designers tailored just for the ladies, thanks to a slimmer fit that's super-flattering.",
#  'black stretch-pima cotton jersey slips on HIGH_PIMA cotton, LOW_ELASTANE hand wash imported',
#  'fashioned from high-quality materials and designed for comfort, our shoes will keep you on your (stylish) toes. flexible, suede upper. breathable synthetic lining. insole with added stability in the heel. exclusive padding system features memory foam and a cushioned insole designed for all-day comfort. flexible skid-resistant outsole with comfort pod at bottom.',
#  'fashioned from high-quality materials and designed for comfort, our shoes will keep you on your (stylish) toes. flexible, suede upper. breathable synthetic lining. insole with added stability in the heel. exclusive padding system features memory foam and a cushioned insole designed for all-day comfort. flexible skid-resistant outsole with comfort pod at bottom.',
#  'gray cotton-jersey slips on HIGH_COTTON machine wash designer color: tinker',
#  'gray cotton-jersey slips on HIGH_COTTON machine wash designer color: tinker',
#  'gray cotton-jersey slips on HIGH_COTTON machine wash designer color: tinker',
#  'camel grain de poudre wool button fastening at front material; buttons: HIGH_WOOL (buffalo) dry clean made in italy',
#  'black leather (lamb) open top  weighs approximately 0.4lbs/ 0.2kg imported',
#  'gray cotton-jersey slips on HIGH_COTTON machine wash designer color: tinker',
#  "a mens-y military-inspired button up that our designers tailored just for the ladies, thanks to a slimmer fit that's super-flattering.",
#  "a mens-y military-inspired button up that our designers tailored just for the ladies, thanks to a slimmer fit that's super-flattering.",
#  'wide, channel-quilted straps crisscross a well-padded slide sandal grounded by razored treads.',
#  'multicolored cotton, nylon, merino wool, alpaca, cashmere and mohair-blend slips on material, material, LOW_COTTON wool,material, material, LOW_NYLON dry clean imported',
#  "crafted in italy, golden goose's 'hi star' sneakers are designed with the brand's signature appliqué star and stamped gold-tone logo on textured-leather uppers. set on a platform rubber sole, this pair is complete with suede vamps and handwritten text accents. highlight its chunky heel by pairing yours with a midi-length skirt.",
#  "edgy style and expert craftsmanship combine on a block-heel combat boot that's cut, sewn and lasted by hand by spanish artisans.",
#  'ready for a stroll on a private beach, this flat sandal is styled with crisscrossing straps of braided raffia.',
#  'we’re suckers for a pretty statement top. which is exactly how we landed on this tee and its ladylike twists. it fits and feels like your favorite t-shirt (you can thank the soft cotton jersey for that), but it’s perked up with high-volume poplin sleeves that gather gracefully toward the cuffs (yes to statement shoulders). and here’s the best news: you can treat it like all your other tees and wear it with every single pair of jeans, trousers, and shorts you own.material clean onlymade in italymeasurements (from size 4): length: 24 3/4"; chest: 17 1/2"model is 5’9.5" with 33" bust, 25" waist, 33.5" hips and wearing a size 2',
#  'ready for a stroll on a private beach, this flat sandal is styled with crisscrossing straps of braided raffia.',
#  "as enchanting as cinderella's glass slipper, but much more wearable, this graceful italian sandal is styled with transparent straps.",
#  'we’re suckers for a pretty statement top. which is exactly how we landed on this tee and its ladylike twists. it fits and feels like your favorite t-shirt (you can thank the soft cotton jersey for that), but it’s perked up with high-volume poplin sleeves that gather gracefully toward the cuffs (yes to statement shoulders). and here’s the best news: you can treat it like all your other tees and wear it with every single pair of jeans, trousers, and shorts you own.material clean onlymade in italymeasurements (from size 4): length: 24 3/4"; chest: 17 1/2"model is 5’9.5" with 33" bust, 25" waist, 33.5" hips and wearing a size 2',
#  'a lean and lengthening silhouette with one-button closure to accentuate the waist. notch lapel. long sleeves with one-button cuffs. two exterior pockets. center-back vent. fully lined with stretch lining for comfort and ease of movement.',
#  'a lean and lengthening silhouette with one-button closure to accentuate the waist. notch lapel. long sleeves with one-button cuffs. two exterior pockets. center-back vent. fully lined with stretch lining for comfort and ease of movement.',
#  "edgy style and expert craftsmanship combine on a block-heel combat boot that's cut, sewn and lasted by hand by spanish artisans.",
#  'a lean and lengthening silhouette with one-button closure to accentuate the waist. notch lapel. long sleeves with one-button cuffs. two exterior pockets. center-back vent. fully lined with stretch lining for comfort and ease of movement.',
#  'a lean and lengthening silhouette with one-button closure to accentuate the waist. notch lapel. long sleeves with one-button cuffs. two exterior pockets. center-back vent. fully lined with stretch lining for comfort and ease of movement.',
#  "nobody denim's 'true' jeans are designed with pre-cuffed hems, saving you time from finding the perfect length. crafted in a medium wash, this style is fashioned with a mid-rise waist and the brand's logo stitching on the back right pocket. couple this skinny style with a puffed sleeve blouse to add volume.",
#  "nobody denim's 'true' jeans are designed with pre-cuffed hems, saving you time from finding the perfect length. crafted in a medium wash, this style is fashioned with a mid-rise waist and the brand's logo stitching on the back right pocket. couple this skinny style with a puffed sleeve blouse to add volume.",
#  "nobody denim's 'true' jeans are designed with pre-cuffed hems, saving you time from finding the perfect length. crafted in a medium wash, this style is fashioned with a mid-rise waist and the brand's logo stitching on the back right pocket. couple this skinny style with a puffed sleeve blouse to add volume.",
#  'these ivory jeans can be as dressed up or toned down as you need them to be. they have a straight-leg fit that’s skinny, but not constricting, with a super-flattering, leg-elongating silhouette that falls just past the ankles—meaning they work equally well with a block-heeled boot (for the office) or low-top sneakers (for kicking around).material washmade in the usamodel is 5’10” with 32" bust, 24" waist, 34" hips and wearing a size 26',
#  "crafted from supple leather, sally lapointe's pants are cut in a wide-leg silhouette. cinched at the waist with a matching belt, this style looks amazing when paired with your favorite sweater tucked in.",
#  'heel measures approximately 95mm/ 4 inches cream leather (lamb) slip on  designer color: buttercream  made in italysmall to size. see size & fit notes.',
#  'heel measures approximately 95mm/ 4 inches cream leather (lamb) slip on  designer color: buttercream  made in italysmall to size. see size & fit notes.',
#  'heel measures approximately 95mm/ 4 inches cream leather (lamb) slip on  designer color: buttercream  made in italysmall to size. see size & fit notes.',
#  "derek lam's oversized silk blouse is designed with a self tie scarf at neck, long cuffed sleeves and a high-low hemline.",
#  "introducing suiting for the first time, re/done based these cropped flare trousers on a vintage pair from the '70s and had them handmade in italy.",
#  "introducing suiting for the first time, re/done based these cropped flare trousers on a vintage pair from the '70s and had them handmade in italy.",
#  "crafted from supple leather, sally lapointe's pants are cut in a wide-leg silhouette. cinched at the waist with a matching belt, this style looks amazing when paired with your favorite sweater tucked in.",
#  "edgy style and expert craftsmanship combine on a block-heel combat boot that's cut, sewn and lasted by hand by spanish artisans.",
#  'a twinkling crystal brooch crowns the toe strap of a party-ready sandal secured by a slender floating ankle strap.',
#  'a twinkling crystal brooch crowns the toe strap of a party-ready sandal secured by a slender floating ankle strap.',
#  'these ivory jeans can be as dressed up or toned down as you need them to be. they have a straight-leg fit that’s skinny, but not constricting, with a super-flattering, leg-elongating silhouette that falls just past the ankles—meaning they work equally well with a block-heeled boot (for the office) or low-top sneakers (for kicking around).material washmade in the usamodel is 5’10” with 32" bust, 24" waist, 34" hips and wearing a size 26',
#  "derek lam's oversized silk blouse is designed with a self tie scarf at neck, long cuffed sleeves and a high-low hemline.",
#  'named for its unique double-point pocket design, this denim western shirt is softly faded and detailed with pearly snaps for an authentic vintage look.',
#  'named for its unique double-point pocket design, this denim western shirt is softly faded and detailed with pearly snaps for an authentic vintage look.',
#  'these ivory jeans can be as dressed up or toned down as you need them to be. they have a straight-leg fit that’s skinny, but not constricting, with a super-flattering, leg-elongating silhouette that falls just past the ankles—meaning they work equally well with a block-heeled boot (for the office) or low-top sneakers (for kicking around).material washmade in the usamodel is 5’10” with 32" bust, 24" waist, 34" hips and wearing a size 26',
#  "designed and curated by minimalistic style icon elin kling, totême provides updated essentials that are effortless to mix and match. ideal for both work and weekends, the high-rise ' ossi' is tailored with a full length and a tailored leg. wear with the matching blazer for a smart look, or keep it casual with an oversized knit and sneakers.",
#  'midnight-blue organic cotton-velour  pull on  HIGH_ORGANIC cotton  machine wash  imported',
#  "designed and curated by minimalistic style icon elin kling, totême provides updated essentials that are effortless to mix and match. ideal for both work and weekends, the high-rise ' ossi' is tailored with a full length and a tailored leg. wear with the matching blazer for a smart look, or keep it casual with an oversized knit and sneakers.",
#  'tan leather (calf) magnetic-fastening front flap weighs approximately 2.2lbs/ 1kg made in italy',
#  "as enchanting as cinderella's glass slipper, but much more wearable, this graceful italian sandal is styled with transparent straps.",
#  "derek lam's oversized silk blouse is designed with a self tie scarf at neck, long cuffed sleeves and a high-low hemline.",
#  "designed and curated by minimalistic style icon elin kling, totême provides updated essentials that are effortless to mix and match. ideal for both work and weekends, the high-rise ' ossi' is tailored with a full length and a tailored leg. wear with the matching blazer for a smart look, or keep it casual with an oversized knit and sneakers.",
#  "derek lam's oversized silk blouse is designed with a self tie scarf at neck, long cuffed sleeves and a high-low hemline.",
#  'croc embossing brings of-the-moment appeal to a double-band sandal finished with gleaming buckles.',
#  'croc embossing brings of-the-moment appeal to a double-band sandal finished with gleaming buckles.',
#  'tan leather (calf) magnetic-fastening front flap weighs approximately 2.2lbs/ 1kg made in italy',
#  "crafted in italy, golden goose's 'hi star' sneakers are designed with the brand's signature appliqué star and stamped gold-tone logo on textured-leather uppers. set on a platform rubber sole, this pair is complete with suede vamps and handwritten text accents. highlight its chunky heel by pairing yours with a midi-length skirt.",
#  'multicolored cotton, nylon, merino wool, alpaca, cashmere and mohair-blend slips on material, material, LOW_COTTON wool,material, material, LOW_NYLON dry clean imported',
#  'black leather (lamb) open top  weighs approximately 0.4lbs/ 0.2kg imported',
#  'these ivory jeans can be as dressed up or toned down as you need them to be. they have a straight-leg fit that’s skinny, but not constricting, with a super-flattering, leg-elongating silhouette that falls just past the ankles—meaning they work equally well with a block-heeled boot (for the office) or low-top sneakers (for kicking around).material washmade in the usamodel is 5’10” with 32" bust, 24" waist, 34" hips and wearing a size 26',
#  'a flouncy tie gathers the neckline of this billowy chartreuse dress finished with an attached hem to enhance the flowy movement.',
#  'black and white lyocell partially concealed snap fastenings through front HIGH_LYOCELL dry clean imported',
#  'black and white lyocell partially concealed snap fastenings through front HIGH_LYOCELL dry clean imported',
#  'gray cotton-jersey slips on HIGH_COTTON machine wash designer color: tinker',
#  'these ivory jeans can be as dressed up or toned down as you need them to be. they have a straight-leg fit that’s skinny, but not constricting, with a super-flattering, leg-elongating silhouette that falls just past the ankles—meaning they work equally well with a block-heeled boot (for the office) or low-top sneakers (for kicking around).material washmade in the usamodel is 5’10” with 32" bust, 24" waist, 34" hips and wearing a size 26',
#  'heel measures approximately 95mm/ 4 inches cream leather (lamb) slip on  designer color: buttercream  made in italysmall to size. see size & fit notes.',
#  "designed and curated by minimalistic style icon elin kling, totême provides updated essentials that are effortless to mix and match. ideal for both work and weekends, the high-rise ' ossi' is tailored with a full length and a tailored leg. wear with the matching blazer for a smart look, or keep it casual with an oversized knit and sneakers.",
#  "designed and curated by minimalistic style icon elin kling, totême provides updated essentials that are effortless to mix and match. ideal for both work and weekends, the high-rise ' ossi' is tailored with a full length and a tailored leg. wear with the matching blazer for a smart look, or keep it casual with an oversized knit and sneakers.",
#  'cream and black jersey button fastening keyhole at back material, material; lining: HIGH_VISCOSE dry clean imported',
#  'heel measures approximately 95mm/ 4 inches cream leather (lamb) slip on  designer color: buttercream  made in italysmall to size. see size & fit notes.',
#  'cream and black jersey button fastening keyhole at back material, material; lining: HIGH_VISCOSE dry clean imported',
#  'heel measures approximately 95mm/ 4 inches cream leather (lamb) slip on  designer color: buttercream  made in italysmall to size. see size & fit notes.',
#  'gray cotton-jersey slips on HIGH_COTTON machine wash designer color: tinker',
#  'midnight-blue organic cotton-velour  pull on  HIGH_ORGANIC cotton  machine wash  imported',
#  'black and white lyocell partially concealed snap fastenings through front HIGH_LYOCELL dry clean imported',
#  'stone stretch-pima cotton pull on HIGH_PIMA cotton, LOW_ELASTANE machine wash imported',
#  'black and white lyocell partially concealed snap fastenings through front HIGH_LYOCELL dry clean imported',
#  'this silhouette of a poised cap-toe pump gets a vacation update with a platform and wedge heel wrapped in braided jute.',
#  'stone stretch-pima cotton pull on HIGH_PIMA cotton, LOW_ELASTANE machine wash imported',
#  'heel measures approximately 95mm/ 4 inches cream leather (lamb) slip on  designer color: buttercream  made in italysmall to size. see size & fit notes.',
#  'this pleat-neck top—made in italy from paper-thin poplin—is a shirting unicorn: it’s got the beauty of your best-loved blouse (thanks to those pretty front pleats and intricate knot detailing at the collar) and the brains of your favorite tee (relaxed shape, roomy sleeves). oh, and the incognito buttons in back are the nicest of touches.\xa0material clean onlymade in italymeasurements (from size 4): 19.5" chest, 11" sleeve length, 23.5" body lengthmodel is 5’11.5” with 33" bust, 24" waist, 34.5" hips and wearing a size 2',
#  'this pleat-neck top—made in italy from paper-thin poplin—is a shirting unicorn: it’s got the beauty of your best-loved blouse (thanks to those pretty front pleats and intricate knot detailing at the collar) and the brains of your favorite tee (relaxed shape, roomy sleeves). oh, and the incognito buttons in back are the nicest of touches.\xa0material clean onlymade in italymeasurements (from size 4): 19.5" chest, 11" sleeve length, 23.5" body lengthmodel is 5’11.5” with 33" bust, 24" waist, 34.5" hips and wearing a size 2',
#  'this silhouette of a poised cap-toe pump gets a vacation update with a platform and wedge heel wrapped in braided jute.',
#  'this pleat-neck top—made in italy from paper-thin poplin—is a shirting unicorn: it’s got the beauty of your best-loved blouse (thanks to those pretty front pleats and intricate knot detailing at the collar) and the brains of your favorite tee (relaxed shape, roomy sleeves). oh, and the incognito buttons in back are the nicest of touches.\xa0material clean onlymade in italymeasurements (from size 4): 19.5" chest, 11" sleeve length, 23.5" body lengthmodel is 5’11.5” with 33" bust, 24" waist, 34.5" hips and wearing a size 2',
#  'this pleat-neck top—made in italy from paper-thin poplin—is a shirting unicorn: it’s got the beauty of your best-loved blouse (thanks to those pretty front pleats and intricate knot detailing at the collar) and the brains of your favorite tee (relaxed shape, roomy sleeves). oh, and the incognito buttons in back are the nicest of touches.\xa0material clean onlymade in italymeasurements (from size 4): 19.5" chest, 11" sleeve length, 23.5" body lengthmodel is 5’11.5” with 33" bust, 24" waist, 34.5" hips and wearing a size 2',
#  'anything leopard tends to automatically fall in the “chic” category. but when you factor in la double j’s romantic touches, like those frilly flutter sleeves and that stunning, almost architectural standing collar, and this italian-made crepe dress becomes something else entirely. oh, and that knee-length cut means it’s just as office appropriate as it is date-night friendly. and it’s just as pretty from the back (you can thank the tie-up detail for that).material, HIGH_VISCOSE cleanmade in italymodel is 5’10” with 32" bust, 24" waist, 34" hips and wearing a size\xa0xs',
#  'this silhouette of a poised cap-toe pump gets a vacation update with a platform and wedge heel wrapped in braided jute.',
#  "nobody denim's 'true' jeans are designed with pre-cuffed hems, saving you time from finding the perfect length. crafted in a medium wash, this style is fashioned with a mid-rise waist and the brand's logo stitching on the back right pocket. couple this skinny style with a puffed sleeve blouse to add volume.",
#  "nobody denim's 'true' jeans are designed with pre-cuffed hems, saving you time from finding the perfect length. crafted in a medium wash, this style is fashioned with a mid-rise waist and the brand's logo stitching on the back right pocket. couple this skinny style with a puffed sleeve blouse to add volume.",
#  "nobody denim's 'true' jeans are designed with pre-cuffed hems, saving you time from finding the perfect length. crafted in a medium wash, this style is fashioned with a mid-rise waist and the brand's logo stitching on the back right pocket. couple this skinny style with a puffed sleeve blouse to add volume.",
#  "aquazzura's 'minute' sandals are crafted from polished leather with ultra-slim straps that secure and frame the foot. this pair will literally take your look to new heights—its set on a slender stiletto heel measuring over four inches.",
#  "aquazzura's 'minute' sandals are crafted from polished leather with ultra-slim straps that secure and frame the foot. this pair will literally take your look to new heights—its set on a slender stiletto heel measuring over four inches.",
#  "just one example of this season's strong tailoring theme, carolina herrera's trousers are cut from a wool and silk blend woven with a classic prince of wales check typically found in men's suiting. this high-waisted pair is fitted through the hips and tapered through the knees before flaring toward the ankles. complete the look with a matching printed jacket.",
#  "just one example of this season's strong tailoring theme, carolina herrera's trousers are cut from a wool and silk blend woven with a classic prince of wales check typically found in men's suiting. this high-waisted pair is fitted through the hips and tapered through the knees before flaring toward the ankles. complete the look with a matching printed jacket.",
#  "designed and curated by minimalistic style icon elin kling, totême provides updated essentials that are effortless to mix and match. ideal for both work and weekends, the high-rise ' ossi' is tailored with a full length and a tailored leg. wear with the matching blazer for a smart look, or keep it casual with an oversized knit and sneakers.",
#  'a drawstring waist and cropped silhouette bring a relaxed, lounge-inspired attitude to pants with a slight sheen, tonal floral pattern and silky feel.',
#  'a drawstring waist and cropped silhouette bring a relaxed, lounge-inspired attitude to pants with a slight sheen, tonal floral pattern and silky feel.',
#  'gray cotton-jersey slips on HIGH_COTTON machine wash designer color: tinker',
#  "aquazzura's 'minute' sandals are crafted from polished leather with ultra-slim straps that secure and frame the foot. this pair will literally take your look to new heights—its set on a slender stiletto heel measuring over four inches.",
#  'a flouncy tie gathers the neckline of this billowy chartreuse dress finished with an attached hem to enhance the flowy movement.',
#  'anything leopard tends to automatically fall in the “chic” category. but when you factor in la double j’s romantic touches, like those frilly flutter sleeves and that stunning, almost architectural standing collar, and this italian-made crepe dress becomes something else entirely. oh, and that knee-length cut means it’s just as office appropriate as it is date-night friendly. and it’s just as pretty from the back (you can thank the tie-up detail for that).material, HIGH_VISCOSE cleanmade in italymodel is 5’10” with 32" bust, 24" waist, 34" hips and wearing a size\xa0xs',
#  'gleaming studs outline the sole of a retro-inspired slide sandal lofted by a chunky woodgrain heel and platform.',
#  "just one example of this season's strong tailoring theme, carolina herrera's trousers are cut from a wool and silk blend woven with a classic prince of wales check typically found in men's suiting. this high-waisted pair is fitted through the hips and tapered through the knees before flaring toward the ankles. complete the look with a matching printed jacket.",
#  "just one example of this season's strong tailoring theme, carolina herrera's trousers are cut from a wool and silk blend woven with a classic prince of wales check typically found in men's suiting. this high-waisted pair is fitted through the hips and tapered through the knees before flaring toward the ankles. complete the look with a matching printed jacket.",
#  'black ribbed-knit slips on material, material, material, MEDIAN_WOOL dry clean imported',
#  'black ribbed-knit slips on material, material, material, MEDIAN_WOOL dry clean imported',
#  'gleaming studs outline the sole of a retro-inspired slide sandal lofted by a chunky woodgrain heel and platform.',
#  'breezy wide leg pants are designed with a glamorous sweeping silhouette in fluid silk.',
#  'breezy wide leg pants are designed with a glamorous sweeping silhouette in fluid silk.',
#  "aquazzura's 'minute' sandals are crafted from polished leather with ultra-slim straps that secure and frame the foot. this pair will literally take your look to new heights—its set on a slender stiletto heel measuring over four inches.",
#  'beige washed stretch-silk satin slips on material, HIGH_SILK hand wash designer color: fawn imported',
#  'beige washed stretch-silk satin slips on material, HIGH_SILK hand wash designer color: fawn imported',
#  'we’re suckers for a pretty statement top. which is exactly how we landed on this tee and its ladylike twists. it fits and feels like your favorite t-shirt (you can thank the soft cotton jersey for that), but it’s perked up with high-volume poplin sleeves that gather gracefully toward the cuffs (yes to statement shoulders). and here’s the best news: you can treat it like all your other tees and wear it with every single pair of jeans, trousers, and shorts you own.material clean onlymade in italymeasurements (from size 4): length: 24 3/4"; chest: 17 1/2"model is 5’9.5" with 33" bust, 25" waist, 33.5" hips and wearing a size 2',
#  'we’re suckers for a pretty statement top. which is exactly how we landed on this tee and its ladylike twists. it fits and feels like your favorite t-shirt (you can thank the soft cotton jersey for that), but it’s perked up with high-volume poplin sleeves that gather gracefully toward the cuffs (yes to statement shoulders). and here’s the best news: you can treat it like all your other tees and wear it with every single pair of jeans, trousers, and shorts you own.material clean onlymade in italymeasurements (from size 4): length: 24 3/4"; chest: 17 1/2"model is 5’9.5" with 33" bust, 25" waist, 33.5" hips and wearing a size 2',
#  'black ribbed-knit slips on material, material, material, MEDIAN_WOOL dry clean imported',
#  'we’re suckers for a pretty statement top. which is exactly how we landed on this tee and its ladylike twists. it fits and feels like your favorite t-shirt (you can thank the soft cotton jersey for that), but it’s perked up with high-volume poplin sleeves that gather gracefully toward the cuffs (yes to statement shoulders). and here’s the best news: you can treat it like all your other tees and wear it with every single pair of jeans, trousers, and shorts you own.material clean onlymade in italymeasurements (from size 4): length: 24 3/4"; chest: 17 1/2"model is 5’9.5" with 33" bust, 25" waist, 33.5" hips and wearing a size 2',
#  'a pointy toe and tapered heel balance the streamlined silhouette of a go-to boot.',
#  'a pointy toe and tapered heel balance the streamlined silhouette of a go-to boot.',
#  'black ribbed-knit slips on material, material, material, MEDIAN_WOOL dry clean imported',
#  'lift your spirits with this double-strap slide sandal perched on a tall block heel and a thick platform for easy gliding.',
#  "as enchanting as cinderella's glass slipper, but much more wearable, this graceful italian sandal is styled with transparent straps.",
#  "the chunky knit and marled hues of this boatneck sweater make it a cold-weather go-to. bonus: the slightly relaxed fit means it'll drape perfectly when you tuck the front into high-waisted pants and jeans.",
#  "the chunky knit and marled hues of this boatneck sweater make it a cold-weather go-to. bonus: the slightly relaxed fit means it'll drape perfectly when you tuck the front into high-waisted pants and jeans.",
#  "the chunky knit and marled hues of this boatneck sweater make it a cold-weather go-to. bonus: the slightly relaxed fit means it'll drape perfectly when you tuck the front into high-waisted pants and jeans.",
#  "edgy style and expert craftsmanship combine on a block-heel combat boot that's cut, sewn and lasted by hand by spanish artisans.",
#  "edgy style and expert craftsmanship combine on a block-heel combat boot that's cut, sewn and lasted by hand by spanish artisans.",
#  "cut from soft camel wool, max mara's chic 'pacos' coat is designed with broad, fringe-trimmed lapels. cinch yours at the waist with the self-tie belt and keep your phone handy in one of the exaggerated patch pockets at the front.",
#  'ivory crepe slips on material, material; buttons: HIGH_ACETATE (cow) dry clean imported',
#  'ivory crepe slips on material, material; buttons: HIGH_ACETATE (cow) dry clean imported',
#  'knotted ties detail the toe strap of an elegant sandal lifted by a covered block heel and tied off with adjustable wraparound straps.',
#  'knotted ties detail the toe strap of an elegant sandal lifted by a covered block heel and tied off with adjustable wraparound straps.',
#  'knotted ties detail the toe strap of an elegant sandal lifted by a covered block heel and tied off with adjustable wraparound straps.',
#  "edgy style and expert craftsmanship combine on a block-heel combat boot that's cut, sewn and lasted by hand by spanish artisans.",
#  'breezy wide leg pants are designed with a glamorous sweeping silhouette in fluid silk.',
#  'multicolored cotton-blend button fastening through front material, material, MEDIAN_COTTON fibers; buttons: LOW_POLYESTER (cow) dry clean',
#  'multicolored cotton-blend button fastening through front material, material, MEDIAN_COTTON fibers; buttons: LOW_POLYESTER (cow) dry clean',
#  'these ivory jeans can be as dressed up or toned down as you need them to be. they have a straight-leg fit that’s skinny, but not constricting, with a super-flattering, leg-elongating silhouette that falls just past the ankles—meaning they work equally well with a block-heeled boot (for the office) or low-top sneakers (for kicking around).material washmade in the usamodel is 5’10” with 32" bust, 24" waist, 34" hips and wearing a size 26',
#  "the chunky knit and marled hues of this boatneck sweater make it a cold-weather go-to. bonus: the slightly relaxed fit means it'll drape perfectly when you tuck the front into high-waisted pants and jeans.",
#  "the chunky knit and marled hues of this boatneck sweater make it a cold-weather go-to. bonus: the slightly relaxed fit means it'll drape perfectly when you tuck the front into high-waisted pants and jeans.",
#  'breezy wide leg pants are designed with a glamorous sweeping silhouette in fluid silk.',
#  "the chunky knit and marled hues of this boatneck sweater make it a cold-weather go-to. bonus: the slightly relaxed fit means it'll drape perfectly when you tuck the front into high-waisted pants and jeans.",
#  'brown cashmere and mulberry silk-blend slips on material, MEDIAN_CASHMERE silk dry clean designer color: bark imported',
#  'brown cashmere and mulberry silk-blend slips on material, MEDIAN_CASHMERE silk dry clean designer color: bark imported',
#  'brown cashmere and mulberry silk-blend slips on material, MEDIAN_CASHMERE silk dry clean designer color: bark imported',
#  'brown cashmere and mulberry silk-blend slips on material, MEDIAN_CASHMERE silk dry clean designer color: bark imported',
#  'sleek and sculptural, this strappy sandal shines in metallic snakeskin and looks modern with a square toe and a slim block heel.',
#  'sleek and sculptural, this strappy sandal shines in metallic snakeskin and looks modern with a square toe and a slim block heel.',
#  'black leather (lamb) open top  weighs approximately 0.4lbs/ 0.2kg imported',
#  'gleaming studs outline the sole of a retro-inspired slide sandal lofted by a chunky woodgrain heel and platform.',
#  "we believe that some animal prints double as neutral and these prada pumps are a prime example. designed in a classic leopard motif, they're sleek silhouette ends in a sharp toe that's fitted with cushioned insoles. try styling with wide-leg trousers to give the hem a lift.",
#  'a classic crewneck sweatshirt gets a luxurious update with a supremely soft cotton blend.',
#  'a classic crewneck sweatshirt gets a luxurious update with a supremely soft cotton blend.',
#  "we believe that some animal prints double as neutral and these prada pumps are a prime example. designed in a classic leopard motif, they're sleek silhouette ends in a sharp toe that's fitted with cushioned insoles. try styling with wide-leg trousers to give the hem a lift.",
#  "we believe that some animal prints double as neutral and these prada pumps are a prime example. designed in a classic leopard motif, they're sleek silhouette ends in a sharp toe that's fitted with cushioned insoles. try styling with wide-leg trousers to give the hem a lift.",
#  "we believe that some animal prints double as neutral and these prada pumps are a prime example. designed in a classic leopard motif, they're sleek silhouette ends in a sharp toe that's fitted with cushioned insoles. try styling with wide-leg trousers to give the hem a lift.",
#  "crafted in italy, golden goose's 'hi star' sneakers are designed with the brand's signature appliqué star and stamped gold-tone logo on textured-leather uppers. set on a platform rubber sole, this pair is complete with suede vamps and handwritten text accents. highlight its chunky heel by pairing yours with a midi-length skirt.",
#  'multicolored cotton, nylon, merino wool, alpaca, cashmere and mohair-blend slips on material, material, LOW_COTTON wool,material, material, LOW_NYLON dry clean imported',
#  'a classic crewneck sweatshirt gets a luxurious update with a supremely soft cotton blend.',
#  'a classic crewneck sweatshirt gets a luxurious update with a supremely soft cotton blend.',
#  "we believe that some animal prints double as neutral and these prada pumps are a prime example. designed in a classic leopard motif, they're sleek silhouette ends in a sharp toe that's fitted with cushioned insoles. try styling with wide-leg trousers to give the hem a lift.",
#  'multicolored cotton, nylon, merino wool, alpaca, cashmere and mohair-blend slips on material, material, LOW_COTTON wool,material, material, LOW_NYLON dry clean imported',
#  'a raffia-wrapped platform wedge with hint of metallic shimmer makes this suede, ankle-tie sandal a refined, resort-ready standout.',
#  'a raffia-wrapped platform wedge with hint of metallic shimmer makes this suede, ankle-tie sandal a refined, resort-ready standout.',
#  'a raffia-wrapped platform wedge with hint of metallic shimmer makes this suede, ankle-tie sandal a refined, resort-ready standout.',
#  "we believe that some animal prints double as neutral and these prada pumps are a prime example. designed in a classic leopard motif, they're sleek silhouette ends in a sharp toe that's fitted with cushioned insoles. try styling with wide-leg trousers to give the hem a lift.",
#  ' ',
#  ' ',
#  'camel grain de poudre wool button fastening at front material; buttons: HIGH_WOOL (buffalo) dry clean made in italy',
#  'sinuous straps cross atop a lightly cushioned sandal shaped with a squared-off toe and an architectural block heel.',
#  ' ',
#  ' ',
#  'anything leopard tends to automatically fall in the “chic” category. but when you factor in la double j’s romantic touches, like those frilly flutter sleeves and that stunning, almost architectural standing collar, and this italian-made crepe dress becomes something else entirely. oh, and that knee-length cut means it’s just as office appropriate as it is date-night friendly. and it’s just as pretty from the back (you can thank the tie-up detail for that).material, HIGH_VISCOSE cleanmade in italymodel is 5’10” with 32" bust, 24" waist, 34" hips and wearing a size\xa0xs',
#  "crafted in italy, golden goose's 'hi star' sneakers are designed with the brand's signature appliqué star and stamped gold-tone logo on textured-leather uppers. set on a platform rubber sole, this pair is complete with suede vamps and handwritten text accents. highlight its chunky heel by pairing yours with a midi-length skirt.",
#  'webbed straps, a contrast wedge and a serrated platform style this modern and sporty sandal.',
#  "as enchanting as cinderella's glass slipper, but much more wearable, this graceful italian sandal is styled with transparent straps.",
#  'brown cashmere and mulberry silk-blend slips on material, MEDIAN_CASHMERE silk dry clean designer color: bark imported',
#  'anything leopard tends to automatically fall in the “chic” category. but when you factor in la double j’s romantic touches, like those frilly flutter sleeves and that stunning, almost architectural standing collar, and this italian-made crepe dress becomes something else entirely. oh, and that knee-length cut means it’s just as office appropriate as it is date-night friendly. and it’s just as pretty from the back (you can thank the tie-up detail for that).material, HIGH_VISCOSE cleanmade in italymodel is 5’10” with 32" bust, 24" waist, 34" hips and wearing a size\xa0xs',
#  'multicolored cotton-jersey slips on HIGH_COTTON machine wash',
#  'multicolored cotton-jersey slips on HIGH_COTTON machine wash',
#  'brown cashmere and mulberry silk-blend slips on material, MEDIAN_CASHMERE silk dry clean designer color: bark imported',
#  'brown cashmere and mulberry silk-blend slips on material, MEDIAN_CASHMERE silk dry clean designer color: bark imported',
#  'brown cashmere and mulberry silk-blend slips on material, MEDIAN_CASHMERE silk dry clean designer color: bark imported',
#  'webbed straps, a contrast wedge and a serrated platform style this modern and sporty sandal.',
#  'black cotton-jersey slips on HIGH_COTTON machine wash imported',
#  'black cotton-jersey slips on HIGH_COTTON machine wash imported',
#  'we partnered with a fabric house in the southwest of france to make the custom trim at the hem of this polished tweed pencil skirt. even better: we also designed a matching jacket for more outfit potential.',
#  'we partnered with a fabric house in the southwest of france to make the custom trim at the hem of this polished tweed pencil skirt. even better: we also designed a matching jacket for more outfit potential.',
#  'black cotton-jersey slips on HIGH_COTTON machine wash imported',
#  'black cotton-jersey slips on HIGH_COTTON machine wash imported',
#  'ivory crepe slips on material, material; buttons: HIGH_ACETATE (cow) dry clean imported',
#  'ivory crepe slips on material, material; buttons: HIGH_ACETATE (cow) dry clean imported',
#  "cut from soft camel wool, max mara's chic 'pacos' coat is designed with broad, fringe-trimmed lapels. cinch yours at the waist with the self-tie belt and keep your phone handy in one of the exaggerated patch pockets at the front.",
#  'sinuous straps cross atop a lightly cushioned sandal shaped with a squared-off toe and an architectural block heel.',
#  "this italian-crafted chelsea boot is a sleek, timeless style that's as low-key as it is luxe.",
#  "this italian-crafted chelsea boot is a sleek, timeless style that's as low-key as it is luxe.",
#  "cut from soft camel wool, max mara's chic 'pacos' coat is designed with broad, fringe-trimmed lapels. cinch yours at the waist with the self-tie belt and keep your phone handy in one of the exaggerated patch pockets at the front.",
#  "channel your inner '90s supermodel in this day-to-night sandal with a toe loop, mid heel and clean, geometric angles.",
#  're/done delivers a one-two punch of comfort and confidence with a cotton tee featuring a comic-style graphic of a butt-kicking boxer.',
#  'dramatic curves and sharp angles marry on this pointy-toe bootie made with a steep slant on a stacked heel.',
#  'black leather (lamb) open top  weighs approximately 0.4lbs/ 0.2kg imported',
#  'dramatic curves and sharp angles marry on this pointy-toe bootie made with a steep slant on a stacked heel.',
#  'camel grain de poudre wool button fastening at front material; buttons: HIGH_WOOL (buffalo) dry clean made in italy',
#  "channel your inner '90s supermodel in this day-to-night sandal with a toe loop, mid heel and clean, geometric angles.",
#  'we partnered with a fabric house in the southwest of france to make the custom trim at the hem of this polished tweed pencil skirt. even better: we also designed a matching jacket for more outfit potential.',
#  'black stretch-pima cotton jersey slips on HIGH_PIMA cotton, LOW_ELASTANE hand wash imported',
#  'gray cotton-jersey slips on HIGH_COTTON machine wash designer color: tinker',
#  'we partnered with a fabric house in the southwest of france to make the custom trim at the hem of this polished tweed pencil skirt. even better: we also designed a matching jacket for more outfit potential.',
#  'an easy slide sandal is a go-everywhere shoe that brings a bit of beachy style to your everyday outfits.',
#  'tan leather (calf) magnetic-fastening front flap weighs approximately 2.2lbs/ 1kg made in italy',
#  'tan leather (calf) magnetic-fastening front flap weighs approximately 2.2lbs/ 1kg made in italy',
#  "off-white c/o virgil abloh's 'fringes popon' bag is crafted in a pom-pom silhouette with fringe details and a wristlet strap.",
#  'an easy slide sandal is a go-everywhere shoe that brings a bit of beachy style to your everyday outfits.',
#  'multicolored cotton-jersey slips on HIGH_COTTON machine wash',
#  "off-white c/o virgil abloh's 'fringes popon' bag is crafted in a pom-pom silhouette with fringe details and a wristlet strap.",
#  'multicolored cotton-jersey slips on HIGH_COTTON machine wash',
#  'styled with a slender mid heel and a v-cut vamp that flows into the pointy toe, this mule looks just as chic on your date as it does in the office.',
#  'styled with a slender mid heel and a v-cut vamp that flows into the pointy toe, this mule looks just as chic on your date as it does in the office.',
#  "cut from soft camel wool, max mara's chic 'pacos' coat is designed with broad, fringe-trimmed lapels. cinch yours at the waist with the self-tie belt and keep your phone handy in one of the exaggerated patch pockets at the front.",
#  'cream crepe slips on material, material; lining: material, MEDIAN_ACETATE dry clean',
#  'cream crepe slips on material, material; lining: material, MEDIAN_ACETATE dry clean',
#  ' ',
#  ' ',
#  'light-blue, navy and off-white jersey pull on material, HIGH_VISCOSE dry clean designer color: celeste blue imported',
#  'light-blue, navy and off-white jersey pull on material, HIGH_VISCOSE dry clean designer color: celeste blue imported',
#  'light-blue, navy and off-white jersey pull on material, HIGH_VISCOSE dry clean designer color: celeste blue imported',
#  'light-blue, navy and off-white jersey pull on material, HIGH_VISCOSE dry clean designer color: celeste blue imported',
#  'light-blue, navy and off-white jersey pull on material, HIGH_VISCOSE dry clean designer color: celeste blue imported',
#  "anaak's 'violeta' midi dress is cut from an airy cotton-voile that artfully embroidered with contrasting topstitches. it's fully lined for coverage and designed with delicate shoulder straps and a v-neckline. keep styling simple with a pair of leather slides.",
#  "anaak's 'violeta' midi dress is cut from an airy cotton-voile that artfully embroidered with contrasting topstitches. it's fully lined for coverage and designed with delicate shoulder straps and a v-neckline. keep styling simple with a pair of leather slides.",
#  "anaak's 'violeta' midi dress is cut from an airy cotton-voile that artfully embroidered with contrasting topstitches. it's fully lined for coverage and designed with delicate shoulder straps and a v-neckline. keep styling simple with a pair of leather slides.",
#  "anaak's 'violeta' midi dress is cut from an airy cotton-voile that artfully embroidered with contrasting topstitches. it's fully lined for coverage and designed with delicate shoulder straps and a v-neckline. keep styling simple with a pair of leather slides.",
#  "anaak's 'violeta' midi dress is cut from an airy cotton-voile that artfully embroidered with contrasting topstitches. it's fully lined for coverage and designed with delicate shoulder straps and a v-neckline. keep styling simple with a pair of leather slides.",
#  'heel measures approximately 85mm/ 3.5 inches olive leather (lamb) zip fastening along side made in italy',
#  'heel measures approximately 85mm/ 3.5 inches olive leather (lamb) zip fastening along side made in italy',
#  'heel measures approximately 85mm/ 3.5 inches olive leather (lamb) zip fastening along side made in italy',
#  'heel measures approximately 85mm/ 3.5 inches olive leather (lamb) zip fastening along side made in italy',
#  'heel measures approximately 85mm/ 3.5 inches olive leather (lamb) zip fastening along side made in italy',
#  'heel measures approximately 85mm/ 3.5 inches olive leather (lamb) zip fastening along side made in italy',
#  'heel measures approximately 85mm/ 3.5 inches olive leather (lamb) zip fastening along side made in italy',
#  'heel measures approximately 85mm/ 3.5 inches olive leather (lamb) zip fastening along side made in italy',
#  'black leather (cow) magnetic-fastening front flap weighs approximately 2.2lbs/ 1kg made in italy',
#  'black leather (cow) magnetic-fastening front flap weighs approximately 2.2lbs/ 1kg made in italy',
#  'black leather (cow) magnetic-fastening front flap weighs approximately 2.2lbs/ 1kg made in italy',
#  'black leather (cow) magnetic-fastening front flap weighs approximately 2.2lbs/ 1kg made in italy',
#  'brown alpaca-blend material, material, HIGH_ALPACA wool hand wash designer color: mushroom imported',
#  'brown alpaca-blend material, material, HIGH_ALPACA wool hand wash designer color: mushroom imported',
# ...
#  "zeynep arçay's pants are crafted from genuine leather, with a flattering high-waisted fit, a full length leg, and a slim silhouette. pair yours with the brand's wrap leather blazer to mirror the fall winter 2019 lookbook style.",
#  "zeynep arçay's pants are crafted from genuine leather, with a flattering high-waisted fit, a full length leg, and a slim silhouette. pair yours with the brand's wrap leather blazer to mirror the fall winter 2019 lookbook style.",
#  "zeynep arçay's pants are crafted from genuine leather, with a flattering high-waisted fit, a full length leg, and a slim silhouette. pair yours with the brand's wrap leather blazer to mirror the fall winter 2019 lookbook style.",
#  'supple faux leather brings glamorous edge to these tailored shorts.',
#  'supple faux leather brings glamorous edge to these tailored shorts.',
#  'supple faux leather brings glamorous edge to these tailored shorts.',
#  'supple faux leather brings glamorous edge to these tailored shorts.',
#  'cigarette pants cut from gingham for a blithe look.',
#  'cigarette pants cut from gingham for a blithe look.',
#  'cigarette pants cut from gingham for a blithe look.',
#  'cigarette pants cut from gingham for a blithe look.',
#  'throw-back to a cropped t-shirt with fine ribbed texture and back seam detail.',
#  'throw-back to a cropped t-shirt with fine ribbed texture and back seam detail.',
#  'throw-back to a cropped t-shirt with fine ribbed texture and back seam detail.',
#  'throw-back to a cropped t-shirt with fine ribbed texture and back seam detail.',
#  "partow's crepe 'everly' midi skirt is tailored to a high-rise fit. designed with an a-line silhouette, its fluid shape is detailed with concealed front pockets and relaxed pleats. style with the matching dress to complete the look.",
#  "partow's crepe 'everly' midi skirt is tailored to a high-rise fit. designed with an a-line silhouette, its fluid shape is detailed with concealed front pockets and relaxed pleats. style with the matching dress to complete the look.",
#  "partow's crepe 'everly' midi skirt is tailored to a high-rise fit. designed with an a-line silhouette, its fluid shape is detailed with concealed front pockets and relaxed pleats. style with the matching dress to complete the look.",
#  "partow's crepe 'everly' midi skirt is tailored to a high-rise fit. designed with an a-line silhouette, its fluid shape is detailed with concealed front pockets and relaxed pleats. style with the matching dress to complete the look.",
#  "between the shoulder-baring design and airy cotton handle, cult gaia's 'claire' top is perfectly suited for the warm-weather months. this long-sleeve style has a tie-detailed front and tiered puffed sleeves that fall in a knuckle-grazing length. highlight the split hem with high-rise shorts.",
#  "between the shoulder-baring design and airy cotton handle, cult gaia's 'claire' top is perfectly suited for the warm-weather months. this long-sleeve style has a tie-detailed front and tiered puffed sleeves that fall in a knuckle-grazing length. highlight the split hem with high-rise shorts.",
#  "between the shoulder-baring design and airy cotton handle, cult gaia's 'claire' top is perfectly suited for the warm-weather months. this long-sleeve style has a tie-detailed front and tiered puffed sleeves that fall in a knuckle-grazing length. highlight the split hem with high-rise shorts.",
#  "between the shoulder-baring design and airy cotton handle, cult gaia's 'claire' top is perfectly suited for the warm-weather months. this long-sleeve style has a tie-detailed front and tiered puffed sleeves that fall in a knuckle-grazing length. highlight the split hem with high-rise shorts.",
#  "between the shoulder-baring design and airy cotton handle, cult gaia's 'claire' top is perfectly suited for the warm-weather months. this long-sleeve style has a tie-detailed front and tiered puffed sleeves that fall in a knuckle-grazing length. highlight the split hem with high-rise shorts.",
#  "between the shoulder-baring design and airy cotton handle, cult gaia's 'claire' top is perfectly suited for the warm-weather months. this long-sleeve style has a tie-detailed front and tiered puffed sleeves that fall in a knuckle-grazing length. highlight the split hem with high-rise shorts.",
#  "between the shoulder-baring design and airy cotton handle, cult gaia's 'claire' top is perfectly suited for the warm-weather months. this long-sleeve style has a tie-detailed front and tiered puffed sleeves that fall in a knuckle-grazing length. highlight the split hem with high-rise shorts.",
#  "between the shoulder-baring design and airy cotton handle, cult gaia's 'claire' top is perfectly suited for the warm-weather months. this long-sleeve style has a tie-detailed front and tiered puffed sleeves that fall in a knuckle-grazing length. highlight the split hem with high-rise shorts.",
#  "isabel marant's 'welly' shirt is cut for an oversized fit, which is enhanced by this season's prominent shoulder. it's made from cotton-poplin in a striped motif and draped with a scarf-inspired cowl neck. style with a tapered wool trouser to complement its tailoring.",
#  "isabel marant's 'welly' shirt is cut for an oversized fit, which is enhanced by this season's prominent shoulder. it's made from cotton-poplin in a striped motif and draped with a scarf-inspired cowl neck. style with a tapered wool trouser to complement its tailoring.",
#  "isabel marant's 'welly' shirt is cut for an oversized fit, which is enhanced by this season's prominent shoulder. it's made from cotton-poplin in a striped motif and draped with a scarf-inspired cowl neck. style with a tapered wool trouser to complement its tailoring.",
#  "isabel marant's 'welly' shirt is cut for an oversized fit, which is enhanced by this season's prominent shoulder. it's made from cotton-poplin in a striped motif and draped with a scarf-inspired cowl neck. style with a tapered wool trouser to complement its tailoring.",
#  'heel measures approximately 100mm/ 4 inches clear pvc, beige suede (calf) elasticated slingback strap  designer color: nude  made in italysmall to size. see size & fit notes.',
#  'heel measures approximately 100mm/ 4 inches clear pvc, beige suede (calf) elasticated slingback strap  designer color: nude  made in italysmall to size. see size & fit notes.',
#  "biker jackets are a simple way to elevate your casual edit. grlfrnd's 'charlie' rendition is crafted from textured leather and detailed with of functional silver-tone zip fastenings and a buckled belt to cinch the boxy shape. complement the cropped hem with high-rise jeans.",
#  "biker jackets are a simple way to elevate your casual edit. grlfrnd's 'charlie' rendition is crafted from textured leather and detailed with of functional silver-tone zip fastenings and a buckled belt to cinch the boxy shape. complement the cropped hem with high-rise jeans.",
#  "biker jackets are a simple way to elevate your casual edit. grlfrnd's 'charlie' rendition is crafted from textured leather and detailed with of functional silver-tone zip fastenings and a buckled belt to cinch the boxy shape. complement the cropped hem with high-rise jeans.",
#  "biker jackets are a simple way to elevate your casual edit. grlfrnd's 'charlie' rendition is crafted from textured leather and detailed with of functional silver-tone zip fastenings and a buckled belt to cinch the boxy shape. complement the cropped hem with high-rise jeans.",
#  "biker jackets are a simple way to elevate your casual edit. grlfrnd's 'charlie' rendition is crafted from textured leather and detailed with of functional silver-tone zip fastenings and a buckled belt to cinch the boxy shape. complement the cropped hem with high-rise jeans.",
#  "biker jackets are a simple way to elevate your casual edit. grlfrnd's 'charlie' rendition is crafted from textured leather and detailed with of functional silver-tone zip fastenings and a buckled belt to cinch the boxy shape. complement the cropped hem with high-rise jeans.",
#  "biker jackets are a simple way to elevate your casual edit. grlfrnd's 'charlie' rendition is crafted from textured leather and detailed with of functional silver-tone zip fastenings and a buckled belt to cinch the boxy shape. complement the cropped hem with high-rise jeans.",
#  "biker jackets are a simple way to elevate your casual edit. grlfrnd's 'charlie' rendition is crafted from textured leather and detailed with of functional silver-tone zip fastenings and a buckled belt to cinch the boxy shape. complement the cropped hem with high-rise jeans.",
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'antique-rose silk-satin slips on HIGH_SILK dry clean designer color: wood rose',
#  'antique-rose silk-satin slips on HIGH_SILK dry clean designer color: wood rose',
#  'antique-rose silk-satin slips on HIGH_SILK dry clean designer color: wood rose',
#  'antique-rose silk-satin slips on HIGH_SILK dry clean designer color: wood rose',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  "detailed with a contrasting strap along the ankle, dorothee schumacher's 'mirror touch' pointed toe booties are crafted from leather with a metallic finish and a stiletto heel. add a twist to a classic look by wearing yours with tailored pants and a structured jacket.",
#  "detailed with a contrasting strap along the ankle, dorothee schumacher's 'mirror touch' pointed toe booties are crafted from leather with a metallic finish and a stiletto heel. add a twist to a classic look by wearing yours with tailored pants and a structured jacket.",
#  "detailed with a contrasting strap along the ankle, dorothee schumacher's 'mirror touch' pointed toe booties are crafted from leather with a metallic finish and a stiletto heel. add a twist to a classic look by wearing yours with tailored pants and a structured jacket.",
#  "detailed with a contrasting strap along the ankle, dorothee schumacher's 'mirror touch' pointed toe booties are crafted from leather with a metallic finish and a stiletto heel. add a twist to a classic look by wearing yours with tailored pants and a structured jacket.",
#  "detailed with a contrasting strap along the ankle, dorothee schumacher's 'mirror touch' pointed toe booties are crafted from leather with a metallic finish and a stiletto heel. add a twist to a classic look by wearing yours with tailored pants and a structured jacket.",
#  "detailed with a contrasting strap along the ankle, dorothee schumacher's 'mirror touch' pointed toe booties are crafted from leather with a metallic finish and a stiletto heel. add a twist to a classic look by wearing yours with tailored pants and a structured jacket.",
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  "whether you're headed to a farmhouse veranda or an urban terrace, the modern prairie appeal of this lacy cotton maxi dress will be most welcome.",
#  "whether you're headed to a farmhouse veranda or an urban terrace, the modern prairie appeal of this lacy cotton maxi dress will be most welcome.",
#  "whether you're headed to a farmhouse veranda or an urban terrace, the modern prairie appeal of this lacy cotton maxi dress will be most welcome.",
#  "whether you're headed to a farmhouse veranda or an urban terrace, the modern prairie appeal of this lacy cotton maxi dress will be most welcome.",
#  "whether you're headed to a farmhouse veranda or an urban terrace, the modern prairie appeal of this lacy cotton maxi dress will be most welcome.",
#  "whether you're headed to a farmhouse veranda or an urban terrace, the modern prairie appeal of this lacy cotton maxi dress will be most welcome.",
#  "perfect for the workday and beyond, victoria beckham's modest dress is designed with drop sleeves and a knee-length hem. this relaxed style is detailed with contrast piping along the front and back— coordinate yours with burgundy ankle boots.",
#  "perfect for the workday and beyond, victoria beckham's modest dress is designed with drop sleeves and a knee-length hem. this relaxed style is detailed with contrast piping along the front and back— coordinate yours with burgundy ankle boots.",
#  "perfect for the workday and beyond, victoria beckham's modest dress is designed with drop sleeves and a knee-length hem. this relaxed style is detailed with contrast piping along the front and back— coordinate yours with burgundy ankle boots.",
#  "perfect for the workday and beyond, victoria beckham's modest dress is designed with drop sleeves and a knee-length hem. this relaxed style is detailed with contrast piping along the front and back— coordinate yours with burgundy ankle boots.",
#  "perfect for the workday and beyond, victoria beckham's modest dress is designed with drop sleeves and a knee-length hem. this relaxed style is detailed with contrast piping along the front and back— coordinate yours with burgundy ankle boots.",
#  "perfect for the workday and beyond, victoria beckham's modest dress is designed with drop sleeves and a knee-length hem. this relaxed style is detailed with contrast piping along the front and back— coordinate yours with burgundy ankle boots.",
#  "bouguessa's classic blazer is designed with a v-neckline, pocket flaps, and a belted waist. pair yours with the matching pants to create the ultimate power suit.",
#  "bouguessa's classic blazer is designed with a v-neckline, pocket flaps, and a belted waist. pair yours with the matching pants to create the ultimate power suit.",
#  "bouguessa's classic blazer is designed with a v-neckline, pocket flaps, and a belted waist. pair yours with the matching pants to create the ultimate power suit.",
#  "bouguessa's classic blazer is designed with a v-neckline, pocket flaps, and a belted waist. pair yours with the matching pants to create the ultimate power suit.",
#  'carry your essentials in style with this rich leather briefcase on a removable crossbody strap.',
#  'carry your essentials in style with this rich leather briefcase on a removable crossbody strap.',
#  'carry your essentials in style with this rich leather briefcase on a removable crossbody strap.',
#  'carry your essentials in style with this rich leather briefcase on a removable crossbody strap.',
#  "loveshackfancy's 'queenie' ultra-feminine silk dress is designed with a ruffled hemline and an all-over floral print. pair yours with minimalist accessories to keep the dress in focus.",
#  "loveshackfancy's 'queenie' ultra-feminine silk dress is designed with a ruffled hemline and an all-over floral print. pair yours with minimalist accessories to keep the dress in focus.",
#  "loveshackfancy's 'queenie' ultra-feminine silk dress is designed with a ruffled hemline and an all-over floral print. pair yours with minimalist accessories to keep the dress in focus.",
#  "loveshackfancy's 'queenie' ultra-feminine silk dress is designed with a ruffled hemline and an all-over floral print. pair yours with minimalist accessories to keep the dress in focus.",
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  "cinched at the waist to accentuate your natural curves, loveshackfancy's 'cheyenne' cotton skirt is designed with a floral print and a fitted waist. pair yours with a sweater for a fun transitional look.",
#  "cinched at the waist to accentuate your natural curves, loveshackfancy's 'cheyenne' cotton skirt is designed with a floral print and a fitted waist. pair yours with a sweater for a fun transitional look.",
#  "cinched at the waist to accentuate your natural curves, loveshackfancy's 'cheyenne' cotton skirt is designed with a floral print and a fitted waist. pair yours with a sweater for a fun transitional look.",
#  "cinched at the waist to accentuate your natural curves, loveshackfancy's 'cheyenne' cotton skirt is designed with a floral print and a fitted waist. pair yours with a sweater for a fun transitional look.",
#  'cream silk-satin pull on HIGH_SILK dry clean made in france',
#  'cream silk-satin pull on HIGH_SILK dry clean made in france',
#  ...]

# %%
no_numeric_description = []
for i in cleaned_material:
    no_numeric_description.append(re.sub(r'((\d+\.\d+)|(\d+))', 'NUMERICAL_VALUE ', i, flags = re.IGNORECASE))

# %%
no_numeric_description
# Out:
# ['black leather (lamb) open top  weighs approximately NUMERICAL_VALUE lbs/ NUMERICAL_VALUE kg imported',
#  "retro-inspired yet current, this stretchy, ribbed bodysuit is based on the slim-fitting clothing that gained popularity in the 'NUMERICAL_VALUE s.",
#  "retro-inspired yet current, this stretchy, ribbed bodysuit is based on the slim-fitting clothing that gained popularity in the 'NUMERICAL_VALUE s.",
#  'black stretch-pima cotton jersey slips on HIGH_PIMA cotton, LOW_ELASTANE hand wash imported',
#  "crafted from supple leather, sally lapointe's pants are cut in a wide-leg silhouette. cinched at the waist with a matching belt, this style looks amazing when paired with your favorite sweater tucked in.",
#  'cream crepe slips on material, material; lining: material, MEDIAN_ACETATE dry clean',
#  'cream crepe slips on material, material; lining: material, MEDIAN_ACETATE dry clean',
#  "crafted from supple leather, sally lapointe's pants are cut in a wide-leg silhouette. cinched at the waist with a matching belt, this style looks amazing when paired with your favorite sweater tucked in.",
#  "crafted from supple leather, sally lapointe's pants are cut in a wide-leg silhouette. cinched at the waist with a matching belt, this style looks amazing when paired with your favorite sweater tucked in.",
#  'heel measures approximately NUMERICAL_VALUE mm/ NUMERICAL_VALUE  inches gold mirrored-leather (calf) buckle-fastening ankle strap come with dust bag made in italy',
#  'heel measures approximately NUMERICAL_VALUE mm/ NUMERICAL_VALUE  inches gold mirrored-leather (calf) buckle-fastening ankle strap come with dust bag made in italy',
#  'clean seams and a towering stacked heel define a polished day-to-night boot.',
#  'chase your summery dreams in this ombré rainbow metallic sandal in a beach-chic design with knotted straps reaching up to wrap the ankle.',
#  'chase your summery dreams in this ombré rainbow metallic sandal in a beach-chic design with knotted straps reaching up to wrap the ankle.',
#  'heel measures approximately NUMERICAL_VALUE mm/ NUMERICAL_VALUE  inches gold mirrored-leather (calf) buckle-fastening ankle strap come with dust bag made in italy',
#  'heel measures approximately NUMERICAL_VALUE mm/ NUMERICAL_VALUE  inches gold mirrored-leather (calf) buckle-fastening ankle strap come with dust bag made in italy',
#  'cream crepe slips on material, material; lining: material, MEDIAN_ACETATE dry clean',
#  'cream crepe slips on material, material; lining: material, MEDIAN_ACETATE dry clean',
#  'camel grain de poudre wool button fastening at front material; buttons: HIGH_WOOL (buffalo) dry clean made in italy',
#  'cream crepe slips on material, material; lining: material, MEDIAN_ACETATE dry clean',
#  'black stretch-pima cotton jersey slips on HIGH_PIMA cotton, LOW_ELASTANE hand wash imported',
#  'clean seams and a towering stacked heel define a polished day-to-night boot.',
#  "a mens-y military-inspired button up that our designers tailored just for the ladies, thanks to a slimmer fit that's super-flattering.",
#  "a mens-y military-inspired button up that our designers tailored just for the ladies, thanks to a slimmer fit that's super-flattering.",
#  'black stretch-pima cotton jersey slips on HIGH_PIMA cotton, LOW_ELASTANE hand wash imported',
#  'fashioned from high-quality materials and designed for comfort, our shoes will keep you on your (stylish) toes. flexible, suede upper. breathable synthetic lining. insole with added stability in the heel. exclusive padding system features memory foam and a cushioned insole designed for all-day comfort. flexible skid-resistant outsole with comfort pod at bottom.',
#  'fashioned from high-quality materials and designed for comfort, our shoes will keep you on your (stylish) toes. flexible, suede upper. breathable synthetic lining. insole with added stability in the heel. exclusive padding system features memory foam and a cushioned insole designed for all-day comfort. flexible skid-resistant outsole with comfort pod at bottom.',
#  'gray cotton-jersey slips on HIGH_COTTON machine wash designer color: tinker',
#  'gray cotton-jersey slips on HIGH_COTTON machine wash designer color: tinker',
#  'gray cotton-jersey slips on HIGH_COTTON machine wash designer color: tinker',
#  'camel grain de poudre wool button fastening at front material; buttons: HIGH_WOOL (buffalo) dry clean made in italy',
#  'black leather (lamb) open top  weighs approximately NUMERICAL_VALUE lbs/ NUMERICAL_VALUE kg imported',
#  'gray cotton-jersey slips on HIGH_COTTON machine wash designer color: tinker',
#  "a mens-y military-inspired button up that our designers tailored just for the ladies, thanks to a slimmer fit that's super-flattering.",
#  "a mens-y military-inspired button up that our designers tailored just for the ladies, thanks to a slimmer fit that's super-flattering.",
#  'wide, channel-quilted straps crisscross a well-padded slide sandal grounded by razored treads.',
#  'multicolored cotton, nylon, merino wool, alpaca, cashmere and mohair-blend slips on material, material, LOW_COTTON wool,material, material, LOW_NYLON dry clean imported',
#  "crafted in italy, golden goose's 'hi star' sneakers are designed with the brand's signature appliqué star and stamped gold-tone logo on textured-leather uppers. set on a platform rubber sole, this pair is complete with suede vamps and handwritten text accents. highlight its chunky heel by pairing yours with a midi-length skirt.",
#  "edgy style and expert craftsmanship combine on a block-heel combat boot that's cut, sewn and lasted by hand by spanish artisans.",
#  'ready for a stroll on a private beach, this flat sandal is styled with crisscrossing straps of braided raffia.',
#  'we’re suckers for a pretty statement top. which is exactly how we landed on this tee and its ladylike twists. it fits and feels like your favorite t-shirt (you can thank the soft cotton jersey for that), but it’s perked up with high-volume poplin sleeves that gather gracefully toward the cuffs (yes to statement shoulders). and here’s the best news: you can treat it like all your other tees and wear it with every single pair of jeans, trousers, and shorts you own.material clean onlymade in italymeasurements (from size NUMERICAL_VALUE ): length: NUMERICAL_VALUE  NUMERICAL_VALUE /NUMERICAL_VALUE "; chest: NUMERICAL_VALUE  NUMERICAL_VALUE /NUMERICAL_VALUE "model is NUMERICAL_VALUE ’NUMERICAL_VALUE " with NUMERICAL_VALUE " bust, NUMERICAL_VALUE " waist, NUMERICAL_VALUE " hips and wearing a size NUMERICAL_VALUE ',
#  'ready for a stroll on a private beach, this flat sandal is styled with crisscrossing straps of braided raffia.',
#  "as enchanting as cinderella's glass slipper, but much more wearable, this graceful italian sandal is styled with transparent straps.",
#  'we’re suckers for a pretty statement top. which is exactly how we landed on this tee and its ladylike twists. it fits and feels like your favorite t-shirt (you can thank the soft cotton jersey for that), but it’s perked up with high-volume poplin sleeves that gather gracefully toward the cuffs (yes to statement shoulders). and here’s the best news: you can treat it like all your other tees and wear it with every single pair of jeans, trousers, and shorts you own.material clean onlymade in italymeasurements (from size NUMERICAL_VALUE ): length: NUMERICAL_VALUE  NUMERICAL_VALUE /NUMERICAL_VALUE "; chest: NUMERICAL_VALUE  NUMERICAL_VALUE /NUMERICAL_VALUE "model is NUMERICAL_VALUE ’NUMERICAL_VALUE " with NUMERICAL_VALUE " bust, NUMERICAL_VALUE " waist, NUMERICAL_VALUE " hips and wearing a size NUMERICAL_VALUE ',
#  'a lean and lengthening silhouette with one-button closure to accentuate the waist. notch lapel. long sleeves with one-button cuffs. two exterior pockets. center-back vent. fully lined with stretch lining for comfort and ease of movement.',
#  'a lean and lengthening silhouette with one-button closure to accentuate the waist. notch lapel. long sleeves with one-button cuffs. two exterior pockets. center-back vent. fully lined with stretch lining for comfort and ease of movement.',
#  "edgy style and expert craftsmanship combine on a block-heel combat boot that's cut, sewn and lasted by hand by spanish artisans.",
#  'a lean and lengthening silhouette with one-button closure to accentuate the waist. notch lapel. long sleeves with one-button cuffs. two exterior pockets. center-back vent. fully lined with stretch lining for comfort and ease of movement.',
#  'a lean and lengthening silhouette with one-button closure to accentuate the waist. notch lapel. long sleeves with one-button cuffs. two exterior pockets. center-back vent. fully lined with stretch lining for comfort and ease of movement.',
#  "nobody denim's 'true' jeans are designed with pre-cuffed hems, saving you time from finding the perfect length. crafted in a medium wash, this style is fashioned with a mid-rise waist and the brand's logo stitching on the back right pocket. couple this skinny style with a puffed sleeve blouse to add volume.",
#  "nobody denim's 'true' jeans are designed with pre-cuffed hems, saving you time from finding the perfect length. crafted in a medium wash, this style is fashioned with a mid-rise waist and the brand's logo stitching on the back right pocket. couple this skinny style with a puffed sleeve blouse to add volume.",
#  "nobody denim's 'true' jeans are designed with pre-cuffed hems, saving you time from finding the perfect length. crafted in a medium wash, this style is fashioned with a mid-rise waist and the brand's logo stitching on the back right pocket. couple this skinny style with a puffed sleeve blouse to add volume.",
#  'these ivory jeans can be as dressed up or toned down as you need them to be. they have a straight-leg fit that’s skinny, but not constricting, with a super-flattering, leg-elongating silhouette that falls just past the ankles—meaning they work equally well with a block-heeled boot (for the office) or low-top sneakers (for kicking around).material washmade in the usamodel is NUMERICAL_VALUE ’NUMERICAL_VALUE ” with NUMERICAL_VALUE " bust, NUMERICAL_VALUE " waist, NUMERICAL_VALUE " hips and wearing a size NUMERICAL_VALUE ',
#  "crafted from supple leather, sally lapointe's pants are cut in a wide-leg silhouette. cinched at the waist with a matching belt, this style looks amazing when paired with your favorite sweater tucked in.",
#  'heel measures approximately NUMERICAL_VALUE mm/ NUMERICAL_VALUE  inches cream leather (lamb) slip on  designer color: buttercream  made in italysmall to size. see size & fit notes.',
#  'heel measures approximately NUMERICAL_VALUE mm/ NUMERICAL_VALUE  inches cream leather (lamb) slip on  designer color: buttercream  made in italysmall to size. see size & fit notes.',
#  'heel measures approximately NUMERICAL_VALUE mm/ NUMERICAL_VALUE  inches cream leather (lamb) slip on  designer color: buttercream  made in italysmall to size. see size & fit notes.',
#  "derek lam's oversized silk blouse is designed with a self tie scarf at neck, long cuffed sleeves and a high-low hemline.",
#  "introducing suiting for the first time, re/done based these cropped flare trousers on a vintage pair from the 'NUMERICAL_VALUE s and had them handmade in italy.",
#  "introducing suiting for the first time, re/done based these cropped flare trousers on a vintage pair from the 'NUMERICAL_VALUE s and had them handmade in italy.",
#  "crafted from supple leather, sally lapointe's pants are cut in a wide-leg silhouette. cinched at the waist with a matching belt, this style looks amazing when paired with your favorite sweater tucked in.",
#  "edgy style and expert craftsmanship combine on a block-heel combat boot that's cut, sewn and lasted by hand by spanish artisans.",
#  'a twinkling crystal brooch crowns the toe strap of a party-ready sandal secured by a slender floating ankle strap.',
#  'a twinkling crystal brooch crowns the toe strap of a party-ready sandal secured by a slender floating ankle strap.',
#  'these ivory jeans can be as dressed up or toned down as you need them to be. they have a straight-leg fit that’s skinny, but not constricting, with a super-flattering, leg-elongating silhouette that falls just past the ankles—meaning they work equally well with a block-heeled boot (for the office) or low-top sneakers (for kicking around).material washmade in the usamodel is NUMERICAL_VALUE ’NUMERICAL_VALUE ” with NUMERICAL_VALUE " bust, NUMERICAL_VALUE " waist, NUMERICAL_VALUE " hips and wearing a size NUMERICAL_VALUE ',
#  "derek lam's oversized silk blouse is designed with a self tie scarf at neck, long cuffed sleeves and a high-low hemline.",
#  'named for its unique double-point pocket design, this denim western shirt is softly faded and detailed with pearly snaps for an authentic vintage look.',
#  'named for its unique double-point pocket design, this denim western shirt is softly faded and detailed with pearly snaps for an authentic vintage look.',
#  'these ivory jeans can be as dressed up or toned down as you need them to be. they have a straight-leg fit that’s skinny, but not constricting, with a super-flattering, leg-elongating silhouette that falls just past the ankles—meaning they work equally well with a block-heeled boot (for the office) or low-top sneakers (for kicking around).material washmade in the usamodel is NUMERICAL_VALUE ’NUMERICAL_VALUE ” with NUMERICAL_VALUE " bust, NUMERICAL_VALUE " waist, NUMERICAL_VALUE " hips and wearing a size NUMERICAL_VALUE ',
#  "designed and curated by minimalistic style icon elin kling, totême provides updated essentials that are effortless to mix and match. ideal for both work and weekends, the high-rise ' ossi' is tailored with a full length and a tailored leg. wear with the matching blazer for a smart look, or keep it casual with an oversized knit and sneakers.",
#  'midnight-blue organic cotton-velour  pull on  HIGH_ORGANIC cotton  machine wash  imported',
#  "designed and curated by minimalistic style icon elin kling, totême provides updated essentials that are effortless to mix and match. ideal for both work and weekends, the high-rise ' ossi' is tailored with a full length and a tailored leg. wear with the matching blazer for a smart look, or keep it casual with an oversized knit and sneakers.",
#  'tan leather (calf) magnetic-fastening front flap weighs approximately NUMERICAL_VALUE lbs/ NUMERICAL_VALUE kg made in italy',
#  "as enchanting as cinderella's glass slipper, but much more wearable, this graceful italian sandal is styled with transparent straps.",
#  "derek lam's oversized silk blouse is designed with a self tie scarf at neck, long cuffed sleeves and a high-low hemline.",
#  "designed and curated by minimalistic style icon elin kling, totême provides updated essentials that are effortless to mix and match. ideal for both work and weekends, the high-rise ' ossi' is tailored with a full length and a tailored leg. wear with the matching blazer for a smart look, or keep it casual with an oversized knit and sneakers.",
#  "derek lam's oversized silk blouse is designed with a self tie scarf at neck, long cuffed sleeves and a high-low hemline.",
#  'croc embossing brings of-the-moment appeal to a double-band sandal finished with gleaming buckles.',
#  'croc embossing brings of-the-moment appeal to a double-band sandal finished with gleaming buckles.',
#  'tan leather (calf) magnetic-fastening front flap weighs approximately NUMERICAL_VALUE lbs/ NUMERICAL_VALUE kg made in italy',
#  "crafted in italy, golden goose's 'hi star' sneakers are designed with the brand's signature appliqué star and stamped gold-tone logo on textured-leather uppers. set on a platform rubber sole, this pair is complete with suede vamps and handwritten text accents. highlight its chunky heel by pairing yours with a midi-length skirt.",
#  'multicolored cotton, nylon, merino wool, alpaca, cashmere and mohair-blend slips on material, material, LOW_COTTON wool,material, material, LOW_NYLON dry clean imported',
#  'black leather (lamb) open top  weighs approximately NUMERICAL_VALUE lbs/ NUMERICAL_VALUE kg imported',
#  'these ivory jeans can be as dressed up or toned down as you need them to be. they have a straight-leg fit that’s skinny, but not constricting, with a super-flattering, leg-elongating silhouette that falls just past the ankles—meaning they work equally well with a block-heeled boot (for the office) or low-top sneakers (for kicking around).material washmade in the usamodel is NUMERICAL_VALUE ’NUMERICAL_VALUE ” with NUMERICAL_VALUE " bust, NUMERICAL_VALUE " waist, NUMERICAL_VALUE " hips and wearing a size NUMERICAL_VALUE ',
#  'a flouncy tie gathers the neckline of this billowy chartreuse dress finished with an attached hem to enhance the flowy movement.',
#  'black and white lyocell partially concealed snap fastenings through front HIGH_LYOCELL dry clean imported',
#  'black and white lyocell partially concealed snap fastenings through front HIGH_LYOCELL dry clean imported',
#  'gray cotton-jersey slips on HIGH_COTTON machine wash designer color: tinker',
#  'these ivory jeans can be as dressed up or toned down as you need them to be. they have a straight-leg fit that’s skinny, but not constricting, with a super-flattering, leg-elongating silhouette that falls just past the ankles—meaning they work equally well with a block-heeled boot (for the office) or low-top sneakers (for kicking around).material washmade in the usamodel is NUMERICAL_VALUE ’NUMERICAL_VALUE ” with NUMERICAL_VALUE " bust, NUMERICAL_VALUE " waist, NUMERICAL_VALUE " hips and wearing a size NUMERICAL_VALUE ',
#  'heel measures approximately NUMERICAL_VALUE mm/ NUMERICAL_VALUE  inches cream leather (lamb) slip on  designer color: buttercream  made in italysmall to size. see size & fit notes.',
#  "designed and curated by minimalistic style icon elin kling, totême provides updated essentials that are effortless to mix and match. ideal for both work and weekends, the high-rise ' ossi' is tailored with a full length and a tailored leg. wear with the matching blazer for a smart look, or keep it casual with an oversized knit and sneakers.",
#  "designed and curated by minimalistic style icon elin kling, totême provides updated essentials that are effortless to mix and match. ideal for both work and weekends, the high-rise ' ossi' is tailored with a full length and a tailored leg. wear with the matching blazer for a smart look, or keep it casual with an oversized knit and sneakers.",
#  'cream and black jersey button fastening keyhole at back material, material; lining: HIGH_VISCOSE dry clean imported',
#  'heel measures approximately NUMERICAL_VALUE mm/ NUMERICAL_VALUE  inches cream leather (lamb) slip on  designer color: buttercream  made in italysmall to size. see size & fit notes.',
#  'cream and black jersey button fastening keyhole at back material, material; lining: HIGH_VISCOSE dry clean imported',
#  'heel measures approximately NUMERICAL_VALUE mm/ NUMERICAL_VALUE  inches cream leather (lamb) slip on  designer color: buttercream  made in italysmall to size. see size & fit notes.',
#  'gray cotton-jersey slips on HIGH_COTTON machine wash designer color: tinker',
#  'midnight-blue organic cotton-velour  pull on  HIGH_ORGANIC cotton  machine wash  imported',
#  'black and white lyocell partially concealed snap fastenings through front HIGH_LYOCELL dry clean imported',
#  'stone stretch-pima cotton pull on HIGH_PIMA cotton, LOW_ELASTANE machine wash imported',
#  'black and white lyocell partially concealed snap fastenings through front HIGH_LYOCELL dry clean imported',
#  'this silhouette of a poised cap-toe pump gets a vacation update with a platform and wedge heel wrapped in braided jute.',
#  'stone stretch-pima cotton pull on HIGH_PIMA cotton, LOW_ELASTANE machine wash imported',
#  'heel measures approximately NUMERICAL_VALUE mm/ NUMERICAL_VALUE  inches cream leather (lamb) slip on  designer color: buttercream  made in italysmall to size. see size & fit notes.',
#  'this pleat-neck top—made in italy from paper-thin poplin—is a shirting unicorn: it’s got the beauty of your best-loved blouse (thanks to those pretty front pleats and intricate knot detailing at the collar) and the brains of your favorite tee (relaxed shape, roomy sleeves). oh, and the incognito buttons in back are the nicest of touches.\xa0material clean onlymade in italymeasurements (from size NUMERICAL_VALUE ): NUMERICAL_VALUE " chest, NUMERICAL_VALUE " sleeve length, NUMERICAL_VALUE " body lengthmodel is NUMERICAL_VALUE ’NUMERICAL_VALUE ” with NUMERICAL_VALUE " bust, NUMERICAL_VALUE " waist, NUMERICAL_VALUE " hips and wearing a size NUMERICAL_VALUE ',
#  'this pleat-neck top—made in italy from paper-thin poplin—is a shirting unicorn: it’s got the beauty of your best-loved blouse (thanks to those pretty front pleats and intricate knot detailing at the collar) and the brains of your favorite tee (relaxed shape, roomy sleeves). oh, and the incognito buttons in back are the nicest of touches.\xa0material clean onlymade in italymeasurements (from size NUMERICAL_VALUE ): NUMERICAL_VALUE " chest, NUMERICAL_VALUE " sleeve length, NUMERICAL_VALUE " body lengthmodel is NUMERICAL_VALUE ’NUMERICAL_VALUE ” with NUMERICAL_VALUE " bust, NUMERICAL_VALUE " waist, NUMERICAL_VALUE " hips and wearing a size NUMERICAL_VALUE ',
#  'this silhouette of a poised cap-toe pump gets a vacation update with a platform and wedge heel wrapped in braided jute.',
#  'this pleat-neck top—made in italy from paper-thin poplin—is a shirting unicorn: it’s got the beauty of your best-loved blouse (thanks to those pretty front pleats and intricate knot detailing at the collar) and the brains of your favorite tee (relaxed shape, roomy sleeves). oh, and the incognito buttons in back are the nicest of touches.\xa0material clean onlymade in italymeasurements (from size NUMERICAL_VALUE ): NUMERICAL_VALUE " chest, NUMERICAL_VALUE " sleeve length, NUMERICAL_VALUE " body lengthmodel is NUMERICAL_VALUE ’NUMERICAL_VALUE ” with NUMERICAL_VALUE " bust, NUMERICAL_VALUE " waist, NUMERICAL_VALUE " hips and wearing a size NUMERICAL_VALUE ',
#  'this pleat-neck top—made in italy from paper-thin poplin—is a shirting unicorn: it’s got the beauty of your best-loved blouse (thanks to those pretty front pleats and intricate knot detailing at the collar) and the brains of your favorite tee (relaxed shape, roomy sleeves). oh, and the incognito buttons in back are the nicest of touches.\xa0material clean onlymade in italymeasurements (from size NUMERICAL_VALUE ): NUMERICAL_VALUE " chest, NUMERICAL_VALUE " sleeve length, NUMERICAL_VALUE " body lengthmodel is NUMERICAL_VALUE ’NUMERICAL_VALUE ” with NUMERICAL_VALUE " bust, NUMERICAL_VALUE " waist, NUMERICAL_VALUE " hips and wearing a size NUMERICAL_VALUE ',
#  'anything leopard tends to automatically fall in the “chic” category. but when you factor in la double j’s romantic touches, like those frilly flutter sleeves and that stunning, almost architectural standing collar, and this italian-made crepe dress becomes something else entirely. oh, and that knee-length cut means it’s just as office appropriate as it is date-night friendly. and it’s just as pretty from the back (you can thank the tie-up detail for that).material, HIGH_VISCOSE cleanmade in italymodel is NUMERICAL_VALUE ’NUMERICAL_VALUE ” with NUMERICAL_VALUE " bust, NUMERICAL_VALUE " waist, NUMERICAL_VALUE " hips and wearing a size\xa0xs',
#  'this silhouette of a poised cap-toe pump gets a vacation update with a platform and wedge heel wrapped in braided jute.',
#  "nobody denim's 'true' jeans are designed with pre-cuffed hems, saving you time from finding the perfect length. crafted in a medium wash, this style is fashioned with a mid-rise waist and the brand's logo stitching on the back right pocket. couple this skinny style with a puffed sleeve blouse to add volume.",
#  "nobody denim's 'true' jeans are designed with pre-cuffed hems, saving you time from finding the perfect length. crafted in a medium wash, this style is fashioned with a mid-rise waist and the brand's logo stitching on the back right pocket. couple this skinny style with a puffed sleeve blouse to add volume.",
#  "nobody denim's 'true' jeans are designed with pre-cuffed hems, saving you time from finding the perfect length. crafted in a medium wash, this style is fashioned with a mid-rise waist and the brand's logo stitching on the back right pocket. couple this skinny style with a puffed sleeve blouse to add volume.",
#  "aquazzura's 'minute' sandals are crafted from polished leather with ultra-slim straps that secure and frame the foot. this pair will literally take your look to new heights—its set on a slender stiletto heel measuring over four inches.",
#  "aquazzura's 'minute' sandals are crafted from polished leather with ultra-slim straps that secure and frame the foot. this pair will literally take your look to new heights—its set on a slender stiletto heel measuring over four inches.",
#  "just one example of this season's strong tailoring theme, carolina herrera's trousers are cut from a wool and silk blend woven with a classic prince of wales check typically found in men's suiting. this high-waisted pair is fitted through the hips and tapered through the knees before flaring toward the ankles. complete the look with a matching printed jacket.",
#  "just one example of this season's strong tailoring theme, carolina herrera's trousers are cut from a wool and silk blend woven with a classic prince of wales check typically found in men's suiting. this high-waisted pair is fitted through the hips and tapered through the knees before flaring toward the ankles. complete the look with a matching printed jacket.",
#  "designed and curated by minimalistic style icon elin kling, totême provides updated essentials that are effortless to mix and match. ideal for both work and weekends, the high-rise ' ossi' is tailored with a full length and a tailored leg. wear with the matching blazer for a smart look, or keep it casual with an oversized knit and sneakers.",
#  'a drawstring waist and cropped silhouette bring a relaxed, lounge-inspired attitude to pants with a slight sheen, tonal floral pattern and silky feel.',
#  'a drawstring waist and cropped silhouette bring a relaxed, lounge-inspired attitude to pants with a slight sheen, tonal floral pattern and silky feel.',
#  'gray cotton-jersey slips on HIGH_COTTON machine wash designer color: tinker',
#  "aquazzura's 'minute' sandals are crafted from polished leather with ultra-slim straps that secure and frame the foot. this pair will literally take your look to new heights—its set on a slender stiletto heel measuring over four inches.",
#  'a flouncy tie gathers the neckline of this billowy chartreuse dress finished with an attached hem to enhance the flowy movement.',
#  'anything leopard tends to automatically fall in the “chic” category. but when you factor in la double j’s romantic touches, like those frilly flutter sleeves and that stunning, almost architectural standing collar, and this italian-made crepe dress becomes something else entirely. oh, and that knee-length cut means it’s just as office appropriate as it is date-night friendly. and it’s just as pretty from the back (you can thank the tie-up detail for that).material, HIGH_VISCOSE cleanmade in italymodel is NUMERICAL_VALUE ’NUMERICAL_VALUE ” with NUMERICAL_VALUE " bust, NUMERICAL_VALUE " waist, NUMERICAL_VALUE " hips and wearing a size\xa0xs',
#  'gleaming studs outline the sole of a retro-inspired slide sandal lofted by a chunky woodgrain heel and platform.',
#  "just one example of this season's strong tailoring theme, carolina herrera's trousers are cut from a wool and silk blend woven with a classic prince of wales check typically found in men's suiting. this high-waisted pair is fitted through the hips and tapered through the knees before flaring toward the ankles. complete the look with a matching printed jacket.",
#  "just one example of this season's strong tailoring theme, carolina herrera's trousers are cut from a wool and silk blend woven with a classic prince of wales check typically found in men's suiting. this high-waisted pair is fitted through the hips and tapered through the knees before flaring toward the ankles. complete the look with a matching printed jacket.",
#  'black ribbed-knit slips on material, material, material, MEDIAN_WOOL dry clean imported',
#  'black ribbed-knit slips on material, material, material, MEDIAN_WOOL dry clean imported',
#  'gleaming studs outline the sole of a retro-inspired slide sandal lofted by a chunky woodgrain heel and platform.',
#  'breezy wide leg pants are designed with a glamorous sweeping silhouette in fluid silk.',
#  'breezy wide leg pants are designed with a glamorous sweeping silhouette in fluid silk.',
#  "aquazzura's 'minute' sandals are crafted from polished leather with ultra-slim straps that secure and frame the foot. this pair will literally take your look to new heights—its set on a slender stiletto heel measuring over four inches.",
#  'beige washed stretch-silk satin slips on material, HIGH_SILK hand wash designer color: fawn imported',
#  'beige washed stretch-silk satin slips on material, HIGH_SILK hand wash designer color: fawn imported',
#  'we’re suckers for a pretty statement top. which is exactly how we landed on this tee and its ladylike twists. it fits and feels like your favorite t-shirt (you can thank the soft cotton jersey for that), but it’s perked up with high-volume poplin sleeves that gather gracefully toward the cuffs (yes to statement shoulders). and here’s the best news: you can treat it like all your other tees and wear it with every single pair of jeans, trousers, and shorts you own.material clean onlymade in italymeasurements (from size NUMERICAL_VALUE ): length: NUMERICAL_VALUE  NUMERICAL_VALUE /NUMERICAL_VALUE "; chest: NUMERICAL_VALUE  NUMERICAL_VALUE /NUMERICAL_VALUE "model is NUMERICAL_VALUE ’NUMERICAL_VALUE " with NUMERICAL_VALUE " bust, NUMERICAL_VALUE " waist, NUMERICAL_VALUE " hips and wearing a size NUMERICAL_VALUE ',
#  'we’re suckers for a pretty statement top. which is exactly how we landed on this tee and its ladylike twists. it fits and feels like your favorite t-shirt (you can thank the soft cotton jersey for that), but it’s perked up with high-volume poplin sleeves that gather gracefully toward the cuffs (yes to statement shoulders). and here’s the best news: you can treat it like all your other tees and wear it with every single pair of jeans, trousers, and shorts you own.material clean onlymade in italymeasurements (from size NUMERICAL_VALUE ): length: NUMERICAL_VALUE  NUMERICAL_VALUE /NUMERICAL_VALUE "; chest: NUMERICAL_VALUE  NUMERICAL_VALUE /NUMERICAL_VALUE "model is NUMERICAL_VALUE ’NUMERICAL_VALUE " with NUMERICAL_VALUE " bust, NUMERICAL_VALUE " waist, NUMERICAL_VALUE " hips and wearing a size NUMERICAL_VALUE ',
#  'black ribbed-knit slips on material, material, material, MEDIAN_WOOL dry clean imported',
#  'we’re suckers for a pretty statement top. which is exactly how we landed on this tee and its ladylike twists. it fits and feels like your favorite t-shirt (you can thank the soft cotton jersey for that), but it’s perked up with high-volume poplin sleeves that gather gracefully toward the cuffs (yes to statement shoulders). and here’s the best news: you can treat it like all your other tees and wear it with every single pair of jeans, trousers, and shorts you own.material clean onlymade in italymeasurements (from size NUMERICAL_VALUE ): length: NUMERICAL_VALUE  NUMERICAL_VALUE /NUMERICAL_VALUE "; chest: NUMERICAL_VALUE  NUMERICAL_VALUE /NUMERICAL_VALUE "model is NUMERICAL_VALUE ’NUMERICAL_VALUE " with NUMERICAL_VALUE " bust, NUMERICAL_VALUE " waist, NUMERICAL_VALUE " hips and wearing a size NUMERICAL_VALUE ',
#  'a pointy toe and tapered heel balance the streamlined silhouette of a go-to boot.',
#  'a pointy toe and tapered heel balance the streamlined silhouette of a go-to boot.',
#  'black ribbed-knit slips on material, material, material, MEDIAN_WOOL dry clean imported',
#  'lift your spirits with this double-strap slide sandal perched on a tall block heel and a thick platform for easy gliding.',
#  "as enchanting as cinderella's glass slipper, but much more wearable, this graceful italian sandal is styled with transparent straps.",
#  "the chunky knit and marled hues of this boatneck sweater make it a cold-weather go-to. bonus: the slightly relaxed fit means it'll drape perfectly when you tuck the front into high-waisted pants and jeans.",
#  "the chunky knit and marled hues of this boatneck sweater make it a cold-weather go-to. bonus: the slightly relaxed fit means it'll drape perfectly when you tuck the front into high-waisted pants and jeans.",
#  "the chunky knit and marled hues of this boatneck sweater make it a cold-weather go-to. bonus: the slightly relaxed fit means it'll drape perfectly when you tuck the front into high-waisted pants and jeans.",
#  "edgy style and expert craftsmanship combine on a block-heel combat boot that's cut, sewn and lasted by hand by spanish artisans.",
#  "edgy style and expert craftsmanship combine on a block-heel combat boot that's cut, sewn and lasted by hand by spanish artisans.",
#  "cut from soft camel wool, max mara's chic 'pacos' coat is designed with broad, fringe-trimmed lapels. cinch yours at the waist with the self-tie belt and keep your phone handy in one of the exaggerated patch pockets at the front.",
#  'ivory crepe slips on material, material; buttons: HIGH_ACETATE (cow) dry clean imported',
#  'ivory crepe slips on material, material; buttons: HIGH_ACETATE (cow) dry clean imported',
#  'knotted ties detail the toe strap of an elegant sandal lifted by a covered block heel and tied off with adjustable wraparound straps.',
#  'knotted ties detail the toe strap of an elegant sandal lifted by a covered block heel and tied off with adjustable wraparound straps.',
#  'knotted ties detail the toe strap of an elegant sandal lifted by a covered block heel and tied off with adjustable wraparound straps.',
#  "edgy style and expert craftsmanship combine on a block-heel combat boot that's cut, sewn and lasted by hand by spanish artisans.",
#  'breezy wide leg pants are designed with a glamorous sweeping silhouette in fluid silk.',
#  'multicolored cotton-blend button fastening through front material, material, MEDIAN_COTTON fibers; buttons: LOW_POLYESTER (cow) dry clean',
#  'multicolored cotton-blend button fastening through front material, material, MEDIAN_COTTON fibers; buttons: LOW_POLYESTER (cow) dry clean',
#  'these ivory jeans can be as dressed up or toned down as you need them to be. they have a straight-leg fit that’s skinny, but not constricting, with a super-flattering, leg-elongating silhouette that falls just past the ankles—meaning they work equally well with a block-heeled boot (for the office) or low-top sneakers (for kicking around).material washmade in the usamodel is NUMERICAL_VALUE ’NUMERICAL_VALUE ” with NUMERICAL_VALUE " bust, NUMERICAL_VALUE " waist, NUMERICAL_VALUE " hips and wearing a size NUMERICAL_VALUE ',
#  "the chunky knit and marled hues of this boatneck sweater make it a cold-weather go-to. bonus: the slightly relaxed fit means it'll drape perfectly when you tuck the front into high-waisted pants and jeans.",
#  "the chunky knit and marled hues of this boatneck sweater make it a cold-weather go-to. bonus: the slightly relaxed fit means it'll drape perfectly when you tuck the front into high-waisted pants and jeans.",
#  'breezy wide leg pants are designed with a glamorous sweeping silhouette in fluid silk.',
#  "the chunky knit and marled hues of this boatneck sweater make it a cold-weather go-to. bonus: the slightly relaxed fit means it'll drape perfectly when you tuck the front into high-waisted pants and jeans.",
#  'brown cashmere and mulberry silk-blend slips on material, MEDIAN_CASHMERE silk dry clean designer color: bark imported',
#  'brown cashmere and mulberry silk-blend slips on material, MEDIAN_CASHMERE silk dry clean designer color: bark imported',
#  'brown cashmere and mulberry silk-blend slips on material, MEDIAN_CASHMERE silk dry clean designer color: bark imported',
#  'brown cashmere and mulberry silk-blend slips on material, MEDIAN_CASHMERE silk dry clean designer color: bark imported',
#  'sleek and sculptural, this strappy sandal shines in metallic snakeskin and looks modern with a square toe and a slim block heel.',
#  'sleek and sculptural, this strappy sandal shines in metallic snakeskin and looks modern with a square toe and a slim block heel.',
#  'black leather (lamb) open top  weighs approximately NUMERICAL_VALUE lbs/ NUMERICAL_VALUE kg imported',
#  'gleaming studs outline the sole of a retro-inspired slide sandal lofted by a chunky woodgrain heel and platform.',
#  "we believe that some animal prints double as neutral and these prada pumps are a prime example. designed in a classic leopard motif, they're sleek silhouette ends in a sharp toe that's fitted with cushioned insoles. try styling with wide-leg trousers to give the hem a lift.",
#  'a classic crewneck sweatshirt gets a luxurious update with a supremely soft cotton blend.',
#  'a classic crewneck sweatshirt gets a luxurious update with a supremely soft cotton blend.',
#  "we believe that some animal prints double as neutral and these prada pumps are a prime example. designed in a classic leopard motif, they're sleek silhouette ends in a sharp toe that's fitted with cushioned insoles. try styling with wide-leg trousers to give the hem a lift.",
#  "we believe that some animal prints double as neutral and these prada pumps are a prime example. designed in a classic leopard motif, they're sleek silhouette ends in a sharp toe that's fitted with cushioned insoles. try styling with wide-leg trousers to give the hem a lift.",
#  "we believe that some animal prints double as neutral and these prada pumps are a prime example. designed in a classic leopard motif, they're sleek silhouette ends in a sharp toe that's fitted with cushioned insoles. try styling with wide-leg trousers to give the hem a lift.",
#  "crafted in italy, golden goose's 'hi star' sneakers are designed with the brand's signature appliqué star and stamped gold-tone logo on textured-leather uppers. set on a platform rubber sole, this pair is complete with suede vamps and handwritten text accents. highlight its chunky heel by pairing yours with a midi-length skirt.",
#  'multicolored cotton, nylon, merino wool, alpaca, cashmere and mohair-blend slips on material, material, LOW_COTTON wool,material, material, LOW_NYLON dry clean imported',
#  'a classic crewneck sweatshirt gets a luxurious update with a supremely soft cotton blend.',
#  'a classic crewneck sweatshirt gets a luxurious update with a supremely soft cotton blend.',
#  "we believe that some animal prints double as neutral and these prada pumps are a prime example. designed in a classic leopard motif, they're sleek silhouette ends in a sharp toe that's fitted with cushioned insoles. try styling with wide-leg trousers to give the hem a lift.",
#  'multicolored cotton, nylon, merino wool, alpaca, cashmere and mohair-blend slips on material, material, LOW_COTTON wool,material, material, LOW_NYLON dry clean imported',
#  'a raffia-wrapped platform wedge with hint of metallic shimmer makes this suede, ankle-tie sandal a refined, resort-ready standout.',
#  'a raffia-wrapped platform wedge with hint of metallic shimmer makes this suede, ankle-tie sandal a refined, resort-ready standout.',
#  'a raffia-wrapped platform wedge with hint of metallic shimmer makes this suede, ankle-tie sandal a refined, resort-ready standout.',
#  "we believe that some animal prints double as neutral and these prada pumps are a prime example. designed in a classic leopard motif, they're sleek silhouette ends in a sharp toe that's fitted with cushioned insoles. try styling with wide-leg trousers to give the hem a lift.",
#  ' ',
#  ' ',
#  'camel grain de poudre wool button fastening at front material; buttons: HIGH_WOOL (buffalo) dry clean made in italy',
#  'sinuous straps cross atop a lightly cushioned sandal shaped with a squared-off toe and an architectural block heel.',
#  ' ',
#  ' ',
#  'anything leopard tends to automatically fall in the “chic” category. but when you factor in la double j’s romantic touches, like those frilly flutter sleeves and that stunning, almost architectural standing collar, and this italian-made crepe dress becomes something else entirely. oh, and that knee-length cut means it’s just as office appropriate as it is date-night friendly. and it’s just as pretty from the back (you can thank the tie-up detail for that).material, HIGH_VISCOSE cleanmade in italymodel is NUMERICAL_VALUE ’NUMERICAL_VALUE ” with NUMERICAL_VALUE " bust, NUMERICAL_VALUE " waist, NUMERICAL_VALUE " hips and wearing a size\xa0xs',
#  "crafted in italy, golden goose's 'hi star' sneakers are designed with the brand's signature appliqué star and stamped gold-tone logo on textured-leather uppers. set on a platform rubber sole, this pair is complete with suede vamps and handwritten text accents. highlight its chunky heel by pairing yours with a midi-length skirt.",
#  'webbed straps, a contrast wedge and a serrated platform style this modern and sporty sandal.',
#  "as enchanting as cinderella's glass slipper, but much more wearable, this graceful italian sandal is styled with transparent straps.",
#  'brown cashmere and mulberry silk-blend slips on material, MEDIAN_CASHMERE silk dry clean designer color: bark imported',
#  'anything leopard tends to automatically fall in the “chic” category. but when you factor in la double j’s romantic touches, like those frilly flutter sleeves and that stunning, almost architectural standing collar, and this italian-made crepe dress becomes something else entirely. oh, and that knee-length cut means it’s just as office appropriate as it is date-night friendly. and it’s just as pretty from the back (you can thank the tie-up detail for that).material, HIGH_VISCOSE cleanmade in italymodel is NUMERICAL_VALUE ’NUMERICAL_VALUE ” with NUMERICAL_VALUE " bust, NUMERICAL_VALUE " waist, NUMERICAL_VALUE " hips and wearing a size\xa0xs',
#  'multicolored cotton-jersey slips on HIGH_COTTON machine wash',
#  'multicolored cotton-jersey slips on HIGH_COTTON machine wash',
#  'brown cashmere and mulberry silk-blend slips on material, MEDIAN_CASHMERE silk dry clean designer color: bark imported',
#  'brown cashmere and mulberry silk-blend slips on material, MEDIAN_CASHMERE silk dry clean designer color: bark imported',
#  'brown cashmere and mulberry silk-blend slips on material, MEDIAN_CASHMERE silk dry clean designer color: bark imported',
#  'webbed straps, a contrast wedge and a serrated platform style this modern and sporty sandal.',
#  'black cotton-jersey slips on HIGH_COTTON machine wash imported',
#  'black cotton-jersey slips on HIGH_COTTON machine wash imported',
#  'we partnered with a fabric house in the southwest of france to make the custom trim at the hem of this polished tweed pencil skirt. even better: we also designed a matching jacket for more outfit potential.',
#  'we partnered with a fabric house in the southwest of france to make the custom trim at the hem of this polished tweed pencil skirt. even better: we also designed a matching jacket for more outfit potential.',
#  'black cotton-jersey slips on HIGH_COTTON machine wash imported',
#  'black cotton-jersey slips on HIGH_COTTON machine wash imported',
#  'ivory crepe slips on material, material; buttons: HIGH_ACETATE (cow) dry clean imported',
#  'ivory crepe slips on material, material; buttons: HIGH_ACETATE (cow) dry clean imported',
#  "cut from soft camel wool, max mara's chic 'pacos' coat is designed with broad, fringe-trimmed lapels. cinch yours at the waist with the self-tie belt and keep your phone handy in one of the exaggerated patch pockets at the front.",
#  'sinuous straps cross atop a lightly cushioned sandal shaped with a squared-off toe and an architectural block heel.',
#  "this italian-crafted chelsea boot is a sleek, timeless style that's as low-key as it is luxe.",
#  "this italian-crafted chelsea boot is a sleek, timeless style that's as low-key as it is luxe.",
#  "cut from soft camel wool, max mara's chic 'pacos' coat is designed with broad, fringe-trimmed lapels. cinch yours at the waist with the self-tie belt and keep your phone handy in one of the exaggerated patch pockets at the front.",
#  "channel your inner 'NUMERICAL_VALUE s supermodel in this day-to-night sandal with a toe loop, mid heel and clean, geometric angles.",
#  're/done delivers a one-two punch of comfort and confidence with a cotton tee featuring a comic-style graphic of a butt-kicking boxer.',
#  'dramatic curves and sharp angles marry on this pointy-toe bootie made with a steep slant on a stacked heel.',
#  'black leather (lamb) open top  weighs approximately NUMERICAL_VALUE lbs/ NUMERICAL_VALUE kg imported',
#  'dramatic curves and sharp angles marry on this pointy-toe bootie made with a steep slant on a stacked heel.',
#  'camel grain de poudre wool button fastening at front material; buttons: HIGH_WOOL (buffalo) dry clean made in italy',
#  "channel your inner 'NUMERICAL_VALUE s supermodel in this day-to-night sandal with a toe loop, mid heel and clean, geometric angles.",
#  'we partnered with a fabric house in the southwest of france to make the custom trim at the hem of this polished tweed pencil skirt. even better: we also designed a matching jacket for more outfit potential.',
#  'black stretch-pima cotton jersey slips on HIGH_PIMA cotton, LOW_ELASTANE hand wash imported',
#  'gray cotton-jersey slips on HIGH_COTTON machine wash designer color: tinker',
#  'we partnered with a fabric house in the southwest of france to make the custom trim at the hem of this polished tweed pencil skirt. even better: we also designed a matching jacket for more outfit potential.',
#  'an easy slide sandal is a go-everywhere shoe that brings a bit of beachy style to your everyday outfits.',
#  'tan leather (calf) magnetic-fastening front flap weighs approximately NUMERICAL_VALUE lbs/ NUMERICAL_VALUE kg made in italy',
#  'tan leather (calf) magnetic-fastening front flap weighs approximately NUMERICAL_VALUE lbs/ NUMERICAL_VALUE kg made in italy',
#  "off-white c/o virgil abloh's 'fringes popon' bag is crafted in a pom-pom silhouette with fringe details and a wristlet strap.",
#  'an easy slide sandal is a go-everywhere shoe that brings a bit of beachy style to your everyday outfits.',
#  'multicolored cotton-jersey slips on HIGH_COTTON machine wash',
#  "off-white c/o virgil abloh's 'fringes popon' bag is crafted in a pom-pom silhouette with fringe details and a wristlet strap.",
#  'multicolored cotton-jersey slips on HIGH_COTTON machine wash',
#  'styled with a slender mid heel and a v-cut vamp that flows into the pointy toe, this mule looks just as chic on your date as it does in the office.',
#  'styled with a slender mid heel and a v-cut vamp that flows into the pointy toe, this mule looks just as chic on your date as it does in the office.',
#  "cut from soft camel wool, max mara's chic 'pacos' coat is designed with broad, fringe-trimmed lapels. cinch yours at the waist with the self-tie belt and keep your phone handy in one of the exaggerated patch pockets at the front.",
#  'cream crepe slips on material, material; lining: material, MEDIAN_ACETATE dry clean',
#  'cream crepe slips on material, material; lining: material, MEDIAN_ACETATE dry clean',
#  ' ',
#  ' ',
#  'light-blue, navy and off-white jersey pull on material, HIGH_VISCOSE dry clean designer color: celeste blue imported',
#  'light-blue, navy and off-white jersey pull on material, HIGH_VISCOSE dry clean designer color: celeste blue imported',
#  'light-blue, navy and off-white jersey pull on material, HIGH_VISCOSE dry clean designer color: celeste blue imported',
#  'light-blue, navy and off-white jersey pull on material, HIGH_VISCOSE dry clean designer color: celeste blue imported',
# ...
#  "zeynep arçay's pants are crafted from genuine leather, with a flattering high-waisted fit, a full length leg, and a slim silhouette. pair yours with the brand's wrap leather blazer to mirror the fall winter NUMERICAL_VALUE  lookbook style.",
#  "zeynep arçay's pants are crafted from genuine leather, with a flattering high-waisted fit, a full length leg, and a slim silhouette. pair yours with the brand's wrap leather blazer to mirror the fall winter NUMERICAL_VALUE  lookbook style.",
#  "zeynep arçay's pants are crafted from genuine leather, with a flattering high-waisted fit, a full length leg, and a slim silhouette. pair yours with the brand's wrap leather blazer to mirror the fall winter NUMERICAL_VALUE  lookbook style.",
#  'supple faux leather brings glamorous edge to these tailored shorts.',
#  'supple faux leather brings glamorous edge to these tailored shorts.',
#  'supple faux leather brings glamorous edge to these tailored shorts.',
#  'supple faux leather brings glamorous edge to these tailored shorts.',
#  'cigarette pants cut from gingham for a blithe look.',
#  'cigarette pants cut from gingham for a blithe look.',
#  'cigarette pants cut from gingham for a blithe look.',
#  'cigarette pants cut from gingham for a blithe look.',
#  'throw-back to a cropped t-shirt with fine ribbed texture and back seam detail.',
#  'throw-back to a cropped t-shirt with fine ribbed texture and back seam detail.',
#  'throw-back to a cropped t-shirt with fine ribbed texture and back seam detail.',
#  'throw-back to a cropped t-shirt with fine ribbed texture and back seam detail.',
#  "partow's crepe 'everly' midi skirt is tailored to a high-rise fit. designed with an a-line silhouette, its fluid shape is detailed with concealed front pockets and relaxed pleats. style with the matching dress to complete the look.",
#  "partow's crepe 'everly' midi skirt is tailored to a high-rise fit. designed with an a-line silhouette, its fluid shape is detailed with concealed front pockets and relaxed pleats. style with the matching dress to complete the look.",
#  "partow's crepe 'everly' midi skirt is tailored to a high-rise fit. designed with an a-line silhouette, its fluid shape is detailed with concealed front pockets and relaxed pleats. style with the matching dress to complete the look.",
#  "partow's crepe 'everly' midi skirt is tailored to a high-rise fit. designed with an a-line silhouette, its fluid shape is detailed with concealed front pockets and relaxed pleats. style with the matching dress to complete the look.",
#  "between the shoulder-baring design and airy cotton handle, cult gaia's 'claire' top is perfectly suited for the warm-weather months. this long-sleeve style has a tie-detailed front and tiered puffed sleeves that fall in a knuckle-grazing length. highlight the split hem with high-rise shorts.",
#  "between the shoulder-baring design and airy cotton handle, cult gaia's 'claire' top is perfectly suited for the warm-weather months. this long-sleeve style has a tie-detailed front and tiered puffed sleeves that fall in a knuckle-grazing length. highlight the split hem with high-rise shorts.",
#  "between the shoulder-baring design and airy cotton handle, cult gaia's 'claire' top is perfectly suited for the warm-weather months. this long-sleeve style has a tie-detailed front and tiered puffed sleeves that fall in a knuckle-grazing length. highlight the split hem with high-rise shorts.",
#  "between the shoulder-baring design and airy cotton handle, cult gaia's 'claire' top is perfectly suited for the warm-weather months. this long-sleeve style has a tie-detailed front and tiered puffed sleeves that fall in a knuckle-grazing length. highlight the split hem with high-rise shorts.",
#  "between the shoulder-baring design and airy cotton handle, cult gaia's 'claire' top is perfectly suited for the warm-weather months. this long-sleeve style has a tie-detailed front and tiered puffed sleeves that fall in a knuckle-grazing length. highlight the split hem with high-rise shorts.",
#  "between the shoulder-baring design and airy cotton handle, cult gaia's 'claire' top is perfectly suited for the warm-weather months. this long-sleeve style has a tie-detailed front and tiered puffed sleeves that fall in a knuckle-grazing length. highlight the split hem with high-rise shorts.",
#  "between the shoulder-baring design and airy cotton handle, cult gaia's 'claire' top is perfectly suited for the warm-weather months. this long-sleeve style has a tie-detailed front and tiered puffed sleeves that fall in a knuckle-grazing length. highlight the split hem with high-rise shorts.",
#  "between the shoulder-baring design and airy cotton handle, cult gaia's 'claire' top is perfectly suited for the warm-weather months. this long-sleeve style has a tie-detailed front and tiered puffed sleeves that fall in a knuckle-grazing length. highlight the split hem with high-rise shorts.",
#  "isabel marant's 'welly' shirt is cut for an oversized fit, which is enhanced by this season's prominent shoulder. it's made from cotton-poplin in a striped motif and draped with a scarf-inspired cowl neck. style with a tapered wool trouser to complement its tailoring.",
#  "isabel marant's 'welly' shirt is cut for an oversized fit, which is enhanced by this season's prominent shoulder. it's made from cotton-poplin in a striped motif and draped with a scarf-inspired cowl neck. style with a tapered wool trouser to complement its tailoring.",
#  "isabel marant's 'welly' shirt is cut for an oversized fit, which is enhanced by this season's prominent shoulder. it's made from cotton-poplin in a striped motif and draped with a scarf-inspired cowl neck. style with a tapered wool trouser to complement its tailoring.",
#  "isabel marant's 'welly' shirt is cut for an oversized fit, which is enhanced by this season's prominent shoulder. it's made from cotton-poplin in a striped motif and draped with a scarf-inspired cowl neck. style with a tapered wool trouser to complement its tailoring.",
#  'heel measures approximately NUMERICAL_VALUE mm/ NUMERICAL_VALUE  inches clear pvc, beige suede (calf) elasticated slingback strap  designer color: nude  made in italysmall to size. see size & fit notes.',
#  'heel measures approximately NUMERICAL_VALUE mm/ NUMERICAL_VALUE  inches clear pvc, beige suede (calf) elasticated slingback strap  designer color: nude  made in italysmall to size. see size & fit notes.',
#  "biker jackets are a simple way to elevate your casual edit. grlfrnd's 'charlie' rendition is crafted from textured leather and detailed with of functional silver-tone zip fastenings and a buckled belt to cinch the boxy shape. complement the cropped hem with high-rise jeans.",
#  "biker jackets are a simple way to elevate your casual edit. grlfrnd's 'charlie' rendition is crafted from textured leather and detailed with of functional silver-tone zip fastenings and a buckled belt to cinch the boxy shape. complement the cropped hem with high-rise jeans.",
#  "biker jackets are a simple way to elevate your casual edit. grlfrnd's 'charlie' rendition is crafted from textured leather and detailed with of functional silver-tone zip fastenings and a buckled belt to cinch the boxy shape. complement the cropped hem with high-rise jeans.",
#  "biker jackets are a simple way to elevate your casual edit. grlfrnd's 'charlie' rendition is crafted from textured leather and detailed with of functional silver-tone zip fastenings and a buckled belt to cinch the boxy shape. complement the cropped hem with high-rise jeans.",
#  "biker jackets are a simple way to elevate your casual edit. grlfrnd's 'charlie' rendition is crafted from textured leather and detailed with of functional silver-tone zip fastenings and a buckled belt to cinch the boxy shape. complement the cropped hem with high-rise jeans.",
#  "biker jackets are a simple way to elevate your casual edit. grlfrnd's 'charlie' rendition is crafted from textured leather and detailed with of functional silver-tone zip fastenings and a buckled belt to cinch the boxy shape. complement the cropped hem with high-rise jeans.",
#  "biker jackets are a simple way to elevate your casual edit. grlfrnd's 'charlie' rendition is crafted from textured leather and detailed with of functional silver-tone zip fastenings and a buckled belt to cinch the boxy shape. complement the cropped hem with high-rise jeans.",
#  "biker jackets are a simple way to elevate your casual edit. grlfrnd's 'charlie' rendition is crafted from textured leather and detailed with of functional silver-tone zip fastenings and a buckled belt to cinch the boxy shape. complement the cropped hem with high-rise jeans.",
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'antique-rose silk-satin slips on HIGH_SILK dry clean designer color: wood rose',
#  'antique-rose silk-satin slips on HIGH_SILK dry clean designer color: wood rose',
#  'antique-rose silk-satin slips on HIGH_SILK dry clean designer color: wood rose',
#  'antique-rose silk-satin slips on HIGH_SILK dry clean designer color: wood rose',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  "detailed with a contrasting strap along the ankle, dorothee schumacher's 'mirror touch' pointed toe booties are crafted from leather with a metallic finish and a stiletto heel. add a twist to a classic look by wearing yours with tailored pants and a structured jacket.",
#  "detailed with a contrasting strap along the ankle, dorothee schumacher's 'mirror touch' pointed toe booties are crafted from leather with a metallic finish and a stiletto heel. add a twist to a classic look by wearing yours with tailored pants and a structured jacket.",
#  "detailed with a contrasting strap along the ankle, dorothee schumacher's 'mirror touch' pointed toe booties are crafted from leather with a metallic finish and a stiletto heel. add a twist to a classic look by wearing yours with tailored pants and a structured jacket.",
#  "detailed with a contrasting strap along the ankle, dorothee schumacher's 'mirror touch' pointed toe booties are crafted from leather with a metallic finish and a stiletto heel. add a twist to a classic look by wearing yours with tailored pants and a structured jacket.",
#  "detailed with a contrasting strap along the ankle, dorothee schumacher's 'mirror touch' pointed toe booties are crafted from leather with a metallic finish and a stiletto heel. add a twist to a classic look by wearing yours with tailored pants and a structured jacket.",
#  "detailed with a contrasting strap along the ankle, dorothee schumacher's 'mirror touch' pointed toe booties are crafted from leather with a metallic finish and a stiletto heel. add a twist to a classic look by wearing yours with tailored pants and a structured jacket.",
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  "whether you're headed to a farmhouse veranda or an urban terrace, the modern prairie appeal of this lacy cotton maxi dress will be most welcome.",
#  "whether you're headed to a farmhouse veranda or an urban terrace, the modern prairie appeal of this lacy cotton maxi dress will be most welcome.",
#  "whether you're headed to a farmhouse veranda or an urban terrace, the modern prairie appeal of this lacy cotton maxi dress will be most welcome.",
#  "whether you're headed to a farmhouse veranda or an urban terrace, the modern prairie appeal of this lacy cotton maxi dress will be most welcome.",
#  "whether you're headed to a farmhouse veranda or an urban terrace, the modern prairie appeal of this lacy cotton maxi dress will be most welcome.",
#  "whether you're headed to a farmhouse veranda or an urban terrace, the modern prairie appeal of this lacy cotton maxi dress will be most welcome.",
#  "perfect for the workday and beyond, victoria beckham's modest dress is designed with drop sleeves and a knee-length hem. this relaxed style is detailed with contrast piping along the front and back— coordinate yours with burgundy ankle boots.",
#  "perfect for the workday and beyond, victoria beckham's modest dress is designed with drop sleeves and a knee-length hem. this relaxed style is detailed with contrast piping along the front and back— coordinate yours with burgundy ankle boots.",
#  "perfect for the workday and beyond, victoria beckham's modest dress is designed with drop sleeves and a knee-length hem. this relaxed style is detailed with contrast piping along the front and back— coordinate yours with burgundy ankle boots.",
#  "perfect for the workday and beyond, victoria beckham's modest dress is designed with drop sleeves and a knee-length hem. this relaxed style is detailed with contrast piping along the front and back— coordinate yours with burgundy ankle boots.",
#  "perfect for the workday and beyond, victoria beckham's modest dress is designed with drop sleeves and a knee-length hem. this relaxed style is detailed with contrast piping along the front and back— coordinate yours with burgundy ankle boots.",
#  "perfect for the workday and beyond, victoria beckham's modest dress is designed with drop sleeves and a knee-length hem. this relaxed style is detailed with contrast piping along the front and back— coordinate yours with burgundy ankle boots.",
#  "bouguessa's classic blazer is designed with a v-neckline, pocket flaps, and a belted waist. pair yours with the matching pants to create the ultimate power suit.",
#  "bouguessa's classic blazer is designed with a v-neckline, pocket flaps, and a belted waist. pair yours with the matching pants to create the ultimate power suit.",
#  "bouguessa's classic blazer is designed with a v-neckline, pocket flaps, and a belted waist. pair yours with the matching pants to create the ultimate power suit.",
#  "bouguessa's classic blazer is designed with a v-neckline, pocket flaps, and a belted waist. pair yours with the matching pants to create the ultimate power suit.",
#  'carry your essentials in style with this rich leather briefcase on a removable crossbody strap.',
#  'carry your essentials in style with this rich leather briefcase on a removable crossbody strap.',
#  'carry your essentials in style with this rich leather briefcase on a removable crossbody strap.',
#  'carry your essentials in style with this rich leather briefcase on a removable crossbody strap.',
#  "loveshackfancy's 'queenie' ultra-feminine silk dress is designed with a ruffled hemline and an all-over floral print. pair yours with minimalist accessories to keep the dress in focus.",
#  "loveshackfancy's 'queenie' ultra-feminine silk dress is designed with a ruffled hemline and an all-over floral print. pair yours with minimalist accessories to keep the dress in focus.",
#  "loveshackfancy's 'queenie' ultra-feminine silk dress is designed with a ruffled hemline and an all-over floral print. pair yours with minimalist accessories to keep the dress in focus.",
#  "loveshackfancy's 'queenie' ultra-feminine silk dress is designed with a ruffled hemline and an all-over floral print. pair yours with minimalist accessories to keep the dress in focus.",
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  "cinched at the waist to accentuate your natural curves, loveshackfancy's 'cheyenne' cotton skirt is designed with a floral print and a fitted waist. pair yours with a sweater for a fun transitional look.",
#  "cinched at the waist to accentuate your natural curves, loveshackfancy's 'cheyenne' cotton skirt is designed with a floral print and a fitted waist. pair yours with a sweater for a fun transitional look.",
#  "cinched at the waist to accentuate your natural curves, loveshackfancy's 'cheyenne' cotton skirt is designed with a floral print and a fitted waist. pair yours with a sweater for a fun transitional look.",
#  "cinched at the waist to accentuate your natural curves, loveshackfancy's 'cheyenne' cotton skirt is designed with a floral print and a fitted waist. pair yours with a sweater for a fun transitional look.",
#  'cream silk-satin pull on HIGH_SILK dry clean made in france',
#  'cream silk-satin pull on HIGH_SILK dry clean made in france',
#  ...]

# %%
def word_count(lines, delimiter = " "):
    words = Counter()
    for line in lines:
        line = line.lower()
        for word in line.split(delimiter):
            words[word] += 1
    return words

# %%
count = word_count(no_numeric_description)
count_sort = sorted((value, key) for (key, value) in count.items())[::-1]

# %%
stopword = set(stopwords.words('english'))
count_sorted_set = set(pd.DataFrame(count_sort[:500])[1])
count_sorted_set.difference_update(stopword)
count_sorted_set
# Out:
# {'',
#  '\r\n',
#  '\r\n\r\nbody:',
#  '"',
#  '")',
#  '&',
#  "'",
#  "'numerical_value",
#  '(numerical_value',
#  ',',
#  '-',
#  '/numerical_value',
#  'across',
#  'add',
#  'added',
#  'adds',
#  'adjustable',
#  'allover',
#  'along',
#  'also',
#  'ankle',
#  'approximately',
#  'around',
#  'available',
#  'back',
#  'back.',
#  'bag',
#  'belt',
#  'best',
#  'black',
#  'blazer',
#  'blend',
#  'blouse',
#  'blue',
#  'body',
#  'bold',
#  'boot',
#  'boots',
#  "brand's",
#  'breathable',
#  'bring',
#  'brings',
#  'button',
#  'button-down',
#  'buttons',
#  'care',
#  'cashmere',
#  'casual',
#  'center',
#  'chest',
#  'chic',
#  'chunky',
#  'classic',
#  'clean',
#  'closure',
#  'closure.',
#  'cm',
#  'coat',
#  'collar',
#  'collar.',
#  'collection',
#  'collection.',
#  'color',
#  'color:',
#  'colors',
#  'comes',
#  'comfort',
#  'comfort.',
#  'comfortable',
#  'comfy',
#  'complete',
#  'concealed',
#  'construction',
#  'contrast',
#  'contrasting',
#  'cool',
#  'cotton',
#  'cotton-blend',
#  'cotton.',
#  'cozy',
#  'crafted',
#  'create',
#  'crepe',
#  'crew',
#  'crewneck',
#  'crisp',
#  'cropped',
#  'crossbody',
#  'cuffs',
#  'cuffs.',
#  'cut',
#  'dark',
#  'day',
#  'delicate',
#  'denim',
#  'depth:\r\n',
#  'design',
#  'design,',
#  'design.',
#  'designed',
#  'designer',
#  'detail',
#  'detail.',
#  'detailed',
#  'detailing',
#  'details',
#  'double',
#  'drawstring',
#  'dress',
#  'drop:\r\n',
#  'dry',
#  'easy',
#  'edge',
#  'effortless',
#  'elastic',
#  'elegant',
#  'elevated',
#  'embroidered',
#  'engineered',
#  'enough',
#  'essential',
#  'even',
#  'every',
#  'everyday',
#  'everything',
#  'extra',
#  'eye',
#  'fabric',
#  'fall',
#  'fastening',
#  'fastenings',
#  'faux',
#  'favorite',
#  'feature',
#  'features',
#  'featuring',
#  'feel',
#  'feel.',
#  'feminine',
#  'fine',
#  'finish',
#  'finish.',
#  'finished',
#  'first',
#  'fit',
#  'fit,',
#  'fit.',
#  'fitted',
#  'flap',
#  'flat',
#  'flattering',
#  'floral',
#  'fly',
#  'formula',
#  'fresh',
#  'front',
#  'front.',
#  'full',
#  'fully',
#  'fun',
#  'get',
#  'give',
#  'gives',
#  'gold',
#  'graphic',
#  'great',
#  'hand',
#  'handle',
#  'heel',
#  'heel.',
#  'height:\r\n',
#  'hem',
#  'hem.',
#  'high',
#  'high-rise',
#  'high-waisted',
#  'high_cotton',
#  'high_polyester',
#  'hips',
#  'hoodie',
#  'iconic',
#  'ideal',
#  'imported',
#  'in,',
#  'in;',
#  'inches',
#  'inspired',
#  'instant',
#  'interior',
#  'italian',
#  'italy',
#  'it’s',
#  'jacket',
#  'japanese',
#  'jean',
#  'jeans',
#  'jersey',
#  'keep',
#  'knit',
#  'lace',
#  'layer',
#  'leather',
#  'leather,',
#  'leather.',
#  'leg',
#  'lend',
#  'lends',
#  'length',
#  'length:',
#  'light',
#  'lightweight',
#  'like',
#  'lined',
#  'linen',
#  'lining:',
#  'little',
#  'logo',
#  'long',
#  'look',
#  'look.',
#  'looks',
#  'love',
#  'luxe',
#  'luxurious',
#  'machine',
#  'made',
#  'make',
#  'makes',
#  'matching',
#  'material,',
#  'material:\r\n',
#  'material;',
#  'measurements:\r\n',
#  'measures',
#  'median_polyester',
#  'medium',
#  'merino',
#  'mesh',
#  'metal',
#  'metallic',
#  'midi',
#  'mini',
#  'minimalist',
#  'mm/',
#  'model',
#  'modern',
#  'natural',
#  'neck',
#  'neck.',
#  'neckline',
#  'need',
#  'never',
#  'new',
#  'numerical_value',
#  'offers',
#  'one',
#  'open',
#  'oversized',
#  'oz.',
#  'pair',
#  'pant',
#  'pants',
#  'patch',
#  'pattern',
#  'perfect',
#  'perfectly',
#  'piece',
#  'pieces',
#  'pima',
#  'plaid',
#  'playful',
#  'plus,',
#  'plush',
#  'pocket',
#  'pockets',
#  'pockets,',
#  'pockets.',
#  'polished',
#  'polo',
#  'premium',
#  'pretty',
#  'print',
#  'print.',
#  'printed',
#  'pullover',
#  'refined',
#  'relaxed',
#  'ribbed',
#  'rich',
#  'right',
#  'rise',
#  'rise,',
#  'rubber',
#  'ruffled',
#  's.',
#  'saks.',
#  'sandal',
#  'sandals',
#  'satin',
#  'scarf',
#  'seams',
#  'set',
#  'shape',
#  'shirt',
#  'shoe',
#  'short',
#  'shorts',
#  'shoulder',
#  'side',
#  'signature',
#  'silhouette',
#  'silhouette,',
#  'silhouette.',
#  'silk',
#  'silver',
#  'simple',
#  'since',
#  'size',
#  'skin',
#  'skinny',
#  'skirt',
#  'skirt.',
#  'sleek',
#  'sleeve',
#  'sleeves',
#  'sleeves,',
#  'sleeves.',
#  'slightly',
#  'slim',
#  'slip',
#  'slips',
#  'small',
#  'smooth',
#  'snap',
#  'sneaker',
#  'sneakers',
#  'soft',
#  'soft,',
#  'sole',
#  'sophisticated',
#  'special',
#  'specially',
#  'sporty',
#  'square',
#  'stainless',
#  'staple',
#  'statement',
#  'steel',
#  'straight',
#  'strap',
#  'straps',
#  'stretch',
#  'stripe',
#  'striped',
#  'stripes',
#  'structured',
#  'style',
#  'style.',
#  'styled',
#  'styling',
#  'styling.',
#  'stylish',
#  'subtle',
#  'suede',
#  'suit',
#  'summer',
#  'sunglasses',
#  'super',
#  'sweater',
#  'sweatshirt',
#  't-shirt',
#  'tailored',
#  'take',
#  'tall',
#  'tapered',
#  'tee',
#  'texture',
#  'textured',
#  'thanks',
#  "that's",
#  "they're",
#  'tie',
#  'timeless',
#  'toe',
#  'tonal',
#  'top',
#  'touch',
#  'traditional',
#  'trim',
#  'trim.',
#  'trousers',
#  'true',
#  'twill',
#  'two',
#  'ultimate',
#  'unique',
#  'updated',
#  'use',
#  'vegan',
#  'velvet',
#  'versatile',
#  'version',
#  'vibrant',
#  'vintage',
#  'waist',
#  'waist,',
#  'waist.',
#  'waistband',
#  'wardrobe',
#  'warm',
#  'wash',
#  'wash.',
#  'washed',
#  'water',
#  'way',
#  'wear',
#  'wearing',
#  'wears',
#  'well',
#  'welt',
#  'white',
#  'wide',
#  'wide-leg',
#  'width:\r\n',
#  'without',
#  'wool',
#  'worn',
#  'woven',
#  'wrap',
#  'x',
#  'yet',
#  'zip',
#  'zipper',
#  '”'}

# %%
updated_stopwords = stopwords.words('english') + [
    '.' , '', 
]

# %%
no_numeric_description
# Out:
# ['black leather (lamb) open top  weighs approximately NUMERICAL_VALUE lbs/ NUMERICAL_VALUE kg imported',
#  "retro-inspired yet current, this stretchy, ribbed bodysuit is based on the slim-fitting clothing that gained popularity in the 'NUMERICAL_VALUE s.",
#  "retro-inspired yet current, this stretchy, ribbed bodysuit is based on the slim-fitting clothing that gained popularity in the 'NUMERICAL_VALUE s.",
#  'black stretch-pima cotton jersey slips on HIGH_PIMA cotton, LOW_ELASTANE hand wash imported',
#  "crafted from supple leather, sally lapointe's pants are cut in a wide-leg silhouette. cinched at the waist with a matching belt, this style looks amazing when paired with your favorite sweater tucked in.",
#  'cream crepe slips on material, material; lining: material, MEDIAN_ACETATE dry clean',
#  'cream crepe slips on material, material; lining: material, MEDIAN_ACETATE dry clean',
#  "crafted from supple leather, sally lapointe's pants are cut in a wide-leg silhouette. cinched at the waist with a matching belt, this style looks amazing when paired with your favorite sweater tucked in.",
#  "crafted from supple leather, sally lapointe's pants are cut in a wide-leg silhouette. cinched at the waist with a matching belt, this style looks amazing when paired with your favorite sweater tucked in.",
#  'heel measures approximately NUMERICAL_VALUE mm/ NUMERICAL_VALUE  inches gold mirrored-leather (calf) buckle-fastening ankle strap come with dust bag made in italy',
#  'heel measures approximately NUMERICAL_VALUE mm/ NUMERICAL_VALUE  inches gold mirrored-leather (calf) buckle-fastening ankle strap come with dust bag made in italy',
#  'clean seams and a towering stacked heel define a polished day-to-night boot.',
#  'chase your summery dreams in this ombré rainbow metallic sandal in a beach-chic design with knotted straps reaching up to wrap the ankle.',
#  'chase your summery dreams in this ombré rainbow metallic sandal in a beach-chic design with knotted straps reaching up to wrap the ankle.',
#  'heel measures approximately NUMERICAL_VALUE mm/ NUMERICAL_VALUE  inches gold mirrored-leather (calf) buckle-fastening ankle strap come with dust bag made in italy',
#  'heel measures approximately NUMERICAL_VALUE mm/ NUMERICAL_VALUE  inches gold mirrored-leather (calf) buckle-fastening ankle strap come with dust bag made in italy',
#  'cream crepe slips on material, material; lining: material, MEDIAN_ACETATE dry clean',
#  'cream crepe slips on material, material; lining: material, MEDIAN_ACETATE dry clean',
#  'camel grain de poudre wool button fastening at front material; buttons: HIGH_WOOL (buffalo) dry clean made in italy',
#  'cream crepe slips on material, material; lining: material, MEDIAN_ACETATE dry clean',
#  'black stretch-pima cotton jersey slips on HIGH_PIMA cotton, LOW_ELASTANE hand wash imported',
#  'clean seams and a towering stacked heel define a polished day-to-night boot.',
#  "a mens-y military-inspired button up that our designers tailored just for the ladies, thanks to a slimmer fit that's super-flattering.",
#  "a mens-y military-inspired button up that our designers tailored just for the ladies, thanks to a slimmer fit that's super-flattering.",
#  'black stretch-pima cotton jersey slips on HIGH_PIMA cotton, LOW_ELASTANE hand wash imported',
#  'fashioned from high-quality materials and designed for comfort, our shoes will keep you on your (stylish) toes. flexible, suede upper. breathable synthetic lining. insole with added stability in the heel. exclusive padding system features memory foam and a cushioned insole designed for all-day comfort. flexible skid-resistant outsole with comfort pod at bottom.',
#  'fashioned from high-quality materials and designed for comfort, our shoes will keep you on your (stylish) toes. flexible, suede upper. breathable synthetic lining. insole with added stability in the heel. exclusive padding system features memory foam and a cushioned insole designed for all-day comfort. flexible skid-resistant outsole with comfort pod at bottom.',
#  'gray cotton-jersey slips on HIGH_COTTON machine wash designer color: tinker',
#  'gray cotton-jersey slips on HIGH_COTTON machine wash designer color: tinker',
#  'gray cotton-jersey slips on HIGH_COTTON machine wash designer color: tinker',
#  'camel grain de poudre wool button fastening at front material; buttons: HIGH_WOOL (buffalo) dry clean made in italy',
#  'black leather (lamb) open top  weighs approximately NUMERICAL_VALUE lbs/ NUMERICAL_VALUE kg imported',
#  'gray cotton-jersey slips on HIGH_COTTON machine wash designer color: tinker',
#  "a mens-y military-inspired button up that our designers tailored just for the ladies, thanks to a slimmer fit that's super-flattering.",
#  "a mens-y military-inspired button up that our designers tailored just for the ladies, thanks to a slimmer fit that's super-flattering.",
#  'wide, channel-quilted straps crisscross a well-padded slide sandal grounded by razored treads.',
#  'multicolored cotton, nylon, merino wool, alpaca, cashmere and mohair-blend slips on material, material, LOW_COTTON wool,material, material, LOW_NYLON dry clean imported',
#  "crafted in italy, golden goose's 'hi star' sneakers are designed with the brand's signature appliqué star and stamped gold-tone logo on textured-leather uppers. set on a platform rubber sole, this pair is complete with suede vamps and handwritten text accents. highlight its chunky heel by pairing yours with a midi-length skirt.",
#  "edgy style and expert craftsmanship combine on a block-heel combat boot that's cut, sewn and lasted by hand by spanish artisans.",
#  'ready for a stroll on a private beach, this flat sandal is styled with crisscrossing straps of braided raffia.',
#  'we’re suckers for a pretty statement top. which is exactly how we landed on this tee and its ladylike twists. it fits and feels like your favorite t-shirt (you can thank the soft cotton jersey for that), but it’s perked up with high-volume poplin sleeves that gather gracefully toward the cuffs (yes to statement shoulders). and here’s the best news: you can treat it like all your other tees and wear it with every single pair of jeans, trousers, and shorts you own.material clean onlymade in italymeasurements (from size NUMERICAL_VALUE ): length: NUMERICAL_VALUE  NUMERICAL_VALUE /NUMERICAL_VALUE "; chest: NUMERICAL_VALUE  NUMERICAL_VALUE /NUMERICAL_VALUE "model is NUMERICAL_VALUE ’NUMERICAL_VALUE " with NUMERICAL_VALUE " bust, NUMERICAL_VALUE " waist, NUMERICAL_VALUE " hips and wearing a size NUMERICAL_VALUE ',
#  'ready for a stroll on a private beach, this flat sandal is styled with crisscrossing straps of braided raffia.',
#  "as enchanting as cinderella's glass slipper, but much more wearable, this graceful italian sandal is styled with transparent straps.",
#  'we’re suckers for a pretty statement top. which is exactly how we landed on this tee and its ladylike twists. it fits and feels like your favorite t-shirt (you can thank the soft cotton jersey for that), but it’s perked up with high-volume poplin sleeves that gather gracefully toward the cuffs (yes to statement shoulders). and here’s the best news: you can treat it like all your other tees and wear it with every single pair of jeans, trousers, and shorts you own.material clean onlymade in italymeasurements (from size NUMERICAL_VALUE ): length: NUMERICAL_VALUE  NUMERICAL_VALUE /NUMERICAL_VALUE "; chest: NUMERICAL_VALUE  NUMERICAL_VALUE /NUMERICAL_VALUE "model is NUMERICAL_VALUE ’NUMERICAL_VALUE " with NUMERICAL_VALUE " bust, NUMERICAL_VALUE " waist, NUMERICAL_VALUE " hips and wearing a size NUMERICAL_VALUE ',
#  'a lean and lengthening silhouette with one-button closure to accentuate the waist. notch lapel. long sleeves with one-button cuffs. two exterior pockets. center-back vent. fully lined with stretch lining for comfort and ease of movement.',
#  'a lean and lengthening silhouette with one-button closure to accentuate the waist. notch lapel. long sleeves with one-button cuffs. two exterior pockets. center-back vent. fully lined with stretch lining for comfort and ease of movement.',
#  "edgy style and expert craftsmanship combine on a block-heel combat boot that's cut, sewn and lasted by hand by spanish artisans.",
#  'a lean and lengthening silhouette with one-button closure to accentuate the waist. notch lapel. long sleeves with one-button cuffs. two exterior pockets. center-back vent. fully lined with stretch lining for comfort and ease of movement.',
#  'a lean and lengthening silhouette with one-button closure to accentuate the waist. notch lapel. long sleeves with one-button cuffs. two exterior pockets. center-back vent. fully lined with stretch lining for comfort and ease of movement.',
#  "nobody denim's 'true' jeans are designed with pre-cuffed hems, saving you time from finding the perfect length. crafted in a medium wash, this style is fashioned with a mid-rise waist and the brand's logo stitching on the back right pocket. couple this skinny style with a puffed sleeve blouse to add volume.",
#  "nobody denim's 'true' jeans are designed with pre-cuffed hems, saving you time from finding the perfect length. crafted in a medium wash, this style is fashioned with a mid-rise waist and the brand's logo stitching on the back right pocket. couple this skinny style with a puffed sleeve blouse to add volume.",
#  "nobody denim's 'true' jeans are designed with pre-cuffed hems, saving you time from finding the perfect length. crafted in a medium wash, this style is fashioned with a mid-rise waist and the brand's logo stitching on the back right pocket. couple this skinny style with a puffed sleeve blouse to add volume.",
#  'these ivory jeans can be as dressed up or toned down as you need them to be. they have a straight-leg fit that’s skinny, but not constricting, with a super-flattering, leg-elongating silhouette that falls just past the ankles—meaning they work equally well with a block-heeled boot (for the office) or low-top sneakers (for kicking around).material washmade in the usamodel is NUMERICAL_VALUE ’NUMERICAL_VALUE ” with NUMERICAL_VALUE " bust, NUMERICAL_VALUE " waist, NUMERICAL_VALUE " hips and wearing a size NUMERICAL_VALUE ',
#  "crafted from supple leather, sally lapointe's pants are cut in a wide-leg silhouette. cinched at the waist with a matching belt, this style looks amazing when paired with your favorite sweater tucked in.",
#  'heel measures approximately NUMERICAL_VALUE mm/ NUMERICAL_VALUE  inches cream leather (lamb) slip on  designer color: buttercream  made in italysmall to size. see size & fit notes.',
#  'heel measures approximately NUMERICAL_VALUE mm/ NUMERICAL_VALUE  inches cream leather (lamb) slip on  designer color: buttercream  made in italysmall to size. see size & fit notes.',
#  'heel measures approximately NUMERICAL_VALUE mm/ NUMERICAL_VALUE  inches cream leather (lamb) slip on  designer color: buttercream  made in italysmall to size. see size & fit notes.',
#  "derek lam's oversized silk blouse is designed with a self tie scarf at neck, long cuffed sleeves and a high-low hemline.",
#  "introducing suiting for the first time, re/done based these cropped flare trousers on a vintage pair from the 'NUMERICAL_VALUE s and had them handmade in italy.",
#  "introducing suiting for the first time, re/done based these cropped flare trousers on a vintage pair from the 'NUMERICAL_VALUE s and had them handmade in italy.",
#  "crafted from supple leather, sally lapointe's pants are cut in a wide-leg silhouette. cinched at the waist with a matching belt, this style looks amazing when paired with your favorite sweater tucked in.",
#  "edgy style and expert craftsmanship combine on a block-heel combat boot that's cut, sewn and lasted by hand by spanish artisans.",
#  'a twinkling crystal brooch crowns the toe strap of a party-ready sandal secured by a slender floating ankle strap.',
#  'a twinkling crystal brooch crowns the toe strap of a party-ready sandal secured by a slender floating ankle strap.',
#  'these ivory jeans can be as dressed up or toned down as you need them to be. they have a straight-leg fit that’s skinny, but not constricting, with a super-flattering, leg-elongating silhouette that falls just past the ankles—meaning they work equally well with a block-heeled boot (for the office) or low-top sneakers (for kicking around).material washmade in the usamodel is NUMERICAL_VALUE ’NUMERICAL_VALUE ” with NUMERICAL_VALUE " bust, NUMERICAL_VALUE " waist, NUMERICAL_VALUE " hips and wearing a size NUMERICAL_VALUE ',
#  "derek lam's oversized silk blouse is designed with a self tie scarf at neck, long cuffed sleeves and a high-low hemline.",
#  'named for its unique double-point pocket design, this denim western shirt is softly faded and detailed with pearly snaps for an authentic vintage look.',
#  'named for its unique double-point pocket design, this denim western shirt is softly faded and detailed with pearly snaps for an authentic vintage look.',
#  'these ivory jeans can be as dressed up or toned down as you need them to be. they have a straight-leg fit that’s skinny, but not constricting, with a super-flattering, leg-elongating silhouette that falls just past the ankles—meaning they work equally well with a block-heeled boot (for the office) or low-top sneakers (for kicking around).material washmade in the usamodel is NUMERICAL_VALUE ’NUMERICAL_VALUE ” with NUMERICAL_VALUE " bust, NUMERICAL_VALUE " waist, NUMERICAL_VALUE " hips and wearing a size NUMERICAL_VALUE ',
#  "designed and curated by minimalistic style icon elin kling, totême provides updated essentials that are effortless to mix and match. ideal for both work and weekends, the high-rise ' ossi' is tailored with a full length and a tailored leg. wear with the matching blazer for a smart look, or keep it casual with an oversized knit and sneakers.",
#  'midnight-blue organic cotton-velour  pull on  HIGH_ORGANIC cotton  machine wash  imported',
#  "designed and curated by minimalistic style icon elin kling, totême provides updated essentials that are effortless to mix and match. ideal for both work and weekends, the high-rise ' ossi' is tailored with a full length and a tailored leg. wear with the matching blazer for a smart look, or keep it casual with an oversized knit and sneakers.",
#  'tan leather (calf) magnetic-fastening front flap weighs approximately NUMERICAL_VALUE lbs/ NUMERICAL_VALUE kg made in italy',
#  "as enchanting as cinderella's glass slipper, but much more wearable, this graceful italian sandal is styled with transparent straps.",
#  "derek lam's oversized silk blouse is designed with a self tie scarf at neck, long cuffed sleeves and a high-low hemline.",
#  "designed and curated by minimalistic style icon elin kling, totême provides updated essentials that are effortless to mix and match. ideal for both work and weekends, the high-rise ' ossi' is tailored with a full length and a tailored leg. wear with the matching blazer for a smart look, or keep it casual with an oversized knit and sneakers.",
#  "derek lam's oversized silk blouse is designed with a self tie scarf at neck, long cuffed sleeves and a high-low hemline.",
#  'croc embossing brings of-the-moment appeal to a double-band sandal finished with gleaming buckles.',
#  'croc embossing brings of-the-moment appeal to a double-band sandal finished with gleaming buckles.',
#  'tan leather (calf) magnetic-fastening front flap weighs approximately NUMERICAL_VALUE lbs/ NUMERICAL_VALUE kg made in italy',
#  "crafted in italy, golden goose's 'hi star' sneakers are designed with the brand's signature appliqué star and stamped gold-tone logo on textured-leather uppers. set on a platform rubber sole, this pair is complete with suede vamps and handwritten text accents. highlight its chunky heel by pairing yours with a midi-length skirt.",
#  'multicolored cotton, nylon, merino wool, alpaca, cashmere and mohair-blend slips on material, material, LOW_COTTON wool,material, material, LOW_NYLON dry clean imported',
#  'black leather (lamb) open top  weighs approximately NUMERICAL_VALUE lbs/ NUMERICAL_VALUE kg imported',
#  'these ivory jeans can be as dressed up or toned down as you need them to be. they have a straight-leg fit that’s skinny, but not constricting, with a super-flattering, leg-elongating silhouette that falls just past the ankles—meaning they work equally well with a block-heeled boot (for the office) or low-top sneakers (for kicking around).material washmade in the usamodel is NUMERICAL_VALUE ’NUMERICAL_VALUE ” with NUMERICAL_VALUE " bust, NUMERICAL_VALUE " waist, NUMERICAL_VALUE " hips and wearing a size NUMERICAL_VALUE ',
#  'a flouncy tie gathers the neckline of this billowy chartreuse dress finished with an attached hem to enhance the flowy movement.',
#  'black and white lyocell partially concealed snap fastenings through front HIGH_LYOCELL dry clean imported',
#  'black and white lyocell partially concealed snap fastenings through front HIGH_LYOCELL dry clean imported',
#  'gray cotton-jersey slips on HIGH_COTTON machine wash designer color: tinker',
#  'these ivory jeans can be as dressed up or toned down as you need them to be. they have a straight-leg fit that’s skinny, but not constricting, with a super-flattering, leg-elongating silhouette that falls just past the ankles—meaning they work equally well with a block-heeled boot (for the office) or low-top sneakers (for kicking around).material washmade in the usamodel is NUMERICAL_VALUE ’NUMERICAL_VALUE ” with NUMERICAL_VALUE " bust, NUMERICAL_VALUE " waist, NUMERICAL_VALUE " hips and wearing a size NUMERICAL_VALUE ',
#  'heel measures approximately NUMERICAL_VALUE mm/ NUMERICAL_VALUE  inches cream leather (lamb) slip on  designer color: buttercream  made in italysmall to size. see size & fit notes.',
#  "designed and curated by minimalistic style icon elin kling, totême provides updated essentials that are effortless to mix and match. ideal for both work and weekends, the high-rise ' ossi' is tailored with a full length and a tailored leg. wear with the matching blazer for a smart look, or keep it casual with an oversized knit and sneakers.",
#  "designed and curated by minimalistic style icon elin kling, totême provides updated essentials that are effortless to mix and match. ideal for both work and weekends, the high-rise ' ossi' is tailored with a full length and a tailored leg. wear with the matching blazer for a smart look, or keep it casual with an oversized knit and sneakers.",
#  'cream and black jersey button fastening keyhole at back material, material; lining: HIGH_VISCOSE dry clean imported',
#  'heel measures approximately NUMERICAL_VALUE mm/ NUMERICAL_VALUE  inches cream leather (lamb) slip on  designer color: buttercream  made in italysmall to size. see size & fit notes.',
#  'cream and black jersey button fastening keyhole at back material, material; lining: HIGH_VISCOSE dry clean imported',
#  'heel measures approximately NUMERICAL_VALUE mm/ NUMERICAL_VALUE  inches cream leather (lamb) slip on  designer color: buttercream  made in italysmall to size. see size & fit notes.',
#  'gray cotton-jersey slips on HIGH_COTTON machine wash designer color: tinker',
#  'midnight-blue organic cotton-velour  pull on  HIGH_ORGANIC cotton  machine wash  imported',
#  'black and white lyocell partially concealed snap fastenings through front HIGH_LYOCELL dry clean imported',
#  'stone stretch-pima cotton pull on HIGH_PIMA cotton, LOW_ELASTANE machine wash imported',
#  'black and white lyocell partially concealed snap fastenings through front HIGH_LYOCELL dry clean imported',
#  'this silhouette of a poised cap-toe pump gets a vacation update with a platform and wedge heel wrapped in braided jute.',
#  'stone stretch-pima cotton pull on HIGH_PIMA cotton, LOW_ELASTANE machine wash imported',
#  'heel measures approximately NUMERICAL_VALUE mm/ NUMERICAL_VALUE  inches cream leather (lamb) slip on  designer color: buttercream  made in italysmall to size. see size & fit notes.',
#  'this pleat-neck top—made in italy from paper-thin poplin—is a shirting unicorn: it’s got the beauty of your best-loved blouse (thanks to those pretty front pleats and intricate knot detailing at the collar) and the brains of your favorite tee (relaxed shape, roomy sleeves). oh, and the incognito buttons in back are the nicest of touches.\xa0material clean onlymade in italymeasurements (from size NUMERICAL_VALUE ): NUMERICAL_VALUE " chest, NUMERICAL_VALUE " sleeve length, NUMERICAL_VALUE " body lengthmodel is NUMERICAL_VALUE ’NUMERICAL_VALUE ” with NUMERICAL_VALUE " bust, NUMERICAL_VALUE " waist, NUMERICAL_VALUE " hips and wearing a size NUMERICAL_VALUE ',
#  'this pleat-neck top—made in italy from paper-thin poplin—is a shirting unicorn: it’s got the beauty of your best-loved blouse (thanks to those pretty front pleats and intricate knot detailing at the collar) and the brains of your favorite tee (relaxed shape, roomy sleeves). oh, and the incognito buttons in back are the nicest of touches.\xa0material clean onlymade in italymeasurements (from size NUMERICAL_VALUE ): NUMERICAL_VALUE " chest, NUMERICAL_VALUE " sleeve length, NUMERICAL_VALUE " body lengthmodel is NUMERICAL_VALUE ’NUMERICAL_VALUE ” with NUMERICAL_VALUE " bust, NUMERICAL_VALUE " waist, NUMERICAL_VALUE " hips and wearing a size NUMERICAL_VALUE ',
#  'this silhouette of a poised cap-toe pump gets a vacation update with a platform and wedge heel wrapped in braided jute.',
#  'this pleat-neck top—made in italy from paper-thin poplin—is a shirting unicorn: it’s got the beauty of your best-loved blouse (thanks to those pretty front pleats and intricate knot detailing at the collar) and the brains of your favorite tee (relaxed shape, roomy sleeves). oh, and the incognito buttons in back are the nicest of touches.\xa0material clean onlymade in italymeasurements (from size NUMERICAL_VALUE ): NUMERICAL_VALUE " chest, NUMERICAL_VALUE " sleeve length, NUMERICAL_VALUE " body lengthmodel is NUMERICAL_VALUE ’NUMERICAL_VALUE ” with NUMERICAL_VALUE " bust, NUMERICAL_VALUE " waist, NUMERICAL_VALUE " hips and wearing a size NUMERICAL_VALUE ',
#  'this pleat-neck top—made in italy from paper-thin poplin—is a shirting unicorn: it’s got the beauty of your best-loved blouse (thanks to those pretty front pleats and intricate knot detailing at the collar) and the brains of your favorite tee (relaxed shape, roomy sleeves). oh, and the incognito buttons in back are the nicest of touches.\xa0material clean onlymade in italymeasurements (from size NUMERICAL_VALUE ): NUMERICAL_VALUE " chest, NUMERICAL_VALUE " sleeve length, NUMERICAL_VALUE " body lengthmodel is NUMERICAL_VALUE ’NUMERICAL_VALUE ” with NUMERICAL_VALUE " bust, NUMERICAL_VALUE " waist, NUMERICAL_VALUE " hips and wearing a size NUMERICAL_VALUE ',
#  'anything leopard tends to automatically fall in the “chic” category. but when you factor in la double j’s romantic touches, like those frilly flutter sleeves and that stunning, almost architectural standing collar, and this italian-made crepe dress becomes something else entirely. oh, and that knee-length cut means it’s just as office appropriate as it is date-night friendly. and it’s just as pretty from the back (you can thank the tie-up detail for that).material, HIGH_VISCOSE cleanmade in italymodel is NUMERICAL_VALUE ’NUMERICAL_VALUE ” with NUMERICAL_VALUE " bust, NUMERICAL_VALUE " waist, NUMERICAL_VALUE " hips and wearing a size\xa0xs',
#  'this silhouette of a poised cap-toe pump gets a vacation update with a platform and wedge heel wrapped in braided jute.',
#  "nobody denim's 'true' jeans are designed with pre-cuffed hems, saving you time from finding the perfect length. crafted in a medium wash, this style is fashioned with a mid-rise waist and the brand's logo stitching on the back right pocket. couple this skinny style with a puffed sleeve blouse to add volume.",
#  "nobody denim's 'true' jeans are designed with pre-cuffed hems, saving you time from finding the perfect length. crafted in a medium wash, this style is fashioned with a mid-rise waist and the brand's logo stitching on the back right pocket. couple this skinny style with a puffed sleeve blouse to add volume.",
#  "nobody denim's 'true' jeans are designed with pre-cuffed hems, saving you time from finding the perfect length. crafted in a medium wash, this style is fashioned with a mid-rise waist and the brand's logo stitching on the back right pocket. couple this skinny style with a puffed sleeve blouse to add volume.",
#  "aquazzura's 'minute' sandals are crafted from polished leather with ultra-slim straps that secure and frame the foot. this pair will literally take your look to new heights—its set on a slender stiletto heel measuring over four inches.",
#  "aquazzura's 'minute' sandals are crafted from polished leather with ultra-slim straps that secure and frame the foot. this pair will literally take your look to new heights—its set on a slender stiletto heel measuring over four inches.",
#  "just one example of this season's strong tailoring theme, carolina herrera's trousers are cut from a wool and silk blend woven with a classic prince of wales check typically found in men's suiting. this high-waisted pair is fitted through the hips and tapered through the knees before flaring toward the ankles. complete the look with a matching printed jacket.",
#  "just one example of this season's strong tailoring theme, carolina herrera's trousers are cut from a wool and silk blend woven with a classic prince of wales check typically found in men's suiting. this high-waisted pair is fitted through the hips and tapered through the knees before flaring toward the ankles. complete the look with a matching printed jacket.",
#  "designed and curated by minimalistic style icon elin kling, totême provides updated essentials that are effortless to mix and match. ideal for both work and weekends, the high-rise ' ossi' is tailored with a full length and a tailored leg. wear with the matching blazer for a smart look, or keep it casual with an oversized knit and sneakers.",
#  'a drawstring waist and cropped silhouette bring a relaxed, lounge-inspired attitude to pants with a slight sheen, tonal floral pattern and silky feel.',
#  'a drawstring waist and cropped silhouette bring a relaxed, lounge-inspired attitude to pants with a slight sheen, tonal floral pattern and silky feel.',
#  'gray cotton-jersey slips on HIGH_COTTON machine wash designer color: tinker',
#  "aquazzura's 'minute' sandals are crafted from polished leather with ultra-slim straps that secure and frame the foot. this pair will literally take your look to new heights—its set on a slender stiletto heel measuring over four inches.",
#  'a flouncy tie gathers the neckline of this billowy chartreuse dress finished with an attached hem to enhance the flowy movement.',
#  'anything leopard tends to automatically fall in the “chic” category. but when you factor in la double j’s romantic touches, like those frilly flutter sleeves and that stunning, almost architectural standing collar, and this italian-made crepe dress becomes something else entirely. oh, and that knee-length cut means it’s just as office appropriate as it is date-night friendly. and it’s just as pretty from the back (you can thank the tie-up detail for that).material, HIGH_VISCOSE cleanmade in italymodel is NUMERICAL_VALUE ’NUMERICAL_VALUE ” with NUMERICAL_VALUE " bust, NUMERICAL_VALUE " waist, NUMERICAL_VALUE " hips and wearing a size\xa0xs',
#  'gleaming studs outline the sole of a retro-inspired slide sandal lofted by a chunky woodgrain heel and platform.',
#  "just one example of this season's strong tailoring theme, carolina herrera's trousers are cut from a wool and silk blend woven with a classic prince of wales check typically found in men's suiting. this high-waisted pair is fitted through the hips and tapered through the knees before flaring toward the ankles. complete the look with a matching printed jacket.",
#  "just one example of this season's strong tailoring theme, carolina herrera's trousers are cut from a wool and silk blend woven with a classic prince of wales check typically found in men's suiting. this high-waisted pair is fitted through the hips and tapered through the knees before flaring toward the ankles. complete the look with a matching printed jacket.",
#  'black ribbed-knit slips on material, material, material, MEDIAN_WOOL dry clean imported',
#  'black ribbed-knit slips on material, material, material, MEDIAN_WOOL dry clean imported',
#  'gleaming studs outline the sole of a retro-inspired slide sandal lofted by a chunky woodgrain heel and platform.',
#  'breezy wide leg pants are designed with a glamorous sweeping silhouette in fluid silk.',
#  'breezy wide leg pants are designed with a glamorous sweeping silhouette in fluid silk.',
#  "aquazzura's 'minute' sandals are crafted from polished leather with ultra-slim straps that secure and frame the foot. this pair will literally take your look to new heights—its set on a slender stiletto heel measuring over four inches.",
#  'beige washed stretch-silk satin slips on material, HIGH_SILK hand wash designer color: fawn imported',
#  'beige washed stretch-silk satin slips on material, HIGH_SILK hand wash designer color: fawn imported',
#  'we’re suckers for a pretty statement top. which is exactly how we landed on this tee and its ladylike twists. it fits and feels like your favorite t-shirt (you can thank the soft cotton jersey for that), but it’s perked up with high-volume poplin sleeves that gather gracefully toward the cuffs (yes to statement shoulders). and here’s the best news: you can treat it like all your other tees and wear it with every single pair of jeans, trousers, and shorts you own.material clean onlymade in italymeasurements (from size NUMERICAL_VALUE ): length: NUMERICAL_VALUE  NUMERICAL_VALUE /NUMERICAL_VALUE "; chest: NUMERICAL_VALUE  NUMERICAL_VALUE /NUMERICAL_VALUE "model is NUMERICAL_VALUE ’NUMERICAL_VALUE " with NUMERICAL_VALUE " bust, NUMERICAL_VALUE " waist, NUMERICAL_VALUE " hips and wearing a size NUMERICAL_VALUE ',
#  'we’re suckers for a pretty statement top. which is exactly how we landed on this tee and its ladylike twists. it fits and feels like your favorite t-shirt (you can thank the soft cotton jersey for that), but it’s perked up with high-volume poplin sleeves that gather gracefully toward the cuffs (yes to statement shoulders). and here’s the best news: you can treat it like all your other tees and wear it with every single pair of jeans, trousers, and shorts you own.material clean onlymade in italymeasurements (from size NUMERICAL_VALUE ): length: NUMERICAL_VALUE  NUMERICAL_VALUE /NUMERICAL_VALUE "; chest: NUMERICAL_VALUE  NUMERICAL_VALUE /NUMERICAL_VALUE "model is NUMERICAL_VALUE ’NUMERICAL_VALUE " with NUMERICAL_VALUE " bust, NUMERICAL_VALUE " waist, NUMERICAL_VALUE " hips and wearing a size NUMERICAL_VALUE ',
#  'black ribbed-knit slips on material, material, material, MEDIAN_WOOL dry clean imported',
#  'we’re suckers for a pretty statement top. which is exactly how we landed on this tee and its ladylike twists. it fits and feels like your favorite t-shirt (you can thank the soft cotton jersey for that), but it’s perked up with high-volume poplin sleeves that gather gracefully toward the cuffs (yes to statement shoulders). and here’s the best news: you can treat it like all your other tees and wear it with every single pair of jeans, trousers, and shorts you own.material clean onlymade in italymeasurements (from size NUMERICAL_VALUE ): length: NUMERICAL_VALUE  NUMERICAL_VALUE /NUMERICAL_VALUE "; chest: NUMERICAL_VALUE  NUMERICAL_VALUE /NUMERICAL_VALUE "model is NUMERICAL_VALUE ’NUMERICAL_VALUE " with NUMERICAL_VALUE " bust, NUMERICAL_VALUE " waist, NUMERICAL_VALUE " hips and wearing a size NUMERICAL_VALUE ',
#  'a pointy toe and tapered heel balance the streamlined silhouette of a go-to boot.',
#  'a pointy toe and tapered heel balance the streamlined silhouette of a go-to boot.',
#  'black ribbed-knit slips on material, material, material, MEDIAN_WOOL dry clean imported',
#  'lift your spirits with this double-strap slide sandal perched on a tall block heel and a thick platform for easy gliding.',
#  "as enchanting as cinderella's glass slipper, but much more wearable, this graceful italian sandal is styled with transparent straps.",
#  "the chunky knit and marled hues of this boatneck sweater make it a cold-weather go-to. bonus: the slightly relaxed fit means it'll drape perfectly when you tuck the front into high-waisted pants and jeans.",
#  "the chunky knit and marled hues of this boatneck sweater make it a cold-weather go-to. bonus: the slightly relaxed fit means it'll drape perfectly when you tuck the front into high-waisted pants and jeans.",
#  "the chunky knit and marled hues of this boatneck sweater make it a cold-weather go-to. bonus: the slightly relaxed fit means it'll drape perfectly when you tuck the front into high-waisted pants and jeans.",
#  "edgy style and expert craftsmanship combine on a block-heel combat boot that's cut, sewn and lasted by hand by spanish artisans.",
#  "edgy style and expert craftsmanship combine on a block-heel combat boot that's cut, sewn and lasted by hand by spanish artisans.",
#  "cut from soft camel wool, max mara's chic 'pacos' coat is designed with broad, fringe-trimmed lapels. cinch yours at the waist with the self-tie belt and keep your phone handy in one of the exaggerated patch pockets at the front.",
#  'ivory crepe slips on material, material; buttons: HIGH_ACETATE (cow) dry clean imported',
#  'ivory crepe slips on material, material; buttons: HIGH_ACETATE (cow) dry clean imported',
#  'knotted ties detail the toe strap of an elegant sandal lifted by a covered block heel and tied off with adjustable wraparound straps.',
#  'knotted ties detail the toe strap of an elegant sandal lifted by a covered block heel and tied off with adjustable wraparound straps.',
#  'knotted ties detail the toe strap of an elegant sandal lifted by a covered block heel and tied off with adjustable wraparound straps.',
#  "edgy style and expert craftsmanship combine on a block-heel combat boot that's cut, sewn and lasted by hand by spanish artisans.",
#  'breezy wide leg pants are designed with a glamorous sweeping silhouette in fluid silk.',
#  'multicolored cotton-blend button fastening through front material, material, MEDIAN_COTTON fibers; buttons: LOW_POLYESTER (cow) dry clean',
#  'multicolored cotton-blend button fastening through front material, material, MEDIAN_COTTON fibers; buttons: LOW_POLYESTER (cow) dry clean',
#  'these ivory jeans can be as dressed up or toned down as you need them to be. they have a straight-leg fit that’s skinny, but not constricting, with a super-flattering, leg-elongating silhouette that falls just past the ankles—meaning they work equally well with a block-heeled boot (for the office) or low-top sneakers (for kicking around).material washmade in the usamodel is NUMERICAL_VALUE ’NUMERICAL_VALUE ” with NUMERICAL_VALUE " bust, NUMERICAL_VALUE " waist, NUMERICAL_VALUE " hips and wearing a size NUMERICAL_VALUE ',
#  "the chunky knit and marled hues of this boatneck sweater make it a cold-weather go-to. bonus: the slightly relaxed fit means it'll drape perfectly when you tuck the front into high-waisted pants and jeans.",
#  "the chunky knit and marled hues of this boatneck sweater make it a cold-weather go-to. bonus: the slightly relaxed fit means it'll drape perfectly when you tuck the front into high-waisted pants and jeans.",
#  'breezy wide leg pants are designed with a glamorous sweeping silhouette in fluid silk.',
#  "the chunky knit and marled hues of this boatneck sweater make it a cold-weather go-to. bonus: the slightly relaxed fit means it'll drape perfectly when you tuck the front into high-waisted pants and jeans.",
#  'brown cashmere and mulberry silk-blend slips on material, MEDIAN_CASHMERE silk dry clean designer color: bark imported',
#  'brown cashmere and mulberry silk-blend slips on material, MEDIAN_CASHMERE silk dry clean designer color: bark imported',
#  'brown cashmere and mulberry silk-blend slips on material, MEDIAN_CASHMERE silk dry clean designer color: bark imported',
#  'brown cashmere and mulberry silk-blend slips on material, MEDIAN_CASHMERE silk dry clean designer color: bark imported',
#  'sleek and sculptural, this strappy sandal shines in metallic snakeskin and looks modern with a square toe and a slim block heel.',
#  'sleek and sculptural, this strappy sandal shines in metallic snakeskin and looks modern with a square toe and a slim block heel.',
#  'black leather (lamb) open top  weighs approximately NUMERICAL_VALUE lbs/ NUMERICAL_VALUE kg imported',
#  'gleaming studs outline the sole of a retro-inspired slide sandal lofted by a chunky woodgrain heel and platform.',
#  "we believe that some animal prints double as neutral and these prada pumps are a prime example. designed in a classic leopard motif, they're sleek silhouette ends in a sharp toe that's fitted with cushioned insoles. try styling with wide-leg trousers to give the hem a lift.",
#  'a classic crewneck sweatshirt gets a luxurious update with a supremely soft cotton blend.',
#  'a classic crewneck sweatshirt gets a luxurious update with a supremely soft cotton blend.',
#  "we believe that some animal prints double as neutral and these prada pumps are a prime example. designed in a classic leopard motif, they're sleek silhouette ends in a sharp toe that's fitted with cushioned insoles. try styling with wide-leg trousers to give the hem a lift.",
#  "we believe that some animal prints double as neutral and these prada pumps are a prime example. designed in a classic leopard motif, they're sleek silhouette ends in a sharp toe that's fitted with cushioned insoles. try styling with wide-leg trousers to give the hem a lift.",
#  "we believe that some animal prints double as neutral and these prada pumps are a prime example. designed in a classic leopard motif, they're sleek silhouette ends in a sharp toe that's fitted with cushioned insoles. try styling with wide-leg trousers to give the hem a lift.",
#  "crafted in italy, golden goose's 'hi star' sneakers are designed with the brand's signature appliqué star and stamped gold-tone logo on textured-leather uppers. set on a platform rubber sole, this pair is complete with suede vamps and handwritten text accents. highlight its chunky heel by pairing yours with a midi-length skirt.",
#  'multicolored cotton, nylon, merino wool, alpaca, cashmere and mohair-blend slips on material, material, LOW_COTTON wool,material, material, LOW_NYLON dry clean imported',
#  'a classic crewneck sweatshirt gets a luxurious update with a supremely soft cotton blend.',
#  'a classic crewneck sweatshirt gets a luxurious update with a supremely soft cotton blend.',
#  "we believe that some animal prints double as neutral and these prada pumps are a prime example. designed in a classic leopard motif, they're sleek silhouette ends in a sharp toe that's fitted with cushioned insoles. try styling with wide-leg trousers to give the hem a lift.",
#  'multicolored cotton, nylon, merino wool, alpaca, cashmere and mohair-blend slips on material, material, LOW_COTTON wool,material, material, LOW_NYLON dry clean imported',
#  'a raffia-wrapped platform wedge with hint of metallic shimmer makes this suede, ankle-tie sandal a refined, resort-ready standout.',
#  'a raffia-wrapped platform wedge with hint of metallic shimmer makes this suede, ankle-tie sandal a refined, resort-ready standout.',
#  'a raffia-wrapped platform wedge with hint of metallic shimmer makes this suede, ankle-tie sandal a refined, resort-ready standout.',
#  "we believe that some animal prints double as neutral and these prada pumps are a prime example. designed in a classic leopard motif, they're sleek silhouette ends in a sharp toe that's fitted with cushioned insoles. try styling with wide-leg trousers to give the hem a lift.",
#  ' ',
#  ' ',
#  'camel grain de poudre wool button fastening at front material; buttons: HIGH_WOOL (buffalo) dry clean made in italy',
#  'sinuous straps cross atop a lightly cushioned sandal shaped with a squared-off toe and an architectural block heel.',
#  ' ',
#  ' ',
#  'anything leopard tends to automatically fall in the “chic” category. but when you factor in la double j’s romantic touches, like those frilly flutter sleeves and that stunning, almost architectural standing collar, and this italian-made crepe dress becomes something else entirely. oh, and that knee-length cut means it’s just as office appropriate as it is date-night friendly. and it’s just as pretty from the back (you can thank the tie-up detail for that).material, HIGH_VISCOSE cleanmade in italymodel is NUMERICAL_VALUE ’NUMERICAL_VALUE ” with NUMERICAL_VALUE " bust, NUMERICAL_VALUE " waist, NUMERICAL_VALUE " hips and wearing a size\xa0xs',
#  "crafted in italy, golden goose's 'hi star' sneakers are designed with the brand's signature appliqué star and stamped gold-tone logo on textured-leather uppers. set on a platform rubber sole, this pair is complete with suede vamps and handwritten text accents. highlight its chunky heel by pairing yours with a midi-length skirt.",
#  'webbed straps, a contrast wedge and a serrated platform style this modern and sporty sandal.',
#  "as enchanting as cinderella's glass slipper, but much more wearable, this graceful italian sandal is styled with transparent straps.",
#  'brown cashmere and mulberry silk-blend slips on material, MEDIAN_CASHMERE silk dry clean designer color: bark imported',
#  'anything leopard tends to automatically fall in the “chic” category. but when you factor in la double j’s romantic touches, like those frilly flutter sleeves and that stunning, almost architectural standing collar, and this italian-made crepe dress becomes something else entirely. oh, and that knee-length cut means it’s just as office appropriate as it is date-night friendly. and it’s just as pretty from the back (you can thank the tie-up detail for that).material, HIGH_VISCOSE cleanmade in italymodel is NUMERICAL_VALUE ’NUMERICAL_VALUE ” with NUMERICAL_VALUE " bust, NUMERICAL_VALUE " waist, NUMERICAL_VALUE " hips and wearing a size\xa0xs',
#  'multicolored cotton-jersey slips on HIGH_COTTON machine wash',
#  'multicolored cotton-jersey slips on HIGH_COTTON machine wash',
#  'brown cashmere and mulberry silk-blend slips on material, MEDIAN_CASHMERE silk dry clean designer color: bark imported',
#  'brown cashmere and mulberry silk-blend slips on material, MEDIAN_CASHMERE silk dry clean designer color: bark imported',
#  'brown cashmere and mulberry silk-blend slips on material, MEDIAN_CASHMERE silk dry clean designer color: bark imported',
#  'webbed straps, a contrast wedge and a serrated platform style this modern and sporty sandal.',
#  'black cotton-jersey slips on HIGH_COTTON machine wash imported',
#  'black cotton-jersey slips on HIGH_COTTON machine wash imported',
#  'we partnered with a fabric house in the southwest of france to make the custom trim at the hem of this polished tweed pencil skirt. even better: we also designed a matching jacket for more outfit potential.',
#  'we partnered with a fabric house in the southwest of france to make the custom trim at the hem of this polished tweed pencil skirt. even better: we also designed a matching jacket for more outfit potential.',
#  'black cotton-jersey slips on HIGH_COTTON machine wash imported',
#  'black cotton-jersey slips on HIGH_COTTON machine wash imported',
#  'ivory crepe slips on material, material; buttons: HIGH_ACETATE (cow) dry clean imported',
#  'ivory crepe slips on material, material; buttons: HIGH_ACETATE (cow) dry clean imported',
#  "cut from soft camel wool, max mara's chic 'pacos' coat is designed with broad, fringe-trimmed lapels. cinch yours at the waist with the self-tie belt and keep your phone handy in one of the exaggerated patch pockets at the front.",
#  'sinuous straps cross atop a lightly cushioned sandal shaped with a squared-off toe and an architectural block heel.',
#  "this italian-crafted chelsea boot is a sleek, timeless style that's as low-key as it is luxe.",
#  "this italian-crafted chelsea boot is a sleek, timeless style that's as low-key as it is luxe.",
#  "cut from soft camel wool, max mara's chic 'pacos' coat is designed with broad, fringe-trimmed lapels. cinch yours at the waist with the self-tie belt and keep your phone handy in one of the exaggerated patch pockets at the front.",
#  "channel your inner 'NUMERICAL_VALUE s supermodel in this day-to-night sandal with a toe loop, mid heel and clean, geometric angles.",
#  're/done delivers a one-two punch of comfort and confidence with a cotton tee featuring a comic-style graphic of a butt-kicking boxer.',
#  'dramatic curves and sharp angles marry on this pointy-toe bootie made with a steep slant on a stacked heel.',
#  'black leather (lamb) open top  weighs approximately NUMERICAL_VALUE lbs/ NUMERICAL_VALUE kg imported',
#  'dramatic curves and sharp angles marry on this pointy-toe bootie made with a steep slant on a stacked heel.',
#  'camel grain de poudre wool button fastening at front material; buttons: HIGH_WOOL (buffalo) dry clean made in italy',
#  "channel your inner 'NUMERICAL_VALUE s supermodel in this day-to-night sandal with a toe loop, mid heel and clean, geometric angles.",
#  'we partnered with a fabric house in the southwest of france to make the custom trim at the hem of this polished tweed pencil skirt. even better: we also designed a matching jacket for more outfit potential.',
#  'black stretch-pima cotton jersey slips on HIGH_PIMA cotton, LOW_ELASTANE hand wash imported',
#  'gray cotton-jersey slips on HIGH_COTTON machine wash designer color: tinker',
#  'we partnered with a fabric house in the southwest of france to make the custom trim at the hem of this polished tweed pencil skirt. even better: we also designed a matching jacket for more outfit potential.',
#  'an easy slide sandal is a go-everywhere shoe that brings a bit of beachy style to your everyday outfits.',
#  'tan leather (calf) magnetic-fastening front flap weighs approximately NUMERICAL_VALUE lbs/ NUMERICAL_VALUE kg made in italy',
#  'tan leather (calf) magnetic-fastening front flap weighs approximately NUMERICAL_VALUE lbs/ NUMERICAL_VALUE kg made in italy',
#  "off-white c/o virgil abloh's 'fringes popon' bag is crafted in a pom-pom silhouette with fringe details and a wristlet strap.",
#  'an easy slide sandal is a go-everywhere shoe that brings a bit of beachy style to your everyday outfits.',
#  'multicolored cotton-jersey slips on HIGH_COTTON machine wash',
#  "off-white c/o virgil abloh's 'fringes popon' bag is crafted in a pom-pom silhouette with fringe details and a wristlet strap.",
#  'multicolored cotton-jersey slips on HIGH_COTTON machine wash',
#  'styled with a slender mid heel and a v-cut vamp that flows into the pointy toe, this mule looks just as chic on your date as it does in the office.',
#  'styled with a slender mid heel and a v-cut vamp that flows into the pointy toe, this mule looks just as chic on your date as it does in the office.',
#  "cut from soft camel wool, max mara's chic 'pacos' coat is designed with broad, fringe-trimmed lapels. cinch yours at the waist with the self-tie belt and keep your phone handy in one of the exaggerated patch pockets at the front.",
#  'cream crepe slips on material, material; lining: material, MEDIAN_ACETATE dry clean',
#  'cream crepe slips on material, material; lining: material, MEDIAN_ACETATE dry clean',
#  ' ',
#  ' ',
#  'light-blue, navy and off-white jersey pull on material, HIGH_VISCOSE dry clean designer color: celeste blue imported',
#  'light-blue, navy and off-white jersey pull on material, HIGH_VISCOSE dry clean designer color: celeste blue imported',
#  'light-blue, navy and off-white jersey pull on material, HIGH_VISCOSE dry clean designer color: celeste blue imported',
#  'light-blue, navy and off-white jersey pull on material, HIGH_VISCOSE dry clean designer color: celeste blue imported',
# ...
#  "zeynep arçay's pants are crafted from genuine leather, with a flattering high-waisted fit, a full length leg, and a slim silhouette. pair yours with the brand's wrap leather blazer to mirror the fall winter NUMERICAL_VALUE  lookbook style.",
#  "zeynep arçay's pants are crafted from genuine leather, with a flattering high-waisted fit, a full length leg, and a slim silhouette. pair yours with the brand's wrap leather blazer to mirror the fall winter NUMERICAL_VALUE  lookbook style.",
#  "zeynep arçay's pants are crafted from genuine leather, with a flattering high-waisted fit, a full length leg, and a slim silhouette. pair yours with the brand's wrap leather blazer to mirror the fall winter NUMERICAL_VALUE  lookbook style.",
#  'supple faux leather brings glamorous edge to these tailored shorts.',
#  'supple faux leather brings glamorous edge to these tailored shorts.',
#  'supple faux leather brings glamorous edge to these tailored shorts.',
#  'supple faux leather brings glamorous edge to these tailored shorts.',
#  'cigarette pants cut from gingham for a blithe look.',
#  'cigarette pants cut from gingham for a blithe look.',
#  'cigarette pants cut from gingham for a blithe look.',
#  'cigarette pants cut from gingham for a blithe look.',
#  'throw-back to a cropped t-shirt with fine ribbed texture and back seam detail.',
#  'throw-back to a cropped t-shirt with fine ribbed texture and back seam detail.',
#  'throw-back to a cropped t-shirt with fine ribbed texture and back seam detail.',
#  'throw-back to a cropped t-shirt with fine ribbed texture and back seam detail.',
#  "partow's crepe 'everly' midi skirt is tailored to a high-rise fit. designed with an a-line silhouette, its fluid shape is detailed with concealed front pockets and relaxed pleats. style with the matching dress to complete the look.",
#  "partow's crepe 'everly' midi skirt is tailored to a high-rise fit. designed with an a-line silhouette, its fluid shape is detailed with concealed front pockets and relaxed pleats. style with the matching dress to complete the look.",
#  "partow's crepe 'everly' midi skirt is tailored to a high-rise fit. designed with an a-line silhouette, its fluid shape is detailed with concealed front pockets and relaxed pleats. style with the matching dress to complete the look.",
#  "partow's crepe 'everly' midi skirt is tailored to a high-rise fit. designed with an a-line silhouette, its fluid shape is detailed with concealed front pockets and relaxed pleats. style with the matching dress to complete the look.",
#  "between the shoulder-baring design and airy cotton handle, cult gaia's 'claire' top is perfectly suited for the warm-weather months. this long-sleeve style has a tie-detailed front and tiered puffed sleeves that fall in a knuckle-grazing length. highlight the split hem with high-rise shorts.",
#  "between the shoulder-baring design and airy cotton handle, cult gaia's 'claire' top is perfectly suited for the warm-weather months. this long-sleeve style has a tie-detailed front and tiered puffed sleeves that fall in a knuckle-grazing length. highlight the split hem with high-rise shorts.",
#  "between the shoulder-baring design and airy cotton handle, cult gaia's 'claire' top is perfectly suited for the warm-weather months. this long-sleeve style has a tie-detailed front and tiered puffed sleeves that fall in a knuckle-grazing length. highlight the split hem with high-rise shorts.",
#  "between the shoulder-baring design and airy cotton handle, cult gaia's 'claire' top is perfectly suited for the warm-weather months. this long-sleeve style has a tie-detailed front and tiered puffed sleeves that fall in a knuckle-grazing length. highlight the split hem with high-rise shorts.",
#  "between the shoulder-baring design and airy cotton handle, cult gaia's 'claire' top is perfectly suited for the warm-weather months. this long-sleeve style has a tie-detailed front and tiered puffed sleeves that fall in a knuckle-grazing length. highlight the split hem with high-rise shorts.",
#  "between the shoulder-baring design and airy cotton handle, cult gaia's 'claire' top is perfectly suited for the warm-weather months. this long-sleeve style has a tie-detailed front and tiered puffed sleeves that fall in a knuckle-grazing length. highlight the split hem with high-rise shorts.",
#  "between the shoulder-baring design and airy cotton handle, cult gaia's 'claire' top is perfectly suited for the warm-weather months. this long-sleeve style has a tie-detailed front and tiered puffed sleeves that fall in a knuckle-grazing length. highlight the split hem with high-rise shorts.",
#  "between the shoulder-baring design and airy cotton handle, cult gaia's 'claire' top is perfectly suited for the warm-weather months. this long-sleeve style has a tie-detailed front and tiered puffed sleeves that fall in a knuckle-grazing length. highlight the split hem with high-rise shorts.",
#  "isabel marant's 'welly' shirt is cut for an oversized fit, which is enhanced by this season's prominent shoulder. it's made from cotton-poplin in a striped motif and draped with a scarf-inspired cowl neck. style with a tapered wool trouser to complement its tailoring.",
#  "isabel marant's 'welly' shirt is cut for an oversized fit, which is enhanced by this season's prominent shoulder. it's made from cotton-poplin in a striped motif and draped with a scarf-inspired cowl neck. style with a tapered wool trouser to complement its tailoring.",
#  "isabel marant's 'welly' shirt is cut for an oversized fit, which is enhanced by this season's prominent shoulder. it's made from cotton-poplin in a striped motif and draped with a scarf-inspired cowl neck. style with a tapered wool trouser to complement its tailoring.",
#  "isabel marant's 'welly' shirt is cut for an oversized fit, which is enhanced by this season's prominent shoulder. it's made from cotton-poplin in a striped motif and draped with a scarf-inspired cowl neck. style with a tapered wool trouser to complement its tailoring.",
#  'heel measures approximately NUMERICAL_VALUE mm/ NUMERICAL_VALUE  inches clear pvc, beige suede (calf) elasticated slingback strap  designer color: nude  made in italysmall to size. see size & fit notes.',
#  'heel measures approximately NUMERICAL_VALUE mm/ NUMERICAL_VALUE  inches clear pvc, beige suede (calf) elasticated slingback strap  designer color: nude  made in italysmall to size. see size & fit notes.',
#  "biker jackets are a simple way to elevate your casual edit. grlfrnd's 'charlie' rendition is crafted from textured leather and detailed with of functional silver-tone zip fastenings and a buckled belt to cinch the boxy shape. complement the cropped hem with high-rise jeans.",
#  "biker jackets are a simple way to elevate your casual edit. grlfrnd's 'charlie' rendition is crafted from textured leather and detailed with of functional silver-tone zip fastenings and a buckled belt to cinch the boxy shape. complement the cropped hem with high-rise jeans.",
#  "biker jackets are a simple way to elevate your casual edit. grlfrnd's 'charlie' rendition is crafted from textured leather and detailed with of functional silver-tone zip fastenings and a buckled belt to cinch the boxy shape. complement the cropped hem with high-rise jeans.",
#  "biker jackets are a simple way to elevate your casual edit. grlfrnd's 'charlie' rendition is crafted from textured leather and detailed with of functional silver-tone zip fastenings and a buckled belt to cinch the boxy shape. complement the cropped hem with high-rise jeans.",
#  "biker jackets are a simple way to elevate your casual edit. grlfrnd's 'charlie' rendition is crafted from textured leather and detailed with of functional silver-tone zip fastenings and a buckled belt to cinch the boxy shape. complement the cropped hem with high-rise jeans.",
#  "biker jackets are a simple way to elevate your casual edit. grlfrnd's 'charlie' rendition is crafted from textured leather and detailed with of functional silver-tone zip fastenings and a buckled belt to cinch the boxy shape. complement the cropped hem with high-rise jeans.",
#  "biker jackets are a simple way to elevate your casual edit. grlfrnd's 'charlie' rendition is crafted from textured leather and detailed with of functional silver-tone zip fastenings and a buckled belt to cinch the boxy shape. complement the cropped hem with high-rise jeans.",
#  "biker jackets are a simple way to elevate your casual edit. grlfrnd's 'charlie' rendition is crafted from textured leather and detailed with of functional silver-tone zip fastenings and a buckled belt to cinch the boxy shape. complement the cropped hem with high-rise jeans.",
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'antique-rose silk-satin slips on HIGH_SILK dry clean designer color: wood rose',
#  'antique-rose silk-satin slips on HIGH_SILK dry clean designer color: wood rose',
#  'antique-rose silk-satin slips on HIGH_SILK dry clean designer color: wood rose',
#  'antique-rose silk-satin slips on HIGH_SILK dry clean designer color: wood rose',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  "detailed with a contrasting strap along the ankle, dorothee schumacher's 'mirror touch' pointed toe booties are crafted from leather with a metallic finish and a stiletto heel. add a twist to a classic look by wearing yours with tailored pants and a structured jacket.",
#  "detailed with a contrasting strap along the ankle, dorothee schumacher's 'mirror touch' pointed toe booties are crafted from leather with a metallic finish and a stiletto heel. add a twist to a classic look by wearing yours with tailored pants and a structured jacket.",
#  "detailed with a contrasting strap along the ankle, dorothee schumacher's 'mirror touch' pointed toe booties are crafted from leather with a metallic finish and a stiletto heel. add a twist to a classic look by wearing yours with tailored pants and a structured jacket.",
#  "detailed with a contrasting strap along the ankle, dorothee schumacher's 'mirror touch' pointed toe booties are crafted from leather with a metallic finish and a stiletto heel. add a twist to a classic look by wearing yours with tailored pants and a structured jacket.",
#  "detailed with a contrasting strap along the ankle, dorothee schumacher's 'mirror touch' pointed toe booties are crafted from leather with a metallic finish and a stiletto heel. add a twist to a classic look by wearing yours with tailored pants and a structured jacket.",
#  "detailed with a contrasting strap along the ankle, dorothee schumacher's 'mirror touch' pointed toe booties are crafted from leather with a metallic finish and a stiletto heel. add a twist to a classic look by wearing yours with tailored pants and a structured jacket.",
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  "whether you're headed to a farmhouse veranda or an urban terrace, the modern prairie appeal of this lacy cotton maxi dress will be most welcome.",
#  "whether you're headed to a farmhouse veranda or an urban terrace, the modern prairie appeal of this lacy cotton maxi dress will be most welcome.",
#  "whether you're headed to a farmhouse veranda or an urban terrace, the modern prairie appeal of this lacy cotton maxi dress will be most welcome.",
#  "whether you're headed to a farmhouse veranda or an urban terrace, the modern prairie appeal of this lacy cotton maxi dress will be most welcome.",
#  "whether you're headed to a farmhouse veranda or an urban terrace, the modern prairie appeal of this lacy cotton maxi dress will be most welcome.",
#  "whether you're headed to a farmhouse veranda or an urban terrace, the modern prairie appeal of this lacy cotton maxi dress will be most welcome.",
#  "perfect for the workday and beyond, victoria beckham's modest dress is designed with drop sleeves and a knee-length hem. this relaxed style is detailed with contrast piping along the front and back— coordinate yours with burgundy ankle boots.",
#  "perfect for the workday and beyond, victoria beckham's modest dress is designed with drop sleeves and a knee-length hem. this relaxed style is detailed with contrast piping along the front and back— coordinate yours with burgundy ankle boots.",
#  "perfect for the workday and beyond, victoria beckham's modest dress is designed with drop sleeves and a knee-length hem. this relaxed style is detailed with contrast piping along the front and back— coordinate yours with burgundy ankle boots.",
#  "perfect for the workday and beyond, victoria beckham's modest dress is designed with drop sleeves and a knee-length hem. this relaxed style is detailed with contrast piping along the front and back— coordinate yours with burgundy ankle boots.",
#  "perfect for the workday and beyond, victoria beckham's modest dress is designed with drop sleeves and a knee-length hem. this relaxed style is detailed with contrast piping along the front and back— coordinate yours with burgundy ankle boots.",
#  "perfect for the workday and beyond, victoria beckham's modest dress is designed with drop sleeves and a knee-length hem. this relaxed style is detailed with contrast piping along the front and back— coordinate yours with burgundy ankle boots.",
#  "bouguessa's classic blazer is designed with a v-neckline, pocket flaps, and a belted waist. pair yours with the matching pants to create the ultimate power suit.",
#  "bouguessa's classic blazer is designed with a v-neckline, pocket flaps, and a belted waist. pair yours with the matching pants to create the ultimate power suit.",
#  "bouguessa's classic blazer is designed with a v-neckline, pocket flaps, and a belted waist. pair yours with the matching pants to create the ultimate power suit.",
#  "bouguessa's classic blazer is designed with a v-neckline, pocket flaps, and a belted waist. pair yours with the matching pants to create the ultimate power suit.",
#  'carry your essentials in style with this rich leather briefcase on a removable crossbody strap.',
#  'carry your essentials in style with this rich leather briefcase on a removable crossbody strap.',
#  'carry your essentials in style with this rich leather briefcase on a removable crossbody strap.',
#  'carry your essentials in style with this rich leather briefcase on a removable crossbody strap.',
#  "loveshackfancy's 'queenie' ultra-feminine silk dress is designed with a ruffled hemline and an all-over floral print. pair yours with minimalist accessories to keep the dress in focus.",
#  "loveshackfancy's 'queenie' ultra-feminine silk dress is designed with a ruffled hemline and an all-over floral print. pair yours with minimalist accessories to keep the dress in focus.",
#  "loveshackfancy's 'queenie' ultra-feminine silk dress is designed with a ruffled hemline and an all-over floral print. pair yours with minimalist accessories to keep the dress in focus.",
#  "loveshackfancy's 'queenie' ultra-feminine silk dress is designed with a ruffled hemline and an all-over floral print. pair yours with minimalist accessories to keep the dress in focus.",
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  "cinched at the waist to accentuate your natural curves, loveshackfancy's 'cheyenne' cotton skirt is designed with a floral print and a fitted waist. pair yours with a sweater for a fun transitional look.",
#  "cinched at the waist to accentuate your natural curves, loveshackfancy's 'cheyenne' cotton skirt is designed with a floral print and a fitted waist. pair yours with a sweater for a fun transitional look.",
#  "cinched at the waist to accentuate your natural curves, loveshackfancy's 'cheyenne' cotton skirt is designed with a floral print and a fitted waist. pair yours with a sweater for a fun transitional look.",
#  "cinched at the waist to accentuate your natural curves, loveshackfancy's 'cheyenne' cotton skirt is designed with a floral print and a fitted waist. pair yours with a sweater for a fun transitional look.",
#  'cream silk-satin pull on HIGH_SILK dry clean made in france',
#  'cream silk-satin pull on HIGH_SILK dry clean made in france',
#  ...]

# %%
cleaned_descriptions = []
updated_stopwords = set(updated_stopwords)

for line in no_numeric_description:
    new_words = []
    line = re.findall(r'\b[a-zA-Z0-9_]{2,}\b',line)
    for word in line:
        if word.lower() in updated_stopwords:
            continue
        new_words.append(word)
    cleaned_description = " ".join(new_words)
    cleaned_descriptions.append(cleaned_description)

# %%
cleaned_descriptions
# Out:
# ['black leather lamb open top weighs approximately NUMERICAL_VALUE lbs NUMERICAL_VALUE kg imported',
#  'retro inspired yet current stretchy ribbed bodysuit based slim fitting clothing gained popularity NUMERICAL_VALUE',
#  'retro inspired yet current stretchy ribbed bodysuit based slim fitting clothing gained popularity NUMERICAL_VALUE',
#  'black stretch pima cotton jersey slips HIGH_PIMA cotton LOW_ELASTANE hand wash imported',
#  'crafted supple leather sally lapointe pants cut wide leg silhouette cinched waist matching belt style looks amazing paired favorite sweater tucked',
#  'cream crepe slips material material lining material MEDIAN_ACETATE dry clean',
#  'cream crepe slips material material lining material MEDIAN_ACETATE dry clean',
#  'crafted supple leather sally lapointe pants cut wide leg silhouette cinched waist matching belt style looks amazing paired favorite sweater tucked',
#  'crafted supple leather sally lapointe pants cut wide leg silhouette cinched waist matching belt style looks amazing paired favorite sweater tucked',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches gold mirrored leather calf buckle fastening ankle strap come dust bag made italy',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches gold mirrored leather calf buckle fastening ankle strap come dust bag made italy',
#  'clean seams towering stacked heel define polished day night boot',
#  'chase summery dreams rainbow metallic sandal beach chic design knotted straps reaching wrap ankle',
#  'chase summery dreams rainbow metallic sandal beach chic design knotted straps reaching wrap ankle',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches gold mirrored leather calf buckle fastening ankle strap come dust bag made italy',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches gold mirrored leather calf buckle fastening ankle strap come dust bag made italy',
#  'cream crepe slips material material lining material MEDIAN_ACETATE dry clean',
#  'cream crepe slips material material lining material MEDIAN_ACETATE dry clean',
#  'camel grain de poudre wool button fastening front material buttons HIGH_WOOL buffalo dry clean made italy',
#  'cream crepe slips material material lining material MEDIAN_ACETATE dry clean',
#  'black stretch pima cotton jersey slips HIGH_PIMA cotton LOW_ELASTANE hand wash imported',
#  'clean seams towering stacked heel define polished day night boot',
#  'mens military inspired button designers tailored ladies thanks slimmer fit super flattering',
#  'mens military inspired button designers tailored ladies thanks slimmer fit super flattering',
#  'black stretch pima cotton jersey slips HIGH_PIMA cotton LOW_ELASTANE hand wash imported',
#  'fashioned high quality materials designed comfort shoes keep stylish toes flexible suede upper breathable synthetic lining insole added stability heel exclusive padding system features memory foam cushioned insole designed day comfort flexible skid resistant outsole comfort pod bottom',
#  'fashioned high quality materials designed comfort shoes keep stylish toes flexible suede upper breathable synthetic lining insole added stability heel exclusive padding system features memory foam cushioned insole designed day comfort flexible skid resistant outsole comfort pod bottom',
#  'gray cotton jersey slips HIGH_COTTON machine wash designer color tinker',
#  'gray cotton jersey slips HIGH_COTTON machine wash designer color tinker',
#  'gray cotton jersey slips HIGH_COTTON machine wash designer color tinker',
#  'camel grain de poudre wool button fastening front material buttons HIGH_WOOL buffalo dry clean made italy',
#  'black leather lamb open top weighs approximately NUMERICAL_VALUE lbs NUMERICAL_VALUE kg imported',
#  'gray cotton jersey slips HIGH_COTTON machine wash designer color tinker',
#  'mens military inspired button designers tailored ladies thanks slimmer fit super flattering',
#  'mens military inspired button designers tailored ladies thanks slimmer fit super flattering',
#  'wide channel quilted straps crisscross well padded slide sandal grounded razored treads',
#  'multicolored cotton nylon merino wool alpaca cashmere mohair blend slips material material LOW_COTTON wool material material LOW_NYLON dry clean imported',
#  'crafted italy golden goose hi star sneakers designed brand signature star stamped gold tone logo textured leather uppers set platform rubber sole pair complete suede vamps handwritten text accents highlight chunky heel pairing midi length skirt',
#  'edgy style expert craftsmanship combine block heel combat boot cut sewn lasted hand spanish artisans',
#  'ready stroll private beach flat sandal styled crisscrossing straps braided raffia',
#  'suckers pretty statement top exactly landed tee ladylike twists fits feels like favorite shirt thank soft cotton jersey perked high volume poplin sleeves gather gracefully toward cuffs yes statement shoulders best news treat like tees wear every single pair jeans trousers shorts material clean onlymade italymeasurements size NUMERICAL_VALUE length NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE chest NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE model NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE bust NUMERICAL_VALUE waist NUMERICAL_VALUE hips wearing size NUMERICAL_VALUE',
#  'ready stroll private beach flat sandal styled crisscrossing straps braided raffia',
#  'enchanting cinderella glass slipper much wearable graceful italian sandal styled transparent straps',
#  'suckers pretty statement top exactly landed tee ladylike twists fits feels like favorite shirt thank soft cotton jersey perked high volume poplin sleeves gather gracefully toward cuffs yes statement shoulders best news treat like tees wear every single pair jeans trousers shorts material clean onlymade italymeasurements size NUMERICAL_VALUE length NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE chest NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE model NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE bust NUMERICAL_VALUE waist NUMERICAL_VALUE hips wearing size NUMERICAL_VALUE',
#  'lean lengthening silhouette one button closure accentuate waist notch lapel long sleeves one button cuffs two exterior pockets center back vent fully lined stretch lining comfort ease movement',
#  'lean lengthening silhouette one button closure accentuate waist notch lapel long sleeves one button cuffs two exterior pockets center back vent fully lined stretch lining comfort ease movement',
#  'edgy style expert craftsmanship combine block heel combat boot cut sewn lasted hand spanish artisans',
#  'lean lengthening silhouette one button closure accentuate waist notch lapel long sleeves one button cuffs two exterior pockets center back vent fully lined stretch lining comfort ease movement',
#  'lean lengthening silhouette one button closure accentuate waist notch lapel long sleeves one button cuffs two exterior pockets center back vent fully lined stretch lining comfort ease movement',
#  'nobody denim true jeans designed pre cuffed hems saving time finding perfect length crafted medium wash style fashioned mid rise waist brand logo stitching back right pocket couple skinny style puffed sleeve blouse add volume',
#  'nobody denim true jeans designed pre cuffed hems saving time finding perfect length crafted medium wash style fashioned mid rise waist brand logo stitching back right pocket couple skinny style puffed sleeve blouse add volume',
#  'nobody denim true jeans designed pre cuffed hems saving time finding perfect length crafted medium wash style fashioned mid rise waist brand logo stitching back right pocket couple skinny style puffed sleeve blouse add volume',
#  'ivory jeans dressed toned need straight leg fit skinny constricting super flattering leg elongating silhouette falls past ankles meaning work equally well block heeled boot office low top sneakers kicking around material washmade usamodel NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE bust NUMERICAL_VALUE waist NUMERICAL_VALUE hips wearing size NUMERICAL_VALUE',
#  'crafted supple leather sally lapointe pants cut wide leg silhouette cinched waist matching belt style looks amazing paired favorite sweater tucked',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches cream leather lamb slip designer color buttercream made italysmall size see size fit notes',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches cream leather lamb slip designer color buttercream made italysmall size see size fit notes',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches cream leather lamb slip designer color buttercream made italysmall size see size fit notes',
#  'derek lam oversized silk blouse designed self tie scarf neck long cuffed sleeves high low hemline',
#  'introducing suiting first time done based cropped flare trousers vintage pair NUMERICAL_VALUE handmade italy',
#  'introducing suiting first time done based cropped flare trousers vintage pair NUMERICAL_VALUE handmade italy',
#  'crafted supple leather sally lapointe pants cut wide leg silhouette cinched waist matching belt style looks amazing paired favorite sweater tucked',
#  'edgy style expert craftsmanship combine block heel combat boot cut sewn lasted hand spanish artisans',
#  'twinkling crystal brooch crowns toe strap party ready sandal secured slender floating ankle strap',
#  'twinkling crystal brooch crowns toe strap party ready sandal secured slender floating ankle strap',
#  'ivory jeans dressed toned need straight leg fit skinny constricting super flattering leg elongating silhouette falls past ankles meaning work equally well block heeled boot office low top sneakers kicking around material washmade usamodel NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE bust NUMERICAL_VALUE waist NUMERICAL_VALUE hips wearing size NUMERICAL_VALUE',
#  'derek lam oversized silk blouse designed self tie scarf neck long cuffed sleeves high low hemline',
#  'named unique double point pocket design denim western shirt softly faded detailed pearly snaps authentic vintage look',
#  'named unique double point pocket design denim western shirt softly faded detailed pearly snaps authentic vintage look',
#  'ivory jeans dressed toned need straight leg fit skinny constricting super flattering leg elongating silhouette falls past ankles meaning work equally well block heeled boot office low top sneakers kicking around material washmade usamodel NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE bust NUMERICAL_VALUE waist NUMERICAL_VALUE hips wearing size NUMERICAL_VALUE',
#  'designed curated minimalistic style icon elin kling provides updated essentials effortless mix match ideal work weekends high rise ossi tailored full length tailored leg wear matching blazer smart look keep casual oversized knit sneakers',
#  'midnight blue organic cotton velour pull HIGH_ORGANIC cotton machine wash imported',
#  'designed curated minimalistic style icon elin kling provides updated essentials effortless mix match ideal work weekends high rise ossi tailored full length tailored leg wear matching blazer smart look keep casual oversized knit sneakers',
#  'tan leather calf magnetic fastening front flap weighs approximately NUMERICAL_VALUE lbs NUMERICAL_VALUE kg made italy',
#  'enchanting cinderella glass slipper much wearable graceful italian sandal styled transparent straps',
#  'derek lam oversized silk blouse designed self tie scarf neck long cuffed sleeves high low hemline',
#  'designed curated minimalistic style icon elin kling provides updated essentials effortless mix match ideal work weekends high rise ossi tailored full length tailored leg wear matching blazer smart look keep casual oversized knit sneakers',
#  'derek lam oversized silk blouse designed self tie scarf neck long cuffed sleeves high low hemline',
#  'croc embossing brings moment appeal double band sandal finished gleaming buckles',
#  'croc embossing brings moment appeal double band sandal finished gleaming buckles',
#  'tan leather calf magnetic fastening front flap weighs approximately NUMERICAL_VALUE lbs NUMERICAL_VALUE kg made italy',
#  'crafted italy golden goose hi star sneakers designed brand signature star stamped gold tone logo textured leather uppers set platform rubber sole pair complete suede vamps handwritten text accents highlight chunky heel pairing midi length skirt',
#  'multicolored cotton nylon merino wool alpaca cashmere mohair blend slips material material LOW_COTTON wool material material LOW_NYLON dry clean imported',
#  'black leather lamb open top weighs approximately NUMERICAL_VALUE lbs NUMERICAL_VALUE kg imported',
#  'ivory jeans dressed toned need straight leg fit skinny constricting super flattering leg elongating silhouette falls past ankles meaning work equally well block heeled boot office low top sneakers kicking around material washmade usamodel NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE bust NUMERICAL_VALUE waist NUMERICAL_VALUE hips wearing size NUMERICAL_VALUE',
#  'flouncy tie gathers neckline billowy chartreuse dress finished attached hem enhance flowy movement',
#  'black white lyocell partially concealed snap fastenings front HIGH_LYOCELL dry clean imported',
#  'black white lyocell partially concealed snap fastenings front HIGH_LYOCELL dry clean imported',
#  'gray cotton jersey slips HIGH_COTTON machine wash designer color tinker',
#  'ivory jeans dressed toned need straight leg fit skinny constricting super flattering leg elongating silhouette falls past ankles meaning work equally well block heeled boot office low top sneakers kicking around material washmade usamodel NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE bust NUMERICAL_VALUE waist NUMERICAL_VALUE hips wearing size NUMERICAL_VALUE',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches cream leather lamb slip designer color buttercream made italysmall size see size fit notes',
#  'designed curated minimalistic style icon elin kling provides updated essentials effortless mix match ideal work weekends high rise ossi tailored full length tailored leg wear matching blazer smart look keep casual oversized knit sneakers',
#  'designed curated minimalistic style icon elin kling provides updated essentials effortless mix match ideal work weekends high rise ossi tailored full length tailored leg wear matching blazer smart look keep casual oversized knit sneakers',
#  'cream black jersey button fastening keyhole back material material lining HIGH_VISCOSE dry clean imported',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches cream leather lamb slip designer color buttercream made italysmall size see size fit notes',
#  'cream black jersey button fastening keyhole back material material lining HIGH_VISCOSE dry clean imported',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches cream leather lamb slip designer color buttercream made italysmall size see size fit notes',
#  'gray cotton jersey slips HIGH_COTTON machine wash designer color tinker',
#  'midnight blue organic cotton velour pull HIGH_ORGANIC cotton machine wash imported',
#  'black white lyocell partially concealed snap fastenings front HIGH_LYOCELL dry clean imported',
#  'stone stretch pima cotton pull HIGH_PIMA cotton LOW_ELASTANE machine wash imported',
#  'black white lyocell partially concealed snap fastenings front HIGH_LYOCELL dry clean imported',
#  'silhouette poised cap toe pump gets vacation update platform wedge heel wrapped braided jute',
#  'stone stretch pima cotton pull HIGH_PIMA cotton LOW_ELASTANE machine wash imported',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches cream leather lamb slip designer color buttercream made italysmall size see size fit notes',
#  'pleat neck top made italy paper thin poplin shirting unicorn got beauty best loved blouse thanks pretty front pleats intricate knot detailing collar brains favorite tee relaxed shape roomy sleeves oh incognito buttons back nicest touches material clean onlymade italymeasurements size NUMERICAL_VALUE NUMERICAL_VALUE chest NUMERICAL_VALUE sleeve length NUMERICAL_VALUE body lengthmodel NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE bust NUMERICAL_VALUE waist NUMERICAL_VALUE hips wearing size NUMERICAL_VALUE',
#  'pleat neck top made italy paper thin poplin shirting unicorn got beauty best loved blouse thanks pretty front pleats intricate knot detailing collar brains favorite tee relaxed shape roomy sleeves oh incognito buttons back nicest touches material clean onlymade italymeasurements size NUMERICAL_VALUE NUMERICAL_VALUE chest NUMERICAL_VALUE sleeve length NUMERICAL_VALUE body lengthmodel NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE bust NUMERICAL_VALUE waist NUMERICAL_VALUE hips wearing size NUMERICAL_VALUE',
#  'silhouette poised cap toe pump gets vacation update platform wedge heel wrapped braided jute',
#  'pleat neck top made italy paper thin poplin shirting unicorn got beauty best loved blouse thanks pretty front pleats intricate knot detailing collar brains favorite tee relaxed shape roomy sleeves oh incognito buttons back nicest touches material clean onlymade italymeasurements size NUMERICAL_VALUE NUMERICAL_VALUE chest NUMERICAL_VALUE sleeve length NUMERICAL_VALUE body lengthmodel NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE bust NUMERICAL_VALUE waist NUMERICAL_VALUE hips wearing size NUMERICAL_VALUE',
#  'pleat neck top made italy paper thin poplin shirting unicorn got beauty best loved blouse thanks pretty front pleats intricate knot detailing collar brains favorite tee relaxed shape roomy sleeves oh incognito buttons back nicest touches material clean onlymade italymeasurements size NUMERICAL_VALUE NUMERICAL_VALUE chest NUMERICAL_VALUE sleeve length NUMERICAL_VALUE body lengthmodel NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE bust NUMERICAL_VALUE waist NUMERICAL_VALUE hips wearing size NUMERICAL_VALUE',
#  'anything leopard tends automatically fall chic category factor la double romantic touches like frilly flutter sleeves stunning almost architectural standing collar italian made crepe dress becomes something else entirely oh knee length cut means office appropriate date night friendly pretty back thank tie detail material HIGH_VISCOSE cleanmade italymodel NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE bust NUMERICAL_VALUE waist NUMERICAL_VALUE hips wearing size xs',
#  'silhouette poised cap toe pump gets vacation update platform wedge heel wrapped braided jute',
#  'nobody denim true jeans designed pre cuffed hems saving time finding perfect length crafted medium wash style fashioned mid rise waist brand logo stitching back right pocket couple skinny style puffed sleeve blouse add volume',
#  'nobody denim true jeans designed pre cuffed hems saving time finding perfect length crafted medium wash style fashioned mid rise waist brand logo stitching back right pocket couple skinny style puffed sleeve blouse add volume',
#  'nobody denim true jeans designed pre cuffed hems saving time finding perfect length crafted medium wash style fashioned mid rise waist brand logo stitching back right pocket couple skinny style puffed sleeve blouse add volume',
#  'aquazzura minute sandals crafted polished leather ultra slim straps secure frame foot pair literally take look new heights set slender stiletto heel measuring four inches',
#  'aquazzura minute sandals crafted polished leather ultra slim straps secure frame foot pair literally take look new heights set slender stiletto heel measuring four inches',
#  'one example season strong tailoring theme carolina herrera trousers cut wool silk blend woven classic prince wales check typically found men suiting high waisted pair fitted hips tapered knees flaring toward ankles complete look matching printed jacket',
#  'one example season strong tailoring theme carolina herrera trousers cut wool silk blend woven classic prince wales check typically found men suiting high waisted pair fitted hips tapered knees flaring toward ankles complete look matching printed jacket',
#  'designed curated minimalistic style icon elin kling provides updated essentials effortless mix match ideal work weekends high rise ossi tailored full length tailored leg wear matching blazer smart look keep casual oversized knit sneakers',
#  'drawstring waist cropped silhouette bring relaxed lounge inspired attitude pants slight sheen tonal floral pattern silky feel',
#  'drawstring waist cropped silhouette bring relaxed lounge inspired attitude pants slight sheen tonal floral pattern silky feel',
#  'gray cotton jersey slips HIGH_COTTON machine wash designer color tinker',
#  'aquazzura minute sandals crafted polished leather ultra slim straps secure frame foot pair literally take look new heights set slender stiletto heel measuring four inches',
#  'flouncy tie gathers neckline billowy chartreuse dress finished attached hem enhance flowy movement',
#  'anything leopard tends automatically fall chic category factor la double romantic touches like frilly flutter sleeves stunning almost architectural standing collar italian made crepe dress becomes something else entirely oh knee length cut means office appropriate date night friendly pretty back thank tie detail material HIGH_VISCOSE cleanmade italymodel NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE bust NUMERICAL_VALUE waist NUMERICAL_VALUE hips wearing size xs',
#  'gleaming studs outline sole retro inspired slide sandal lofted chunky woodgrain heel platform',
#  'one example season strong tailoring theme carolina herrera trousers cut wool silk blend woven classic prince wales check typically found men suiting high waisted pair fitted hips tapered knees flaring toward ankles complete look matching printed jacket',
#  'one example season strong tailoring theme carolina herrera trousers cut wool silk blend woven classic prince wales check typically found men suiting high waisted pair fitted hips tapered knees flaring toward ankles complete look matching printed jacket',
#  'black ribbed knit slips material material material MEDIAN_WOOL dry clean imported',
#  'black ribbed knit slips material material material MEDIAN_WOOL dry clean imported',
#  'gleaming studs outline sole retro inspired slide sandal lofted chunky woodgrain heel platform',
#  'breezy wide leg pants designed glamorous sweeping silhouette fluid silk',
#  'breezy wide leg pants designed glamorous sweeping silhouette fluid silk',
#  'aquazzura minute sandals crafted polished leather ultra slim straps secure frame foot pair literally take look new heights set slender stiletto heel measuring four inches',
#  'beige washed stretch silk satin slips material HIGH_SILK hand wash designer color fawn imported',
#  'beige washed stretch silk satin slips material HIGH_SILK hand wash designer color fawn imported',
#  'suckers pretty statement top exactly landed tee ladylike twists fits feels like favorite shirt thank soft cotton jersey perked high volume poplin sleeves gather gracefully toward cuffs yes statement shoulders best news treat like tees wear every single pair jeans trousers shorts material clean onlymade italymeasurements size NUMERICAL_VALUE length NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE chest NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE model NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE bust NUMERICAL_VALUE waist NUMERICAL_VALUE hips wearing size NUMERICAL_VALUE',
#  'suckers pretty statement top exactly landed tee ladylike twists fits feels like favorite shirt thank soft cotton jersey perked high volume poplin sleeves gather gracefully toward cuffs yes statement shoulders best news treat like tees wear every single pair jeans trousers shorts material clean onlymade italymeasurements size NUMERICAL_VALUE length NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE chest NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE model NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE bust NUMERICAL_VALUE waist NUMERICAL_VALUE hips wearing size NUMERICAL_VALUE',
#  'black ribbed knit slips material material material MEDIAN_WOOL dry clean imported',
#  'suckers pretty statement top exactly landed tee ladylike twists fits feels like favorite shirt thank soft cotton jersey perked high volume poplin sleeves gather gracefully toward cuffs yes statement shoulders best news treat like tees wear every single pair jeans trousers shorts material clean onlymade italymeasurements size NUMERICAL_VALUE length NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE chest NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE model NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE bust NUMERICAL_VALUE waist NUMERICAL_VALUE hips wearing size NUMERICAL_VALUE',
#  'pointy toe tapered heel balance streamlined silhouette go boot',
#  'pointy toe tapered heel balance streamlined silhouette go boot',
#  'black ribbed knit slips material material material MEDIAN_WOOL dry clean imported',
#  'lift spirits double strap slide sandal perched tall block heel thick platform easy gliding',
#  'enchanting cinderella glass slipper much wearable graceful italian sandal styled transparent straps',
#  'chunky knit marled hues boatneck sweater make cold weather go bonus slightly relaxed fit means drape perfectly tuck front high waisted pants jeans',
#  'chunky knit marled hues boatneck sweater make cold weather go bonus slightly relaxed fit means drape perfectly tuck front high waisted pants jeans',
#  'chunky knit marled hues boatneck sweater make cold weather go bonus slightly relaxed fit means drape perfectly tuck front high waisted pants jeans',
#  'edgy style expert craftsmanship combine block heel combat boot cut sewn lasted hand spanish artisans',
#  'edgy style expert craftsmanship combine block heel combat boot cut sewn lasted hand spanish artisans',
#  'cut soft camel wool max mara chic pacos coat designed broad fringe trimmed lapels cinch waist self tie belt keep phone handy one exaggerated patch pockets front',
#  'ivory crepe slips material material buttons HIGH_ACETATE cow dry clean imported',
#  'ivory crepe slips material material buttons HIGH_ACETATE cow dry clean imported',
#  'knotted ties detail toe strap elegant sandal lifted covered block heel tied adjustable wraparound straps',
#  'knotted ties detail toe strap elegant sandal lifted covered block heel tied adjustable wraparound straps',
#  'knotted ties detail toe strap elegant sandal lifted covered block heel tied adjustable wraparound straps',
#  'edgy style expert craftsmanship combine block heel combat boot cut sewn lasted hand spanish artisans',
#  'breezy wide leg pants designed glamorous sweeping silhouette fluid silk',
#  'multicolored cotton blend button fastening front material material MEDIAN_COTTON fibers buttons LOW_POLYESTER cow dry clean',
#  'multicolored cotton blend button fastening front material material MEDIAN_COTTON fibers buttons LOW_POLYESTER cow dry clean',
#  'ivory jeans dressed toned need straight leg fit skinny constricting super flattering leg elongating silhouette falls past ankles meaning work equally well block heeled boot office low top sneakers kicking around material washmade usamodel NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE bust NUMERICAL_VALUE waist NUMERICAL_VALUE hips wearing size NUMERICAL_VALUE',
#  'chunky knit marled hues boatneck sweater make cold weather go bonus slightly relaxed fit means drape perfectly tuck front high waisted pants jeans',
#  'chunky knit marled hues boatneck sweater make cold weather go bonus slightly relaxed fit means drape perfectly tuck front high waisted pants jeans',
#  'breezy wide leg pants designed glamorous sweeping silhouette fluid silk',
#  'chunky knit marled hues boatneck sweater make cold weather go bonus slightly relaxed fit means drape perfectly tuck front high waisted pants jeans',
#  'brown cashmere mulberry silk blend slips material MEDIAN_CASHMERE silk dry clean designer color bark imported',
#  'brown cashmere mulberry silk blend slips material MEDIAN_CASHMERE silk dry clean designer color bark imported',
#  'brown cashmere mulberry silk blend slips material MEDIAN_CASHMERE silk dry clean designer color bark imported',
#  'brown cashmere mulberry silk blend slips material MEDIAN_CASHMERE silk dry clean designer color bark imported',
#  'sleek sculptural strappy sandal shines metallic snakeskin looks modern square toe slim block heel',
#  'sleek sculptural strappy sandal shines metallic snakeskin looks modern square toe slim block heel',
#  'black leather lamb open top weighs approximately NUMERICAL_VALUE lbs NUMERICAL_VALUE kg imported',
#  'gleaming studs outline sole retro inspired slide sandal lofted chunky woodgrain heel platform',
#  'believe animal prints double neutral prada pumps prime example designed classic leopard motif sleek silhouette ends sharp toe fitted cushioned insoles try styling wide leg trousers give hem lift',
#  'classic crewneck sweatshirt gets luxurious update supremely soft cotton blend',
#  'classic crewneck sweatshirt gets luxurious update supremely soft cotton blend',
#  'believe animal prints double neutral prada pumps prime example designed classic leopard motif sleek silhouette ends sharp toe fitted cushioned insoles try styling wide leg trousers give hem lift',
#  'believe animal prints double neutral prada pumps prime example designed classic leopard motif sleek silhouette ends sharp toe fitted cushioned insoles try styling wide leg trousers give hem lift',
#  'believe animal prints double neutral prada pumps prime example designed classic leopard motif sleek silhouette ends sharp toe fitted cushioned insoles try styling wide leg trousers give hem lift',
#  'crafted italy golden goose hi star sneakers designed brand signature star stamped gold tone logo textured leather uppers set platform rubber sole pair complete suede vamps handwritten text accents highlight chunky heel pairing midi length skirt',
#  'multicolored cotton nylon merino wool alpaca cashmere mohair blend slips material material LOW_COTTON wool material material LOW_NYLON dry clean imported',
#  'classic crewneck sweatshirt gets luxurious update supremely soft cotton blend',
#  'classic crewneck sweatshirt gets luxurious update supremely soft cotton blend',
#  'believe animal prints double neutral prada pumps prime example designed classic leopard motif sleek silhouette ends sharp toe fitted cushioned insoles try styling wide leg trousers give hem lift',
#  'multicolored cotton nylon merino wool alpaca cashmere mohair blend slips material material LOW_COTTON wool material material LOW_NYLON dry clean imported',
#  'raffia wrapped platform wedge hint metallic shimmer makes suede ankle tie sandal refined resort ready standout',
#  'raffia wrapped platform wedge hint metallic shimmer makes suede ankle tie sandal refined resort ready standout',
#  'raffia wrapped platform wedge hint metallic shimmer makes suede ankle tie sandal refined resort ready standout',
#  'believe animal prints double neutral prada pumps prime example designed classic leopard motif sleek silhouette ends sharp toe fitted cushioned insoles try styling wide leg trousers give hem lift',
#  '',
#  '',
#  'camel grain de poudre wool button fastening front material buttons HIGH_WOOL buffalo dry clean made italy',
#  'sinuous straps cross atop lightly cushioned sandal shaped squared toe architectural block heel',
#  '',
#  '',
#  'anything leopard tends automatically fall chic category factor la double romantic touches like frilly flutter sleeves stunning almost architectural standing collar italian made crepe dress becomes something else entirely oh knee length cut means office appropriate date night friendly pretty back thank tie detail material HIGH_VISCOSE cleanmade italymodel NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE bust NUMERICAL_VALUE waist NUMERICAL_VALUE hips wearing size xs',
#  'crafted italy golden goose hi star sneakers designed brand signature star stamped gold tone logo textured leather uppers set platform rubber sole pair complete suede vamps handwritten text accents highlight chunky heel pairing midi length skirt',
#  'webbed straps contrast wedge serrated platform style modern sporty sandal',
#  'enchanting cinderella glass slipper much wearable graceful italian sandal styled transparent straps',
#  'brown cashmere mulberry silk blend slips material MEDIAN_CASHMERE silk dry clean designer color bark imported',
#  'anything leopard tends automatically fall chic category factor la double romantic touches like frilly flutter sleeves stunning almost architectural standing collar italian made crepe dress becomes something else entirely oh knee length cut means office appropriate date night friendly pretty back thank tie detail material HIGH_VISCOSE cleanmade italymodel NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE bust NUMERICAL_VALUE waist NUMERICAL_VALUE hips wearing size xs',
#  'multicolored cotton jersey slips HIGH_COTTON machine wash',
#  'multicolored cotton jersey slips HIGH_COTTON machine wash',
#  'brown cashmere mulberry silk blend slips material MEDIAN_CASHMERE silk dry clean designer color bark imported',
#  'brown cashmere mulberry silk blend slips material MEDIAN_CASHMERE silk dry clean designer color bark imported',
#  'brown cashmere mulberry silk blend slips material MEDIAN_CASHMERE silk dry clean designer color bark imported',
#  'webbed straps contrast wedge serrated platform style modern sporty sandal',
#  'black cotton jersey slips HIGH_COTTON machine wash imported',
#  'black cotton jersey slips HIGH_COTTON machine wash imported',
#  'partnered fabric house southwest france make custom trim hem polished tweed pencil skirt even better also designed matching jacket outfit potential',
#  'partnered fabric house southwest france make custom trim hem polished tweed pencil skirt even better also designed matching jacket outfit potential',
#  'black cotton jersey slips HIGH_COTTON machine wash imported',
#  'black cotton jersey slips HIGH_COTTON machine wash imported',
#  'ivory crepe slips material material buttons HIGH_ACETATE cow dry clean imported',
#  'ivory crepe slips material material buttons HIGH_ACETATE cow dry clean imported',
#  'cut soft camel wool max mara chic pacos coat designed broad fringe trimmed lapels cinch waist self tie belt keep phone handy one exaggerated patch pockets front',
#  'sinuous straps cross atop lightly cushioned sandal shaped squared toe architectural block heel',
#  'italian crafted chelsea boot sleek timeless style low key luxe',
#  'italian crafted chelsea boot sleek timeless style low key luxe',
#  'cut soft camel wool max mara chic pacos coat designed broad fringe trimmed lapels cinch waist self tie belt keep phone handy one exaggerated patch pockets front',
#  'channel inner NUMERICAL_VALUE supermodel day night sandal toe loop mid heel clean geometric angles',
#  'done delivers one two punch comfort confidence cotton tee featuring comic style graphic butt kicking boxer',
#  'dramatic curves sharp angles marry pointy toe bootie made steep slant stacked heel',
#  'black leather lamb open top weighs approximately NUMERICAL_VALUE lbs NUMERICAL_VALUE kg imported',
#  'dramatic curves sharp angles marry pointy toe bootie made steep slant stacked heel',
#  'camel grain de poudre wool button fastening front material buttons HIGH_WOOL buffalo dry clean made italy',
#  'channel inner NUMERICAL_VALUE supermodel day night sandal toe loop mid heel clean geometric angles',
#  'partnered fabric house southwest france make custom trim hem polished tweed pencil skirt even better also designed matching jacket outfit potential',
#  'black stretch pima cotton jersey slips HIGH_PIMA cotton LOW_ELASTANE hand wash imported',
#  'gray cotton jersey slips HIGH_COTTON machine wash designer color tinker',
#  'partnered fabric house southwest france make custom trim hem polished tweed pencil skirt even better also designed matching jacket outfit potential',
#  'easy slide sandal go everywhere shoe brings bit beachy style everyday outfits',
#  'tan leather calf magnetic fastening front flap weighs approximately NUMERICAL_VALUE lbs NUMERICAL_VALUE kg made italy',
#  'tan leather calf magnetic fastening front flap weighs approximately NUMERICAL_VALUE lbs NUMERICAL_VALUE kg made italy',
#  'white virgil abloh fringes popon bag crafted pom pom silhouette fringe details wristlet strap',
#  'easy slide sandal go everywhere shoe brings bit beachy style everyday outfits',
#  'multicolored cotton jersey slips HIGH_COTTON machine wash',
#  'white virgil abloh fringes popon bag crafted pom pom silhouette fringe details wristlet strap',
#  'multicolored cotton jersey slips HIGH_COTTON machine wash',
#  'styled slender mid heel cut vamp flows pointy toe mule looks chic date office',
#  'styled slender mid heel cut vamp flows pointy toe mule looks chic date office',
#  'cut soft camel wool max mara chic pacos coat designed broad fringe trimmed lapels cinch waist self tie belt keep phone handy one exaggerated patch pockets front',
#  'cream crepe slips material material lining material MEDIAN_ACETATE dry clean',
#  'cream crepe slips material material lining material MEDIAN_ACETATE dry clean',
#  '',
#  '',
#  'light blue navy white jersey pull material HIGH_VISCOSE dry clean designer color celeste blue imported',
#  'light blue navy white jersey pull material HIGH_VISCOSE dry clean designer color celeste blue imported',
#  'light blue navy white jersey pull material HIGH_VISCOSE dry clean designer color celeste blue imported',
#  'light blue navy white jersey pull material HIGH_VISCOSE dry clean designer color celeste blue imported',
#  'light blue navy white jersey pull material HIGH_VISCOSE dry clean designer color celeste blue imported',
#  'anaak violeta midi dress cut airy cotton voile artfully embroidered contrasting topstitches fully lined coverage designed delicate shoulder straps neckline keep styling simple pair leather slides',
#  'anaak violeta midi dress cut airy cotton voile artfully embroidered contrasting topstitches fully lined coverage designed delicate shoulder straps neckline keep styling simple pair leather slides',
#  'anaak violeta midi dress cut airy cotton voile artfully embroidered contrasting topstitches fully lined coverage designed delicate shoulder straps neckline keep styling simple pair leather slides',
#  'anaak violeta midi dress cut airy cotton voile artfully embroidered contrasting topstitches fully lined coverage designed delicate shoulder straps neckline keep styling simple pair leather slides',
#  'anaak violeta midi dress cut airy cotton voile artfully embroidered contrasting topstitches fully lined coverage designed delicate shoulder straps neckline keep styling simple pair leather slides',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches olive leather lamb zip fastening along side made italy',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches olive leather lamb zip fastening along side made italy',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches olive leather lamb zip fastening along side made italy',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches olive leather lamb zip fastening along side made italy',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches olive leather lamb zip fastening along side made italy',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches olive leather lamb zip fastening along side made italy',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches olive leather lamb zip fastening along side made italy',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches olive leather lamb zip fastening along side made italy',
#  'black leather cow magnetic fastening front flap weighs approximately NUMERICAL_VALUE lbs NUMERICAL_VALUE kg made italy',
#  'black leather cow magnetic fastening front flap weighs approximately NUMERICAL_VALUE lbs NUMERICAL_VALUE kg made italy',
#  'black leather cow magnetic fastening front flap weighs approximately NUMERICAL_VALUE lbs NUMERICAL_VALUE kg made italy',
#  'black leather cow magnetic fastening front flap weighs approximately NUMERICAL_VALUE lbs NUMERICAL_VALUE kg made italy',
#  'brown alpaca blend material material HIGH_ALPACA wool hand wash designer color mushroom imported',
#  'brown alpaca blend material material HIGH_ALPACA wool hand wash designer color mushroom imported',
#  'brown alpaca blend material material HIGH_ALPACA wool hand wash designer color mushroom imported',
#  'brown alpaca blend material material HIGH_ALPACA wool hand wash designer color mushroom imported',
#  'fan distinctive shapes colors wandler handbags really like brand debut shoe collection label bente mules crafted plush zebra printed calf hair sleek point toe silhouette glossy leather kitten heels create cool contrast',
#  'fan distinctive shapes colors wandler handbags really like brand debut shoe collection label bente mules crafted plush zebra printed calf hair sleek point toe silhouette glossy leather kitten heels create cool contrast',
#  'fan distinctive shapes colors wandler handbags really like brand debut shoe collection label bente mules crafted plush zebra printed calf hair sleek point toe silhouette glossy leather kitten heels create cool contrast',
#  'fan distinctive shapes colors wandler handbags really like brand debut shoe collection label bente mules crafted plush zebra printed calf hair sleek point toe silhouette glossy leather kitten heels create cool contrast',
#  'fan distinctive shapes colors wandler handbags really like brand debut shoe collection label bente mules crafted plush zebra printed calf hair sleek point toe silhouette glossy leather kitten heels create cool contrast',
#  'fan distinctive shapes colors wandler handbags really like brand debut shoe collection label bente mules crafted plush zebra printed calf hair sleek point toe silhouette glossy leather kitten heels create cool contrast',
#  'calling inner vintage goddess kindred mia maxi dress features floral fabric mermaid silhouette slightest train designed deep neckline swooping back top hook closure long keyhole split leading invisible zip fastening fitted waist gives way full maxi skirt ruffled split knee length ending perforated hem light grey contrast binding frames delicate button detailing along front pair brands edie fur mirror brands pre fall NUMERICAL_VALUE lookbook',
#  'calling inner vintage goddess kindred mia maxi dress features floral fabric mermaid silhouette slightest train designed deep neckline swooping back top hook closure long keyhole split leading invisible zip fastening fitted waist gives way full maxi skirt ruffled split knee length ending perforated hem light grey contrast binding frames delicate button detailing along front pair brands edie fur mirror brands pre fall NUMERICAL_VALUE lookbook',
#  'calling inner vintage goddess kindred mia maxi dress features floral fabric mermaid silhouette slightest train designed deep neckline swooping back top hook closure long keyhole split leading invisible zip fastening fitted waist gives way full maxi skirt ruffled split knee length ending perforated hem light grey contrast binding frames delicate button detailing along front pair brands edie fur mirror brands pre fall NUMERICAL_VALUE lookbook',
#  'calling inner vintage goddess kindred mia maxi dress features floral fabric mermaid silhouette slightest train designed deep neckline swooping back top hook closure long keyhole split leading invisible zip fastening fitted waist gives way full maxi skirt ruffled split knee length ending perforated hem light grey contrast binding frames delicate button detailing along front pair brands edie fur mirror brands pre fall NUMERICAL_VALUE lookbook',
#  'soft leather tote opens unlined interior slender straps slip easily shoulder',
#  'soft leather tote opens unlined interior slender straps slip easily shoulder',
#  'soft leather tote opens unlined interior slender straps slip easily shoulder',
#  'soft leather tote opens unlined interior slender straps slip easily shoulder',
#  'soft leather tote opens unlined interior slender straps slip easily shoulder',
#  'soft leather tote opens unlined interior slender straps slip easily shoulder',
#  '',
#  '',
#  '',
#  '',
#  'fringe shawl toss look expertly spun italy merino wool yarns smooth sensuous',
#  'fringe shawl toss look expertly spun italy merino wool yarns smooth sensuous',
#  'fringe shawl toss look expertly spun italy merino wool yarns smooth sensuous',
#  'fringe shawl toss look expertly spun italy merino wool yarns smooth sensuous',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'goldsign designed relaxed bound shirt warm hue brand describes ochre fitted round collar short sleeve style easily transitioned seasonal wardrobe add extra layers weather permits',
#  'beige satin ties side concealed button fastenings front material MEDIAN_CUPRO dry clean imported',
#  'beige satin ties side concealed button fastenings front material MEDIAN_CUPRO dry clean imported',
#  'beige satin ties side concealed button fastenings front material MEDIAN_CUPRO dry clean imported',
#  'handcrafted italy amina muaddi dua ankle boots wonderfully retro silhouette built thick platform soles pair chunky heel upper comes ankle style cropped jeans show best advantage',
#  'handcrafted italy amina muaddi dua ankle boots wonderfully retro silhouette built thick platform soles pair chunky heel upper comes ankle style cropped jeans show best advantage',
#  'goldsign designed relaxed bound shirt warm hue brand describes ochre fitted round collar short sleeve style easily transitioned seasonal wardrobe add extra layers weather permits',
#  'goldsign designed relaxed bound shirt warm hue brand describes ochre fitted round collar short sleeve style easily transitioned seasonal wardrobe add extra layers weather permits',
#  'goldsign designed relaxed bound shirt warm hue brand describes ochre fitted round collar short sleeve style easily transitioned seasonal wardrobe add extra layers weather permits',
#  'goldsign designed relaxed bound shirt warm hue brand describes ochre fitted round collar short sleeve style easily transitioned seasonal wardrobe add extra layers weather permits',
#  'clean trouser goldsign crafted figure flattering wide leg skim boots rigid construction worry stretching throughout day pair lightweight tonal knits sleek monochromatic look',
#  'clean trouser goldsign crafted figure flattering wide leg skim boots rigid construction worry stretching throughout day pair lightweight tonal knits sleek monochromatic look',
#  'clean trouser goldsign crafted figure flattering wide leg skim boots rigid construction worry stretching throughout day pair lightweight tonal knits sleek monochromatic look',
#  'clean trouser goldsign crafted figure flattering wide leg skim boots rigid construction worry stretching throughout day pair lightweight tonal knits sleek monochromatic look',
#  'clean trouser goldsign crafted figure flattering wide leg skim boots rigid construction worry stretching throughout day pair lightweight tonal knits sleek monochromatic look',
#  'clean trouser goldsign crafted figure flattering wide leg skim boots rigid construction worry stretching throughout day pair lightweight tonal knits sleek monochromatic look',
#  'clean trouser goldsign crafted figure flattering wide leg skim boots rigid construction worry stretching throughout day pair lightweight tonal knits sleek monochromatic look',
#  'multicolored knit construction feels fresh lace sneaker silhouette',
#  'multicolored knit construction feels fresh lace sneaker silhouette',
#  'multicolored knit construction feels fresh lace sneaker silhouette',
#  'multicolored knit construction feels fresh lace sneaker silhouette',
#  'slim silhouette cropped ankle exquisitely tailored finish define chic trousers crafted crisp cotton hint silk lined added comfort',
#  'slim silhouette cropped ankle exquisitely tailored finish define chic trousers crafted crisp cotton hint silk lined added comfort',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'akris skirt crafted buttery lamb leather wrap style falls knee try styling slim fitting turtleneck',
#  'akris skirt crafted buttery lamb leather wrap style falls knee try styling slim fitting turtleneck',
# ...
#  'high waisted wide leg pant full length cut made fluid twill fabric designed smooth look beautiful drape soft feel skin zip fly hook bar closure front slant pockets rear welt pockets flat front trouser crease side stripe piping accent side vents hem measure NUMERICAL_VALUE unlined',
#  'rotate sequined mini dress designed slim strap silhouette neckline sequin pattern creates floral like detail',
#  'rotate sequined mini dress designed slim strap silhouette neckline sequin pattern creates floral like detail',
#  'rotate sequined mini dress designed slim strap silhouette neckline sequin pattern creates floral like detail',
#  'rotate sequined mini dress designed slim strap silhouette neckline sequin pattern creates floral like detail',
#  'fresh take lbd spaghetti strap version trumpet style silhouette delicate sheer mesh accent neckline luxe feminine look neck mesh accent adjustable slider straps invisible zipper back flounce hem fully lined',
#  'fresh take lbd spaghetti strap version trumpet style silhouette delicate sheer mesh accent neckline luxe feminine look neck mesh accent adjustable slider straps invisible zipper back flounce hem fully lined',
#  '',
#  '',
#  '',
#  '',
#  'iconic style japanese influence designed sized specifically japan customers available online part highly limited edition collection elongating wide leg silhouette blake pant equal parts modern stylish classic wide leg trouser expertly cut flattering fit comfortable chic made soft stretch fabric tie waist zip side vertical welt front pockets rear welt pockets flat front trouser crease unlined please consult size guide find best fit',
#  'iconic style japanese influence designed sized specifically japan customers available online part highly limited edition collection elongating wide leg silhouette blake pant equal parts modern stylish classic wide leg trouser expertly cut flattering fit comfortable chic made soft stretch fabric tie waist zip side vertical welt front pockets rear welt pockets flat front trouser crease unlined please consult size guide find best fit',
#  'iconic style japanese influence designed sized specifically japan customers available online part highly limited edition collection elongating wide leg silhouette blake pant equal parts modern stylish classic wide leg trouser expertly cut flattering fit comfortable chic made soft stretch fabric tie waist zip side vertical welt front pockets rear welt pockets flat front trouser crease unlined please consult size guide find best fit',
#  'iconic style japanese influence designed sized specifically japan customers available online part highly limited edition collection elongating wide leg silhouette blake pant equal parts modern stylish classic wide leg trouser expertly cut flattering fit comfortable chic made soft stretch fabric tie waist zip side vertical welt front pockets rear welt pockets flat front trouser crease unlined please consult size guide find best fit',
#  'figure flattering midi dress sleek sheath silhouette neck adjustable slider straps invisible zipper back flounce hem lined bodice unlined skirt high low hem',
#  'figure flattering midi dress sleek sheath silhouette neck adjustable slider straps invisible zipper back flounce hem lined bodice unlined skirt high low hem',
#  'figure flattering midi dress sleek sheath silhouette neck adjustable slider straps invisible zipper back flounce hem lined bodice unlined skirt high low hem',
#  'figure flattering midi dress sleek sheath silhouette neck adjustable slider straps invisible zipper back flounce hem lined bodice unlined skirt high low hem',
#  'zeynep pants crafted genuine leather flattering high waisted fit full length leg slim silhouette pair brand wrap leather blazer mirror fall winter NUMERICAL_VALUE lookbook style',
#  'zeynep pants crafted genuine leather flattering high waisted fit full length leg slim silhouette pair brand wrap leather blazer mirror fall winter NUMERICAL_VALUE lookbook style',
#  'zeynep pants crafted genuine leather flattering high waisted fit full length leg slim silhouette pair brand wrap leather blazer mirror fall winter NUMERICAL_VALUE lookbook style',
#  'zeynep pants crafted genuine leather flattering high waisted fit full length leg slim silhouette pair brand wrap leather blazer mirror fall winter NUMERICAL_VALUE lookbook style',
#  'supple faux leather brings glamorous edge tailored shorts',
#  'supple faux leather brings glamorous edge tailored shorts',
#  'supple faux leather brings glamorous edge tailored shorts',
#  'supple faux leather brings glamorous edge tailored shorts',
#  'cigarette pants cut gingham blithe look',
#  'cigarette pants cut gingham blithe look',
#  'cigarette pants cut gingham blithe look',
#  'cigarette pants cut gingham blithe look',
#  'throw back cropped shirt fine ribbed texture back seam detail',
#  'throw back cropped shirt fine ribbed texture back seam detail',
#  'throw back cropped shirt fine ribbed texture back seam detail',
#  'throw back cropped shirt fine ribbed texture back seam detail',
#  'partow crepe everly midi skirt tailored high rise fit designed line silhouette fluid shape detailed concealed front pockets relaxed pleats style matching dress complete look',
#  'partow crepe everly midi skirt tailored high rise fit designed line silhouette fluid shape detailed concealed front pockets relaxed pleats style matching dress complete look',
#  'partow crepe everly midi skirt tailored high rise fit designed line silhouette fluid shape detailed concealed front pockets relaxed pleats style matching dress complete look',
#  'partow crepe everly midi skirt tailored high rise fit designed line silhouette fluid shape detailed concealed front pockets relaxed pleats style matching dress complete look',
#  'shoulder baring design airy cotton handle cult gaia claire top perfectly suited warm weather months long sleeve style tie detailed front tiered puffed sleeves fall knuckle grazing length highlight split hem high rise shorts',
#  'shoulder baring design airy cotton handle cult gaia claire top perfectly suited warm weather months long sleeve style tie detailed front tiered puffed sleeves fall knuckle grazing length highlight split hem high rise shorts',
#  'shoulder baring design airy cotton handle cult gaia claire top perfectly suited warm weather months long sleeve style tie detailed front tiered puffed sleeves fall knuckle grazing length highlight split hem high rise shorts',
#  'shoulder baring design airy cotton handle cult gaia claire top perfectly suited warm weather months long sleeve style tie detailed front tiered puffed sleeves fall knuckle grazing length highlight split hem high rise shorts',
#  'shoulder baring design airy cotton handle cult gaia claire top perfectly suited warm weather months long sleeve style tie detailed front tiered puffed sleeves fall knuckle grazing length highlight split hem high rise shorts',
#  'shoulder baring design airy cotton handle cult gaia claire top perfectly suited warm weather months long sleeve style tie detailed front tiered puffed sleeves fall knuckle grazing length highlight split hem high rise shorts',
#  'shoulder baring design airy cotton handle cult gaia claire top perfectly suited warm weather months long sleeve style tie detailed front tiered puffed sleeves fall knuckle grazing length highlight split hem high rise shorts',
#  'shoulder baring design airy cotton handle cult gaia claire top perfectly suited warm weather months long sleeve style tie detailed front tiered puffed sleeves fall knuckle grazing length highlight split hem high rise shorts',
#  'isabel marant welly shirt cut oversized fit enhanced season prominent shoulder made cotton poplin striped motif draped scarf inspired cowl neck style tapered wool trouser complement tailoring',
#  'isabel marant welly shirt cut oversized fit enhanced season prominent shoulder made cotton poplin striped motif draped scarf inspired cowl neck style tapered wool trouser complement tailoring',
#  'isabel marant welly shirt cut oversized fit enhanced season prominent shoulder made cotton poplin striped motif draped scarf inspired cowl neck style tapered wool trouser complement tailoring',
#  'isabel marant welly shirt cut oversized fit enhanced season prominent shoulder made cotton poplin striped motif draped scarf inspired cowl neck style tapered wool trouser complement tailoring',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches clear pvc beige suede calf elasticated slingback strap designer color nude made italysmall size see size fit notes',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches clear pvc beige suede calf elasticated slingback strap designer color nude made italysmall size see size fit notes',
#  'biker jackets simple way elevate casual edit grlfrnd charlie rendition crafted textured leather detailed functional silver tone zip fastenings buckled belt cinch boxy shape complement cropped hem high rise jeans',
#  'biker jackets simple way elevate casual edit grlfrnd charlie rendition crafted textured leather detailed functional silver tone zip fastenings buckled belt cinch boxy shape complement cropped hem high rise jeans',
#  'biker jackets simple way elevate casual edit grlfrnd charlie rendition crafted textured leather detailed functional silver tone zip fastenings buckled belt cinch boxy shape complement cropped hem high rise jeans',
#  'biker jackets simple way elevate casual edit grlfrnd charlie rendition crafted textured leather detailed functional silver tone zip fastenings buckled belt cinch boxy shape complement cropped hem high rise jeans',
#  'biker jackets simple way elevate casual edit grlfrnd charlie rendition crafted textured leather detailed functional silver tone zip fastenings buckled belt cinch boxy shape complement cropped hem high rise jeans',
#  'biker jackets simple way elevate casual edit grlfrnd charlie rendition crafted textured leather detailed functional silver tone zip fastenings buckled belt cinch boxy shape complement cropped hem high rise jeans',
#  'biker jackets simple way elevate casual edit grlfrnd charlie rendition crafted textured leather detailed functional silver tone zip fastenings buckled belt cinch boxy shape complement cropped hem high rise jeans',
#  'biker jackets simple way elevate casual edit grlfrnd charlie rendition crafted textured leather detailed functional silver tone zip fastenings buckled belt cinch boxy shape complement cropped hem high rise jeans',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'antique rose silk satin slips HIGH_SILK dry clean designer color wood rose',
#  'antique rose silk satin slips HIGH_SILK dry clean designer color wood rose',
#  'antique rose silk satin slips HIGH_SILK dry clean designer color wood rose',
#  'antique rose silk satin slips HIGH_SILK dry clean designer color wood rose',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'detailed contrasting strap along ankle dorothee schumacher mirror touch pointed toe booties crafted leather metallic finish stiletto heel add twist classic look wearing tailored pants structured jacket',
#  'detailed contrasting strap along ankle dorothee schumacher mirror touch pointed toe booties crafted leather metallic finish stiletto heel add twist classic look wearing tailored pants structured jacket',
#  'detailed contrasting strap along ankle dorothee schumacher mirror touch pointed toe booties crafted leather metallic finish stiletto heel add twist classic look wearing tailored pants structured jacket',
#  'detailed contrasting strap along ankle dorothee schumacher mirror touch pointed toe booties crafted leather metallic finish stiletto heel add twist classic look wearing tailored pants structured jacket',
#  'detailed contrasting strap along ankle dorothee schumacher mirror touch pointed toe booties crafted leather metallic finish stiletto heel add twist classic look wearing tailored pants structured jacket',
#  'detailed contrasting strap along ankle dorothee schumacher mirror touch pointed toe booties crafted leather metallic finish stiletto heel add twist classic look wearing tailored pants structured jacket',
#  '',
#  '',
#  '',
#  '',
#  'whether headed farmhouse veranda urban terrace modern prairie appeal lacy cotton maxi dress welcome',
#  'whether headed farmhouse veranda urban terrace modern prairie appeal lacy cotton maxi dress welcome',
#  'whether headed farmhouse veranda urban terrace modern prairie appeal lacy cotton maxi dress welcome',
#  'whether headed farmhouse veranda urban terrace modern prairie appeal lacy cotton maxi dress welcome',
#  'whether headed farmhouse veranda urban terrace modern prairie appeal lacy cotton maxi dress welcome',
#  'whether headed farmhouse veranda urban terrace modern prairie appeal lacy cotton maxi dress welcome',
#  'perfect workday beyond victoria beckham modest dress designed drop sleeves knee length hem relaxed style detailed contrast piping along front back coordinate burgundy ankle boots',
#  'perfect workday beyond victoria beckham modest dress designed drop sleeves knee length hem relaxed style detailed contrast piping along front back coordinate burgundy ankle boots',
#  'perfect workday beyond victoria beckham modest dress designed drop sleeves knee length hem relaxed style detailed contrast piping along front back coordinate burgundy ankle boots',
#  'perfect workday beyond victoria beckham modest dress designed drop sleeves knee length hem relaxed style detailed contrast piping along front back coordinate burgundy ankle boots',
#  'perfect workday beyond victoria beckham modest dress designed drop sleeves knee length hem relaxed style detailed contrast piping along front back coordinate burgundy ankle boots',
#  'perfect workday beyond victoria beckham modest dress designed drop sleeves knee length hem relaxed style detailed contrast piping along front back coordinate burgundy ankle boots',
#  'bouguessa classic blazer designed neckline pocket flaps belted waist pair matching pants create ultimate power suit',
#  'bouguessa classic blazer designed neckline pocket flaps belted waist pair matching pants create ultimate power suit',
#  'bouguessa classic blazer designed neckline pocket flaps belted waist pair matching pants create ultimate power suit',
#  'bouguessa classic blazer designed neckline pocket flaps belted waist pair matching pants create ultimate power suit',
#  'carry essentials style rich leather briefcase removable crossbody strap',
#  'carry essentials style rich leather briefcase removable crossbody strap',
#  'carry essentials style rich leather briefcase removable crossbody strap',
#  'carry essentials style rich leather briefcase removable crossbody strap',
#  'loveshackfancy queenie ultra feminine silk dress designed ruffled hemline floral print pair minimalist accessories keep dress focus',
#  'loveshackfancy queenie ultra feminine silk dress designed ruffled hemline floral print pair minimalist accessories keep dress focus',
#  'loveshackfancy queenie ultra feminine silk dress designed ruffled hemline floral print pair minimalist accessories keep dress focus',
#  'loveshackfancy queenie ultra feminine silk dress designed ruffled hemline floral print pair minimalist accessories keep dress focus',
#  '',
#  '',
#  '',
#  '',
#  'cinched waist accentuate natural curves loveshackfancy cheyenne cotton skirt designed floral print fitted waist pair sweater fun transitional look',
#  'cinched waist accentuate natural curves loveshackfancy cheyenne cotton skirt designed floral print fitted waist pair sweater fun transitional look',
#  'cinched waist accentuate natural curves loveshackfancy cheyenne cotton skirt designed floral print fitted waist pair sweater fun transitional look',
#  'cinched waist accentuate natural curves loveshackfancy cheyenne cotton skirt designed floral print fitted waist pair sweater fun transitional look',
#  'cream silk satin pull HIGH_SILK dry clean made france',
#  'cream silk satin pull HIGH_SILK dry clean made france',
#  ...]

# %% [markdown]
# # Brand Feature Pre-Processing (Regex)

# %%
def removeSpecialChars(z):
    
    return z.translate ({ord(c): "" for c in "!@#$%^&*()[]{};:,./'<>?\|`~-=_+"})

def initial_clean(data,column):
    
    data[column]=data[column].apply(str)
    data[column]=data[column].apply(lambda x:x.lower())
    data[column]=data[column].apply(lambda x:re.sub("[\(\[].*?[\)\]]", "", x))
    data[column]=data[column].apply(lambda x:removeSpecialChars(x))
    
initial_clean(data1,'brand')

# %%
brand = data1['brand'].fillna(" ")
stopwords = ['by','and','the','of','for','to','inc','','a','an']
def remove_stopwords(text: str):
    tokens = nltk.word_tokenize(text)
    filtered_tokens = list(filter(lambda token: token not in stopwords, tokens))
    return " ".join(filtered_tokens)
brand = brand.apply(remove_stopwords)

# %%
brand
# Out:
# 0                       albus lumen
# 1                            redone
# 2                            redone
# 3        atm anthony thomas melillo
# 4                    sally lapointe
#                     ...
# 92025                        movado
# 92026                  ralph lauren
# 92027                        lobjet
# 92028                       bonobos
# 92029                      tom ford
# Name: brand, Length: 68326, dtype: object

# %% [markdown]
# # Details Feature Pre-Processsing (Regex)

# %%
#get required features and fill in null values with blank
df1=data1["details"]
df1=df1.fillna(" ")

# %% [markdown]
# #extract all % number in details as a new column
# perc=df1.str.findall(r"(\d+)(?:%)\s(\w+)")
# result=[]
# temp_result=[]
# temp=""
# for i in range(len(perc)):
#     if perc[i]!=[]:
#         for j in range(len(perc[i])):
#             if int(perc[i][j][0])>=80:
#                 temp="High_"+perc[i][j][1]
#             elif int(perc[i][j][0])>=60:
#                 temp="Medium_"+perc[i][j][1]
#             else:
#                 temp="Low_"+perc[i][j][1]
#             temp_result.append(temp)
#         result.append(temp_result)
#         temp=""
#         temp_result=[]
#     else:
#         result.append("")

# %%
#remove punctuations and numbers
df1=df1.apply(lambda x: x.lower()).str.replace(r"[^a-z\s]+", "", case=False)
df1=df1.str.replace(r"\r\n", " ", case=False)
df1
# Out:
# 0        this items measurements are depth cm height cm...
# 1        true to size xs s m l snap closure crewneck lo...
# 2        true to size xs s m l snap closure crewneck lo...
# 3        fits true to size take your normal size cut fo...
# 4        as seen on the fall  runway removable waist un...
#                                ...
# 92025    digital smart module stationary black bezel go...
# 92026    belt loops button closure zip fly front angled...
# 92027    depth about  earthenware dishwasher safe made ...
# 92028    cotton dress pants that matched your formal we...
# 92029     uv protection gradient lenses cloth and case ...
# Name: details, Length: 68326, dtype: object

# %%
count=word_count(list(df1))
count_sort=sorted((value, key) for (key, value) in count.items())[::-1]

# %%
from nltk.corpus import stopwords
nltk.download("stopwords")
# set(stopwords.words("English"))
nltk_stopwords = list(set(stopwords.words("English")))
count_sorted_set = set(pd.DataFrame(count_sort[:100])[1])
count_sorted_set.difference_update(nltk_stopwords)
nltk_stopwords.extend(["","h","l","mm","w","x","xl","xs","cm","uv"])

def remove_stopwords(title: str):
    tokens = nltk.word_tokenize(title)
    filtered_tokens = list(filter(lambda token: token not in nltk_stopwords, tokens))
    return " ".join(filtered_tokens)
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Sharon
# [nltk_data]     Jia\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#check spelling and remove stopwords
#df1["details"]=df1["details"].apply(lambda x: spellcheck_document(x))
df1=df1.apply(lambda x: remove_stopwords(x))
df1
# Out:
# 0                    items measurements depth height width
# 1        true size snap closure crewneck long sleeves m...
# 2        true size snap closure crewneck long sleeves m...
# 3        fits true size take normal size cut slim fit l...
# 4        seen fall runway removable waist unlined butto...
#                                ...
# 92025    digital smart module stationary black bezel go...
# 92026    belt loops button closure zip fly front angled...
# 92027      depth earthenware dishwasher safe made portugal
# 92028    cotton dress pants matched formal wear belt lo...
# 92029    protection gradient lenses cloth case included...
# Name: details, Length: 68326, dtype: object

# %% [markdown]
# # Product Name Pre-Processing (Regex)

# %%
# Make everything lowercase
product_full_name = data1['product_full_name'].str.lower()
# Remove hyphen
product_full_name = product_full_name.str.replace("-","",case=False)
# Remove numbers
product_full_name = product_full_name.str.replace(r'[0-9]+',"",case=False)
# Remove special characters and stop words
import nltk
stopwords = ['&','|',',','.',"'",'in','le','mm','and','with','the','k','x','les','de','of',"'s"]
def remove_stopwords(text: str):
    tokens = nltk.word_tokenize(text)
    filtered_tokens = list(filter(lambda token: token not in stopwords, tokens))
    return " ".join(filtered_tokens)
product_full_name = product_full_name.apply(remove_stopwords)

# %% [markdown]
# # Lemmatization

# %%
list(df1)
# Out:
# ['items measurements depth height width',
#  'true size snap closure crewneck long sleeves modal spandex machine wash tumble dry made usa imported fabric via c',
#  'true size snap closure crewneck long sleeves modal spandex machine wash tumble dry made usa imported fabric via c',
#  'fits true size take normal size cut slim fit lightweight stretchy fabric take next size wish achieve comfortable fit model wearing size small',
#  'seen fall runway removable waist unlined button concealed zip fastening front composition calf skin specialist clean made usa model wearing sample size us item fits true size recommend taking normal size',
#  'fits true size take normal size cut loose fit midweight slightly stretchy fabric model wearing us',
#  'fits true size take normal size cut loose fit midweight slightly stretchy fabric model wearing us',
#  'seen fall runway removable waist unlined button concealed zip fastening front composition calf skin specialist clean made usa model wearing sample size us item fits true size recommend taking normal size',
#  'seen fall runway removable waist unlined button concealed zip fastening front composition calf skin specialist clean made usa model wearing sample size us item fits true size recommend taking normal size',
#  'fits true size take normal size italian sizing',
#  'fits true size take normal size italian sizing',
#  'true size wide calf circumference check measurements ensure good fit',
#  'true size ties ankle leather upper lining sole made brazil salon shoes',
#  'true size ties ankle leather upper lining sole made brazil salon shoes',
#  'fits true size take normal size italian sizing',
#  'fits true size take normal size italian sizing',
#  'fits true size take normal size cut loose fit midweight slightly stretchy fabric model wearing us',
#  'fits true size take normal size cut loose fit midweight slightly stretchy fabric model wearing us',
#  'fits true size take normal size designed slim fit midweight nonstretchy fabric model wearing',
#  'fits true size take normal size cut loose fit midweight slightly stretchy fabric model wearing us',
#  'fits true size take normal size cut slim fit lightweight stretchy fabric take next size wish achieve comfortable fit model wearing size small',
#  'true size wide calf circumference check measurements ensure good fit',
#  '',
#  '',
#  'fits true size take normal size cut slim fit lightweight stretchy fabric take next size wish achieve comfortable fit model wearing size small',
#  'fashioned highquality materials designed comfort shoes keep stylish toes flexible suede upper breathable synthetic lining insole added stability heel exclusive padding system features memory foam cushioned insole designed allday comfort flexible skidresistant outsole comfort pod bottom suede imported heel height',
#  'fashioned highquality materials designed comfort shoes keep stylish toes flexible suede upper breathable synthetic lining insole added stability heel exclusive padding system features memory foam cushioned insole designed allday comfort flexible skidresistant outsole comfort pod bottom suede imported heel height',
#  'fits true size take normal size intended fitted hip loosely cut top midweight slightly stretchy fabric model wearing designers size',
#  'fits true size take normal size intended fitted hip loosely cut top midweight slightly stretchy fabric model wearing designers size',
#  'fits true size take normal size intended fitted hip loosely cut top midweight slightly stretchy fabric model wearing designers size',
#  'fits true size take normal size designed slim fit midweight nonstretchy fabric model wearing',
#  'items measurements depth height width',
#  'fits true size take normal size intended fitted hip loosely cut top midweight slightly stretchy fabric model wearing designers size',
#  '',
#  '',
#  'sizes order next size',
#  'fits true size take normal size designed slim fit slightly short length lightweight open knit model wearing size xsmall',
#  'lace front composition suede leather rubber made italy heel measures approx highthis style fits true sizewe suggest taking normal size',
#  'true size heel size shaft laceup style leather upper liningleather synthetic sole made spain salon shoes',
#  'true size',
#  '',
#  'true size',
#  'runs small order next size',
#  '',
#  'lean lengthening silhouette onebutton closure accentuate waist notch lapel long sleeves onebutton cuffs two exterior pockets centerback vent fully lined stretch lining comfort ease movement shell polyester rayon elastane lining polyester spandex machine wash cold gentle cycle line dry cool iron needed dry clean tumble dry imported looking matching pant long lean fit slim waist shoulder sleeve hits hip center back length size petite regular tall sleeve length petite regular tall model size',
#  'lean lengthening silhouette onebutton closure accentuate waist notch lapel long sleeves onebutton cuffs two exterior pockets centerback vent fully lined stretch lining comfort ease movement shell polyester rayon elastane lining polyester spandex machine wash cold gentle cycle line dry cool iron needed dry clean tumble dry imported looking matching pant long lean fit slim waist shoulder sleeve hits hip center back length size petite regular tall sleeve length petite regular tall model size',
#  'true size heel size shaft laceup style leather upper liningleather synthetic sole made spain salon shoes',
#  'lean lengthening silhouette onebutton closure accentuate waist notch lapel long sleeves onebutton cuffs two exterior pockets centerback vent fully lined stretch lining comfort ease movement shell polyester rayon elastane lining polyester spandex machine wash cold gentle cycle line dry cool iron needed dry clean tumble dry imported looking matching pant long lean fit slim waist shoulder sleeve hits hip center back length size petite regular tall sleeve length petite regular tall model size',
#  'lean lengthening silhouette onebutton closure accentuate waist notch lapel long sleeves onebutton cuffs two exterior pockets centerback vent fully lined stretch lining comfort ease movement shell polyester rayon elastane lining polyester spandex machine wash cold gentle cycle line dry cool iron needed dry clean tumble dry imported looking matching pant long lean fit slim waist shoulder sleeve hits hip center back length size petite regular tall sleeve length petite regular tall model size',
#  'button concealed zip fastening front composition cotton machine wash designer color graceful made usa style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size',
#  'button concealed zip fastening front composition cotton machine wash designer color graceful made usa style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size',
#  'button concealed zip fastening front composition cotton machine wash designer color graceful made usa style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size',
#  '',
#  'seen fall runway removable waist unlined button concealed zip fastening front composition calf skin specialist clean made usa model wearing sample size us item fits true size recommend taking normal size',
#  'fits small size take full size larger normal italian sizing',
#  'fits small size take full size larger normal italian sizing',
#  'fits small size take full size larger normal italian sizing',
#  'featured prefall lookbook draped wrap front side slit detail unlined slips composition silk dry clean made italy model wearing sample size style fits true size suggest taking usual size',
#  'pair one kind fit vary generally recommend ordering one size high rise inseam leg opening front rise back rise size zip fly hookandbar closure front scoop pockets back besom pockets partially lined wool polyamide dry clean made italy via c',
#  'pair one kind fit vary generally recommend ordering one size high rise inseam leg opening front rise back rise size zip fly hookandbar closure front scoop pockets back besom pockets partially lined wool polyamide dry clean made italy via c',
#  'seen fall runway removable waist unlined button concealed zip fastening front composition calf skin specialist clean made usa model wearing sample size us item fits true size recommend taking normal size',
#  'true size heel size shaft laceup style leather upper liningleather synthetic sole made spain salon shoes',
#  'true size heel size strap height adjustable strap buckle closure cushioned footbed leather uppersynthetic liningleather sole imported womens shoes',
#  'true size heel size strap height adjustable strap buckle closure cushioned footbed leather uppersynthetic liningleather sole imported womens shoes',
#  '',
#  'featured prefall lookbook draped wrap front side slit detail unlined slips composition silk dry clean made italy model wearing sample size style fits true size suggest taking usual size',
#  'true size length size medium front snap closure spread collar long sleeves snap cuffs chest snapflap pockets cotton machine wash tumble dry imported via c',
#  'true size length size medium front snap closure spread collar long sleeves snap cuffs chest snapflap pockets cotton machine wash tumble dry imported via c',
#  '',
#  'button concealed zip fastening front composition polyamide wool imported style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size small',
#  'fits true size take normal size highrise intended relaxed fit drawstring waist designed comfortable fit midweight stretchy fabric model wearing size xsmall',
#  'button concealed zip fastening front composition polyamide wool imported style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size small',
#  'items measurements depth handle drop height max strap length min strap length width',
#  'runs small order next size',
#  'featured prefall lookbook draped wrap front side slit detail unlined slips composition silk dry clean made italy model wearing sample size style fits true size suggest taking usual size',
#  'button concealed zip fastening front composition polyamide wool imported style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size small',
#  'featured prefall lookbook draped wrap front side slit detail unlined slips composition silk dry clean made italy model wearing sample size style fits true size suggest taking usual size',
#  'sizes order next size',
#  'sizes order next size',
#  'items measurements depth handle drop height max strap length min strap length width',
#  'lace front composition suede leather rubber made italy heel measures approx highthis style fits true sizewe suggest taking normal size',
#  'fits true size take normal size designed slim fit slightly short length lightweight open knit model wearing size xsmall',
#  'items measurements depth height width',
#  '',
#  'true size',
#  'fits true size take normal size cut relaxed fit midweight nonstretchy fabric model wearing uk',
#  'fits true size take normal size cut relaxed fit midweight nonstretchy fabric model wearing uk',
#  'fits true size take normal size intended fitted hip loosely cut top midweight slightly stretchy fabric model wearing designers size',
#  '',
#  'fits small size take full size larger normal italian sizing',
#  'button concealed zip fastening front composition polyamide wool imported style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size small',
#  'button concealed zip fastening front composition polyamide wool imported style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size small',
#  'fits true size take normal size cut slim fit lightweight slightly stretchy fabric model wearing uk',
#  'fits small size take full size larger normal italian sizing',
#  'fits true size take normal size cut slim fit lightweight slightly stretchy fabric model wearing uk',
#  'fits small size take full size larger normal italian sizing',
#  'fits true size take normal size intended fitted hip loosely cut top midweight slightly stretchy fabric model wearing designers size',
#  'fits true size take normal size highrise intended relaxed fit drawstring waist designed comfortable fit midweight stretchy fabric model wearing size xsmall',
#  'fits true size take normal size cut relaxed fit midweight nonstretchy fabric model wearing uk',
#  'fits true size take normal size highrise cut relaxed fit elasticated waist flexible fit midweight stretchy fabric model wearing size xsmall',
#  'fits true size take normal size cut relaxed fit midweight nonstretchy fabric model wearing uk',
#  'true size',
#  'fits true size take normal size highrise cut relaxed fit elasticated waist flexible fit midweight stretchy fabric model wearing size xsmall',
#  'fits small size take full size larger normal italian sizing',
#  '',
#  '',
#  'true size',
#  '',
#  '',
#  '',
#  'true size',
#  'button concealed zip fastening front composition cotton machine wash designer color graceful made usa style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size',
#  'button concealed zip fastening front composition cotton machine wash designer color graceful made usa style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size',
#  'button concealed zip fastening front composition cotton machine wash designer color graceful made usa style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size',
#  'heel height measures approximately inches bucklefastening ankle strap composition leather made italy heel measures approx highthis style fits true sizewe suggest taking normal size',
#  'heel height measures approximately inches bucklefastening ankle strap composition leather made italy heel measures approx highthis style fits true sizewe suggest taking normal size',
#  'button concealed zip fastening front composition virgin wool silk dry clean made usa style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size us',
#  'button concealed zip fastening front composition virgin wool silk dry clean made usa style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size us',
#  'button concealed zip fastening front composition polyamide wool imported style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size small',
#  'true size high rise inseam leg opening front rise back rise size elasticdrawstring waist front slant pockets back patch pocket viscose rayon hand wash dry flat made usa via c',
#  'true size high rise inseam leg opening front rise back rise size elasticdrawstring waist front slant pockets back patch pocket viscose rayon hand wash dry flat made usa via c',
#  'fits true size take normal size intended fitted hip loosely cut top midweight slightly stretchy fabric model wearing designers size',
#  'heel height measures approximately inches bucklefastening ankle strap composition leather made italy heel measures approx highthis style fits true sizewe suggest taking normal size',
#  'true size',
#  '',
#  'sizes order next size',
#  'button concealed zip fastening front composition virgin wool silk dry clean made usa style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size us',
#  'button concealed zip fastening front composition virgin wool silk dry clean made usa style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size us',
#  'fits true size take normal size designed relaxed fit dropped shoulder seam midweight knit model wearing size small',
#  'fits true size take normal size designed relaxed fit dropped shoulder seam midweight knit model wearing size small',
#  'sizes order next size',
#  'elasticized drawstring waist side slip pockets pullon style silk dry clean made italy size fitwide leg inseam model shown wearing us size',
#  'elasticized drawstring waist side slip pockets pullon style silk dry clean made italy size fitwide leg inseam model shown wearing us size',
#  'heel height measures approximately inches bucklefastening ankle strap composition leather made italy heel measures approx highthis style fits true sizewe suggest taking normal size',
#  'fits true size take normal size cut slightly loose fit lightweight slightly stretchy fabric model wearing designers size',
#  'fits true size take normal size cut slightly loose fit lightweight slightly stretchy fabric model wearing designers size',
#  '',
#  '',
#  'fits true size take normal size designed relaxed fit dropped shoulder seam midweight knit model wearing size small',
#  '',
#  'runs small order size',
#  'runs small order size',
#  'fits true size take normal size designed relaxed fit dropped shoulder seam midweight knit model wearing size small',
#  'true size heel platform size elastic gore inset leather upper liningleather rubber sole imported womens shoes',
#  'runs small order next size',
#  '',
#  '',
#  '',
#  'true size heel size shaft laceup style leather upper liningleather synthetic sole made spain salon shoes',
#  'true size heel size shaft laceup style leather upper liningleather synthetic sole made spain salon shoes',
#  'tie fastening front dry clean composition camel wool made italy style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size',
#  'fits true size take normal size designed loose fit lightweight nonstretchy fabric model wearing size xsmall',
#  'fits true size take normal size designed loose fit lightweight nonstretchy fabric model wearing size xsmall',
#  'true size heel size adjustable ankle strap tie closure leather upper lining sole made brazil salon shoes',
#  'true size heel size adjustable ankle strap tie closure leather upper lining sole made brazil salon shoes',
#  'true size heel size adjustable ankle strap tie closure leather upper lining sole made brazil salon shoes',
#  'true size heel size shaft laceup style leather upper liningleather synthetic sole made spain salon shoes',
#  'elasticized drawstring waist side slip pockets pullon style silk dry clean made italy size fitwide leg inseam model shown wearing us size',
#  'fits true size take normal size model wearing size larger normal size achieve boxy fit cut slightly loose fit internal shoulder pads midweight nonstretchy fabric model wearing us',
#  'fits true size take normal size model wearing size larger normal size achieve boxy fit cut slightly loose fit internal shoulder pads midweight nonstretchy fabric model wearing us',
#  '',
#  '',
#  '',
#  'elasticized drawstring waist side slip pockets pullon style silk dry clean made italy size fitwide leg inseam model shown wearing us size',
#  '',
#  'fits true size take normal size designed close fit lightweight knit model wearing us',
#  'fits true size take normal size designed close fit lightweight knit model wearing us',
#  'fits true size take normal size designed close fit lightweight knit model wearing us',
#  'fits true size take normal size designed close fit lightweight knit model wearing us',
#  'true size heel size adjustable strap buckle closure genuine snakeskin upperleather lining sole made brazil salon shoes',
#  'true size heel size adjustable strap buckle closure genuine snakeskin upperleather lining sole made brazil salon shoes',
#  'items measurements depth height width',
#  'sizes order next size',
#  'heel measures approximately inches slip composition leather made italy heel measures approx highthis style fits true sizewe suggest taking normal size',
#  'true size',
#  'true size',
#  'heel measures approximately inches slip composition leather made italy heel measures approx highthis style fits true sizewe suggest taking normal size',
#  'heel measures approximately inches slip composition leather made italy heel measures approx highthis style fits true sizewe suggest taking normal size',
#  'heel measures approximately inches slip composition leather made italy heel measures approx highthis style fits true sizewe suggest taking normal size',
#  'lace front composition suede leather rubber made italy heel measures approx highthis style fits true sizewe suggest taking normal size',
#  'fits true size take normal size designed slim fit slightly short length lightweight open knit model wearing size xsmall',
#  'true size',
#  'true size',
#  'heel measures approximately inches slip composition leather made italy heel measures approx highthis style fits true sizewe suggest taking normal size',
#  'fits true size take normal size designed slim fit slightly short length lightweight open knit model wearing size xsmall',
#  'true size heel platform size strap height ankle strap tie closure leather upper lining sole made brazil salon shoes',
#  'true size heel platform size strap height ankle strap tie closure leather upper lining sole made brazil salon shoes',
#  'true size heel platform size strap height ankle strap tie closure leather upper lining sole made brazil salon shoes',
#  'heel measures approximately inches slip composition leather made italy heel measures approx highthis style fits true sizewe suggest taking normal size',
#  'featured spring summer runway pair neon flip flops square toed slides mirror runway styling mid rise form fitting bicycle short unlined slip composition wool polyurethane dry clean imported model wearing sample size eu style fits true size suggest taking normal size',
#  'featured spring summer runway pair neon flip flops square toed slides mirror runway styling mid rise form fitting bicycle short unlined slip composition wool polyurethane dry clean imported model wearing sample size eu style fits true size suggest taking normal size',
#  'fits true size take normal size designed slim fit midweight nonstretchy fabric model wearing',
#  'true size',
#  'featured spring summer runway pair neon flip flops square toed slides mirror runway styling mid rise form fitting bicycle short unlined slip composition wool polyurethane dry clean imported model wearing sample size eu style fits true size suggest taking normal size',
#  'featured spring summer runway pair neon flip flops square toed slides mirror runway styling mid rise form fitting bicycle short unlined slip composition wool polyurethane dry clean imported model wearing sample size eu style fits true size suggest taking normal size',
#  '',
#  'lace front composition suede leather rubber made italy heel measures approx highthis style fits true sizewe suggest taking normal size',
#  'sizes order next size heel hookandloop strap closure cushioned footbed textile upperleather liningrubber sole imported womens shoes',
#  'runs small order next size',
#  'fits true size take normal size designed close fit lightweight knit model wearing us',
#  '',
#  'fits true size take normal size cut relaxed fit lightweight slightly stretchy fabric model wearing size xsmall',
#  'fits true size take normal size cut relaxed fit lightweight slightly stretchy fabric model wearing size xsmall',
#  'fits true size take normal size designed close fit lightweight knit model wearing us',
#  'fits true size take normal size designed close fit lightweight knit model wearing us',
#  'fits true size take normal size designed close fit lightweight knit model wearing us',
#  'sizes order next size heel hookandloop strap closure cushioned footbed textile upperleather liningrubber sole imported womens shoes',
#  'comfortably fits size xsmallmedium body shapes items measurements',
#  'comfortably fits size xsmallmedium body shapes items measurements',
#  '',
#  '',
#  'comfortably fits size xsmallmedium body shapes items measurements',
#  'comfortably fits size xsmallmedium body shapes items measurements',
#  'fits true size take normal size designed loose fit lightweight nonstretchy fabric model wearing size xsmall',
#  'fits true size take normal size designed loose fit lightweight nonstretchy fabric model wearing size xsmall',
#  'tie fastening front dry clean composition camel wool made italy style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size',
#  'true size',
#  'whole sizes sizes order next size heel size shaft pullon style elastic gore insets leather upper lining sole made italy salon shoes',
#  'whole sizes sizes order next size heel size shaft pullon style elastic gore insets leather upper lining sole made italy salon shoes',
#  'tie fastening front dry clean composition camel wool made italy style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size',
#  'true size',
#  'true size length size medium crewneck short sleeves cotton machine wash tumble dry made usa via c',
#  'true size',
#  'items measurements depth height width',
#  'true size',
#  'fits true size take normal size designed slim fit midweight nonstretchy fabric model wearing',
#  'true size',
#  '',
#  'fits true size take normal size cut slim fit lightweight stretchy fabric take next size wish achieve comfortable fit model wearing size small',
#  'fits true size take normal size intended fitted hip loosely cut top midweight slightly stretchy fabric model wearing designers size',
#  '',
#  'true size',
#  'items measurements depth handle drop height max strap length min strap length width',
#  'items measurements depth handle drop height max strap length min strap length width',
#  'seen prefall runway fringe details wristlet strap fully lined drawstring closure composition plastic made italy',
#  'true size',
#  'fits true size take normal size cut relaxed fit lightweight slightly stretchy fabric model wearing size xsmall',
#  'seen prefall runway fringe details wristlet strap fully lined drawstring closure composition plastic made italy',
#  'fits true size take normal size cut relaxed fit lightweight slightly stretchy fabric model wearing size xsmall',
#  'true size heel size leather upper lining sole imported womens shoes',
#  'true size heel size leather upper lining sole imported womens shoes',
#  'tie fastening front dry clean composition camel wool made italy style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size',
#  'fits true size take normal size cut loose fit midweight slightly stretchy fabric model wearing us',
#  'fits true size take normal size cut loose fit midweight slightly stretchy fabric model wearing us',
#  'classic lowtop sneakers crafted smooth leather leather upper laceup vamp round toe leather lining rubber sole imported',
#  'classic lowtop sneakers crafted smooth leather leather upper laceup vamp round toe leather lining rubber sole imported',
#  'fits true size take normal size midrise intended wideleg fit midweight stretchy fabric model wearing size small',
#  'fits true size take normal size midrise intended wideleg fit midweight stretchy fabric model wearing size small',
#  'fits true size take normal size midrise intended wideleg fit midweight stretchy fabric model wearing size small',
#  'fits true size take normal size midrise intended wideleg fit midweight stretchy fabric model wearing size small',
#  'fits true size take normal size midrise intended wideleg fit midweight stretchy fabric model wearing size small',
#  'fully lined slips composition cotton machine wash imported style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size',
#  'fully lined slips composition cotton machine wash imported style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size',
#  'fully lined slips composition cotton machine wash imported style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size',
#  'fully lined slips composition cotton machine wash imported style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size',
#  'fully lined slips composition cotton machine wash imported style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size',
#  'fits true size take normal size italian sizing',
#  'fits true size take normal size italian sizing',
#  'fits true size take normal size italian sizing',
#  'fits true size take normal size italian sizing',
#  'fits true size take normal size italian sizing',
#  'fits true size take normal size italian sizing',
#  'fits true size take normal size italian sizing',
#  'fits true size take normal size italian sizing',
#  'items measurements depth handle drop height max strap length min strap length width',
#  'items measurements depth handle drop height max strap length min strap length width',
#  'items measurements depth handle drop height max strap length min strap length width',
#  'items measurements depth handle drop height max strap length min strap length width',
#  'items measurements length width',
#  'items measurements length width',
#  'items measurements length width',
#  'items measurements length width',
#  'heel measures approximately inches slip composition calf hair leather made italy heel measures approx highthis style fits true sizewe suggest taking normal size',
#  'heel measures approximately inches slip composition calf hair leather made italy heel measures approx highthis style fits true sizewe suggest taking normal size',
#  'heel measures approximately inches slip composition calf hair leather made italy heel measures approx highthis style fits true sizewe suggest taking normal size',
#  'heel measures approximately inches slip composition calf hair leather made italy heel measures approx highthis style fits true sizewe suggest taking normal size',
#  'heel measures approximately inches slip composition calf hair leather made italy heel measures approx highthis style fits true sizewe suggest taking normal size',
#  'heel measures approximately inches slip composition calf hair leather made italy heel measures approx highthis style fits true sizewe suggest taking normal size',
#  'featured prefall lookbook contrast binding unlined concealed zip fastening along back composition polyester cold hand wash imported model wearing sample size us style fits true size suggest taking normal size',
#  'featured prefall lookbook contrast binding unlined concealed zip fastening along back composition polyester cold hand wash imported model wearing sample size us style fits true size suggest taking normal size',
#  'featured prefall lookbook contrast binding unlined concealed zip fastening along back composition polyester cold hand wash imported model wearing sample size us style fits true size suggest taking normal size',
#  'featured prefall lookbook contrast binding unlined concealed zip fastening along back composition polyester cold hand wash imported model wearing sample size us style fits true size suggest taking normal size',
#  'open top magnetic closure front zip pocket goldtone hardware interior slip pocket dust bag included leather made usa sizedual top handle drop',
#  'open top magnetic closure front zip pocket goldtone hardware interior slip pocket dust bag included leather made usa sizedual top handle drop',
#  'open top magnetic closure front zip pocket goldtone hardware interior slip pocket dust bag included leather made usa sizedual top handle drop',
#  'open top magnetic closure front zip pocket goldtone hardware interior slip pocket dust bag included leather made usa sizedual top handle drop',
#  'open top magnetic closure front zip pocket goldtone hardware interior slip pocket dust bag included leather made usa sizedual top handle drop',
#  'open top magnetic closure front zip pocket goldtone hardware interior slip pocket dust bag included leather made usa sizedual top handle drop',
#  'featured ss lookbook wear highrise fauxleather mini skirt satin pumps elevate look cut tailored fit cropped silhouette doublebreasted long sleeves button detail lined button fastening front composition viscose dry clean imported sample size',
#  'featured ss lookbook wear highrise fauxleather mini skirt satin pumps elevate look cut tailored fit cropped silhouette doublebreasted long sleeves button detail lined button fastening front composition viscose dry clean imported sample size',
#  'featured ss lookbook wear highrise fauxleather mini skirt satin pumps elevate look cut tailored fit cropped silhouette doublebreasted long sleeves button detail lined button fastening front composition viscose dry clean imported sample size',
#  'featured ss lookbook wear highrise fauxleather mini skirt satin pumps elevate look cut tailored fit cropped silhouette doublebreasted long sleeves button detail lined button fastening front composition viscose dry clean imported sample size',
#  'extra fine merino wool hand wash imported size fit',
#  'extra fine merino wool hand wash imported size fit',
#  'extra fine merino wool hand wash imported size fit',
#  'extra fine merino wool hand wash imported size fit',
#  'flowing palazzo pants pleated detail waist extra volume concealed side zip pleated detail silk dry clean imported size fitinseam model shown wearing us size',
#  'flowing palazzo pants pleated detail waist extra volume concealed side zip pleated detail silk dry clean imported size fitinseam model shown wearing us size',
#  'flowing palazzo pants pleated detail waist extra volume concealed side zip pleated detail silk dry clean imported size fitinseam model shown wearing us size',
#  'flowing palazzo pants pleated detail waist extra volume concealed side zip pleated detail silk dry clean imported size fitinseam model shown wearing us size',
#  'featured ss lookbook dress best complemented minimal accessories pointedtoe pumps cut slim fit aline silhouette print detail draped detail pleated skirt unlined button fastening front composition viscose elastine dry clean imported sample size',
#  'featured ss lookbook dress best complemented minimal accessories pointedtoe pumps cut slim fit aline silhouette print detail draped detail pleated skirt unlined button fastening front composition viscose elastine dry clean imported sample size',
#  'featured ss lookbook dress best complemented minimal accessories pointedtoe pumps cut slim fit aline silhouette print detail draped detail pleated skirt unlined button fastening front composition viscose elastine dry clean imported sample size',
#  'featured ss lookbook dress best complemented minimal accessories pointedtoe pumps cut slim fit aline silhouette print detail draped detail pleated skirt unlined button fastening front composition viscose elastine dry clean imported sample size',
#  'featured ss lookbook style brands matching fauxleather mini skirt pumps chic finish cut tailored fit button detail square neckline pockets lined button fastening front composition polyurethane dry clean imported sample size',
#  'featured ss lookbook style brands matching fauxleather mini skirt pumps chic finish cut tailored fit button detail square neckline pockets lined button fastening front composition polyurethane dry clean imported sample size',
#  'featured ss lookbook style brands matching fauxleather mini skirt pumps chic finish cut tailored fit button detail square neckline pockets lined button fastening front composition polyurethane dry clean imported sample size',
#  'featured ss lookbook style brands matching fauxleather mini skirt pumps chic finish cut tailored fit button detail square neckline pockets lined button fastening front composition polyurethane dry clean imported sample size',
#  'slips composition knit dry clean designer color ochre made usa style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size small',
#  'fits true size take normal size wraparound design ties waist adjustable fit midweight nonstretchy fabric model wearing size small',
#  'fits true size take normal size wraparound design ties waist adjustable fit midweight nonstretchy fabric model wearing size small',
#  'fits true size take normal size wraparound design ties waist adjustable fit midweight nonstretchy fabric model wearing size small',
#  'zip fastening along side composition nappa leather made italy heel measures approx highthis style fits true sizewe suggest taking normal size',
#  'zip fastening along side composition nappa leather made italy heel measures approx highthis style fits true sizewe suggest taking normal size',
#  'slips composition knit dry clean designer color ochre made usa style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size small',
#  'slips composition knit dry clean designer color ochre made usa style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size small',
#  'slips composition knit dry clean designer color ochre made usa style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size small',
#  'slips composition knit dry clean designer color ochre made usa style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size small',
#  'button concealed zip fastening front composition cotton designer wash white made usa style fits true sizewe suggest taking normal size model measurements height bust waist hip',
#  'button concealed zip fastening front composition cotton designer wash white made usa style fits true sizewe suggest taking normal size model measurements height bust waist hip',
#  'button concealed zip fastening front composition cotton designer wash white made usa style fits true sizewe suggest taking normal size model measurements height bust waist hip',
#  'button concealed zip fastening front composition cotton designer wash white made usa style fits true sizewe suggest taking normal size model measurements height bust waist hip',
#  'button concealed zip fastening front composition cotton designer wash white made usa style fits true sizewe suggest taking normal size model measurements height bust waist hip',
#  'button concealed zip fastening front composition cotton designer wash white made usa style fits true sizewe suggest taking normal size model measurements height bust waist hip',
#  'button concealed zip fastening front composition cotton designer wash white made usa style fits true sizewe suggest taking normal size model measurements height bust waist hip',
#  'textile synthetic upper round toe laceup vamp rubber sole imported',
#  'textile synthetic upper round toe laceup vamp rubber sole imported',
#  'textile synthetic upper round toe laceup vamp rubber sole imported',
#  'textile synthetic upper round toe laceup vamp rubber sole imported',
#  'banded waist belt loops zip fly tab closure waist zip pockets lined cottonsilk dry clean imported size fitslim leg rise inseam model shown wearing us size',
#  'banded waist belt loops zip fly tab closure waist zip pockets lined cottonsilk dry clean imported size fitslim leg rise inseam model shown wearing us size',
#  'featured resort collection anklegrazing silhouette styles well cropped pants pointed toe angled block heel zip fastening along back composition calf leather made italy heel measures approximately inches fits true size suggest ordering normal size italian sizing',
#  'featured resort collection anklegrazing silhouette styles well cropped pants pointed toe angled block heel zip fastening along back composition calf leather made italy heel measures approximately inches fits true size suggest ordering normal size italian sizing',
#  'featured resort collection anklegrazing silhouette styles well cropped pants pointed toe angled block heel zip fastening along back composition calf leather made italy heel measures approximately inches fits true size suggest ordering normal size italian sizing',
#  'featured resort collection anklegrazing silhouette styles well cropped pants pointed toe angled block heel zip fastening along back composition calf leather made italy heel measures approximately inches fits true size suggest ordering normal size italian sizing',
#  'featured resort collection anklegrazing silhouette styles well cropped pants pointed toe angled block heel zip fastening along back composition calf leather made italy heel measures approximately inches fits true size suggest ordering normal size italian sizing',
#  'featured resort collection anklegrazing silhouette styles well cropped pants pointed toe angled block heel zip fastening along back composition calf leather made italy heel measures approximately inches fits true size suggest ordering normal size italian sizing',
#  'featured resort collection anklegrazing silhouette styles well cropped pants pointed toe angled block heel zip fastening along back composition calf leather made italy heel measures approximately inches fits true size suggest ordering normal size italian sizing',
#  'featured resort collection anklegrazing silhouette styles well cropped pants pointed toe angled block heel zip fastening along back composition calf leather made italy heel measures approximately inches fits true size suggest ordering normal size italian sizing',
#  'featured fall winter runway wrapsilhouette kneelength fully lined zip fastening along back composition lamb nappa leather dry clean imported',
#  'featured fall winter runway wrapsilhouette kneelength fully lined zip fastening along back composition lamb nappa leather dry clean imported',
#  'featured fall winter runway wrapsilhouette kneelength fully lined zip fastening along back composition lamb nappa leather dry clean imported',
#  'featured fall winter runway wrapsilhouette kneelength fully lined zip fastening along back composition lamb nappa leather dry clean imported',
#  'seen fall winter collection heel measures approximately inches rounded toe zipper fastening composition pebble patent leather color creamy made italy style fits true size suggest ordering normal size',
#  'seen fall winter collection heel measures approximately inches rounded toe zipper fastening composition pebble patent leather color creamy made italy style fits true size suggest ordering normal size',
#  'seen fall winter collection heel measures approximately inches rounded toe zipper fastening composition pebble patent leather color creamy made italy style fits true size suggest ordering normal size',
#  'seen fall winter collection heel measures approximately inches rounded toe zipper fastening composition pebble patent leather color creamy made italy style fits true size suggest ordering normal size',
#  'seen fall winter collection heel measures approximately inches rounded toe zipper fastening composition pebble patent leather color creamy made italy style fits true size suggest ordering normal size',
#  'seen fall winter collection heel measures approximately inches rounded toe zipper fastening composition pebble patent leather color creamy made italy style fits true size suggest ordering normal size',
#  'heel height measures approximately inches pull composition leather made italy',
#  'heel height measures approximately inches pull composition leather made italy',
#  '',
#  '',
#  'fully lined detachable shoulder strap lobster clasp fastening open top composition leather made italy bag measures depth width height bag handle drop measures length',
#  'fully lined detachable shoulder strap lobster clasp fastening open top composition leather made italy bag measures depth width height bag handle drop measures length',
#  'fully lined detachable shoulder strap lobster clasp fastening open top composition leather made italy bag measures depth width height bag handle drop measures length',
#  'fully lined detachable shoulder strap lobster clasp fastening open top composition leather made italy bag measures depth width height bag handle drop measures length',
#  'fully lined detachable shoulder strap lobster clasp fastening open top composition leather made italy bag measures depth width height bag handle drop measures length',
#  'fully lined slips composition cotton machine wash imported style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size',
#  'heel height measures approximately inches pull composition leather made italy',
#  'heel height measures approximately inches pull composition leather made italy',
#  'unlined zip fastening front composition leather dry clean made italy model wearing sample size style fits true size suggest taking usual size',
#  'unlined zip fastening front composition leather dry clean made italy model wearing sample size style fits true size suggest taking usual size',
#  'unlined zip fastening front composition leather dry clean made italy model wearing sample size style fits true size suggest taking usual size',
#  'unlined zip fastening front composition leather dry clean made italy model wearing sample size style fits true size suggest taking usual size',
#  'unlined zip fastening front composition leather dry clean made italy model wearing sample size style fits true size suggest taking usual size',
#  'unlined zip fastening front composition leather dry clean made italy model wearing sample size style fits true size suggest taking usual size',
#  'fits small size take one size larger normal highrise cut slim fit elasticated waist flexible fit midweight slightly stretchy fabric model wearing uk',
#  'fits small size take one size larger normal highrise cut slim fit elasticated waist flexible fit midweight slightly stretchy fabric model wearing uk',
#  'fits small size take one size larger normal highrise cut slim fit elasticated waist flexible fit midweight slightly stretchy fabric model wearing uk',
#  'fits small size take one size larger normal highrise cut slim fit elasticated waist flexible fit midweight slightly stretchy fabric model wearing uk',
#  'banded waist zip fly waist slash pockets silkpolyester dry clean made italy size fitwideleg silhouette rise inseam model shown wearing us size',
#  'banded waist zip fly waist slash pockets silkpolyester dry clean made italy size fitwideleg silhouette rise inseam model shown wearing us size',
#  'banded waist zip fly waist slash pockets silkpolyester dry clean made italy size fitwideleg silhouette rise inseam model shown wearing us size',
#  'banded waist zip fly waist slash pockets silkpolyester dry clean made italy size fitwideleg silhouette rise inseam model shown wearing us size',
#  'fits true size take normal size midrise cut relaxed fit elasticated waist flexible fit midweight stretchy fabric model wearing size small',
#  'fits true size take normal size midrise cut relaxed fit elasticated waist flexible fit midweight stretchy fabric model wearing size small',
#  'fits true size take normal size midrise cut relaxed fit elasticated waist flexible fit midweight stretchy fabric model wearing size small',
#  'fits true size take normal size highrise cut slim fit elasticated waist flexible fit midweight slightly stretchy fabric model wearing size xsmall',
#  'fits true size take normal size highrise cut slim fit elasticated waist flexible fit midweight slightly stretchy fabric model wearing size xsmall',
#  'fits true size take normal size highrise cut slim fit elasticated waist flexible fit midweight slightly stretchy fabric model wearing size xsmall',
#  'fits true size take normal size highrise cut slim fit elasticated waist flexible fit midweight slightly stretchy fabric model wearing size xsmall',
#  'fits true size take normal size highrise cut slim fit elasticated waist flexible fit midweight slightly stretchy fabric model wearing size xsmall',
#  'fits true size take normal size designed relaxed fit use tie belt cinch waist chunky knit model wearing size small',
#  'fits true size take normal size designed relaxed fit use tie belt cinch waist chunky knit model wearing size small',
#  'fits true size take normal size designed relaxed fit use tie belt cinch waist chunky knit model wearing size small',
#  'fits true size take normal size designed relaxed fit use tie belt cinch waist chunky knit model wearing size small',
# ...
#  'featured prefall lookbook midi length flared hem unlined zip fastening along back composition viscose virgin wool dry clean designer color caramel made usa style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size us',
#  'featured prefall lookbook midi length flared hem unlined zip fastening along back composition viscose virgin wool dry clean designer color caramel made usa style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size us',
#  'featured prefall lookbook midi length flared hem unlined zip fastening along back composition viscose virgin wool dry clean designer color caramel made usa style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size us',
#  'slip composition cotton dry clean made usa style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size small',
#  'slip composition cotton dry clean made usa style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size small',
#  'slip composition cotton dry clean made usa style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size small',
#  'slip composition cotton dry clean made usa style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size small',
#  'slip composition cotton dry clean made usa style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size small',
#  'slip composition cotton dry clean made usa style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size small',
#  'slip composition cotton dry clean made usa style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size small',
#  'slip composition cotton dry clean made usa style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size small',
#  'slip composition cotton silk dry clean imported style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size fr',
#  'slip composition cotton silk dry clean imported style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size fr',
#  'slip composition cotton silk dry clean imported style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size fr',
#  'slip composition cotton silk dry clean imported style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size fr',
#  'fits small size take half size larger normal italian sizing',
#  'fits small size take half size larger normal italian sizing',
#  'fully lined composition leather dry clean imported style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size small',
#  'fully lined composition leather dry clean imported style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size small',
#  'fully lined composition leather dry clean imported style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size small',
#  'fully lined composition leather dry clean imported style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size small',
#  'fully lined composition leather dry clean imported style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size small',
#  'fully lined composition leather dry clean imported style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size small',
#  'fully lined composition leather dry clean imported style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size small',
#  'fully lined composition leather dry clean imported style fits true sizewe suggest taking normal size model measurements height bust waist hip cmshe wearing size small',
#  'seen spring summer lookbook style matching pants slim sleek look cut slim fit cropped sleeveless three frontal pocket details fully lined button fastening front composition faux leather polyester cotton dry clean imported sample size',
#  'seen spring summer lookbook style matching pants slim sleek look cut slim fit cropped sleeveless three frontal pocket details fully lined button fastening front composition faux leather polyester cotton dry clean imported sample size',
#  'seen spring summer lookbook style matching pants slim sleek look cut slim fit cropped sleeveless three frontal pocket details fully lined button fastening front composition faux leather polyester cotton dry clean imported sample size',
#  'seen spring summer lookbook style matching pants slim sleek look cut slim fit cropped sleeveless three frontal pocket details fully lined button fastening front composition faux leather polyester cotton dry clean imported sample size',
#  'seen spring summer lookbook style matching pants slim sleek look cut slim fit cropped sleeveless three frontal pocket details fully lined button fastening front composition faux leather polyester cotton dry clean imported sample size',
#  'seen spring summer lookbook style matching pants slim sleek look cut slim fit cropped sleeveless three frontal pocket details fully lined button fastening front composition faux leather polyester cotton dry clean imported sample size',
#  'fits true size take normal size designed slightly loose fit lightweight nonstretchy fabric model wearing us',
#  'fits true size take normal size designed slightly loose fit lightweight nonstretchy fabric model wearing us',
#  'fits true size take normal size designed slightly loose fit lightweight nonstretchy fabric model wearing us',
#  'fits true size take normal size designed slightly loose fit lightweight nonstretchy fabric model wearing us',
#  'featured pre fall lookbook pair brands pastel crepe wide leg pants transitional spring look speckled sleeveless loose fit unlined slip composition cotton acrylic dry clean imported model wearing sample size style fits true size suggest taking normal size',
#  'featured pre fall lookbook pair brands pastel crepe wide leg pants transitional spring look speckled sleeveless loose fit unlined slip composition cotton acrylic dry clean imported model wearing sample size style fits true size suggest taking normal size',
#  'featured pre fall lookbook pair brands pastel crepe wide leg pants transitional spring look speckled sleeveless loose fit unlined slip composition cotton acrylic dry clean imported model wearing sample size style fits true size suggest taking normal size',
#  'featured pre fall lookbook pair brands pastel crepe wide leg pants transitional spring look speckled sleeveless loose fit unlined slip composition cotton acrylic dry clean imported model wearing sample size style fits true size suggest taking normal size',
#  'featured pre fall lookbook pair brands pastel crepe wide leg pants transitional spring look speckled sleeveless loose fit unlined slip composition cotton acrylic dry clean imported model wearing sample size style fits true size suggest taking normal size',
#  'featured pre fall lookbook pair brands pastel crepe wide leg pants transitional spring look speckled sleeveless loose fit unlined slip composition cotton acrylic dry clean imported model wearing sample size style fits true size suggest taking normal size',
#  'featured fall lookbook pointed toe heel measures approximately mminches pull composition leather imported style fits true size suggest ordering normal size',
#  'featured fall lookbook pointed toe heel measures approximately mminches pull composition leather imported style fits true size suggest ordering normal size',
#  'featured fall lookbook pointed toe heel measures approximately mminches pull composition leather imported style fits true size suggest ordering normal size',
#  'featured fall lookbook pointed toe heel measures approximately mminches pull composition leather imported style fits true size suggest ordering normal size',
#  'featured fall lookbook pointed toe heel measures approximately mminches pull composition leather imported style fits true size suggest ordering normal size',
#  'featured fall lookbook pointed toe heel measures approximately mminches pull composition leather imported style fits true size suggest ordering normal size',
#  'featured pre fall lookbook pair brands pastel crepe wide leg pants transitional spring look loose fit printed high neck unlined button fastening composition recycled polyester spandex dry clean imported model wearing sample size eu style fits true size suggest taking normal size',
#  'featured pre fall lookbook pair brands pastel crepe wide leg pants transitional spring look loose fit printed high neck unlined button fastening composition recycled polyester spandex dry clean imported model wearing sample size eu style fits true size suggest taking normal size',
#  'featured pre fall lookbook pair brands pastel crepe wide leg pants transitional spring look loose fit printed high neck unlined button fastening composition recycled polyester spandex dry clean imported model wearing sample size eu style fits true size suggest taking normal size',
#  'featured pre fall lookbook pair brands pastel crepe wide leg pants transitional spring look loose fit printed high neck unlined button fastening composition recycled polyester spandex dry clean imported model wearing sample size eu style fits true size suggest taking normal size',
#  'true size',
#  'true size',
#  'true size',
#  'true size',
#  'true size',
#  'true size',
#  'slip composition viscose polyester machine wash imported model measurements height bust waist hip cmshe wearing size small style fits true sizewe suggest taking normal size',
#  'slip composition viscose polyester machine wash imported model measurements height bust waist hip cmshe wearing size small style fits true sizewe suggest taking normal size',
#  'slip composition viscose polyester machine wash imported model measurements height bust waist hip cmshe wearing size small style fits true sizewe suggest taking normal size',
#  'slip composition viscose polyester machine wash imported model measurements height bust waist hip cmshe wearing size small style fits true sizewe suggest taking normal size',
#  'slip composition viscose polyester machine wash imported model measurements height bust waist hip cmshe wearing size small style fits true sizewe suggest taking normal size',
#  'slip composition viscose polyester machine wash imported model measurements height bust waist hip cmshe wearing size small style fits true sizewe suggest taking normal size',
#  'featured fall lookbook lapels adjustable belt fully lined button fastening front composition polyester lining cupro dry clean imported model wearing sample size small item fits true size recommend taking normal size',
#  'featured fall lookbook lapels adjustable belt fully lined button fastening front composition polyester lining cupro dry clean imported model wearing sample size small item fits true size recommend taking normal size',
#  'featured fall lookbook lapels adjustable belt fully lined button fastening front composition polyester lining cupro dry clean imported model wearing sample size small item fits true size recommend taking normal size',
#  'featured fall lookbook lapels adjustable belt fully lined button fastening front composition polyester lining cupro dry clean imported model wearing sample size small item fits true size recommend taking normal size',
#  'top flap pushlock closure silvertone hardware interior open compartments interior zip compartment interior cell phone pocket interior multifunction pocket interior laptop sleeve lined leather imported sizeremovable adjustable shoulder strap drop top handle drop',
#  'top flap pushlock closure silvertone hardware interior open compartments interior zip compartment interior cell phone pocket interior multifunction pocket interior laptop sleeve lined leather imported sizeremovable adjustable shoulder strap drop top handle drop',
#  'top flap pushlock closure silvertone hardware interior open compartments interior zip compartment interior cell phone pocket interior multifunction pocket interior laptop sleeve lined leather imported sizeremovable adjustable shoulder strap drop top handle drop',
#  'top flap pushlock closure silvertone hardware interior open compartments interior zip compartment interior cell phone pocket interior multifunction pocket interior laptop sleeve lined leather imported sizeremovable adjustable shoulder strap drop top handle drop',
#  'featured fall lookbook tie details shoulder fitted waist unlined slips composition silk dry clean imported model wearing sample size style fits true size suggest taking normal size',
#  'featured fall lookbook tie details shoulder fitted waist unlined slips composition silk dry clean imported model wearing sample size style fits true size suggest taking normal size',
#  'featured fall lookbook tie details shoulder fitted waist unlined slips composition silk dry clean imported model wearing sample size style fits true size suggest taking normal size',
#  'featured fall lookbook tie details shoulder fitted waist unlined slips composition silk dry clean imported model wearing sample size style fits true size suggest taking normal size',
#  'featured spring summer lookbook pair seasons square toed black boot take day night ease blazer overlay corset feature around waist tapered fit partially lined button zipper fastening composition wool polyester dry clean imported model wearing sample size style fits true size suggest taking normal size',
#  'featured spring summer lookbook pair seasons square toed black boot take day night ease blazer overlay corset feature around waist tapered fit partially lined button zipper fastening composition wool polyester dry clean imported model wearing sample size style fits true size suggest taking normal size',
#  'featured spring summer lookbook pair seasons square toed black boot take day night ease blazer overlay corset feature around waist tapered fit partially lined button zipper fastening composition wool polyester dry clean imported model wearing sample size style fits true size suggest taking normal size',
#  'featured spring summer lookbook pair seasons square toed black boot take day night ease blazer overlay corset feature around waist tapered fit partially lined button zipper fastening composition wool polyester dry clean imported model wearing sample size style fits true size suggest taking normal size',
#  'featured fall lookbook tie belt waist unlined pulls composition cotton dry clean imported model wearing sample size style fits true size suggest taking normal size',
#  'featured fall lookbook tie belt waist unlined pulls composition cotton dry clean imported model wearing sample size style fits true size suggest taking normal size',
#  'featured fall lookbook tie belt waist unlined pulls composition cotton dry clean imported model wearing sample size style fits true size suggest taking normal size',
#  'featured fall lookbook tie belt waist unlined pulls composition cotton dry clean imported model wearing sample size style fits true size suggest taking normal size',
#  'fits true size take normal size highrise cut wideleg fit cropped length elasticated waist flexible fit lightweight nonstretchy fabric model wearing size xsmall',
#  'fits true size take normal size highrise cut wideleg fit cropped length elasticated waist flexible fit lightweight nonstretchy fabric model wearing size xsmall',
#  ...]

# %%
lemmatizer = WordNetLemmatizer()

#function to convert nltk tag to wordnet tag
def nltk2wn_tag(nltk_tag):
    if nltk_tag.startswith('J'):
        return wordnet.ADJ
    elif nltk_tag.startswith('V'):
        return wordnet.VERB
    elif nltk_tag.startswith('N'):
        return wordnet.NOUN
    elif nltk_tag.startswith('R'):
        return wordnet.ADV
    else:
        return None
def lemmatize_sentence(sentence):
    nltk_tagged = nltk.pos_tag(nltk.word_tokenize(sentence))
    wn_tagged = map(lambda x :(x[0], nltk2wn_tag(x[1])), nltk_tagged)
    res_words = []
    for word, tag in wn_tagged:
        if tag is None:
            res_words.append(word)
        else:
            res_words.append(lemmatizer.lemmatize(word,tag))
    return " ".join(res_words)

# %%
cleaned_description_lem = []
for sentence in cleaned_descriptions:
    cleaned_description_lem = cleaned_description_lem + [lemmatize_sentence(sentence)]

# %%
cleaned_descriptions
# Out:
# ['black leather lamb open top weighs approximately NUMERICAL_VALUE lbs NUMERICAL_VALUE kg imported',
#  'retro inspired yet current stretchy ribbed bodysuit based slim fitting clothing gained popularity NUMERICAL_VALUE',
#  'retro inspired yet current stretchy ribbed bodysuit based slim fitting clothing gained popularity NUMERICAL_VALUE',
#  'black stretch pima cotton jersey slips HIGH_PIMA cotton LOW_ELASTANE hand wash imported',
#  'crafted supple leather sally lapointe pants cut wide leg silhouette cinched waist matching belt style looks amazing paired favorite sweater tucked',
#  'cream crepe slips material material lining material MEDIAN_ACETATE dry clean',
#  'cream crepe slips material material lining material MEDIAN_ACETATE dry clean',
#  'crafted supple leather sally lapointe pants cut wide leg silhouette cinched waist matching belt style looks amazing paired favorite sweater tucked',
#  'crafted supple leather sally lapointe pants cut wide leg silhouette cinched waist matching belt style looks amazing paired favorite sweater tucked',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches gold mirrored leather calf buckle fastening ankle strap come dust bag made italy',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches gold mirrored leather calf buckle fastening ankle strap come dust bag made italy',
#  'clean seams towering stacked heel define polished day night boot',
#  'chase summery dreams rainbow metallic sandal beach chic design knotted straps reaching wrap ankle',
#  'chase summery dreams rainbow metallic sandal beach chic design knotted straps reaching wrap ankle',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches gold mirrored leather calf buckle fastening ankle strap come dust bag made italy',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches gold mirrored leather calf buckle fastening ankle strap come dust bag made italy',
#  'cream crepe slips material material lining material MEDIAN_ACETATE dry clean',
#  'cream crepe slips material material lining material MEDIAN_ACETATE dry clean',
#  'camel grain de poudre wool button fastening front material buttons HIGH_WOOL buffalo dry clean made italy',
#  'cream crepe slips material material lining material MEDIAN_ACETATE dry clean',
#  'black stretch pima cotton jersey slips HIGH_PIMA cotton LOW_ELASTANE hand wash imported',
#  'clean seams towering stacked heel define polished day night boot',
#  'mens military inspired button designers tailored ladies thanks slimmer fit super flattering',
#  'mens military inspired button designers tailored ladies thanks slimmer fit super flattering',
#  'black stretch pima cotton jersey slips HIGH_PIMA cotton LOW_ELASTANE hand wash imported',
#  'fashioned high quality materials designed comfort shoes keep stylish toes flexible suede upper breathable synthetic lining insole added stability heel exclusive padding system features memory foam cushioned insole designed day comfort flexible skid resistant outsole comfort pod bottom',
#  'fashioned high quality materials designed comfort shoes keep stylish toes flexible suede upper breathable synthetic lining insole added stability heel exclusive padding system features memory foam cushioned insole designed day comfort flexible skid resistant outsole comfort pod bottom',
#  'gray cotton jersey slips HIGH_COTTON machine wash designer color tinker',
#  'gray cotton jersey slips HIGH_COTTON machine wash designer color tinker',
#  'gray cotton jersey slips HIGH_COTTON machine wash designer color tinker',
#  'camel grain de poudre wool button fastening front material buttons HIGH_WOOL buffalo dry clean made italy',
#  'black leather lamb open top weighs approximately NUMERICAL_VALUE lbs NUMERICAL_VALUE kg imported',
#  'gray cotton jersey slips HIGH_COTTON machine wash designer color tinker',
#  'mens military inspired button designers tailored ladies thanks slimmer fit super flattering',
#  'mens military inspired button designers tailored ladies thanks slimmer fit super flattering',
#  'wide channel quilted straps crisscross well padded slide sandal grounded razored treads',
#  'multicolored cotton nylon merino wool alpaca cashmere mohair blend slips material material LOW_COTTON wool material material LOW_NYLON dry clean imported',
#  'crafted italy golden goose hi star sneakers designed brand signature star stamped gold tone logo textured leather uppers set platform rubber sole pair complete suede vamps handwritten text accents highlight chunky heel pairing midi length skirt',
#  'edgy style expert craftsmanship combine block heel combat boot cut sewn lasted hand spanish artisans',
#  'ready stroll private beach flat sandal styled crisscrossing straps braided raffia',
#  'suckers pretty statement top exactly landed tee ladylike twists fits feels like favorite shirt thank soft cotton jersey perked high volume poplin sleeves gather gracefully toward cuffs yes statement shoulders best news treat like tees wear every single pair jeans trousers shorts material clean onlymade italymeasurements size NUMERICAL_VALUE length NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE chest NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE model NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE bust NUMERICAL_VALUE waist NUMERICAL_VALUE hips wearing size NUMERICAL_VALUE',
#  'ready stroll private beach flat sandal styled crisscrossing straps braided raffia',
#  'enchanting cinderella glass slipper much wearable graceful italian sandal styled transparent straps',
#  'suckers pretty statement top exactly landed tee ladylike twists fits feels like favorite shirt thank soft cotton jersey perked high volume poplin sleeves gather gracefully toward cuffs yes statement shoulders best news treat like tees wear every single pair jeans trousers shorts material clean onlymade italymeasurements size NUMERICAL_VALUE length NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE chest NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE model NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE bust NUMERICAL_VALUE waist NUMERICAL_VALUE hips wearing size NUMERICAL_VALUE',
#  'lean lengthening silhouette one button closure accentuate waist notch lapel long sleeves one button cuffs two exterior pockets center back vent fully lined stretch lining comfort ease movement',
#  'lean lengthening silhouette one button closure accentuate waist notch lapel long sleeves one button cuffs two exterior pockets center back vent fully lined stretch lining comfort ease movement',
#  'edgy style expert craftsmanship combine block heel combat boot cut sewn lasted hand spanish artisans',
#  'lean lengthening silhouette one button closure accentuate waist notch lapel long sleeves one button cuffs two exterior pockets center back vent fully lined stretch lining comfort ease movement',
#  'lean lengthening silhouette one button closure accentuate waist notch lapel long sleeves one button cuffs two exterior pockets center back vent fully lined stretch lining comfort ease movement',
#  'nobody denim true jeans designed pre cuffed hems saving time finding perfect length crafted medium wash style fashioned mid rise waist brand logo stitching back right pocket couple skinny style puffed sleeve blouse add volume',
#  'nobody denim true jeans designed pre cuffed hems saving time finding perfect length crafted medium wash style fashioned mid rise waist brand logo stitching back right pocket couple skinny style puffed sleeve blouse add volume',
#  'nobody denim true jeans designed pre cuffed hems saving time finding perfect length crafted medium wash style fashioned mid rise waist brand logo stitching back right pocket couple skinny style puffed sleeve blouse add volume',
#  'ivory jeans dressed toned need straight leg fit skinny constricting super flattering leg elongating silhouette falls past ankles meaning work equally well block heeled boot office low top sneakers kicking around material washmade usamodel NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE bust NUMERICAL_VALUE waist NUMERICAL_VALUE hips wearing size NUMERICAL_VALUE',
#  'crafted supple leather sally lapointe pants cut wide leg silhouette cinched waist matching belt style looks amazing paired favorite sweater tucked',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches cream leather lamb slip designer color buttercream made italysmall size see size fit notes',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches cream leather lamb slip designer color buttercream made italysmall size see size fit notes',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches cream leather lamb slip designer color buttercream made italysmall size see size fit notes',
#  'derek lam oversized silk blouse designed self tie scarf neck long cuffed sleeves high low hemline',
#  'introducing suiting first time done based cropped flare trousers vintage pair NUMERICAL_VALUE handmade italy',
#  'introducing suiting first time done based cropped flare trousers vintage pair NUMERICAL_VALUE handmade italy',
#  'crafted supple leather sally lapointe pants cut wide leg silhouette cinched waist matching belt style looks amazing paired favorite sweater tucked',
#  'edgy style expert craftsmanship combine block heel combat boot cut sewn lasted hand spanish artisans',
#  'twinkling crystal brooch crowns toe strap party ready sandal secured slender floating ankle strap',
#  'twinkling crystal brooch crowns toe strap party ready sandal secured slender floating ankle strap',
#  'ivory jeans dressed toned need straight leg fit skinny constricting super flattering leg elongating silhouette falls past ankles meaning work equally well block heeled boot office low top sneakers kicking around material washmade usamodel NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE bust NUMERICAL_VALUE waist NUMERICAL_VALUE hips wearing size NUMERICAL_VALUE',
#  'derek lam oversized silk blouse designed self tie scarf neck long cuffed sleeves high low hemline',
#  'named unique double point pocket design denim western shirt softly faded detailed pearly snaps authentic vintage look',
#  'named unique double point pocket design denim western shirt softly faded detailed pearly snaps authentic vintage look',
#  'ivory jeans dressed toned need straight leg fit skinny constricting super flattering leg elongating silhouette falls past ankles meaning work equally well block heeled boot office low top sneakers kicking around material washmade usamodel NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE bust NUMERICAL_VALUE waist NUMERICAL_VALUE hips wearing size NUMERICAL_VALUE',
#  'designed curated minimalistic style icon elin kling provides updated essentials effortless mix match ideal work weekends high rise ossi tailored full length tailored leg wear matching blazer smart look keep casual oversized knit sneakers',
#  'midnight blue organic cotton velour pull HIGH_ORGANIC cotton machine wash imported',
#  'designed curated minimalistic style icon elin kling provides updated essentials effortless mix match ideal work weekends high rise ossi tailored full length tailored leg wear matching blazer smart look keep casual oversized knit sneakers',
#  'tan leather calf magnetic fastening front flap weighs approximately NUMERICAL_VALUE lbs NUMERICAL_VALUE kg made italy',
#  'enchanting cinderella glass slipper much wearable graceful italian sandal styled transparent straps',
#  'derek lam oversized silk blouse designed self tie scarf neck long cuffed sleeves high low hemline',
#  'designed curated minimalistic style icon elin kling provides updated essentials effortless mix match ideal work weekends high rise ossi tailored full length tailored leg wear matching blazer smart look keep casual oversized knit sneakers',
#  'derek lam oversized silk blouse designed self tie scarf neck long cuffed sleeves high low hemline',
#  'croc embossing brings moment appeal double band sandal finished gleaming buckles',
#  'croc embossing brings moment appeal double band sandal finished gleaming buckles',
#  'tan leather calf magnetic fastening front flap weighs approximately NUMERICAL_VALUE lbs NUMERICAL_VALUE kg made italy',
#  'crafted italy golden goose hi star sneakers designed brand signature star stamped gold tone logo textured leather uppers set platform rubber sole pair complete suede vamps handwritten text accents highlight chunky heel pairing midi length skirt',
#  'multicolored cotton nylon merino wool alpaca cashmere mohair blend slips material material LOW_COTTON wool material material LOW_NYLON dry clean imported',
#  'black leather lamb open top weighs approximately NUMERICAL_VALUE lbs NUMERICAL_VALUE kg imported',
#  'ivory jeans dressed toned need straight leg fit skinny constricting super flattering leg elongating silhouette falls past ankles meaning work equally well block heeled boot office low top sneakers kicking around material washmade usamodel NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE bust NUMERICAL_VALUE waist NUMERICAL_VALUE hips wearing size NUMERICAL_VALUE',
#  'flouncy tie gathers neckline billowy chartreuse dress finished attached hem enhance flowy movement',
#  'black white lyocell partially concealed snap fastenings front HIGH_LYOCELL dry clean imported',
#  'black white lyocell partially concealed snap fastenings front HIGH_LYOCELL dry clean imported',
#  'gray cotton jersey slips HIGH_COTTON machine wash designer color tinker',
#  'ivory jeans dressed toned need straight leg fit skinny constricting super flattering leg elongating silhouette falls past ankles meaning work equally well block heeled boot office low top sneakers kicking around material washmade usamodel NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE bust NUMERICAL_VALUE waist NUMERICAL_VALUE hips wearing size NUMERICAL_VALUE',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches cream leather lamb slip designer color buttercream made italysmall size see size fit notes',
#  'designed curated minimalistic style icon elin kling provides updated essentials effortless mix match ideal work weekends high rise ossi tailored full length tailored leg wear matching blazer smart look keep casual oversized knit sneakers',
#  'designed curated minimalistic style icon elin kling provides updated essentials effortless mix match ideal work weekends high rise ossi tailored full length tailored leg wear matching blazer smart look keep casual oversized knit sneakers',
#  'cream black jersey button fastening keyhole back material material lining HIGH_VISCOSE dry clean imported',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches cream leather lamb slip designer color buttercream made italysmall size see size fit notes',
#  'cream black jersey button fastening keyhole back material material lining HIGH_VISCOSE dry clean imported',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches cream leather lamb slip designer color buttercream made italysmall size see size fit notes',
#  'gray cotton jersey slips HIGH_COTTON machine wash designer color tinker',
#  'midnight blue organic cotton velour pull HIGH_ORGANIC cotton machine wash imported',
#  'black white lyocell partially concealed snap fastenings front HIGH_LYOCELL dry clean imported',
#  'stone stretch pima cotton pull HIGH_PIMA cotton LOW_ELASTANE machine wash imported',
#  'black white lyocell partially concealed snap fastenings front HIGH_LYOCELL dry clean imported',
#  'silhouette poised cap toe pump gets vacation update platform wedge heel wrapped braided jute',
#  'stone stretch pima cotton pull HIGH_PIMA cotton LOW_ELASTANE machine wash imported',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches cream leather lamb slip designer color buttercream made italysmall size see size fit notes',
#  'pleat neck top made italy paper thin poplin shirting unicorn got beauty best loved blouse thanks pretty front pleats intricate knot detailing collar brains favorite tee relaxed shape roomy sleeves oh incognito buttons back nicest touches material clean onlymade italymeasurements size NUMERICAL_VALUE NUMERICAL_VALUE chest NUMERICAL_VALUE sleeve length NUMERICAL_VALUE body lengthmodel NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE bust NUMERICAL_VALUE waist NUMERICAL_VALUE hips wearing size NUMERICAL_VALUE',
#  'pleat neck top made italy paper thin poplin shirting unicorn got beauty best loved blouse thanks pretty front pleats intricate knot detailing collar brains favorite tee relaxed shape roomy sleeves oh incognito buttons back nicest touches material clean onlymade italymeasurements size NUMERICAL_VALUE NUMERICAL_VALUE chest NUMERICAL_VALUE sleeve length NUMERICAL_VALUE body lengthmodel NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE bust NUMERICAL_VALUE waist NUMERICAL_VALUE hips wearing size NUMERICAL_VALUE',
#  'silhouette poised cap toe pump gets vacation update platform wedge heel wrapped braided jute',
#  'pleat neck top made italy paper thin poplin shirting unicorn got beauty best loved blouse thanks pretty front pleats intricate knot detailing collar brains favorite tee relaxed shape roomy sleeves oh incognito buttons back nicest touches material clean onlymade italymeasurements size NUMERICAL_VALUE NUMERICAL_VALUE chest NUMERICAL_VALUE sleeve length NUMERICAL_VALUE body lengthmodel NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE bust NUMERICAL_VALUE waist NUMERICAL_VALUE hips wearing size NUMERICAL_VALUE',
#  'pleat neck top made italy paper thin poplin shirting unicorn got beauty best loved blouse thanks pretty front pleats intricate knot detailing collar brains favorite tee relaxed shape roomy sleeves oh incognito buttons back nicest touches material clean onlymade italymeasurements size NUMERICAL_VALUE NUMERICAL_VALUE chest NUMERICAL_VALUE sleeve length NUMERICAL_VALUE body lengthmodel NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE bust NUMERICAL_VALUE waist NUMERICAL_VALUE hips wearing size NUMERICAL_VALUE',
#  'anything leopard tends automatically fall chic category factor la double romantic touches like frilly flutter sleeves stunning almost architectural standing collar italian made crepe dress becomes something else entirely oh knee length cut means office appropriate date night friendly pretty back thank tie detail material HIGH_VISCOSE cleanmade italymodel NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE bust NUMERICAL_VALUE waist NUMERICAL_VALUE hips wearing size xs',
#  'silhouette poised cap toe pump gets vacation update platform wedge heel wrapped braided jute',
#  'nobody denim true jeans designed pre cuffed hems saving time finding perfect length crafted medium wash style fashioned mid rise waist brand logo stitching back right pocket couple skinny style puffed sleeve blouse add volume',
#  'nobody denim true jeans designed pre cuffed hems saving time finding perfect length crafted medium wash style fashioned mid rise waist brand logo stitching back right pocket couple skinny style puffed sleeve blouse add volume',
#  'nobody denim true jeans designed pre cuffed hems saving time finding perfect length crafted medium wash style fashioned mid rise waist brand logo stitching back right pocket couple skinny style puffed sleeve blouse add volume',
#  'aquazzura minute sandals crafted polished leather ultra slim straps secure frame foot pair literally take look new heights set slender stiletto heel measuring four inches',
#  'aquazzura minute sandals crafted polished leather ultra slim straps secure frame foot pair literally take look new heights set slender stiletto heel measuring four inches',
#  'one example season strong tailoring theme carolina herrera trousers cut wool silk blend woven classic prince wales check typically found men suiting high waisted pair fitted hips tapered knees flaring toward ankles complete look matching printed jacket',
#  'one example season strong tailoring theme carolina herrera trousers cut wool silk blend woven classic prince wales check typically found men suiting high waisted pair fitted hips tapered knees flaring toward ankles complete look matching printed jacket',
#  'designed curated minimalistic style icon elin kling provides updated essentials effortless mix match ideal work weekends high rise ossi tailored full length tailored leg wear matching blazer smart look keep casual oversized knit sneakers',
#  'drawstring waist cropped silhouette bring relaxed lounge inspired attitude pants slight sheen tonal floral pattern silky feel',
#  'drawstring waist cropped silhouette bring relaxed lounge inspired attitude pants slight sheen tonal floral pattern silky feel',
#  'gray cotton jersey slips HIGH_COTTON machine wash designer color tinker',
#  'aquazzura minute sandals crafted polished leather ultra slim straps secure frame foot pair literally take look new heights set slender stiletto heel measuring four inches',
#  'flouncy tie gathers neckline billowy chartreuse dress finished attached hem enhance flowy movement',
#  'anything leopard tends automatically fall chic category factor la double romantic touches like frilly flutter sleeves stunning almost architectural standing collar italian made crepe dress becomes something else entirely oh knee length cut means office appropriate date night friendly pretty back thank tie detail material HIGH_VISCOSE cleanmade italymodel NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE bust NUMERICAL_VALUE waist NUMERICAL_VALUE hips wearing size xs',
#  'gleaming studs outline sole retro inspired slide sandal lofted chunky woodgrain heel platform',
#  'one example season strong tailoring theme carolina herrera trousers cut wool silk blend woven classic prince wales check typically found men suiting high waisted pair fitted hips tapered knees flaring toward ankles complete look matching printed jacket',
#  'one example season strong tailoring theme carolina herrera trousers cut wool silk blend woven classic prince wales check typically found men suiting high waisted pair fitted hips tapered knees flaring toward ankles complete look matching printed jacket',
#  'black ribbed knit slips material material material MEDIAN_WOOL dry clean imported',
#  'black ribbed knit slips material material material MEDIAN_WOOL dry clean imported',
#  'gleaming studs outline sole retro inspired slide sandal lofted chunky woodgrain heel platform',
#  'breezy wide leg pants designed glamorous sweeping silhouette fluid silk',
#  'breezy wide leg pants designed glamorous sweeping silhouette fluid silk',
#  'aquazzura minute sandals crafted polished leather ultra slim straps secure frame foot pair literally take look new heights set slender stiletto heel measuring four inches',
#  'beige washed stretch silk satin slips material HIGH_SILK hand wash designer color fawn imported',
#  'beige washed stretch silk satin slips material HIGH_SILK hand wash designer color fawn imported',
#  'suckers pretty statement top exactly landed tee ladylike twists fits feels like favorite shirt thank soft cotton jersey perked high volume poplin sleeves gather gracefully toward cuffs yes statement shoulders best news treat like tees wear every single pair jeans trousers shorts material clean onlymade italymeasurements size NUMERICAL_VALUE length NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE chest NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE model NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE bust NUMERICAL_VALUE waist NUMERICAL_VALUE hips wearing size NUMERICAL_VALUE',
#  'suckers pretty statement top exactly landed tee ladylike twists fits feels like favorite shirt thank soft cotton jersey perked high volume poplin sleeves gather gracefully toward cuffs yes statement shoulders best news treat like tees wear every single pair jeans trousers shorts material clean onlymade italymeasurements size NUMERICAL_VALUE length NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE chest NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE model NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE bust NUMERICAL_VALUE waist NUMERICAL_VALUE hips wearing size NUMERICAL_VALUE',
#  'black ribbed knit slips material material material MEDIAN_WOOL dry clean imported',
#  'suckers pretty statement top exactly landed tee ladylike twists fits feels like favorite shirt thank soft cotton jersey perked high volume poplin sleeves gather gracefully toward cuffs yes statement shoulders best news treat like tees wear every single pair jeans trousers shorts material clean onlymade italymeasurements size NUMERICAL_VALUE length NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE chest NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE model NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE bust NUMERICAL_VALUE waist NUMERICAL_VALUE hips wearing size NUMERICAL_VALUE',
#  'pointy toe tapered heel balance streamlined silhouette go boot',
#  'pointy toe tapered heel balance streamlined silhouette go boot',
#  'black ribbed knit slips material material material MEDIAN_WOOL dry clean imported',
#  'lift spirits double strap slide sandal perched tall block heel thick platform easy gliding',
#  'enchanting cinderella glass slipper much wearable graceful italian sandal styled transparent straps',
#  'chunky knit marled hues boatneck sweater make cold weather go bonus slightly relaxed fit means drape perfectly tuck front high waisted pants jeans',
#  'chunky knit marled hues boatneck sweater make cold weather go bonus slightly relaxed fit means drape perfectly tuck front high waisted pants jeans',
#  'chunky knit marled hues boatneck sweater make cold weather go bonus slightly relaxed fit means drape perfectly tuck front high waisted pants jeans',
#  'edgy style expert craftsmanship combine block heel combat boot cut sewn lasted hand spanish artisans',
#  'edgy style expert craftsmanship combine block heel combat boot cut sewn lasted hand spanish artisans',
#  'cut soft camel wool max mara chic pacos coat designed broad fringe trimmed lapels cinch waist self tie belt keep phone handy one exaggerated patch pockets front',
#  'ivory crepe slips material material buttons HIGH_ACETATE cow dry clean imported',
#  'ivory crepe slips material material buttons HIGH_ACETATE cow dry clean imported',
#  'knotted ties detail toe strap elegant sandal lifted covered block heel tied adjustable wraparound straps',
#  'knotted ties detail toe strap elegant sandal lifted covered block heel tied adjustable wraparound straps',
#  'knotted ties detail toe strap elegant sandal lifted covered block heel tied adjustable wraparound straps',
#  'edgy style expert craftsmanship combine block heel combat boot cut sewn lasted hand spanish artisans',
#  'breezy wide leg pants designed glamorous sweeping silhouette fluid silk',
#  'multicolored cotton blend button fastening front material material MEDIAN_COTTON fibers buttons LOW_POLYESTER cow dry clean',
#  'multicolored cotton blend button fastening front material material MEDIAN_COTTON fibers buttons LOW_POLYESTER cow dry clean',
#  'ivory jeans dressed toned need straight leg fit skinny constricting super flattering leg elongating silhouette falls past ankles meaning work equally well block heeled boot office low top sneakers kicking around material washmade usamodel NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE bust NUMERICAL_VALUE waist NUMERICAL_VALUE hips wearing size NUMERICAL_VALUE',
#  'chunky knit marled hues boatneck sweater make cold weather go bonus slightly relaxed fit means drape perfectly tuck front high waisted pants jeans',
#  'chunky knit marled hues boatneck sweater make cold weather go bonus slightly relaxed fit means drape perfectly tuck front high waisted pants jeans',
#  'breezy wide leg pants designed glamorous sweeping silhouette fluid silk',
#  'chunky knit marled hues boatneck sweater make cold weather go bonus slightly relaxed fit means drape perfectly tuck front high waisted pants jeans',
#  'brown cashmere mulberry silk blend slips material MEDIAN_CASHMERE silk dry clean designer color bark imported',
#  'brown cashmere mulberry silk blend slips material MEDIAN_CASHMERE silk dry clean designer color bark imported',
#  'brown cashmere mulberry silk blend slips material MEDIAN_CASHMERE silk dry clean designer color bark imported',
#  'brown cashmere mulberry silk blend slips material MEDIAN_CASHMERE silk dry clean designer color bark imported',
#  'sleek sculptural strappy sandal shines metallic snakeskin looks modern square toe slim block heel',
#  'sleek sculptural strappy sandal shines metallic snakeskin looks modern square toe slim block heel',
#  'black leather lamb open top weighs approximately NUMERICAL_VALUE lbs NUMERICAL_VALUE kg imported',
#  'gleaming studs outline sole retro inspired slide sandal lofted chunky woodgrain heel platform',
#  'believe animal prints double neutral prada pumps prime example designed classic leopard motif sleek silhouette ends sharp toe fitted cushioned insoles try styling wide leg trousers give hem lift',
#  'classic crewneck sweatshirt gets luxurious update supremely soft cotton blend',
#  'classic crewneck sweatshirt gets luxurious update supremely soft cotton blend',
#  'believe animal prints double neutral prada pumps prime example designed classic leopard motif sleek silhouette ends sharp toe fitted cushioned insoles try styling wide leg trousers give hem lift',
#  'believe animal prints double neutral prada pumps prime example designed classic leopard motif sleek silhouette ends sharp toe fitted cushioned insoles try styling wide leg trousers give hem lift',
#  'believe animal prints double neutral prada pumps prime example designed classic leopard motif sleek silhouette ends sharp toe fitted cushioned insoles try styling wide leg trousers give hem lift',
#  'crafted italy golden goose hi star sneakers designed brand signature star stamped gold tone logo textured leather uppers set platform rubber sole pair complete suede vamps handwritten text accents highlight chunky heel pairing midi length skirt',
#  'multicolored cotton nylon merino wool alpaca cashmere mohair blend slips material material LOW_COTTON wool material material LOW_NYLON dry clean imported',
#  'classic crewneck sweatshirt gets luxurious update supremely soft cotton blend',
#  'classic crewneck sweatshirt gets luxurious update supremely soft cotton blend',
#  'believe animal prints double neutral prada pumps prime example designed classic leopard motif sleek silhouette ends sharp toe fitted cushioned insoles try styling wide leg trousers give hem lift',
#  'multicolored cotton nylon merino wool alpaca cashmere mohair blend slips material material LOW_COTTON wool material material LOW_NYLON dry clean imported',
#  'raffia wrapped platform wedge hint metallic shimmer makes suede ankle tie sandal refined resort ready standout',
#  'raffia wrapped platform wedge hint metallic shimmer makes suede ankle tie sandal refined resort ready standout',
#  'raffia wrapped platform wedge hint metallic shimmer makes suede ankle tie sandal refined resort ready standout',
#  'believe animal prints double neutral prada pumps prime example designed classic leopard motif sleek silhouette ends sharp toe fitted cushioned insoles try styling wide leg trousers give hem lift',
#  '',
#  '',
#  'camel grain de poudre wool button fastening front material buttons HIGH_WOOL buffalo dry clean made italy',
#  'sinuous straps cross atop lightly cushioned sandal shaped squared toe architectural block heel',
#  '',
#  '',
#  'anything leopard tends automatically fall chic category factor la double romantic touches like frilly flutter sleeves stunning almost architectural standing collar italian made crepe dress becomes something else entirely oh knee length cut means office appropriate date night friendly pretty back thank tie detail material HIGH_VISCOSE cleanmade italymodel NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE bust NUMERICAL_VALUE waist NUMERICAL_VALUE hips wearing size xs',
#  'crafted italy golden goose hi star sneakers designed brand signature star stamped gold tone logo textured leather uppers set platform rubber sole pair complete suede vamps handwritten text accents highlight chunky heel pairing midi length skirt',
#  'webbed straps contrast wedge serrated platform style modern sporty sandal',
#  'enchanting cinderella glass slipper much wearable graceful italian sandal styled transparent straps',
#  'brown cashmere mulberry silk blend slips material MEDIAN_CASHMERE silk dry clean designer color bark imported',
#  'anything leopard tends automatically fall chic category factor la double romantic touches like frilly flutter sleeves stunning almost architectural standing collar italian made crepe dress becomes something else entirely oh knee length cut means office appropriate date night friendly pretty back thank tie detail material HIGH_VISCOSE cleanmade italymodel NUMERICAL_VALUE NUMERICAL_VALUE NUMERICAL_VALUE bust NUMERICAL_VALUE waist NUMERICAL_VALUE hips wearing size xs',
#  'multicolored cotton jersey slips HIGH_COTTON machine wash',
#  'multicolored cotton jersey slips HIGH_COTTON machine wash',
#  'brown cashmere mulberry silk blend slips material MEDIAN_CASHMERE silk dry clean designer color bark imported',
#  'brown cashmere mulberry silk blend slips material MEDIAN_CASHMERE silk dry clean designer color bark imported',
#  'brown cashmere mulberry silk blend slips material MEDIAN_CASHMERE silk dry clean designer color bark imported',
#  'webbed straps contrast wedge serrated platform style modern sporty sandal',
#  'black cotton jersey slips HIGH_COTTON machine wash imported',
#  'black cotton jersey slips HIGH_COTTON machine wash imported',
#  'partnered fabric house southwest france make custom trim hem polished tweed pencil skirt even better also designed matching jacket outfit potential',
#  'partnered fabric house southwest france make custom trim hem polished tweed pencil skirt even better also designed matching jacket outfit potential',
#  'black cotton jersey slips HIGH_COTTON machine wash imported',
#  'black cotton jersey slips HIGH_COTTON machine wash imported',
#  'ivory crepe slips material material buttons HIGH_ACETATE cow dry clean imported',
#  'ivory crepe slips material material buttons HIGH_ACETATE cow dry clean imported',
#  'cut soft camel wool max mara chic pacos coat designed broad fringe trimmed lapels cinch waist self tie belt keep phone handy one exaggerated patch pockets front',
#  'sinuous straps cross atop lightly cushioned sandal shaped squared toe architectural block heel',
#  'italian crafted chelsea boot sleek timeless style low key luxe',
#  'italian crafted chelsea boot sleek timeless style low key luxe',
#  'cut soft camel wool max mara chic pacos coat designed broad fringe trimmed lapels cinch waist self tie belt keep phone handy one exaggerated patch pockets front',
#  'channel inner NUMERICAL_VALUE supermodel day night sandal toe loop mid heel clean geometric angles',
#  'done delivers one two punch comfort confidence cotton tee featuring comic style graphic butt kicking boxer',
#  'dramatic curves sharp angles marry pointy toe bootie made steep slant stacked heel',
#  'black leather lamb open top weighs approximately NUMERICAL_VALUE lbs NUMERICAL_VALUE kg imported',
#  'dramatic curves sharp angles marry pointy toe bootie made steep slant stacked heel',
#  'camel grain de poudre wool button fastening front material buttons HIGH_WOOL buffalo dry clean made italy',
#  'channel inner NUMERICAL_VALUE supermodel day night sandal toe loop mid heel clean geometric angles',
#  'partnered fabric house southwest france make custom trim hem polished tweed pencil skirt even better also designed matching jacket outfit potential',
#  'black stretch pima cotton jersey slips HIGH_PIMA cotton LOW_ELASTANE hand wash imported',
#  'gray cotton jersey slips HIGH_COTTON machine wash designer color tinker',
#  'partnered fabric house southwest france make custom trim hem polished tweed pencil skirt even better also designed matching jacket outfit potential',
#  'easy slide sandal go everywhere shoe brings bit beachy style everyday outfits',
#  'tan leather calf magnetic fastening front flap weighs approximately NUMERICAL_VALUE lbs NUMERICAL_VALUE kg made italy',
#  'tan leather calf magnetic fastening front flap weighs approximately NUMERICAL_VALUE lbs NUMERICAL_VALUE kg made italy',
#  'white virgil abloh fringes popon bag crafted pom pom silhouette fringe details wristlet strap',
#  'easy slide sandal go everywhere shoe brings bit beachy style everyday outfits',
#  'multicolored cotton jersey slips HIGH_COTTON machine wash',
#  'white virgil abloh fringes popon bag crafted pom pom silhouette fringe details wristlet strap',
#  'multicolored cotton jersey slips HIGH_COTTON machine wash',
#  'styled slender mid heel cut vamp flows pointy toe mule looks chic date office',
#  'styled slender mid heel cut vamp flows pointy toe mule looks chic date office',
#  'cut soft camel wool max mara chic pacos coat designed broad fringe trimmed lapels cinch waist self tie belt keep phone handy one exaggerated patch pockets front',
#  'cream crepe slips material material lining material MEDIAN_ACETATE dry clean',
#  'cream crepe slips material material lining material MEDIAN_ACETATE dry clean',
#  '',
#  '',
#  'light blue navy white jersey pull material HIGH_VISCOSE dry clean designer color celeste blue imported',
#  'light blue navy white jersey pull material HIGH_VISCOSE dry clean designer color celeste blue imported',
#  'light blue navy white jersey pull material HIGH_VISCOSE dry clean designer color celeste blue imported',
#  'light blue navy white jersey pull material HIGH_VISCOSE dry clean designer color celeste blue imported',
#  'light blue navy white jersey pull material HIGH_VISCOSE dry clean designer color celeste blue imported',
#  'anaak violeta midi dress cut airy cotton voile artfully embroidered contrasting topstitches fully lined coverage designed delicate shoulder straps neckline keep styling simple pair leather slides',
#  'anaak violeta midi dress cut airy cotton voile artfully embroidered contrasting topstitches fully lined coverage designed delicate shoulder straps neckline keep styling simple pair leather slides',
#  'anaak violeta midi dress cut airy cotton voile artfully embroidered contrasting topstitches fully lined coverage designed delicate shoulder straps neckline keep styling simple pair leather slides',
#  'anaak violeta midi dress cut airy cotton voile artfully embroidered contrasting topstitches fully lined coverage designed delicate shoulder straps neckline keep styling simple pair leather slides',
#  'anaak violeta midi dress cut airy cotton voile artfully embroidered contrasting topstitches fully lined coverage designed delicate shoulder straps neckline keep styling simple pair leather slides',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches olive leather lamb zip fastening along side made italy',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches olive leather lamb zip fastening along side made italy',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches olive leather lamb zip fastening along side made italy',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches olive leather lamb zip fastening along side made italy',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches olive leather lamb zip fastening along side made italy',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches olive leather lamb zip fastening along side made italy',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches olive leather lamb zip fastening along side made italy',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches olive leather lamb zip fastening along side made italy',
#  'black leather cow magnetic fastening front flap weighs approximately NUMERICAL_VALUE lbs NUMERICAL_VALUE kg made italy',
#  'black leather cow magnetic fastening front flap weighs approximately NUMERICAL_VALUE lbs NUMERICAL_VALUE kg made italy',
#  'black leather cow magnetic fastening front flap weighs approximately NUMERICAL_VALUE lbs NUMERICAL_VALUE kg made italy',
#  'black leather cow magnetic fastening front flap weighs approximately NUMERICAL_VALUE lbs NUMERICAL_VALUE kg made italy',
#  'brown alpaca blend material material HIGH_ALPACA wool hand wash designer color mushroom imported',
#  'brown alpaca blend material material HIGH_ALPACA wool hand wash designer color mushroom imported',
#  'brown alpaca blend material material HIGH_ALPACA wool hand wash designer color mushroom imported',
#  'brown alpaca blend material material HIGH_ALPACA wool hand wash designer color mushroom imported',
#  'fan distinctive shapes colors wandler handbags really like brand debut shoe collection label bente mules crafted plush zebra printed calf hair sleek point toe silhouette glossy leather kitten heels create cool contrast',
#  'fan distinctive shapes colors wandler handbags really like brand debut shoe collection label bente mules crafted plush zebra printed calf hair sleek point toe silhouette glossy leather kitten heels create cool contrast',
#  'fan distinctive shapes colors wandler handbags really like brand debut shoe collection label bente mules crafted plush zebra printed calf hair sleek point toe silhouette glossy leather kitten heels create cool contrast',
#  'fan distinctive shapes colors wandler handbags really like brand debut shoe collection label bente mules crafted plush zebra printed calf hair sleek point toe silhouette glossy leather kitten heels create cool contrast',
#  'fan distinctive shapes colors wandler handbags really like brand debut shoe collection label bente mules crafted plush zebra printed calf hair sleek point toe silhouette glossy leather kitten heels create cool contrast',
#  'fan distinctive shapes colors wandler handbags really like brand debut shoe collection label bente mules crafted plush zebra printed calf hair sleek point toe silhouette glossy leather kitten heels create cool contrast',
#  'calling inner vintage goddess kindred mia maxi dress features floral fabric mermaid silhouette slightest train designed deep neckline swooping back top hook closure long keyhole split leading invisible zip fastening fitted waist gives way full maxi skirt ruffled split knee length ending perforated hem light grey contrast binding frames delicate button detailing along front pair brands edie fur mirror brands pre fall NUMERICAL_VALUE lookbook',
#  'calling inner vintage goddess kindred mia maxi dress features floral fabric mermaid silhouette slightest train designed deep neckline swooping back top hook closure long keyhole split leading invisible zip fastening fitted waist gives way full maxi skirt ruffled split knee length ending perforated hem light grey contrast binding frames delicate button detailing along front pair brands edie fur mirror brands pre fall NUMERICAL_VALUE lookbook',
#  'calling inner vintage goddess kindred mia maxi dress features floral fabric mermaid silhouette slightest train designed deep neckline swooping back top hook closure long keyhole split leading invisible zip fastening fitted waist gives way full maxi skirt ruffled split knee length ending perforated hem light grey contrast binding frames delicate button detailing along front pair brands edie fur mirror brands pre fall NUMERICAL_VALUE lookbook',
#  'calling inner vintage goddess kindred mia maxi dress features floral fabric mermaid silhouette slightest train designed deep neckline swooping back top hook closure long keyhole split leading invisible zip fastening fitted waist gives way full maxi skirt ruffled split knee length ending perforated hem light grey contrast binding frames delicate button detailing along front pair brands edie fur mirror brands pre fall NUMERICAL_VALUE lookbook',
#  'soft leather tote opens unlined interior slender straps slip easily shoulder',
#  'soft leather tote opens unlined interior slender straps slip easily shoulder',
#  'soft leather tote opens unlined interior slender straps slip easily shoulder',
#  'soft leather tote opens unlined interior slender straps slip easily shoulder',
#  'soft leather tote opens unlined interior slender straps slip easily shoulder',
#  'soft leather tote opens unlined interior slender straps slip easily shoulder',
#  '',
#  '',
#  '',
#  '',
#  'fringe shawl toss look expertly spun italy merino wool yarns smooth sensuous',
#  'fringe shawl toss look expertly spun italy merino wool yarns smooth sensuous',
#  'fringe shawl toss look expertly spun italy merino wool yarns smooth sensuous',
#  'fringe shawl toss look expertly spun italy merino wool yarns smooth sensuous',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'goldsign designed relaxed bound shirt warm hue brand describes ochre fitted round collar short sleeve style easily transitioned seasonal wardrobe add extra layers weather permits',
#  'beige satin ties side concealed button fastenings front material MEDIAN_CUPRO dry clean imported',
#  'beige satin ties side concealed button fastenings front material MEDIAN_CUPRO dry clean imported',
#  'beige satin ties side concealed button fastenings front material MEDIAN_CUPRO dry clean imported',
#  'handcrafted italy amina muaddi dua ankle boots wonderfully retro silhouette built thick platform soles pair chunky heel upper comes ankle style cropped jeans show best advantage',
#  'handcrafted italy amina muaddi dua ankle boots wonderfully retro silhouette built thick platform soles pair chunky heel upper comes ankle style cropped jeans show best advantage',
#  'goldsign designed relaxed bound shirt warm hue brand describes ochre fitted round collar short sleeve style easily transitioned seasonal wardrobe add extra layers weather permits',
#  'goldsign designed relaxed bound shirt warm hue brand describes ochre fitted round collar short sleeve style easily transitioned seasonal wardrobe add extra layers weather permits',
#  'goldsign designed relaxed bound shirt warm hue brand describes ochre fitted round collar short sleeve style easily transitioned seasonal wardrobe add extra layers weather permits',
#  'goldsign designed relaxed bound shirt warm hue brand describes ochre fitted round collar short sleeve style easily transitioned seasonal wardrobe add extra layers weather permits',
#  'clean trouser goldsign crafted figure flattering wide leg skim boots rigid construction worry stretching throughout day pair lightweight tonal knits sleek monochromatic look',
#  'clean trouser goldsign crafted figure flattering wide leg skim boots rigid construction worry stretching throughout day pair lightweight tonal knits sleek monochromatic look',
#  'clean trouser goldsign crafted figure flattering wide leg skim boots rigid construction worry stretching throughout day pair lightweight tonal knits sleek monochromatic look',
#  'clean trouser goldsign crafted figure flattering wide leg skim boots rigid construction worry stretching throughout day pair lightweight tonal knits sleek monochromatic look',
#  'clean trouser goldsign crafted figure flattering wide leg skim boots rigid construction worry stretching throughout day pair lightweight tonal knits sleek monochromatic look',
#  'clean trouser goldsign crafted figure flattering wide leg skim boots rigid construction worry stretching throughout day pair lightweight tonal knits sleek monochromatic look',
#  'clean trouser goldsign crafted figure flattering wide leg skim boots rigid construction worry stretching throughout day pair lightweight tonal knits sleek monochromatic look',
#  'multicolored knit construction feels fresh lace sneaker silhouette',
#  'multicolored knit construction feels fresh lace sneaker silhouette',
#  'multicolored knit construction feels fresh lace sneaker silhouette',
#  'multicolored knit construction feels fresh lace sneaker silhouette',
#  'slim silhouette cropped ankle exquisitely tailored finish define chic trousers crafted crisp cotton hint silk lined added comfort',
#  'slim silhouette cropped ankle exquisitely tailored finish define chic trousers crafted crisp cotton hint silk lined added comfort',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'akris skirt crafted buttery lamb leather wrap style falls knee try styling slim fitting turtleneck',
#  'akris skirt crafted buttery lamb leather wrap style falls knee try styling slim fitting turtleneck',
# ...
#  'high waisted wide leg pant full length cut made fluid twill fabric designed smooth look beautiful drape soft feel skin zip fly hook bar closure front slant pockets rear welt pockets flat front trouser crease side stripe piping accent side vents hem measure NUMERICAL_VALUE unlined',
#  'rotate sequined mini dress designed slim strap silhouette neckline sequin pattern creates floral like detail',
#  'rotate sequined mini dress designed slim strap silhouette neckline sequin pattern creates floral like detail',
#  'rotate sequined mini dress designed slim strap silhouette neckline sequin pattern creates floral like detail',
#  'rotate sequined mini dress designed slim strap silhouette neckline sequin pattern creates floral like detail',
#  'fresh take lbd spaghetti strap version trumpet style silhouette delicate sheer mesh accent neckline luxe feminine look neck mesh accent adjustable slider straps invisible zipper back flounce hem fully lined',
#  'fresh take lbd spaghetti strap version trumpet style silhouette delicate sheer mesh accent neckline luxe feminine look neck mesh accent adjustable slider straps invisible zipper back flounce hem fully lined',
#  '',
#  '',
#  '',
#  '',
#  'iconic style japanese influence designed sized specifically japan customers available online part highly limited edition collection elongating wide leg silhouette blake pant equal parts modern stylish classic wide leg trouser expertly cut flattering fit comfortable chic made soft stretch fabric tie waist zip side vertical welt front pockets rear welt pockets flat front trouser crease unlined please consult size guide find best fit',
#  'iconic style japanese influence designed sized specifically japan customers available online part highly limited edition collection elongating wide leg silhouette blake pant equal parts modern stylish classic wide leg trouser expertly cut flattering fit comfortable chic made soft stretch fabric tie waist zip side vertical welt front pockets rear welt pockets flat front trouser crease unlined please consult size guide find best fit',
#  'iconic style japanese influence designed sized specifically japan customers available online part highly limited edition collection elongating wide leg silhouette blake pant equal parts modern stylish classic wide leg trouser expertly cut flattering fit comfortable chic made soft stretch fabric tie waist zip side vertical welt front pockets rear welt pockets flat front trouser crease unlined please consult size guide find best fit',
#  'iconic style japanese influence designed sized specifically japan customers available online part highly limited edition collection elongating wide leg silhouette blake pant equal parts modern stylish classic wide leg trouser expertly cut flattering fit comfortable chic made soft stretch fabric tie waist zip side vertical welt front pockets rear welt pockets flat front trouser crease unlined please consult size guide find best fit',
#  'figure flattering midi dress sleek sheath silhouette neck adjustable slider straps invisible zipper back flounce hem lined bodice unlined skirt high low hem',
#  'figure flattering midi dress sleek sheath silhouette neck adjustable slider straps invisible zipper back flounce hem lined bodice unlined skirt high low hem',
#  'figure flattering midi dress sleek sheath silhouette neck adjustable slider straps invisible zipper back flounce hem lined bodice unlined skirt high low hem',
#  'figure flattering midi dress sleek sheath silhouette neck adjustable slider straps invisible zipper back flounce hem lined bodice unlined skirt high low hem',
#  'zeynep pants crafted genuine leather flattering high waisted fit full length leg slim silhouette pair brand wrap leather blazer mirror fall winter NUMERICAL_VALUE lookbook style',
#  'zeynep pants crafted genuine leather flattering high waisted fit full length leg slim silhouette pair brand wrap leather blazer mirror fall winter NUMERICAL_VALUE lookbook style',
#  'zeynep pants crafted genuine leather flattering high waisted fit full length leg slim silhouette pair brand wrap leather blazer mirror fall winter NUMERICAL_VALUE lookbook style',
#  'zeynep pants crafted genuine leather flattering high waisted fit full length leg slim silhouette pair brand wrap leather blazer mirror fall winter NUMERICAL_VALUE lookbook style',
#  'supple faux leather brings glamorous edge tailored shorts',
#  'supple faux leather brings glamorous edge tailored shorts',
#  'supple faux leather brings glamorous edge tailored shorts',
#  'supple faux leather brings glamorous edge tailored shorts',
#  'cigarette pants cut gingham blithe look',
#  'cigarette pants cut gingham blithe look',
#  'cigarette pants cut gingham blithe look',
#  'cigarette pants cut gingham blithe look',
#  'throw back cropped shirt fine ribbed texture back seam detail',
#  'throw back cropped shirt fine ribbed texture back seam detail',
#  'throw back cropped shirt fine ribbed texture back seam detail',
#  'throw back cropped shirt fine ribbed texture back seam detail',
#  'partow crepe everly midi skirt tailored high rise fit designed line silhouette fluid shape detailed concealed front pockets relaxed pleats style matching dress complete look',
#  'partow crepe everly midi skirt tailored high rise fit designed line silhouette fluid shape detailed concealed front pockets relaxed pleats style matching dress complete look',
#  'partow crepe everly midi skirt tailored high rise fit designed line silhouette fluid shape detailed concealed front pockets relaxed pleats style matching dress complete look',
#  'partow crepe everly midi skirt tailored high rise fit designed line silhouette fluid shape detailed concealed front pockets relaxed pleats style matching dress complete look',
#  'shoulder baring design airy cotton handle cult gaia claire top perfectly suited warm weather months long sleeve style tie detailed front tiered puffed sleeves fall knuckle grazing length highlight split hem high rise shorts',
#  'shoulder baring design airy cotton handle cult gaia claire top perfectly suited warm weather months long sleeve style tie detailed front tiered puffed sleeves fall knuckle grazing length highlight split hem high rise shorts',
#  'shoulder baring design airy cotton handle cult gaia claire top perfectly suited warm weather months long sleeve style tie detailed front tiered puffed sleeves fall knuckle grazing length highlight split hem high rise shorts',
#  'shoulder baring design airy cotton handle cult gaia claire top perfectly suited warm weather months long sleeve style tie detailed front tiered puffed sleeves fall knuckle grazing length highlight split hem high rise shorts',
#  'shoulder baring design airy cotton handle cult gaia claire top perfectly suited warm weather months long sleeve style tie detailed front tiered puffed sleeves fall knuckle grazing length highlight split hem high rise shorts',
#  'shoulder baring design airy cotton handle cult gaia claire top perfectly suited warm weather months long sleeve style tie detailed front tiered puffed sleeves fall knuckle grazing length highlight split hem high rise shorts',
#  'shoulder baring design airy cotton handle cult gaia claire top perfectly suited warm weather months long sleeve style tie detailed front tiered puffed sleeves fall knuckle grazing length highlight split hem high rise shorts',
#  'shoulder baring design airy cotton handle cult gaia claire top perfectly suited warm weather months long sleeve style tie detailed front tiered puffed sleeves fall knuckle grazing length highlight split hem high rise shorts',
#  'isabel marant welly shirt cut oversized fit enhanced season prominent shoulder made cotton poplin striped motif draped scarf inspired cowl neck style tapered wool trouser complement tailoring',
#  'isabel marant welly shirt cut oversized fit enhanced season prominent shoulder made cotton poplin striped motif draped scarf inspired cowl neck style tapered wool trouser complement tailoring',
#  'isabel marant welly shirt cut oversized fit enhanced season prominent shoulder made cotton poplin striped motif draped scarf inspired cowl neck style tapered wool trouser complement tailoring',
#  'isabel marant welly shirt cut oversized fit enhanced season prominent shoulder made cotton poplin striped motif draped scarf inspired cowl neck style tapered wool trouser complement tailoring',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches clear pvc beige suede calf elasticated slingback strap designer color nude made italysmall size see size fit notes',
#  'heel measures approximately NUMERICAL_VALUE mm NUMERICAL_VALUE inches clear pvc beige suede calf elasticated slingback strap designer color nude made italysmall size see size fit notes',
#  'biker jackets simple way elevate casual edit grlfrnd charlie rendition crafted textured leather detailed functional silver tone zip fastenings buckled belt cinch boxy shape complement cropped hem high rise jeans',
#  'biker jackets simple way elevate casual edit grlfrnd charlie rendition crafted textured leather detailed functional silver tone zip fastenings buckled belt cinch boxy shape complement cropped hem high rise jeans',
#  'biker jackets simple way elevate casual edit grlfrnd charlie rendition crafted textured leather detailed functional silver tone zip fastenings buckled belt cinch boxy shape complement cropped hem high rise jeans',
#  'biker jackets simple way elevate casual edit grlfrnd charlie rendition crafted textured leather detailed functional silver tone zip fastenings buckled belt cinch boxy shape complement cropped hem high rise jeans',
#  'biker jackets simple way elevate casual edit grlfrnd charlie rendition crafted textured leather detailed functional silver tone zip fastenings buckled belt cinch boxy shape complement cropped hem high rise jeans',
#  'biker jackets simple way elevate casual edit grlfrnd charlie rendition crafted textured leather detailed functional silver tone zip fastenings buckled belt cinch boxy shape complement cropped hem high rise jeans',
#  'biker jackets simple way elevate casual edit grlfrnd charlie rendition crafted textured leather detailed functional silver tone zip fastenings buckled belt cinch boxy shape complement cropped hem high rise jeans',
#  'biker jackets simple way elevate casual edit grlfrnd charlie rendition crafted textured leather detailed functional silver tone zip fastenings buckled belt cinch boxy shape complement cropped hem high rise jeans',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'antique rose silk satin slips HIGH_SILK dry clean designer color wood rose',
#  'antique rose silk satin slips HIGH_SILK dry clean designer color wood rose',
#  'antique rose silk satin slips HIGH_SILK dry clean designer color wood rose',
#  'antique rose silk satin slips HIGH_SILK dry clean designer color wood rose',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'detailed contrasting strap along ankle dorothee schumacher mirror touch pointed toe booties crafted leather metallic finish stiletto heel add twist classic look wearing tailored pants structured jacket',
#  'detailed contrasting strap along ankle dorothee schumacher mirror touch pointed toe booties crafted leather metallic finish stiletto heel add twist classic look wearing tailored pants structured jacket',
#  'detailed contrasting strap along ankle dorothee schumacher mirror touch pointed toe booties crafted leather metallic finish stiletto heel add twist classic look wearing tailored pants structured jacket',
#  'detailed contrasting strap along ankle dorothee schumacher mirror touch pointed toe booties crafted leather metallic finish stiletto heel add twist classic look wearing tailored pants structured jacket',
#  'detailed contrasting strap along ankle dorothee schumacher mirror touch pointed toe booties crafted leather metallic finish stiletto heel add twist classic look wearing tailored pants structured jacket',
#  'detailed contrasting strap along ankle dorothee schumacher mirror touch pointed toe booties crafted leather metallic finish stiletto heel add twist classic look wearing tailored pants structured jacket',
#  '',
#  '',
#  '',
#  '',
#  'whether headed farmhouse veranda urban terrace modern prairie appeal lacy cotton maxi dress welcome',
#  'whether headed farmhouse veranda urban terrace modern prairie appeal lacy cotton maxi dress welcome',
#  'whether headed farmhouse veranda urban terrace modern prairie appeal lacy cotton maxi dress welcome',
#  'whether headed farmhouse veranda urban terrace modern prairie appeal lacy cotton maxi dress welcome',
#  'whether headed farmhouse veranda urban terrace modern prairie appeal lacy cotton maxi dress welcome',
#  'whether headed farmhouse veranda urban terrace modern prairie appeal lacy cotton maxi dress welcome',
#  'perfect workday beyond victoria beckham modest dress designed drop sleeves knee length hem relaxed style detailed contrast piping along front back coordinate burgundy ankle boots',
#  'perfect workday beyond victoria beckham modest dress designed drop sleeves knee length hem relaxed style detailed contrast piping along front back coordinate burgundy ankle boots',
#  'perfect workday beyond victoria beckham modest dress designed drop sleeves knee length hem relaxed style detailed contrast piping along front back coordinate burgundy ankle boots',
#  'perfect workday beyond victoria beckham modest dress designed drop sleeves knee length hem relaxed style detailed contrast piping along front back coordinate burgundy ankle boots',
#  'perfect workday beyond victoria beckham modest dress designed drop sleeves knee length hem relaxed style detailed contrast piping along front back coordinate burgundy ankle boots',
#  'perfect workday beyond victoria beckham modest dress designed drop sleeves knee length hem relaxed style detailed contrast piping along front back coordinate burgundy ankle boots',
#  'bouguessa classic blazer designed neckline pocket flaps belted waist pair matching pants create ultimate power suit',
#  'bouguessa classic blazer designed neckline pocket flaps belted waist pair matching pants create ultimate power suit',
#  'bouguessa classic blazer designed neckline pocket flaps belted waist pair matching pants create ultimate power suit',
#  'bouguessa classic blazer designed neckline pocket flaps belted waist pair matching pants create ultimate power suit',
#  'carry essentials style rich leather briefcase removable crossbody strap',
#  'carry essentials style rich leather briefcase removable crossbody strap',
#  'carry essentials style rich leather briefcase removable crossbody strap',
#  'carry essentials style rich leather briefcase removable crossbody strap',
#  'loveshackfancy queenie ultra feminine silk dress designed ruffled hemline floral print pair minimalist accessories keep dress focus',
#  'loveshackfancy queenie ultra feminine silk dress designed ruffled hemline floral print pair minimalist accessories keep dress focus',
#  'loveshackfancy queenie ultra feminine silk dress designed ruffled hemline floral print pair minimalist accessories keep dress focus',
#  'loveshackfancy queenie ultra feminine silk dress designed ruffled hemline floral print pair minimalist accessories keep dress focus',
#  '',
#  '',
#  '',
#  '',
#  'cinched waist accentuate natural curves loveshackfancy cheyenne cotton skirt designed floral print fitted waist pair sweater fun transitional look',
#  'cinched waist accentuate natural curves loveshackfancy cheyenne cotton skirt designed floral print fitted waist pair sweater fun transitional look',
#  'cinched waist accentuate natural curves loveshackfancy cheyenne cotton skirt designed floral print fitted waist pair sweater fun transitional look',
#  'cinched waist accentuate natural curves loveshackfancy cheyenne cotton skirt designed floral print fitted waist pair sweater fun transitional look',
#  'cream silk satin pull HIGH_SILK dry clean made france',
#  'cream silk satin pull HIGH_SILK dry clean made france',
#  ...]

# %%
cleaned_brand_lem = []
for sentence in list(brand):
    cleaned_brand_lem = cleaned_brand_lem + [lemmatize_sentence(sentence)]

# %%
cleaned_details_lem = []
for sentence in list(df1):
    cleaned_details_lem = cleaned_details_lem + [lemmatize_sentence(sentence)]

# %%
cleaned_productname_lem = []
for sentence in list(product_full_name):
    cleaned_productname_lem = cleaned_productname_lem + [lemmatize_sentence(sentence)]

# %%
cleaned_productname_lem
# Out:
# ['sensillo leather tote',
#  's rib bodysuit',
#  's rib bodysuit',
#  'stretchpima cotton jersey tshirt',
#  'belt leather wideleg pant',
#  'larina crepe dress',
#  'larina crepe dress',
#  'belt leather wideleg pant',
#  'belt leather wideleg pant',
#  'purist mirroredleather sandal',
#  'purist mirroredleather sandal',
#  'intermix knee high boot',
#  'rebecca rainbow flat sandal',
#  'rebecca rainbow flat sandal',
#  'purist mirroredleather sandal',
#  'purist mirroredleather sandal',
#  'larina crepe dress',
#  'larina crepe dress',
#  'belt grain poudre wool blazer',
#  'larina crepe dress',
#  'stretchpima cotton jersey tshirt',
#  'intermix knee high boot',
#  'boyfriend utility shirt',
#  'boyfriend utility shirt',
#  'stretchpima cotton jersey tshirt',
#  'kitten heel pump',
#  'kitten heel pump',
#  'drape cottonjersey dress',
#  'drape cottonjersey dress',
#  'drape cottonjersey dress',
#  'belt grain poudre wool blazer',
#  'sensillo leather tote',
#  'drape cottonjersey dress',
#  'boyfriend utility shirt',
#  'boyfriend utility shirt',
#  'lye slide sandal',
#  'meredith strip knit sweater',
#  'hi star platform leather suede sneaker',
#  'ace bootie',
#  'stanza slide sandal',
#  'christopher puffsleeve poplin tshirt',
#  'stanza slide sandal',
#  'scolto transparent strap sandal',
#  'christopher puffsleeve poplin tshirt',
#  'long leanfit plaid blazer',
#  'long leanfit plaid blazer',
#  'ace bootie',
#  'long leanfit plaid blazer',
#  'long leanfit plaid blazer',
#  'true crop midrise skinny jean',
#  'true crop midrise skinny jean',
#  'true crop midrise skinny jean',
#  'vanessa jean',
#  'belt leather wideleg pant',
#  'lina leather ankle boot',
#  'lina leather ankle boot',
#  'lina leather ankle boot',
#  'oversized drape silk blouse self tie neckline',
#  's plaid wool blend crop flare trouser',
#  's plaid wool blend crop flare trouser',
#  'belt leather wideleg pant',
#  'ace bootie',
#  'vanity crystal embellish sandal',
#  'vanity crystal embellish sandal',
#  'vanessa jean',
#  'oversized drape silk blouse self tie neckline',
#  'sawtooth denim western shirt',
#  'sawtooth denim western shirt',
#  'vanessa jean',
#  'ossi woolblend highrise trouser',
#  'al organic cottonvelour track pant',
#  'ossi woolblend highrise trouser',
#  'hortensia large leather shoulder bag',
#  'scolto transparent strap sandal',
#  'oversized drape silk blouse self tie neckline',
#  'ossi woolblend highrise trouser',
#  'oversized drape silk blouse self tie neckline',
#  'lonnie croc emboss sandal',
#  'lonnie croc emboss sandal',
#  'hortensia large leather shoulder bag',
#  'hi star platform leather suede sneaker',
#  'meredith strip knit sweater',
#  'sensillo leather tote',
#  'vanessa jean',
#  'tie shoulder ruffle hem silk maxi dress',
#  '# name ?',
#  '# name ?',
#  'drape cottonjersey dress',
#  'vanessa jean',
#  'lina leather ankle boot',
#  'ossi woolblend highrise trouser',
#  'ossi woolblend highrise trouser',
#  'openback ruched leopardprint jersey maxi dress',
#  'lina leather ankle boot',
#  'openback ruched leopardprint jersey maxi dress',
#  'lina leather ankle boot',
#  'drape cottonjersey dress',
#  'al organic cottonvelour track pant',
#  '# name ?',
#  'stretchpima cotton track pant',
#  '# name ?',
#  'glider espadrille wedge pump',
#  'stretchpima cotton track pant',
#  'lina leather ankle boot',
#  'gerda pleatneck blouse',
#  'gerda pleatneck blouse',
#  'glider espadrille wedge pump',
#  'gerda pleatneck blouse',
#  'gerda pleatneck blouse',
#  'bon ton leopard dress',
#  'glider espadrille wedge pump',
#  'true crop midrise skinny jean',
#  'true crop midrise skinny jean',
#  'true crop midrise skinny jean',
#  'minute leather sandal',
#  'minute leather sandal',
#  'highwaisted check silk wool wideleg pant',
#  'highwaisted check silk wool wideleg pant',
#  'ossi woolblend highrise trouser',
#  'floral crop pant',
#  'floral crop pant',
#  'drape cottonjersey dress',
#  'minute leather sandal',
#  'tie shoulder ruffle hem silk maxi dress',
#  'bon ton leopard dress',
#  'electric slide sandal',
#  'highwaisted check silk wool wideleg pant',
#  'highwaisted check silk wool wideleg pant',
#  'distressed ribbedknit sweater',
#  'distressed ribbedknit sweater',
#  'electric slide sandal',
#  'silk wide leg drawstring pant',
#  'silk wide leg drawstring pant',
#  'minute leather sandal',
#  'tara drape washed stretchsilk satin camisole',
#  'tara drape washed stretchsilk satin camisole',
#  'christopher puffsleeve poplin tshirt',
#  'christopher puffsleeve poplin tshirt',
#  'distressed ribbedknit sweater',
#  'christopher puffsleeve poplin tshirt',
#  'phenom knee high boot',
#  'phenom knee high boot',
#  'distressed ribbedknit sweater',
#  'jinx platform slide sandal',
#  'scolto transparent strap sandal',
#  'buttondetail chunky knit pullover sweater',
#  'buttondetail chunky knit pullover sweater',
#  'buttondetail chunky knit pullover sweater',
#  'ace bootie',
#  'ace bootie',
#  'pacos fringetrimmed wool coat',
#  'athena laceup crepe blouse',
#  'athena laceup crepe blouse',
#  'clarita block heel sandal',
#  'clarita block heel sandal',
#  'clarita block heel sandal',
#  'ace bootie',
#  'silk wide leg drawstring pant',
#  'elektra prince wale check cottonblend blazer',
#  'elektra prince wale check cottonblend blazer',
#  'vanessa jean',
#  'buttondetail chunky knit pullover sweater',
#  'buttondetail chunky knit pullover sweater',
#  'silk wide leg drawstring pant',
#  'buttondetail chunky knit pullover sweater',
#  'rib cashmere mulberry silkblend turtleneck sweater',
#  'rib cashmere mulberry silkblend turtleneck sweater',
#  'rib cashmere mulberry silkblend turtleneck sweater',
#  'rib cashmere mulberry silkblend turtleneck sweater',
#  'ally strappy sandal',
#  'ally strappy sandal',
#  'sensillo leather tote',
#  'electric slide sandal',
#  'leopardprint calf hair pump',
#  'sweatshirt',
#  'sweatshirt',
#  'leopardprint calf hair pump',
#  'leopardprint calf hair pump',
#  'leopardprint calf hair pump',
#  'hi star platform leather suede sneaker',
#  'meredith strip knit sweater',
#  'sweatshirt',
#  'sweatshirt',
#  'leopardprint calf hair pump',
#  'meredith strip knit sweater',
#  'clarita raffia platform wedge sandal',
#  'clarita raffia platform wedge sandal',
#  'clarita raffia platform wedge sandal',
#  'leopardprint calf hair pump',
#  'woolblended biker short',
#  'woolblended biker short',
#  'belt grain poudre wool blazer',
#  'vanguard sandal',
#  'woolblended biker short',
#  'woolblended biker short',
#  'bon ton leopard dress',
#  'hi star platform leather suede sneaker',
#  'rikki platform sandal',
#  'scolto transparent strap sandal',
#  'rib cashmere mulberry silkblend turtleneck sweater',
#  'bon ton leopard dress',
#  'iggy pop distress print cottonjersey tshirt',
#  'iggy pop distress print cottonjersey tshirt',
#  'rib cashmere mulberry silkblend turtleneck sweater',
#  'rib cashmere mulberry silkblend turtleneck sweater',
#  'rib cashmere mulberry silkblend turtleneck sweater',
#  'rikki platform sandal',
#  'milo cottonjersey dress',
#  'milo cottonjersey dress',
#  'tweed pencil skirt fringe',
#  'tweed pencil skirt fringe',
#  'milo cottonjersey dress',
#  'milo cottonjersey dress',
#  'athena laceup crepe blouse',
#  'athena laceup crepe blouse',
#  'pacos fringetrimmed wool coat',
#  'vanguard sandal',
#  'chelsea boot',
#  'chelsea boot',
#  'pacos fringetrimmed wool coat',
#  'henry slide sandal',
#  'classic kick graphic tee',
#  'niche bootie',
#  'sensillo leather tote',
#  'niche bootie',
#  'belt grain poudre wool blazer',
#  'henry slide sandal',
#  'tweed pencil skirt fringe',
#  'stretchpima cotton jersey tshirt',
#  'drape cottonjersey dress',
#  'tweed pencil skirt fringe',
#  'spinner slide sandal',
#  'hortensia large leather shoulder bag',
#  'hortensia large leather shoulder bag',
#  'plastic fringe popon bag',
#  'spinner slide sandal',
#  'iggy pop distress print cottonjersey tshirt',
#  'plastic fringe popon bag',
#  'iggy pop distress print cottonjersey tshirt',
#  'askan mule',
#  'askan mule',
#  'pacos fringetrimmed wool coat',
#  'larina crepe dress',
#  'larina crepe dress',
#  'leather lowtop sneaker',
#  'leather lowtop sneaker',
#  'liv wide strip jersey track pant',
#  'liv wide strip jersey track pant',
#  'liv wide strip jersey track pant',
#  'liv wide strip jersey track pant',
#  'liv wide strip jersey track pant',
#  'violeta embroider cottonvoile midi dress',
#  'violeta embroider cottonvoile midi dress',
#  'violeta embroider cottonvoile midi dress',
#  'violeta embroider cottonvoile midi dress',
#  'violeta embroider cottonvoile midi dress',
#  'isa leather ankle boot',
#  'isa leather ankle boot',
#  'isa leather ankle boot',
#  'isa leather ankle boot',
#  'isa leather ankle boot',
#  'isa leather ankle boot',
#  'isa leather ankle boot',
#  'isa leather ankle boot',
#  'hortensia large leather shoulder bag',
#  'hortensia large leather shoulder bag',
#  'hortensia large leather shoulder bag',
#  'hortensia large leather shoulder bag',
#  'alpacablend scarf',
#  'alpacablend scarf',
#  'alpacablend scarf',
#  'alpacablend scarf',
#  'bente zebraprint calf hair mule',
#  'bente zebraprint calf hair mule',
#  'bente zebraprint calf hair mule',
#  'bente zebraprint calf hair mule',
#  'bente zebraprint calf hair mule',
#  'bente zebraprint calf hair mule',
#  'mia matelassé maxi dress',
#  'mia matelassé maxi dress',
#  'mia matelassé maxi dress',
#  'mia matelassé maxi dress',
#  'torus leather tote',
#  'torus leather tote',
#  'torus leather tote',
#  'torus leather tote',
#  'torus leather tote',
#  'torus leather tote',
#  'doublebreasted crop cady blazer',
#  'doublebreasted crop cady blazer',
#  'doublebreasted crop cady blazer',
#  'doublebreasted crop cady blazer',
#  'fringe merino wool shawl',
#  'fringe merino wool shawl',
#  'fringe merino wool shawl',
#  'fringe merino wool shawl',
#  'wide leg trouser',
#  'wide leg trouser',
#  'wide leg trouser',
#  'wide leg trouser',
#  'print drape crepe dress',
#  'print drape crepe dress',
#  'print drape crepe dress',
#  'print drape crepe dress',
#  'fauxleather blazer',
#  'fauxleather blazer',
#  'fauxleather blazer',
#  'fauxleather blazer',
#  'bound sleeve tshirt',
#  'drape satin wrap dress',
#  'drape satin wrap dress',
#  'drape satin wrap dress',
#  'dua leather platform ankle boot',
#  'dua leather platform ankle boot',
#  'bound sleeve tshirt',
#  'bound sleeve tshirt',
#  'bound sleeve tshirt',
#  'bound sleeve tshirt',
#  'clean rigid cotton wideleg trouser',
#  'clean rigid cotton wideleg trouser',
#  'clean rigid cotton wideleg trouser',
#  'clean rigid cotton wideleg trouser',
#  'clean rigid cotton wideleg trouser',
#  'clean rigid cotton wideleg trouser',
#  'clean rigid cotton wideleg trouser',
#  'ultraboost clima missoni knit sneaker',
#  'ultraboost clima missoni knit sneaker',
#  'ultraboost clima missoni knit sneaker',
#  'ultraboost clima missoni knit sneaker',
#  'melvin cotton silk trouser',
#  'melvin cotton silk trouser',
#  'dahlia leather boot',
#  'dahlia leather boot',
#  'dahlia leather boot',
#  'dahlia leather boot',
#  'dahlia leather boot',
#  'dahlia leather boot',
#  'dahlia leather boot',
#  'dahlia leather boot',
#  'leather wrap skirt',
#  'leather wrap skirt',
#  'leather wrap skirt',
#  'leather wrap skirt',
#  'mel patent ankle boot',
#  'mel patent ankle boot',
#  'mel patent ankle boot',
#  'mel patent ankle boot',
#  'mel patent ankle boot',
#  'mel patent ankle boot',
#  'bea calf leather boot',
#  'bea calf leather boot',
#  'serena high skinny jean',
#  'serena high skinny jean',
#  'mia print leather shoulder bag',
#  'mia print leather shoulder bag',
#  'mia print leather shoulder bag',
#  'mia print leather shoulder bag',
#  'mia print leather shoulder bag',
#  'violeta embroider cottonvoile midi dress',
#  'bea calf leather boot',
#  'bea calf leather boot',
#  'belt leather pencil midi skirt',
#  'belt leather pencil midi skirt',
#  'belt leather pencil midi skirt',
#  'belt leather pencil midi skirt',
#  'belt leather pencil midi skirt',
#  'belt leather pencil midi skirt',
#  'superstar strip satinjersey track pant',
#  'superstar strip satinjersey track pant',
#  'superstar strip satinjersey track pant',
#  'superstar strip satinjersey track pant',
#  'strip lurex trouser',
#  'strip lurex trouser',
#  'strip lurex trouser',
#  'strip lurex trouser',
#  'superstar strip stretchjersey track pant',
#  'superstar strip stretchjersey track pant',
#  'superstar strip stretchjersey track pant',
#  'superstar strip satinjersey track pant',
#  'superstar strip satinjersey track pant',
#  'superstar strip satinjersey track pant',
#  'superstar strip satinjersey track pant',
#  'superstar strip satinjersey track pant',
#  'fringe wool silk cashmereblend jacquard cardigan',
#  'fringe wool silk cashmereblend jacquard cardigan',
#  'fringe wool silk cashmereblend jacquard cardigan',
#  'fringe wool silk cashmereblend jacquard cardigan',
#  'fringe wool silk cashmereblend jacquard cardigan',
#  'fringe wool silk cashmereblend jacquard cardigan',
#  'bardot print crepe mini dress',
#  'bardot print crepe mini dress',
#  'bardot print crepe mini dress',
#  'bardot print crepe mini dress',
#  'bardot print crepe mini dress',
#  'bardot print crepe mini dress',
#  'dessie floralprint tieneck blouse',
#  'dessie floralprint tieneck blouse',
#  'dessie floralprint tieneck blouse',
#  'dessie floralprint tieneck blouse',
#  'dessie floralprint tieneck blouse',
#  'dessie floralprint tieneck blouse',
#  'raquelle wrapeffect garden jacquard blazer',
#  'raquelle wrapeffect garden jacquard blazer',
#  'raquelle wrapeffect garden jacquard blazer',
#  'raquelle wrapeffect garden jacquard blazer',
#  'raquelle wrapeffect garden jacquard blazer',
#  'raquelle wrapeffect garden jacquard blazer',
#  'sanjit geoprint silk flaredleg pant',
#  'sanjit geoprint silk flaredleg pant',
#  'sanjit geoprint silk flaredleg pant',
#  'sanjit geoprint silk flaredleg pant',
#  'sanjit geoprint silk flaredleg pant',
#  'sanjit geoprint silk flaredleg pant',
#  'idun print crepe chine mini dress',
#  'idun print crepe chine mini dress',
#  'idun print crepe chine mini dress',
#  'idun print crepe chine mini dress',
#  'idun print crepe chine mini dress',
#  'idun print crepe chine mini dress',
#  'briana highwaisted faux leather mini skirt',
#  'briana highwaisted faux leather mini skirt',
#  'briana highwaisted faux leather mini skirt',
#  'briana highwaisted faux leather mini skirt',
#  'arabel ruffle silkchiffon blouse',
#  'arabel ruffle silkchiffon blouse',
#  'arabel ruffle silkchiffon blouse',
#  'arabel ruffle silkchiffon blouse',
#  'burgos splithem garden jacquard slimleg pant',
#  'burgos splithem garden jacquard slimleg pant',
#  'burgos splithem garden jacquard slimleg pant',
#  'burgos splithem garden jacquard slimleg pant',
#  'burgos splithem garden jacquard slimleg pant',
#  'burgos splithem garden jacquard slimleg pant',
#  'dominica print pleated crepe maxi dress',
#  'dominica print pleated crepe maxi dress',
#  'dominica print pleated crepe maxi dress',
#  'dominica print pleated crepe maxi dress',
#  'dominica print pleated crepe maxi dress',
#  'dominica print pleated crepe maxi dress',
#  'd logo slide',
#  'd logo slide',
#  'd logo slide',
#  'd logo slide',
#  'maika floralprint crepe mini dress',
#  'maika floralprint crepe mini dress',
#  'maika floralprint crepe mini dress',
#  'maika floralprint crepe mini dress',
#  'maika floralprint crepe mini dress',
#  'maika floralprint crepe mini dress',
#  'houndstooth wool pencil midi skirt',
#  'houndstooth wool pencil midi skirt',
#  'porter buckle snakeeffect leather ankle boot',
#  'porter buckle snakeeffect leather ankle boot',
#  'porter buckle snakeeffect leather ankle boot',
#  'porter buckle snakeeffect leather ankle boot',
#  'porter buckle snakeeffect leather ankle boot',
#  'porter buckle snakeeffect leather ankle boot',
#  'tieback washedgeorgette mini dress',
#  'tieback washedgeorgette mini dress',
#  'tieback washedgeorgette mini dress',
#  'tieback washedgeorgette mini dress',
#  'otto rib offtheshoulder crop top',
#  'otto rib offtheshoulder crop top',
#  'otto rib offtheshoulder crop top',
#  'otto rib offtheshoulder crop top',
#  'pleated clean collar top',
#  'pleated clean collar top',
#  'pleated clean collar top',
#  'pleated clean collar top',
#  'limited edition olivia cotton velvet overall',
#  'limited edition olivia cotton velvet overall',
#  'limited edition olivia cotton velvet overall',
#  'limited edition olivia cotton velvet overall',
#  'stretchcotton jersey hoodie',
#  'stretchcotton jersey hoodie',
#  'stretchcotton jersey hoodie',
#  'stretchcotton jersey hoodie',
#  'stretchcotton jersey hoodie',
#  'highrise faux leather wrap pant',
#  'highrise faux leather wrap pant',
#  'highrise faux leather wrap pant',
#  'highrise faux leather wrap pant',
#  'mirella oversized checked woven blazer',
#  'mirella oversized checked woven blazer',
#  'mirella oversized checked woven blazer',
#  'mirella oversized checked woven blazer',
#  'mirella oversized checked woven blazer',
#  'mirella oversized checked woven blazer',
#  'natti panel snakeeffect smooth leather mule',
#  'natti panel snakeeffect smooth leather mule',
#  'natti panel snakeeffect smooth leather mule',
#  'natti panel snakeeffect smooth leather mule',
#  'natti panel snakeeffect smooth leather mule',
#  'natti panel snakeeffect smooth leather mule',
#  'natti panel snakeeffect smooth leather mule',
#  'natti panel snakeeffect smooth leather mule',
#  'leopardprint stretchjersey jumpsuit',
#  'leopardprint stretchjersey jumpsuit',
#  'leopardprint stretchjersey jumpsuit',
#  'leopardprint stretchjersey jumpsuit',
#  'leopardprint stretchjersey jumpsuit',
#  'leopardprint stretchjersey jumpsuit',
#  'leopardprint stretchjersey jumpsuit',
#  'leopardprint stretchjersey jumpsuit',
#  'boy strip cottonjersey tshirt',
#  'boy strip cottonjersey tshirt',
#  'boy strip cottonjersey tshirt',
#  'boy strip cottonjersey tshirt',
#  'gweneth cashmere cardigan',
#  'gweneth cashmere cardigan',
#  'leisure hood mohairblend cardigan',
#  'leisure hood mohairblend cardigan',
#  'leisure hood mohairblend cardigan',
#  'leisure hood mohairblend cardigan',
#  'leisure hood mohairblend cardigan',
#  'oversized cottonfleece sweatshirt',
#  'oversized cottonfleece sweatshirt',
#  'oversized cottonfleece sweatshirt',
#  'reversible tiefront strip cottonblend poplin shirt',
#  'reversible tiefront strip cottonblend poplin shirt',
#  'reversible tiefront strip cottonblend poplin shirt',
#  'reversible tiefront strip cottonblend poplin shirt',
#  'reversible tiefront strip cottonblend poplin shirt',
#  'reversible tiefront strip cottonblend poplin shirt',
#  'reversible tiefront strip cottonblend poplin shirt',
#  'chloe asymmetric pleat satin midi skirt',
#  'chloe asymmetric pleat satin midi skirt',
#  'chloe asymmetric pleat satin midi skirt',
#  'chloe asymmetric pleat satin midi skirt',
#  'chloe asymmetric pleat satin midi skirt',
#  'chloe asymmetric pleat satin midi skirt',
#  'gather linen cotton skirt',
#  'gather linen cotton skirt',
#  'gather linen cotton skirt',
#  'gather linen cotton skirt',
#  'gather linen cotton skirt',
#  'gather linen cotton skirt',
#  'andie twotone shearling jacket',
#  'andie twotone shearling jacket',
#  'andie twotone shearling jacket',
#  'andie twotone shearling jacket',
#  'andie twotone shearling jacket',
#  'hyper reality crop cottonblend jacquardknit hoodie',
#  'hyper reality crop cottonblend jacquardknit hoodie',
#  'crop embroider slub cottonjersey track pant',
#  'crop embroider slub cottonjersey track pant',
#  'roll stone us tour tee',
#  'roll stone us tour tee',
#  'roll stone us tour tee',
#  'roll stone us tour tee',
#  'roll stone us tour tee',
#  'roll stone us tour tee',
#  'galina leather midi skirt',
#  'galina leather midi skirt',
#  'atlas oversized belted mélange wool coat',
#  'atlas oversized belted mélange wool coat',
#  'atlas oversized belted mélange wool coat',
#  'atlas oversized belted mélange wool coat',
#  'leather lowtop sneaker',
#  'leather lowtop sneaker',
#  'marco charmeuse midi skirt',
#  'magalli kneehigh snakeskinembossed leather boot',
#  'magalli kneehigh snakeskinembossed leather boot',
#  'magalli kneehigh snakeskinembossed leather boot',
#  'magalli kneehigh snakeskinembossed leather boot',
#  'magalli kneehigh snakeskinembossed leather boot',
#  'magalli kneehigh snakeskinembossed leather boot',
#  'small monogram matelassé metallic leather walletonchain',
#  'small monogram matelassé metallic leather walletonchain',
#  'small monogram matelassé metallic leather walletonchain',
#  'small monogram matelassé metallic leather walletonchain',
#  'pascale print peasant top',
#  'pascale print peasant top',
#  'pascale print peasant top',
#  'pascale print peasant top',
#  'sponge sweat hoodie',
#  'sponge sweat hoodie',
#  'carine faille mule',
#  'carine faille mule',
#  'carine faille mule',
#  'carine faille mule',
#  'carine faille mule',
#  'belt doublefaced cotton coat',
#  'belt doublefaced cotton coat',
#  'belt doublefaced cotton coat',
#  'belt doublefaced cotton coat',
#  'belt doublefaced cotton coat',
#  'belt doublefaced cotton coat',
#  'two way tulip large leather tote',
#  'two way tulip large leather tote',
#  'two way tulip large leather tote',
#  'two way tulip large leather tote',
#  'two way tulip large leather tote',
#  'two way tulip large leather tote',
#  'jamie mini duchessesatin croceffect leather shoulder bag',
#  'jamie mini duchessesatin croceffect leather shoulder bag',
#  'jamie mini duchessesatin croceffect leather shoulder bag',
#  'jamie mini duchessesatin croceffect leather shoulder bag',
#  'jamie mini duchessesatin croceffect leather shoulder bag',
#  'jamie mini duchessesatin croceffect leather shoulder bag',
#  'print rubber slide',
#  'print rubber slide',
#  'print rubber slide',
#  'print rubber slide',
#  'miranda croceffect leather shoulder bag',
#  'miranda croceffect leather shoulder bag',
#  'miranda croceffect leather shoulder bag',
#  'miranda croceffect leather shoulder bag',
#  'miranda croceffect leather shoulder bag',
#  'miranda croceffect leather shoulder bag',
#  'phoebe bi twotone croceffect leather bag',
#  'phoebe bi twotone croceffect leather bag',
#  'phoebe bi twotone croceffect leather bag',
#  'phoebe bi twotone croceffect leather bag',
#  'phoebe bi twotone croceffect leather bag',
#  'phoebe bi twotone croceffect leather bag',
#  'nicholas rib mohairblend turtleneck sweater',
#  'nicholas rib mohairblend turtleneck sweater',
#  'nicholas rib mohairblend turtleneck sweater',
#  'nicholas rib mohairblend turtleneck sweater',
#  'nicholas rib mohairblend turtleneck sweater',
#  'madison hour loafer pump',
#  'madison hour loafer pump',
#  'jogger everyday cashmere',
#  'jogger everyday cashmere',
#  'shell short',
#  'shell short',
#  'small marcie leather saddle bag',
#  'small marcie leather saddle bag',
#  'small marcie leather saddle bag',
#  'small marcie leather saddle bag',
#  'curvy slim stretch perfect shirt stripe',
#  'curvy slim stretch perfect shirt stripe',
#  'curvy slim stretch perfect shirt stripe',
#  'curvy slim stretch perfect shirt stripe',
#  'supercozy balloon sleeve mockneck top tencel™ lyocell',
#  'supercozy balloon sleeve mockneck top tencel™ lyocell',
#  'supercozy balloon sleeve mockneck top tencel™ lyocell',
#  'supercozy balloon sleeve mockneck top tencel™ lyocell',
#  'supercozy balloon sleeve mockneck top tencel™ lyocell',
#  'supercozy balloon sleeve mockneck top tencel™ lyocell',
#  'lashby leather ankle boot',
#  'lashby leather ankle boot',
#  'lashby leather ankle boot',
#  'lashby leather ankle boot',
#  'lashby leather ankle boot',
#  'lashby leather ankle boot',
#  'floralembroidered alpaca woolblend sweater',
#  'floralembroidered alpaca woolblend sweater',
#  'floralembroidered alpaca woolblend sweater',
#  'floralembroidered alpaca woolblend sweater',
#  'larel leather ankle boot',
#  'larel leather ankle boot',
#  'larel leather ankle boot',
#  'larel leather ankle boot',
#  'larel leather ankle boot',
#  'larel leather ankle boot',
#  'snakeeffect leather slingback flat',
#  'snakeeffect leather slingback flat',
#  'snakeeffect leather slingback flat',
#  'snakeeffect leather slingback flat',
#  'snakeeffect leather slingback flat',
#  'painter smock check cottonflannel shirt',
#  'painter smock check cottonflannel shirt',
#  'painter smock check cottonflannel shirt',
#  'painter smock check cottonflannel shirt',
#  'painter smock check cottonflannel shirt',
#  'croceffect leather belt bag',
#  'croceffect leather belt bag',
#  'croceffect leather belt bag',
#  'croceffect leather belt bag',
#  'croceffect leather belt bag',
#  'luka cottonjersey sweatshirt',
#  'luka cottonjersey sweatshirt',
#  'luka cottonjersey sweatshirt',
#  'luka cottonjersey sweatshirt',
#  'luka cottonjersey sweatshirt',
#  'luka cottonjersey sweatshirt',
#  'luka cottonjersey sweatshirt',
#  'leather slipon sneaker',
#  'leather slipon sneaker',
#  'leather slipon sneaker',
#  'leather slipon sneaker',
#  'adler crop cottonblend corduroy straightleg pant',
#  'adler crop cottonblend corduroy straightleg pant',
#  'adler crop cottonblend corduroy straightleg pant',
#  'adler crop cottonblend corduroy straightleg pant',
#  'adler crop cottonblend corduroy straightleg pant',
#  'crop cottonblend twill taper pant',
#  'crop cottonblend twill taper pant',
#  'crop cottonblend twill taper pant',
#  'crop cottonblend twill taper pant',
#  'crop cottonblend twill taper pant',
#  'shadow slub linenblend tshirt',
#  'shadow slub linenblend tshirt',
#  'shadow slub linenblend tshirt',
#  'shadow slub linenblend tshirt',
#  'shadow slub linenblend tshirt',
#  'lustrous camouflageprint stretch legging',
#  'lustrous camouflageprint stretch legging',
#  'lustrous camouflageprint stretch legging',
#  'lustrous camouflageprint stretch legging',
#  'journey embroider cottongauze top',
#  'journey embroider cottongauze top',
#  'journey embroider cottongauze top',
#  'journey embroider cottongauze top',
#  'journey embroider cottongauze top',
#  'journey embroider cottongauze top',
#  'mitsu crop vegan leather straightleg pant',
#  'mitsu crop vegan leather straightleg pant',
#  'mitsu crop vegan leather straightleg pant',
#  'andrea zebraprint calf hair leather mule',
#  'andrea zebraprint calf hair leather mule',
#  'andrea zebraprint calf hair leather mule',
#  'andrea zebraprint calf hair leather mule',
#  'andrea zebraprint calf hair leather mule',
#  'strip cashmere sweater',
#  'strip cashmere sweater',
#  'strip cashmere sweater',
#  'strip cashmere sweater',
#  'strip cashmere sweater',
#  'lembongan wool wrap midi skirt',
#  'lembongan wool wrap midi skirt',
#  'lembongan wool wrap midi skirt',
#  'lembongan wool wrap midi skirt',
#  'lembongan wool wrap midi skirt',
#  'gabriella snakeprint silk crepe chine camisole',
#  'gabriella snakeprint silk crepe chine camisole',
#  'gabriella snakeprint silk crepe chine camisole',
#  'gabriella snakeprint silk crepe chine camisole',
#  'gabriella snakeprint silk crepe chine camisole',
#  'gabriella snakeprint silk crepe chine camisole',
#  'swissdot mesh leather mule',
#  'swissdot mesh leather mule',
#  'swissdot mesh leather mule',
#  'swissdot mesh leather mule',
#  'swissdot mesh leather mule',
#  'swissdot mesh leather mule',
#  'swissdot mesh leather mule',
#  'swissdot mesh leather mule',
#  'marco charmeuse midi skirt',
#  'marco charmeuse midi skirt',
#  'marco charmeuse midi skirt',
#  'marco charmeuse midi skirt',
#  'marco charmeuse midi skirt',
#  'marco charmeuse midi skirt',
#  'colroy cashmere sweater',
#  'colroy cashmere sweater',
#  'colroy cashmere sweater',
#  'colroy cashmere sweater',
#  'colroy cashmere sweater',
#  'cottonvoile shirt',
#  'cottonvoile shirt',
#  'cottonvoile shirt',
#  'cottonvoile shirt',
#  'beverly wrapeffect silksatin stretchtencel bodysuit',
#  'beverly wrapeffect silksatin stretchtencel bodysuit',
#  'beverly wrapeffect silksatin stretchtencel bodysuit',
#  'beverly wrapeffect silksatin stretchtencel bodysuit',
#  'beverly wrapeffect silksatin stretchtencel bodysuit',
#  'plexi python metallic leather pvc pump',
#  'plexi python metallic leather pvc pump',
#  'plexi python metallic leather pvc pump',
#  'plexi python metallic leather pvc pump',
#  'plexi python metallic leather pvc pump',
#  'plexi python metallic leather pvc pump',
#  'yara leather shoulder bag',
#  'yara leather shoulder bag',
#  'yara leather shoulder bag',
#  'yara leather shoulder bag',
#  'yara leather shoulder bag',
#  'jenna stretchcotton twill straightleg pant',
#  'jenna stretchcotton twill straightleg pant',
#  'jenna stretchcotton twill straightleg pant',
#  'jenna stretchcotton twill straightleg pant',
#  'kittie leather ankle boot',
#  'kittie leather ankle boot',
#  'kittie leather ankle boot',
#  'kittie leather ankle boot',
#  'kittie leather ankle boot',
#  'kittie leather ankle boot',
#  'metallic texturedleather pump',
#  'metallic texturedleather pump',
#  'metallic texturedleather pump',
#  'metallic texturedleather pump',
#  'metallic texturedleather pump',
#  'metallic texturedleather pump',
#  'riley pleat voile turtleneck blouse',
#  'riley pleat voile turtleneck blouse',
#  'riley pleat voile turtleneck blouse',
#  'riley pleat voile turtleneck blouse',
#  'riley pleat voile turtleneck blouse',
#  'cottontwill wideleg pant',
#  'cottontwill wideleg pant',
#  'cottontwill wideleg pant',
#  'cottontwill wideleg pant',
#  'cottontwill wideleg pant',
#  'cottontwill wideleg pant',
#  'joan crop cottonblend corduroy wideleg pant',
#  'joan crop cottonblend corduroy wideleg pant',
#  'joan crop cottonblend corduroy wideleg pant',
#  'joan crop cottonblend corduroy wideleg pant',
#  'joan crop cottonblend corduroy wideleg pant',
#  'merino wool sweater',
#  'merino wool sweater',
#  'merino wool sweater',
#  'merino wool sweater',
#  'merino wool sweater',
#  'merino wool sweater',
#  'pima cotton alpacablend jersey turtleneck top',
#  'pima cotton alpacablend jersey turtleneck top',
#  'pima cotton alpacablend jersey turtleneck top',
#  'pima cotton alpacablend jersey turtleneck top',
#  'pima cotton alpacablend jersey turtleneck top',
#  'pima cotton alpacablend jersey turtleneck top',
#  'pima cotton alpacablend turtleneck top',
#  'pima cotton alpacablend turtleneck top',
#  'pima cotton alpacablend turtleneck top',
#  'pima cotton alpacablend turtleneck top',
#  'pima cotton alpacablend turtleneck top',
#  'pima cotton alpacablend turtleneck top',
#  'corben belt crepe wrap mini dress',
#  'corben belt crepe wrap mini dress',
#  'corben belt crepe wrap mini dress',
#  'corben belt crepe wrap mini dress',
#  'corben belt crepe wrap mini dress',
#  'ribbedknit wrap cardigan',
#  'ribbedknit wrap cardigan',
#  'ribbedknit wrap cardigan',
#  'ribbedknit wrap cardigan',
#  'ribbedknit wrap cardigan',
#  'ribbedknit wrap cardigan',
#  'figue linen jumpsuit',
#  'figue linen jumpsuit',
#  'figue linen jumpsuit',
#  'figue linen jumpsuit',
#  'figue linen jumpsuit',
#  'lucille rib alpacablend sweater',
#  'lucille rib alpacablend sweater',
#  'lucille rib alpacablend sweater',
#  'lucille rib alpacablend sweater',
#  'eva crop highrise wideleg jean',
#  'eva crop highrise wideleg jean',
#  'eva crop highrise wideleg jean',
#  'eva crop highrise wideleg jean',
#  'eva crop highrise wideleg jean',
#  'eva crop highrise wideleg jean',
#  'danny wool cashmereblend cardigan',
#  'danny wool cashmereblend cardigan',
#  'danny wool cashmereblend cardigan',
#  'danny wool cashmereblend cardigan',
#  'danny wool cashmereblend cardigan',
#  'francoise highrise wideleg jean',
#  'francoise highrise wideleg jean',
#  'francoise highrise wideleg jean',
#  'francoise highrise wideleg jean',
#  'francoise highrise wideleg jean',
#  'francoise highrise wideleg jean',
#  'marcie mini texturedleather shoulder bag',
#  'marcie mini texturedleather shoulder bag',
#  'kate chunky cashmere turtleneck sweater',
#  'kate chunky cashmere turtleneck sweater',
#  'kate chunky cashmere turtleneck sweater',
#  'kate chunky cashmere turtleneck sweater',
#  'silkblend shirt',
#  'silkblend shirt',
#  'silkblend shirt',
#  'silkblend shirt',
#  'young distress snakeeffect leather ankle boot',
#  'young distress snakeeffect leather ankle boot',
#  'young distress snakeeffect leather ankle boot',
#  'young distress snakeeffect leather ankle boot',
#  'metallic stripe pvc leather pump',
#  'metallic stripe pvc leather pump',
#  'metallic stripe pvc leather pump',
#  'metallic stripe pvc leather pump',
#  'highrise wideleg pant',
#  'highrise wideleg pant',
#  'highrise wideleg pant',
#  'highrise wideleg pant',
#  'sequined mini dress',
#  'sequined mini dress',
#  'sequined mini dress',
#  'sequined mini dress',
#  'petite fishtail midi sheath dress',
#  'petite fishtail midi sheath dress',
#  'openback crop vinyl vest',
#  'openback crop vinyl vest',
#  'openback crop vinyl vest',
#  'openback crop vinyl vest',
#  'japan exclusive blake wide legfit herringbone pant',
#  'japan exclusive blake wide legfit herringbone pant',
#  'japan exclusive blake wide legfit herringbone pant',
#  'japan exclusive blake wide legfit herringbone pant',
#  'petite print midi sheath dress',
#  'petite print midi sheath dress',
#  'petite print midi sheath dress',
#  'petite print midi sheath dress',
#  'stretchleather skinny pant',
#  'stretchleather skinny pant',
#  'stretchleather skinny pant',
#  'stretchleather skinny pant',
#  'faux leather short',
#  'faux leather short',
#  'faux leather short',
#  'faux leather short',
#  'jessalyn gingham stretch cotton pant',
#  'jessalyn gingham stretch cotton pant',
#  'jessalyn gingham stretch cotton pant',
#  'jessalyn gingham stretch cotton pant',
#  's rib capsleeve tee',
#  's rib capsleeve tee',
#  's rib capsleeve tee',
#  's rib capsleeve tee',
#  'everly aline crepe midi skirt',
#  'everly aline crepe midi skirt',
#  'everly aline crepe midi skirt',
#  'everly aline crepe midi skirt',
#  'claire offtheshoulder cotton top',
#  'claire offtheshoulder cotton top',
#  'claire offtheshoulder cotton top',
#  'claire offtheshoulder cotton top',
#  'claire offtheshoulder cotton top',
#  'claire offtheshoulder cotton top',
#  'claire offtheshoulder cotton top',
#  'claire offtheshoulder cotton top',
#  'welly strip cottonblend shirt',
#  'welly strip cottonblend shirt',
#  'welly strip cottonblend shirt',
#  'welly strip cottonblend shirt',
#  'kaia pvc suede slingback sandal',
#  'kaia pvc suede slingback sandal',
#  'charlie texturedleather biker jacket',
#  'charlie texturedleather biker jacket',
#  'charlie texturedleather biker jacket',
#  'charlie texturedleather biker jacket',
#  'charlie texturedleather biker jacket',
#  'charlie texturedleather biker jacket',
#  'charlie texturedleather biker jacket',
#  'charlie texturedleather biker jacket',
#  'faux leather crop vest',
#  'faux leather crop vest',
#  'faux leather crop vest',
#  'faux leather crop vest',
#  'faux leather crop vest',
#  'faux leather crop vest',
#  'drape silksatin top',
#  'drape silksatin top',
#  'drape silksatin top',
#  'drape silksatin top',
#  'custella knit vest vneck',
#  'custella knit vest vneck',
#  'custella knit vest vneck',
#  'custella knit vest vneck',
#  'custella knit vest vneck',
#  'custella knit vest vneck',
#  'mirror touch metallic strapdetailed leather booty',
#  'mirror touch metallic strapdetailed leather booty',
#  'mirror touch metallic strapdetailed leather booty',
#  'mirror touch metallic strapdetailed leather booty',
#  'mirror touch metallic strapdetailed leather booty',
#  'mirror touch metallic strapdetailed leather booty',
#  'madelyn voluminous sleeve blouse',
#  'madelyn voluminous sleeve blouse',
#  'madelyn voluminous sleeve blouse',
#  'madelyn voluminous sleeve blouse',
#  'ryan lace inset ruffle maxi dress',
#  'ryan lace inset ruffle maxi dress',
#  'ryan lace inset ruffle maxi dress',
#  'ryan lace inset ruffle maxi dress',
#  'ryan lace inset ruffle maxi dress',
#  'ryan lace inset ruffle maxi dress',
#  'stretchterry dress',
#  'stretchterry dress',
#  'stretchterry dress',
#  'stretchterry dress',
#  'stretchterry dress',
#  'stretchterry dress',
#  'classic belt twill blazer',
#  'classic belt twill blazer',
#  'classic belt twill blazer',
#  'classic belt twill blazer',
#  'metropolitan leather briefcase',
#  'metropolitan leather briefcase',
#  'metropolitan leather briefcase',
#  'metropolitan leather briefcase',
#  'queenie tiedetailed floralprint silk dress',
#  'queenie tiedetailed floralprint silk dress',
#  'queenie tiedetailed floralprint silk dress',
#  'queenie tiedetailed floralprint silk dress',
#  'bond wool mini blazer dress',
#  'bond wool mini blazer dress',
#  'bond wool mini blazer dress',
#  'bond wool mini blazer dress',
#  'cheyenne floralprint cotton mini skirt',
#  'cheyenne floralprint cotton mini skirt',
#  'cheyenne floralprint cotton mini skirt',
#  'cheyenne floralprint cotton mini skirt',
#  'gansu crop silksatin wideleg pant',
#  'gansu crop silksatin wideleg pant',
#  ...]

# %% [markdown]
# # Stemming

# %%
stemmer = PorterStemmer()
def stemm_sentence(sentence):
    word_token = nltk.word_tokenize(sentence)
    res_words = []
    for word in word_token:
        res_words.append(stemmer.stem(word))
    return " ".join(res_words)

# %%
cleaned_description_stemm = []
for sentence in cleaned_descriptions:
    cleaned_description_stemm = cleaned_description_stemm + [stemm_sentence(sentence)]

# %%
cleaned_brand_stemm = []
for sentence in list(brand):
    cleaned_brand_stemm = cleaned_brand_stemm + [stemm_sentence(sentence)]

# %%
cleaned_details_stemm = []
for sentence in list(df1):
    cleaned_details_stemm = cleaned_details_stemm + [stemm_sentence(sentence)]

# %%
cleaned_productname_stemm = []
for sentence in list(product_full_name):
    cleaned_productname_stemm = cleaned_productname_stemm + [stemm_sentence(sentence)]

# %% [markdown]
# # TF-IDF Score

# %% [markdown]
# ## Description Feature

# %%
vectorizer = TfidfVectorizer(ngram_range=(1,1),
                             token_pattern=r'\b[a-zA-Z0-9]{2,}\b',
                             max_df=0.8,
                             min_df = 0.01, stop_words=updated_stopwords, max_features = 500)

# %%
X = vectorizer.fit_transform(cleaned_description_lem)
terms = vectorizer.get_feature_names()
tf_idf = pd.DataFrame(X.toarray().transpose(), index=terms)
tf_idf = tf_idf.sum(axis=1)
description_lem_tfidf_score = pd.DataFrame(tf_idf, columns=["score"])
description_lem_tfidf_score.sort_values(by="score", ascending=False, inplace=True)

# %%
X = vectorizer.fit_transform(cleaned_description_stemm)
terms = vectorizer.get_feature_names()
tf_idf = pd.DataFrame(X.toarray().transpose(), index=terms)
tf_idf = tf_idf.sum(axis=1)
description_stemm_tfidf_score = pd.DataFrame(tf_idf, columns=["score"])
description_stemm_tfidf_score.sort_values(by="score", ascending=False, inplace=True)

# %% [markdown]
# ## Brand Feature

# %%
X = vectorizer.fit_transform(cleaned_brand_lem)
terms = vectorizer.get_feature_names()
tf_idf = pd.DataFrame(X.toarray().transpose(), index=terms)
tf_idf = tf_idf.sum(axis=1)
brand_lem_tfidf_score = pd.DataFrame(tf_idf, columns=["score"])
brand_lem_tfidf_score.sort_values(by="score", ascending=False, inplace=True)

# %%
X = vectorizer.fit_transform(cleaned_brand_stemm)
terms = vectorizer.get_feature_names()
tf_idf = pd.DataFrame(X.toarray().transpose(), index=terms)
tf_idf = tf_idf.sum(axis=1)
brand_stemm_tfidf_score = pd.DataFrame(tf_idf, columns=["score"])
brand_stemm_tfidf_score.sort_values(by="score", ascending=False, inplace=True)

# %% [markdown]
# ## Details Feature

# %%
X = vectorizer.fit_transform(cleaned_details_lem)
terms = vectorizer.get_feature_names() 
tf_idf = pd.DataFrame(X.toarray().transpose(), index=terms)
tf_idf = tf_idf.sum(axis=1)
details_lem_tfidf_score = pd.DataFrame(tf_idf, columns=["score"])
details_lem_tfidf_score.sort_values(by="score", ascending=False, inplace=True)

# %%
X = vectorizer.fit_transform(cleaned_details_stemm)
terms = vectorizer.get_feature_names() 
tf_idf = pd.DataFrame(X.toarray().transpose(), index=terms)
tf_idf = tf_idf.sum(axis=1)
details_stemm_tfidf_score = pd.DataFrame(tf_idf, columns=["score"])
details_stemm_tfidf_score.sort_values(by="score", ascending=False, inplace=True)

# %% [markdown]
# ## Product Name Feature

# %%
X = vectorizer.fit_transform(cleaned_productname_lem)
terms = vectorizer.get_feature_names()
tf_idf = pd.DataFrame(X.toarray().transpose(), index=terms)
tf_idf = tf_idf.sum(axis=1)
productname_lem_tfidf_score = pd.DataFrame(tf_idf, columns=["score"])
productname_lem_tfidf_score.sort_values(by="score", ascending=False, inplace=True)

# %%
X = vectorizer.fit_transform(cleaned_productname_stemm)
terms = vectorizer.get_feature_names()
tf_idf = pd.DataFrame(X.toarray().transpose(), index=terms)
tf_idf = tf_idf.sum(axis=1)
productname_stemm_tfidf_score = pd.DataFrame(tf_idf, columns=["score"])
productname_stemm_tfidf_score.sort_values(by="score", ascending=False, inplace=True)

# %% [markdown]
# # Word2Vec

# %% [markdown]
# ## Description Feature

# %%
docs = [word_tokenize(sentence) for sentence in cleaned_description_lem ]
description_lem_word2vec_model = Word2Vec(docs, min_count = 1, window = 5, size = 200)

# %%
docs = [word_tokenize(sentence) for sentence in cleaned_description_stemm]
description_stemm_word2vec_model = Word2Vec(docs, min_count = 1, window = 5, size = 200)

# %% [markdown]
# ## Brand Feature

# %%
docs = [word_tokenize(sentence) for sentence in cleaned_brand_lem ]
brand_lem_word2vec_model = Word2Vec(docs, min_count = 1, window = 5, size = 200)

# %%
docs = [word_tokenize(sentence) for sentence in cleaned_brand_stemm ]
brand_stemm_word2vec_model = Word2Vec(docs, min_count = 1, window = 5, size = 200)

# %% [markdown]
# ## Details Feature

# %%
docs = [word_tokenize(sentence) for sentence in cleaned_details_lem ]
details_lem_word2vec_model = Word2Vec(docs, min_count = 1, window = 5, size = 200)

# %%
docs = [word_tokenize(sentence) for sentence in cleaned_details_stemm ]
details_stemm_word2vec_model = Word2Vec(docs, min_count = 1, window = 5, size = 200)

# %% [markdown]
# ## Product Name Feature

# %%
docs = [word_tokenize(sentence) for sentence in cleaned_productname_lem ]
productname_lem_word2vec_model = Word2Vec(docs, min_count = 1, window = 5, size = 200)

# %%
docs = [word_tokenize(sentence) for sentence in cleaned_productname_stemm ]
productname_stemm_word2vec_model = Word2Vec(docs, min_count = 1, window = 5, size = 200)

# %%
product = pd.Series(cleaned_description_lem)+" "+pd.Series(cleaned_brand_lem)+" "+\
        pd.Series(cleaned_details_lem)+" "+pd.Series(cleaned_productname_lem)
product = list(product)

# %%
phrases = Phrases(product, min_count=10)
bi_gram = Phraser(phrases)
product=list(bi_gram[product])

# %%
docs = [word_tokenize(sentence) for sentence in product]
model = Word2Vec(docs, min_count = 1, window = 5, size = 200)

# %%
product_vector = []
for item in product:
    temp_vector = np.zeros((1,200))
    n = 0
    for word in item.split(" "):
        if word in model.wv.vocab:
            temp_vector += model.wv.get_vector(word)
        else:
            temp_vector += np.random.normal(size=200)
        n += 1
    product_vector.append(temp_vector/n)

# %% [markdown]
# # RNN

# %%
def pred_category(data,threshold):
    pred = list(map(lambda v:[i for i, e in enumerate(v) if e > threshold] ,data))
    return np.array(pred)

def pred_category_name(data,threshold):
    pred = list(map(lambda v:[list(dummies.columns)[i] for i, e in enumerate(v) if e > threshold] ,data))
    return np.array(pred)

def actual_category(data):
    actual=list()
    for v in data:
        t = []
        for i,a in enumerate(v):
            if a == 1:
                t.append(i)
        actual.append(t)
    return actual

def actual_category_name(data):
    actual=list()
    for v in data:
        t = []
        for i,a in enumerate(v):
            if a == 1:
                t.append(list(dummies.columns)[i])
        actual.append(t)
    return actual

def F1(pred_result,actual_result):
    def recall(pred_result,actual_result,attribute_value):   
        Actual=0
        TP=0

        for i in range(len(actual_result)):
            if actual_result[i]==attribute_value:
                Actual+= 1

                pred = set(pred_result[i])
                true = set(actual_result[i])

                if len(pred.intersection(true)) != 0:
                    TP += 1

        return TP/Actual if Actual>0 else ''


    def Precision(pred_result,actual_result,attribute_value):   
        Positive=0
        TP=0

        for i in range(len(pred_result)):
            if pred_result[i]==attribute_value:
                Positive+= 1

                pred = set(pred_result[i])
                true = set(actual_result[i])

                if len(pred.intersection(true)) != 0:
                    TP += 1
                    
        return TP/Positive if Positive>0 else ''

    F1=pd.DataFrame(list(dummies.columns))
    F1['attribute_name']=attribute
    F1.columns=['attribute_value','attribute_name']
    F1=F1[['attribute_name','attribute_value']]
    F1['recall']=''
    F1['Precision']=''
    F1['F1']=''
    for i in F1.index:
        try:
            F1.loc[i,'recall']=  recall(pred_result,actual_result,[F1.loc[i,'attribute_value']])
        except:
            continue
    for i in F1.index:
        try:
            F1.loc[i,'Precision']=Precision(pred_result,actual_result,[F1.loc[i,'attribute_value']])
        except:
            continue
            
    for i in F1.index:
        try:
            F1.loc[i,'F1']=2*(F1.loc[i,'recall']*F1.loc[i,'Precision'])/(F1.loc[i,'recall']+F1.loc[i,'Precision'])
        except:
            continue  

    return F1

# %% [markdown]
# ## input 1 - product_vector

# %% [markdown]
# ## input 2 - sentence_vector + PCA(100)

# %%
sentence_vector=pd.read_csv('sentence vector.csv', index_col=0)

# %%
from sklearn.decomposition import PCA

scaler = StandardScaler()
X_scaled = scaler.fit_transform(sentence_vector)

pca = PCA()
pca_samples = pca.fit_transform(X_scaled)

pc_8 = pca_samples[:,:100].copy()
pc = scaler.fit_transform(pc_8)

# %%
pc=pd.DataFrame(pc)
pc_vector=[]
for i in pc.index:
    row=[]
    for j in range(0,pc.shape[1],1):
        row.append(pc.loc[i,j])
    pc_vector.append([row])

# %% [markdown]
# ## input 3 - weighted_vector

# %%
weighted_vector=pd.read_csv('weighted vector.csv', index_col=0)

# %%
weighted_vector=weighted_vector.fillna(0)

# %%
from sklearn.decomposition import PCA

scaler = StandardScaler()
X_scaled = scaler.fit_transform(weighted_vector)

pca = PCA()
pca_samples = pca.fit_transform(X_scaled)

pc_8 = pca_samples[:,:50].copy()
pc = scaler.fit_transform(pc_8)
pc=pd.DataFrame(pc)
pc_vector_weighted=[]
for i in pc.index:
    row=[]
    for j in range(0,pc.shape[1],1):
        row.append(pc.loc[i,j])
    pc_vector_weighted.append([row])

# %% [markdown]
# ## input 4 - combine_stemm_tfidf_score

# %%
combine_stemm_tfidf_score=pd.read_csv('combine_stemm_tfidf_score.csv', index_col=0)

# %%
from sklearn.decomposition import PCA

scaler = StandardScaler()
X_scaled = scaler.fit_transform(combine_stemm_tfidf_score)

pca = PCA()
pca_samples = pca.fit_transform(X_scaled)

pc_50 = pca_samples[:,:50].copy()
pc = scaler.fit_transform(pc_50)
pc=pd.DataFrame(pc)
pc_vector_combine_stemm_tfidf_score=[]
for i in pc.index:
    row=[]
    for j in range(0,pc.shape[1],1):
        row.append(pc.loc[i,j])
    pc_vector_combine_stemm_tfidf_score.append([row])

# %%
df = pd.DataFrame({ 'input':pd.Series(product_vector),
                    'attribute_name': list(data1['attribute_name']),
                    'attribute_value': list(data1['new_attribute_value'])
                   })

df['attribute_value']=df['attribute_value'].apply(lambda x:x.lower())

# %%
from keras.preprocessing.text import one_hot
from keras.preprocessing.sequence import pad_sequences
from numpy import asarray
from numpy import zeros
from keras.preprocessing.text import Tokenizer
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten, LSTM
from keras.layers import Embedding
from keras.layers.core import Activation, Dropout, Dense
from keras.layers import GlobalMaxPooling1D
from keras.models import Model
from sklearn.model_selection import train_test_split
from keras.layers import Input
from keras.layers.merge import Concatenate
from keras.preprocessing.text import text_to_word_sequence
from typing import List

# %% [markdown]
# ## all_attributes

# %%
df=df[~df['attribute_value'].isna()]
dummies = pd.get_dummies(df['attribute_value'])
data = pd.concat([df, dummies], axis=1, sort=False)
data=data.drop('attribute_value',axis=1)
data=data.drop('attribute_name',axis=1)

X=data['input']
y= data.iloc[:,1:].values

X_train, X_test, y_train, y_test = \
train_test_split(X,y, test_size=0.25,random_state=1)

vocab_size = 200

from keras.layers.recurrent import SimpleRNN
from keras.layers import Flatten, Masking

max_length = 200

X_train = pad_sequences(X_train, padding='post', maxlen=max_length)
X_test = pad_sequences(X_test, padding='post', maxlen=max_length)

# define rnn model

model = Sequential()
model.add(SimpleRNN(units=64, input_shape=(1, max_length)))
model.add(Dense(y_train.shape[1], activation='softmax'))

from keras.utils.vis_utils import plot_model

# Compile the model
model.compile(
    optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# summarize the model
# print(model.summary())
# plot_model(model, to_file='model.png', show_shapes=True)

# fit the model
model.fit(X_train, y_train,batch_size=200,epochs=50,verbose=0)

pred_vectors_train = model.predict(X_train)
pred_vectors_test = model.predict(X_test)

model.save('product_vector_model.h5')

# %%
model.save('product_vector_model.h5')

# %%
df=df[~df['attribute_value'].isna()]
dummies = pd.get_dummies(df['attribute_value'])
data = pd.concat([df, dummies], axis=1, sort=False)
data=data.drop('attribute_value',axis=1)
data=data.drop('attribute_name',axis=1)

X=data['input']
y= data.iloc[:,1:].values

X_train, X_test, y_train, y_test = \
train_test_split(X,y, test_size=0.25,random_state=1)

vocab_size = 200

from keras.layers.recurrent import SimpleRNN
from keras.layers import Flatten, Masking

max_length = 200

X_train = pad_sequences(X_train, padding='post', maxlen=max_length)
X_test = pad_sequences(X_test, padding='post', maxlen=max_length)

# define rnn model

model = Sequential()
model.add(Masking(mask_value=0.0)) # masking layer, masks any words that don't have an embedding as 0s.
model.add(SimpleRNN(units=64, input_shape=(1, max_length)))
model.add(Dense(100,activation='relu'))
model.add(Dense(y_train.shape[1], activation='softmax'))

from keras.utils.vis_utils import plot_model

# Compile the model
model.compile(
    optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# summarize the model
# print(model.summary())
# plot_model(model, to_file='model.png', show_shapes=True)

# fit the model
model.fit(X_train, y_train,batch_size=200,epochs=50,verbose=0)

pred_vectors_train = model.predict(X_train)
pred_vectors_test = model.predict(X_test)

model.save('product_vector_model.h5')

# %% [markdown]
# ## style

# %%
attribute='style'
data=df[df['attribute_name'] == attribute]
dummies = pd.get_dummies(data['attribute_value'])
data = pd.concat([data, dummies], axis=1, sort=False)
data=data.drop('attribute_value',axis=1)
data=data.drop('attribute_name',axis=1)

X=data['input']
y= data.iloc[:,1:].values

X_train, X_test, y_train, y_test = \
train_test_split(X,y, test_size=0.25,random_state=1)

vocab_size = 200

from keras.layers.recurrent import SimpleRNN
from keras.layers import Flatten, Masking

max_length = 200

X_train = pad_sequences(X_train, padding='post', maxlen=max_length)
X_test = pad_sequences(X_test, padding='post', maxlen=max_length)

# define rnn model

model = Sequential()
model.add(Masking(mask_value=0.0)) # masking layer, masks any words that don't have an embedding as 0s.
model.add(SimpleRNN(units=64, input_shape=(1, max_length)))
model.add(Dense(100,activation='relu'))
model.add(Dense(y_train.shape[1], activation='softmax'))

from keras.utils.vis_utils import plot_model

# Compile the model
model.compile(
    optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# summarize the model
# print(model.summary())
# plot_model(model, to_file='model.png', show_shapes=True)

# fit the model
model.fit(X_train, y_train,batch_size=200,epochs=50,verbose=0)

style_pred_vectors_train = model.predict(X_train)
style_pred_vectors_test = model.predict(X_test)

## save model

# model.save('style_combine_stemm_tfidf_score_model.h5')
model.save('style_product_vector_model.h5')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1158-c3f590ef8295> in <module>
#      40
#      41 # fit the model
# ---> 42 model.fit(X_train, y_train,batch_size=200,epochs=50,verbose=0)
#      43
#      44 style_pred_vectors_train = model.predict(X_train)
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# ~\Anaconda3\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     194                     ins_batch[i] = ins_batch[i].toarray()
#     195
# --> 196                 outs = fit_function(ins_batch)
#     197                 outs = to_list(outs)
#     198                 for l, o in zip(out_labels, outs):
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\keras\backend.py in __call__(self, inputs)
#    3738         value = math_ops.cast(value, tensor.dtype)
#    3739       converted_inputs.append(value)
# -> 3740     outputs = self._graph_fn(*converted_inputs)
#    3741
#    3742     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    1079       TypeError: For invalid positional/keyword argument combinations.
#    1080     """
# -> 1081     return self._call_impl(args, kwargs)
#    1082
#    1083   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1119       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1120           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1121     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1122
#    1123   def _filtered_call(self, args, kwargs):
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1222     if executing_eagerly:
#    1223       flat_outputs = forward_function.call(
# -> 1224           ctx, args, cancellation_manager=cancellation_manager)
#    1225     else:
#    1226       gradient_name = self._delayed_rewrite_functions.register()
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     509               inputs=args,
#     510               attrs=("executor_type", executor_type, "config_proto", config),
# --> 511               ctx=ctx)
#     512         else:
#     513           outputs = execute.execute_with_cancellation(
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
threshold=0.3
style_train_pred_classes = pred_category(style_pred_vectors_train,threshold)
style_test_pred_classes = pred_category(style_pred_vectors_test,threshold)

style_train_pred_classes_name = pred_category_name(style_pred_vectors_train,threshold)
style_test_pred_classes_name = pred_category_name(style_pred_vectors_test,threshold)

style_train_true_classes = actual_category(y_train)
style_test_true_classes = actual_category(y_test)

style_train_true_classes_name = actual_category_name(y_train)
style_test_true_classes_name = actual_category_name(y_test)

style_test_F1=F1(style_test_pred_classes_name,style_test_true_classes_name)
style_train_F1=F1(style_train_pred_classes_name,style_train_true_classes_name)

# %%
threshold=0.15
occasion_train_pred_classes = pred_category(occasion_pred_vectors_train,threshold)
occasion_test_pred_classes = pred_category(occasion_pred_vectors_test,threshold)

occasion_train_pred_classes_name = pred_category_name(occasion_pred_vectors_train,threshold)
occasion_test_pred_classes_name = pred_category_name(occasion_pred_vectors_test,threshold)

occasion_train_true_classes = actual_category(y_train)
occasion_test_true_classes = actual_category(y_test)

occasion_train_true_classes_name = actual_category_name(y_train)
occasion_test_true_classes_name = actual_category_name(y_test)

occasion_test_F1=F1(occasion_test_pred_classes_name,occasion_test_true_classes_name)
occasion_train_F1=F1(occasion_train_pred_classes_name,occasion_train_true_classes_name)

# %% [markdown]
# ## occasion

# %%
attribute='occasion'
data=df[df['attribute_name'] == attribute]
dummies = pd.get_dummies(data['attribute_value'])
data = pd.concat([data, dummies], axis=1, sort=False)
data=data.drop('attribute_value',axis=1)
data=data.drop('attribute_name',axis=1)

X=data['input']
y= data.iloc[:,1:].values

X_train, X_test, y_train, y_test = \
train_test_split(X,y, test_size=0.25,random_state=1)

vocab_size = 200

from keras.layers.recurrent import SimpleRNN
from keras.layers import Flatten, Masking

max_length = 200

# X_train = pad_sequences(X_train, padding='post', maxlen=max_length)
# X_test = pad_sequences(X_test, padding='post', maxlen=max_length)

# define rnn model

model = Sequential()
model.add(Masking(mask_value=0.0)) # masking layer, masks any words that don't have an embedding as 0s.
model.add(SimpleRNN(units=64, input_shape=(1, max_length)))
model.add(Dense(100,activation='relu'))
model.add(Dense(y_train.shape[1], activation='softmax'))

from keras.utils.vis_utils import plot_model

# Compile the model
model.compile(
    optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# summarize the model
# print(model.summary())
# plot_model(model, to_file='model.png', show_shapes=True)

# fit the model
model.fit(X_train, y_train,batch_size=200,epochs=50,verbose=0)

occasion_pred_vectors_train = model.predict(X_train)
occasion_pred_vectors_test = model.predict(X_test)

# %%
threshold=0.15
occasion_train_pred_classes = pred_category(occasion_pred_vectors_train,threshold)
occasion_test_pred_classes = pred_category(occasion_pred_vectors_test,threshold)

occasion_train_pred_classes_name = pred_category_name(occasion_pred_vectors_train,threshold)
occasion_test_pred_classes_name = pred_category_name(occasion_pred_vectors_test,threshold)

occasion_train_true_classes = actual_category(y_train)
occasion_test_true_classes = actual_category(y_test)

occasion_train_true_classes_name = actual_category_name(y_train)
occasion_test_true_classes_name = actual_category_name(y_test)

occasion_test_F1=F1(occasion_test_pred_classes_name,occasion_test_true_classes_name)
occasion_train_F1=F1(occasion_train_pred_classes_name,occasion_train_true_classes_name)

# %%
occasion_train_F1
# Out:
#   attribute_name attribute_value    recall Precision        F1
# 0       occasion     coldweather  0.628458         1  0.771845
# 1       occasion      daytonight  0.987308  0.811321  0.890704
# 2       occasion        nightout  0.747259  0.944444   0.83436
# 3       occasion        vacation  0.698845  0.833333  0.760187
# 4       occasion         weekend  0.985863  0.927835  0.955969
# 5       occasion            work  0.848087     0.975  0.907126
# 6       occasion         workout   0.79661         1  0.886792

# %%
occasion_test_F1
# Out:
#   attribute_name attribute_value    recall Precision        F1
# 0       occasion     coldweather  0.265306         0         0
# 1       occasion      daytonight  0.911265      0.16  0.272206
# 2       occasion        nightout  0.539179       0.5  0.518851
# 3       occasion        vacation  0.483871         0         0
# 4       occasion         weekend  0.930956  0.347826  0.506436
# 5       occasion            work  0.683894  0.352941  0.465598
# 6       occasion         workout  0.647541  0.333333  0.440111

# %% [markdown]
# ## subcategory_top

# %%
attribute='subcategory_top'

data=df[df['attribute_name'] == attribute]
dummies = pd.get_dummies(data['attribute_value'])
data = pd.concat([data, dummies], axis=1, sort=False)
data=data.drop('attribute_value',axis=1)
data=data.drop('attribute_name',axis=1)

X=data['input']
y= data.iloc[:,1:].values

X_train, X_test, y_train, y_test = \
train_test_split(X,y, test_size=0.25,random_state=1)

vocab_size = 200

from keras.layers.recurrent import SimpleRNN
from keras.layers import Flatten, Masking

max_length = 200

# X_train = pad_sequences(X_train, padding='post', maxlen=max_length)
# X_test = pad_sequences(X_test, padding='post', maxlen=max_length)

# define rnn model

model = Sequential()
model.add(Masking(mask_value=0.0)) # masking layer, masks any words that don't have an embedding as 0s.
model.add(SimpleRNN(units=64, input_shape=(1, max_length)))
model.add(Dense(100,activation='relu'))
model.add(Dense(y_train.shape[1], activation='softmax'))

from keras.utils.vis_utils import plot_model

# Compile the model
model.compile(
    optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# summarize the model
# print(model.summary())
# plot_model(model, to_file='model.png', show_shapes=True)

# fit the model
model.fit(X_train, y_train,batch_size=200,epochs=50,verbose=0)

top_pred_vectors_train = model.predict(X_train)
top_pred_vectors_test = model.predict(X_test)

# %%
threshold=0.15
top_train_pred_classes = pred_category(top_pred_vectors_train,threshold)
top_test_pred_classes = pred_category(top_pred_vectors_test,threshold)

top_train_pred_classes_name = pred_category_name(top_pred_vectors_train,threshold)
top_test_pred_classes_name = pred_category_name(top_pred_vectors_test,threshold)

top_train_true_classes = actual_category(y_train)
top_test_true_classes = actual_category(y_test)

top_train_true_classes_name = actual_category_name(y_train)
top_test_true_classes_name = actual_category_name(y_test)

top_test_F1=F1(top_test_pred_classes_name,top_test_true_classes_name)
top_train_F1=F1(top_train_pred_classes_name,top_train_true_classes_name)

# %%
top_train_F1

# %%
top_test_F1

# %% [markdown]
# ## subcategory_bottom

# %%
attribute='subcategory_bottom'
data=df[df['attribute_name'] == attribute]
dummies = pd.get_dummies(data['attribute_value'])
data = pd.concat([data, dummies], axis=1, sort=False)
data=data.drop('attribute_value',axis=1)
data=data.drop('attribute_name',axis=1)

X=data['input']
y= data.iloc[:,1:].values

X_train, X_test, y_train, y_test = \
train_test_split(X,y, test_size=0.25,random_state=1)

vocab_size = 200

from keras.layers.recurrent import SimpleRNN
from keras.layers import Flatten, Masking

max_length = 200

# X_train = pad_sequences(X_train, padding='post', maxlen=max_length)
# X_test = pad_sequences(X_test, padding='post', maxlen=max_length)

# define rnn model

model = Sequential()
model.add(Masking(mask_value=0.0)) # masking layer, masks any words that don't have an embedding as 0s.
model.add(SimpleRNN(units=64, input_shape=(1, max_length)))
model.add(Dense(100,activation='relu'))
model.add(Dense(y_train.shape[1], activation='softmax'))

from keras.utils.vis_utils import plot_model

# Compile the model
model.compile(
    optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# summarize the model
# print(model.summary())
# plot_model(model, to_file='model.png', show_shapes=True)

# fit the model
model.fit(X_train, y_train,batch_size=200,epochs=50,verbose=0)

# %%
threshold=0.15
bottom_train_pred_classes = pred_category(bottom_pred_vectors_train,threshold)
bottom_test_pred_classes = pred_category(bottom_pred_vectors_test,threshold)

bottom_train_pred_classes_name = pred_category_name(bottom_pred_vectors_train,threshold)
bottom_test_pred_classes_name = pred_category_name(bottom_pred_vectors_test,threshold)

bottom_train_true_classes = actual_category(y_train)
bottom_test_true_classes = actual_category(y_test)

bottom_train_true_classes_name = actual_category_name(y_train)
bottom_test_true_classes_name = actual_category_name(y_test)

bottom_test_F1=F1(bottom_test_pred_classes_name,bottom_test_true_classes_name)
bottom_train_F1=F1(bottom_train_pred_classes_name,bottom_train_true_classes_name)

# %%
bottom_test_F1

# %%
bottom_train_F1

# %%
F1(bottom_train_pred_classes_name,bottom_train_true_classes_name)
# Out:
#        attribute_name attribute_value    recall Precision        F1
# 0  subcategory_bottom  pants&leggings         1  0.960317  0.979757
# 1  subcategory_bottom          shorts       0.4         1  0.571429
# 2  subcategory_bottom          skirts  0.938776         1  0.968421

# %%
F1(bottom_test_pred_classes_name,bottom_test_true_classes_name)
# Out:
#        attribute_name attribute_value   recall Precision        F1
# 0  subcategory_bottom  pants&leggings        1  0.954545  0.976744
# 1  subcategory_bottom          shorts        0
# 2  subcategory_bottom          skirts  0.90625         1   0.95082

# %% [markdown]
# # RNN function

# %%
def run_rnn(attribute):
    data=df[df['attribute_name'] == attribute]
    dummies = pd.get_dummies(data['attribute_value'])
    data = pd.concat([data, dummies], axis=1, sort=False)
    data=data.drop('attribute_value',axis=1)
    data=data.drop('attribute_name',axis=1)

    X=data['text']
    y= data.iloc[:,1:].values

    X_train, X_test, y_train, y_test = \
    train_test_split(X,y, test_size=0.25,random_state=1)

    vocab_size = 200

    from keras.layers.recurrent import SimpleRNN
    from keras.layers import Flatten, Masking

    max_length = 200

    X_train = pad_sequences(X_train, padding='post', maxlen=max_length)
    X_test = pad_sequences(X_test, padding='post', maxlen=max_length)

    # define rnn model

    model = Sequential()
    model.add(Masking(mask_value=0.0)) # masking layer, masks any words that don't have an embedding as 0s.
    model.add(SimpleRNN(units=64, input_shape=(1, max_length)))
    model.add(Dense(100,activation='relu'))
    model.add(Dense(y_train.shape[1], activation='softmax'))

    from keras.utils.vis_utils import plot_model

    # Compile the model
    model.compile(
        optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    # summarize the model
    # print(model.summary())
    # plot_model(model, to_file='model.png', show_shapes=True)

    # fit the model
    model.fit(X_train, y_train,batch_size=200,epochs=50,verbose=0)
    
    pred_vectors_train = model.predict(X_train)
    pred_vectors_test = model.predict(X_test)
    
    train_pred_classes = pred_category(pred_vectors_train)
    test_pred_classes = pred_category(pred_vectors_test)

    train_pred_classes_name = pred_category_name(pred_vectors_train)
    test_pred_classes_name = pred_category_name(pred_vectors_test)
    
    train_true_classes = actual_category(y_train)
    test_true_classes = actual_category(y_test)

    train_true_classes_name = actual_category_name(y_train)
    test_true_classes_name = actual_category_name(y_test)
    
    test_F1=F1(test_pred_classes_name,test_true_classes_name)
    train_F1=F1(train_pred_classes_name,train_true_classes_name)
    
    return train_F1,test_F1
